# %% [markdown]
# ## Leaky integrated firing neuron model
# ## Few feautures :
# ### Spatial network, no memory term but exponential decay of cumulative dose
#
# This is a minor change of the Dodds and Watts model
# Implement adaptive rewiring and generate statistics

# %%
#importing the required libraries

import networkx as nx
import matplotlib.pyplot as plt #for plotting
import numpy as np #for using arrays and vectorising the code wherever possible
import scipy
import random
# from numba import jit #numba precomplier to make the code faster
import pandas as pd
import copy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Variables used in the simulation

# %%
N = 100
gamma = 1 #decay of cumulative dose per unit time (second)
T = 100 #total number of seconds
dt = 0.05 #seconds
'''number of simulation steps is T/dt'''

'''Dodds watts parameters'''
p = 1 #rate of dose transfer (per unit time (second))
p = p*dt #rate of dose transfer per unit simulation step
r = 1/dt
r = r*dt
rho = 1/dt
rho = rho*dt
# r = 0.5
# r = r*dt

d_star = 1
# dose_quantity = 1
D_ini = 3

'''network parameters'''
circ_rad = 100 #for a network in which each node is connected to other nodes withing a circle of radius circ_rad
nn = 7 #the number of nearest neighbours(i.e. k) in knn
average_degree = 6
total_edges = N*4

'''rewiring parameters'''
w_minus = 1
w_minus = w_minus*dt
# p_rew = 5 #rate of rewiring(per unit time(second))
# p_rew = p_rew*dt

# %% [markdown]
# # Creating the network.
# ### The network outputs coordinates, distance matrix, edge_list and adjacency matrix

# %%
'''
obtains the number of nodes N
generates N points
calculates euclidean distance between each pair of points
returns the coordinates of the points and the distance matrix which is N*N
'''
def calc_dist(N) :
    coords = []
    for counter in range(N) :
        coords.append((N*np.random.random(),N*np.random.random()))

    dist_mat = scipy.spatial.distance.cdist(coords,coords)
    return dist_mat,coords

# %% [markdown]
# ### 1. metric network

# %%
'''network = connect to points withing a circle of radius'''
#creates a link between points/nodes which satisfies the conditions of the network
def coupling(dist_mat,circ_rad) :
    edge_list = []
    edge_mask = (dist_mat<circ_rad) & (dist_mat>0)
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(edge_mask))))
#     print(type(np.ndarray.tolist(np.transpose(np.where(edge_mask)))))
    return edge_list

# %% [markdown]
# ### 2. K nearest neighbour network

# %%
'''network = knn'''
def knn(dist_mat,nn,N) :
    near_neigh = np.argsort(dist_mat)
    selec_near_neigh = np.zeros((N,nn))
    selec_near_neigh = near_neigh[:,0:nn+1]

    edge_list = []
    for i in range(N) :
        for j in range(1,nn+1) :
            link = [i,selec_near_neigh[i,j]]
            edge_list.append(link)

    return edge_list

# %% [markdown]
# ### 3. Random Network : GNP type

# %%
'''random network'''
def rand_network(average_degree,N) :
    z1 = np.random.uniform(size = (N,N))
    E,F = np.meshgrid(np.arange(0,N),np.arange(0,N))
    mask = ((average_degree/N) > z1) & (E!=F)
    adjacency_matrix = np.int64(np.zeros(shape=(N,N)))
    adjacency_matrix[mask] = np.int64(1)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list,adjacency_matrix

# %% [markdown]
# ### 4. Random Network : GNM type

# %%
def rand_net_gnm(total_edges,N) :
    the_graph = nx.gnm_random_graph(N, total_edges,directed=True)
    adjacency_matrix = nx.adjacency_matrix(the_graph)
    adjacency_matrix = np.asarray(adjacency_matrix.todense())
    np.fill_diagonal(adjacency_matrix,0)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list

# %% [markdown]
# # Function defintions required for the main part of the script

# %%
# # @jit(nopython=True)
# '''infecting the left part of space.'''
# def left_part_infec(N) :
#     x_coord = []
#     y_coord = []
#     for j in range(len(coords)) :
#         x_coord.append(coords[j][0])
#         y_coord.append(coords[j][1])
#     x_coord = np.asarray(x_coord)
#     y_coord = np.asarray(y_coord)
#     points = np.asarray(np.where(x_coord<(N/5))) 
#     indi_state[points.T] = 2

#     return indi_state

# %%
'''infecting connected nodes'''
def InfectNetworkNeighbors(net,seed_node,init_infected_nodes):
     # if in bulk find one node randomly, and infect its neighbours
    infected_nodes = set()
    candidate_nodes = set()
    explored_nodes = set()

    #pick the seed node
    infected_nodes.add(seed_node)
    explored_nodes.add(seed_node)

    curr_node=seed_node

    #add its neighbors to the list of candidates
    for n in net.neighbors(curr_node):
        candidate_nodes.add(int(n))
    #print( curr_node)
    #print( candidate_nodes)

    #while we need to select more nodes...
    while len(infected_nodes) < init_infected_nodes:

        #if there are candidate nodes, select one of them
        if(len(candidate_nodes) > 0):
            new_node = np.random.choice(list(candidate_nodes),1)[0]
            infected_nodes.add(new_node)
            candidate_nodes.remove(new_node)

        elif len(infected_nodes - explored_nodes) > 0:
            curr_node = np.random.choice(list(infected_nodes -
            explored_nodes),1)[0]
            explored_nodes.add(curr_node)
            for n in set(net.neighbors(curr_node)) - infected_nodes:
                candidate_nodes.add(n)

        else:
#             print('Initial node infection step failed')
            return None
    return infected_nodes

# %%
''' function to transfer doses'''
# @jit(nopython=True)
def dose(adj_mat,p,partner_state_prev,d) :

    z1 = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    dose_transfer_mask = p > z1
    mod_adj_mat = np.multiply(adj_mat,z1) #modifying adjacency matrix to include the proability of dose transfer
    dose_mask = (p>mod_adj_mat) & (adj_mat!=0) & (partner_state_prev == 2)
    d[dose_mask] = dose_quantity #whenever it is proabable, dose transfer occurs
    
    return d

# %%
def rew(p_rew,adjacency_matrix,indi_state_for_rew_prev,OD_mesh2,lamb_da) :
    
    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew > z1_rew_prew)  & (indi_state_for_rew_prev == 1)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    rew_mask_minus1 = (w_minus > z1_rew_prew) & (indi_state_for_rew_prev == 2)
    #break links. Dont create any.
    adjacency_matrix[rew_mask_minus1] = 0
    rew_mask_minus2 = ((lamb_da*OD_mesh2) > z1_rew_lambda) & (indi_state_for_rew_prev == 1)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
'''function to update cumulative doses'''
def cumu_dose(d,D_prev,gamma) :
    I = d.sum(axis=1).reshape(N,1)
#     I = 0
    D = (D_prev - (gamma*D_prev*dt)) + I
    return D

# %%
'''function to update the states of the nodes of the system'''
def upd_indi_state(D,d_star,indi_state_prev) :
    
    z2 = np.random.uniform(size=(N,1))
    z3 = np.random.uniform(size=(N,1))
    
    indi_state = indi_state_prev
    
    indi_state_mask1 = (D>=d_star) & (indi_state_prev==1)
    indi_state[indi_state_mask1] = 2
    
    indi_state_mask21 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho>=z3)
    indi_state[indi_state_mask21] = 1
    
    indi_state_mask22 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho<z3)
    indi_state[indi_state_mask22] = 3
    
    indi_state_mask23 = (D<d_star) & (indi_state_prev==2) & (r<z2)
    indi_state[indi_state_mask23] = 2
    
    return indi_state

# %%
'''function to get/identify the infected nodes and the suceptible nodes'''
def states(indi_state) :
    infec_indi = []
    suscep_indi = []
    infec_indi = np.transpose(np.where(indi_state==2))
    suscep_indi = np.transpose(np.where(indi_state==1))
    return infec_indi,suscep_indi

# %%
def networkx_graph(coords,edge_list) :
    G = nx.DiGraph()
    pos = {(i): (coords[i][0],coords[i][1]) for i in range(N)}
    G.add_nodes_from(pos.keys())
    G.add_edges_from(edge_list)
    return G

# %%
def edge_from_adj_mat(adj_mat_list,q):
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adj_mat_list[q]==1))))
    return edge_list

# %% [markdown]
# # Choose which network you want in the program
# ### Coupling network of knn network?

# %%
# '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''

# dist_mat,coords = calc_dist(N) #node placement

# # edge_list = coupling(dist_mat,circ_rad)
# # edge_list = knn(dist_mat,nn,N)
# # edge_list = rand_network(average_degree,N)
# edge_list = rand_net_gnm(total_edges,N)

# org_adj_mat = np.int64(np.zeros((N,N)))
# for i in range(len(edge_list)):
#     org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)

# %% [markdown]
# # The main part of the script

# %%
#infected state time series data frame
#columns indicate the time steps
timeseries_infec_frac = pd.DataFrame()

#in degree as columns and rows as nodes
timeseries_in_degree = pd.DataFrame() 

#out degree as columns and rows as nodes
timeseries_out_degree = pd.DataFrame()

#strongly connected components as columns
timeseries_connec_comps = pd.DataFrame()

# %%
p_rew_vals = [0.01,0.1,1,10]
start_vals = [1,10]
dose_quantity_vals = [0.5,2]

# %%
for sim in range(70,70+25) :
    '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''
    dist_mat,coords = calc_dist(N) #node placement
    edge_list = rand_net_gnm(total_edges,N)
    org_adj_mat = np.int64(np.zeros((N,N)))
    for i in range(len(edge_list)):
        org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)
        
    df_row = 0
    for p_rew in p_rew_vals : #rate of rewiring (per unit time (second))
        lamb_da = p_rew/10
        lamb_da = lamb_da*dt
        p_rew = p_rew*dt
        for start in start_vals : #rate of dose transfer (per unit time (second))
            for dose_quantity in dose_quantity_vals : #number of nodes to infect initially
                print('(sim,lamb_da,p_rew,w_minus,start,dose_quantity) = ', (sim,lamb_da/dt,p_rew/dt,w_minus/dt,start,dose_quantity))

                '''clearing exsiting data frames and creating new ones '''
                timeseries_infec_frac = pd.DataFrame()
                timeseries_in_degree = pd.DataFrame()
                timeseries_out_degree = pd.DataFrame()
                timeseries_connec_comps = pd.DataFrame()

                q = 0 #to generate new edge_list from the new adjacency matrix 
                t = np.arange(0,T,dt)

    #             numpy_array = np.zeros((N,len(t)),dtype = np.int64) #stores the states of the nodes. Rows are nodes and columns are time steps
                D_array = np.zeros((N,len(t))) #stores the cumulative doses. Rows are nodes and columns are time steps

                adj_mat_list = []
                adj_mat = copy.deepcopy(org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new) #list of arrays which shows the time series of the adjacency matrix

                #coords remain the same. Get new edge_list from the latest adjacency matrix
                edge_list = edge_from_adj_mat(adj_mat_list,q)
                G = networkx_graph(coords,edge_list) #networkx graph

                '''from G, obtain the in degree and the out degree'''
                timeseries_in_degree.loc[:,0] = np.asarray([val for (node, val) in G.in_degree()])
                timeseries_out_degree.loc[:,0] = np.asarray([val for (node, val) in G.out_degree()])

                '''strongly and weekely connected components'''
                timeseries_connec_comps.loc[0,0] = nx.number_connected_components(G.to_undirected())

                '''choosing initially infected nodes'''
                indi_state = np.random.randint(1,2,size=(N,1))
                infected_nodes = None
                while infected_nodes is None : #infecting 'start' number of network neighbours
                    infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)
                print(infected_nodes)
                infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
                indi_state[infected_nodes[:,0],0] = 2

                A,B = np.meshgrid(indi_state,indi_state) 
                partner_state = A
                indi_state_for_rew = B

    #             numpy_array [:,0] = indi_state[:,0]

                indi_state_prev = indi_state
                partner_state_prev = partner_state
                indi_state_for_rew_prev = indi_state_for_rew

                d = np.zeros((len(adj_mat),len(adj_mat[0])))

                D = np.zeros((N,1))
                D[np.where(indi_state==2)] = D_ini
                D_array[:,0] = D[:,0]
                D_prev = D

                infec_frac = np.count_nonzero(indi_state == 2)/N
                timeseries_infec_frac.loc[df_row,0] = infec_frac
                '''the main part of the simulation'''
                counter = 0
                df_col = 1
                for t in np.arange(dt,T,dt) :
                    q = q + 1 
                    counter = counter + 1
                    infec_indi = []
                    suscep_indi = []
                    d = np.zeros((len(adj_mat),len(adj_mat[0])))
                    d = dose(adj_mat,p,partner_state_prev,d)

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)
                    adj_mat = rew(p_rew,adj_mat,indi_state_for_rew_prev,OD_mesh2,lamb_da)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    '''from G, obtain the in degree and the out degree'''
                    timeseries_in_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.in_degree()])
                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])

                    '''strongly and weekely connected components'''
                    timeseries_connec_comps.loc[df_row,df_col] = nx.number_connected_components(G.to_undirected())

                    D = cumu_dose(d,D_prev,gamma)
                    D_array[:,counter] = D[:,0]

                    indi_state = upd_indi_state(D,d_star,indi_state_prev)
                    infec_frac = np.count_nonzero(indi_state == 2)/N
                    timeseries_infec_frac.loc[df_row,df_col] = infec_frac

    #                 numpy_array[:,counter] = indi_state[:,0]
                    A,B = np.meshgrid(indi_state,indi_state)

                    infec_indi, suscep_indi = states(indi_state)

                    partner_state = A
                    indi_state_for_rew = B
                    indi_state_prev = indi_state
                    partner_state_prev = partner_state
                    indi_state_for_rew_prev = indi_state_for_rew

                    D_prev = D
                    D = np.zeros((N,1))
                    df_col = df_col + 1 

    #             df_row = df_row + 1 #going to the next row of the df to store timeseries of next (p,start)

                filename_infec_frac = 'infec_frac.h5'
                filename_in_deg = 'in_deg.h5'
                filename_out_deg = 'out_deg.h5'
                filename_connec_comps = 'connec_comps.h5'
                p_rew_val = '%g'%(p_rew/dt)
                key_val = 'sim_'+str(sim)+'_p_rew_'+str(p_rew_val)+'_start_'+str(start)+'_dq_'+str(dose_quantity)
                print(key_val)
                timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
                timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
                timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
                timeseries_connec_comps.to_hdf(filename_connec_comps, key = key_val, mode='a')
                df_row = 0
# Out:
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.001, 0.01, 1.0, 1, 0.5)
# {54}
# sim_70_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.001, 0.01, 1.0, 1, 2)
# {88}
# sim_70_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.001, 0.01, 1.0, 10, 0.5)
# {34, 68, 70, 42, 92, 16, 87, 60, 93, 31}
# sim_70_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.001, 0.01, 1.0, 10, 2)
# {97, 6, 38, 41, 49, 82, 22, 28, 61, 30}
# sim_70_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {63}
# sim_70_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {61}
# sim_70_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {2, 8, 78, 47, 79, 49, 52, 23, 25, 90}
# sim_70_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {33, 34, 75, 76, 81, 21, 53, 87, 57, 61}
# sim_70_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {80}
# sim_70_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {4}
# sim_70_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {97, 2, 34, 5, 70, 43, 12, 49, 54, 61}
# sim_70_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {33, 34, 75, 76, 81, 21, 53, 87, 57, 61}
# sim_70_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 1.0, 10.0, 1.0, 1, 0.5)
# {47}
# sim_70_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 1.0, 10.0, 1.0, 1, 2)
# {49}
# sim_70_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 1.0, 10.0, 1.0, 10, 0.5)
# {69, 90, 7, 73, 44, 77, 52, 89, 58, 28}
# sim_70_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (70, 1.0, 10.0, 1.0, 10, 2)
# {97, 36, 72, 80, 51, 52, 21, 87, 56, 30}
# sim_70_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.001, 0.01, 1.0, 1, 0.5)
# {59}
# sim_71_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.001, 0.01, 1.0, 1, 2)
# {23}
# sim_71_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.001, 0.01, 1.0, 10, 0.5)
# {64, 98, 67, 4, 9, 12, 79, 50, 53, 92}
# sim_71_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.001, 0.01, 1.0, 10, 2)
# {64, 1, 36, 68, 48, 22, 86, 57, 61, 63}
# sim_71_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {33}
# sim_71_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {44}
# sim_71_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {65, 4, 38, 7, 13, 16, 50, 18, 89, 93}
# sim_71_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {32, 99, 36, 37, 15, 79, 48, 86, 56, 30}
# sim_71_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {68}
# sim_71_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {25}
# sim_71_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {33, 37, 39, 79, 81, 50, 85, 22, 56, 63}
# sim_71_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {0, 91, 11, 79, 19, 22, 90, 27, 61, 95}
# sim_71_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 1.0, 10.0, 1.0, 1, 0.5)
# {31}
# sim_71_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 1.0, 10.0, 1.0, 1, 2)
# {27}
# sim_71_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 1.0, 10.0, 1.0, 10, 0.5)
# {64, 98, 3, 8, 73, 41, 24, 58, 27, 94}
# sim_71_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (71, 1.0, 10.0, 1.0, 10, 2)
# {33, 65, 4, 39, 16, 50, 18, 85, 22, 56}
# sim_71_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.001, 0.01, 1.0, 1, 0.5)
# {12}
# sim_72_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.001, 0.01, 1.0, 1, 2)
# {10}
# sim_72_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.001, 0.01, 1.0, 10, 0.5)
# {97, 67, 35, 5, 39, 42, 43, 13, 52, 24}
# sim_72_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.001, 0.01, 1.0, 10, 2)
# {38, 11, 47, 48, 19, 53, 54, 25, 90, 29}
# sim_72_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {11}
# sim_72_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {82}
# sim_72_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {97, 34, 67, 11, 77, 47, 84, 23, 57, 94}
# sim_72_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {67, 71, 82, 19, 20, 56, 90, 27, 94, 31}
# sim_72_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {32}
# sim_72_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {90}
# sim_72_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {65, 37, 7, 8, 77, 81, 17, 53, 25, 90}
# sim_72_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {0, 96, 3, 69, 38, 8, 83, 87, 91, 95}
# sim_72_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 1.0, 10.0, 1.0, 1, 0.5)
# {30}
# sim_72_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 1.0, 10.0, 1.0, 1, 2)
# {87}
# sim_72_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 1.0, 10.0, 1.0, 10, 0.5)
# {68, 37, 70, 71, 90, 38, 44, 13, 84, 58}
# sim_72_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (72, 1.0, 10.0, 1.0, 10, 2)
# {37, 73, 9, 12, 78, 47, 19, 21, 87, 60}
# sim_72_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.001, 0.01, 1.0, 1, 0.5)
# {86}
# sim_73_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.001, 0.01, 1.0, 1, 2)
# {27}
# sim_73_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.001, 0.01, 1.0, 10, 0.5)
# {32, 6, 71, 9, 45, 80, 82, 86, 89, 58}
# sim_73_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.001, 0.01, 1.0, 10, 2)
# {2, 36, 37, 9, 77, 46, 79, 48, 85, 87}
# sim_73_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {65}
# sim_73_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {76}
# sim_73_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {39, 72, 75, 82, 21, 22, 57, 92, 29, 31}
# sim_73_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {97, 36, 68, 37, 41, 85, 23, 58, 91, 93}
# sim_73_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {11}
# sim_73_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {29}
# sim_73_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {96, 99, 39, 23, 62, 25, 56, 29, 94, 95}
# sim_73_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {98, 3, 37, 39, 73, 13, 46, 48, 22, 31}
# sim_73_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 1.0, 10.0, 1.0, 1, 0.5)
# {25}
# sim_73_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 1.0, 10.0, 1.0, 1, 2)
# {11}
# sim_73_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 1.0, 10.0, 1.0, 10, 0.5)
# {96, 98, 4, 5, 38, 71, 41, 42, 22, 94}
# sim_73_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (73, 1.0, 10.0, 1.0, 10, 2)
# {64, 0, 99, 43, 77, 78, 16, 88, 25, 59}
# sim_73_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.001, 0.01, 1.0, 1, 0.5)
# {4}
# sim_74_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.001, 0.01, 1.0, 1, 2)
# {89}
# sim_74_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.001, 0.01, 1.0, 10, 0.5)
# {98, 35, 7, 41, 43, 44, 78, 48, 88, 89}
# sim_74_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.001, 0.01, 1.0, 10, 2)
# {64, 0, 34, 12, 76, 47, 16, 19, 52, 23}
# sim_74_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {49}
# sim_74_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {48}
# sim_74_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {32, 1, 35, 7, 72, 42, 44, 85, 86, 56}
# sim_74_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {1, 40, 13, 77, 78, 52, 53, 57, 95, 63}
# sim_74_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {38}
# sim_74_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {77}
# sim_74_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {96, 68, 70, 8, 75, 44, 13, 88, 24, 59}
# sim_74_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {96, 68, 70, 40, 8, 75, 13, 88, 90, 29}
# sim_74_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 1.0, 10.0, 1.0, 1, 0.5)
# {52}
# sim_74_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 1.0, 10.0, 1.0, 1, 2)
# {18}
# sim_74_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 1.0, 10.0, 1.0, 10, 0.5)
# {0, 36, 38, 73, 12, 18, 19, 53, 26, 29}
# sim_74_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (74, 1.0, 10.0, 1.0, 10, 2)
# {97, 35, 70, 13, 45, 81, 19, 56, 60, 95}
# sim_74_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.001, 0.01, 1.0, 1, 0.5)
# {99}
# sim_75_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.001, 0.01, 1.0, 1, 2)
# {48}
# sim_75_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.001, 0.01, 1.0, 10, 0.5)
# {0, 74, 44, 80, 21, 54, 87, 90, 59, 61}
# sim_75_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.001, 0.01, 1.0, 10, 2)
# {99, 67, 3, 11, 17, 50, 21, 56, 25, 24}
# sim_75_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {7}
# sim_75_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {45}
# sim_75_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {2, 7, 74, 13, 14, 85, 22, 24, 91, 63}
# sim_75_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {3, 68, 73, 50, 21, 54, 24, 25, 63, 57}
# sim_75_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {94}
# sim_75_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {58}
# sim_75_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {96, 0, 3, 37, 10, 14, 19, 21, 89, 94}
# sim_75_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {65, 99, 70, 73, 42, 41, 76, 45, 19, 61}
# sim_75_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 1.0, 10.0, 1.0, 1, 0.5)
# {45}
# sim_75_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 1.0, 10.0, 1.0, 1, 2)
# {66}
# sim_75_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 1.0, 10.0, 1.0, 10, 0.5)
# {67, 69, 41, 76, 15, 81, 56, 89, 26, 93}
# sim_75_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (75, 1.0, 10.0, 1.0, 10, 2)
# {2, 38, 9, 43, 50, 51, 55, 24, 88, 30}
# sim_75_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.001, 0.01, 1.0, 1, 0.5)
# {14}
# sim_76_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.001, 0.01, 1.0, 1, 2)
# {21}
# sim_76_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.001, 0.01, 1.0, 10, 0.5)
# {64, 36, 69, 41, 44, 48, 20, 23, 88, 27}
# sim_76_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.001, 0.01, 1.0, 10, 2)
# {33, 99, 69, 41, 78, 79, 16, 21, 59, 29}
# sim_76_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {83}
# sim_76_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {1}
# sim_76_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {66, 4, 5, 14, 48, 18, 91, 60, 61, 30}
# sim_76_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {64, 1, 66, 67, 99, 38, 8, 76, 44, 81}
# sim_76_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {71}
# sim_76_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {83}
# sim_76_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {97, 66, 35, 70, 43, 14, 49, 91, 93, 95}
# sim_76_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {37, 70, 73, 10, 14, 50, 61, 51, 58, 93}
# sim_76_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 1.0, 10.0, 1.0, 1, 0.5)
# {82}
# sim_76_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 1.0, 10.0, 1.0, 1, 2)
# {27}
# sim_76_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 1.0, 10.0, 1.0, 10, 0.5)
# {96, 97, 5, 69, 39, 48, 51, 85, 53, 27}
# sim_76_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (76, 1.0, 10.0, 1.0, 10, 2)
# {1, 65, 42, 19, 84, 85, 27, 60, 95, 31}
# sim_76_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.001, 0.01, 1.0, 1, 0.5)
# {82}
# sim_77_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.001, 0.01, 1.0, 1, 2)
# {75}
# sim_77_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.001, 0.01, 1.0, 10, 0.5)
# {0, 96, 33, 39, 42, 43, 78, 87, 30, 95}
# sim_77_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.001, 0.01, 1.0, 10, 2)
# {37, 6, 69, 38, 41, 42, 53, 87, 59, 95}
# sim_77_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {43}
# sim_77_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {28}
# sim_77_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {97, 98, 5, 71, 50, 18, 55, 57, 27, 63}
# sim_77_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {4, 6, 71, 46, 48, 16, 23, 56, 94, 95}
# sim_77_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {98}
# sim_77_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {4}
# sim_77_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {1, 67, 99, 49, 81, 84, 22, 56, 88, 62}
# sim_77_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {32, 65, 34, 70, 76, 79, 17, 82, 85, 93}
# sim_77_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 1.0, 10.0, 1.0, 1, 0.5)
# {82}
# sim_77_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 1.0, 10.0, 1.0, 1, 2)
# {55}
# sim_77_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 1.0, 10.0, 1.0, 10, 0.5)
# {32, 33, 40, 75, 48, 52, 85, 90, 91, 95}
# sim_77_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (77, 1.0, 10.0, 1.0, 10, 2)
# {33, 97, 43, 17, 52, 87, 57, 29, 30, 31}
# sim_77_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.001, 0.01, 1.0, 1, 0.5)
# {96}
# sim_78_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.001, 0.01, 1.0, 1, 2)
# {38}
# sim_78_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.001, 0.01, 1.0, 10, 0.5)
# {0, 97, 6, 38, 9, 78, 50, 24, 57, 30}
# sim_78_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.001, 0.01, 1.0, 10, 2)
# {98, 36, 40, 59, 8, 75, 77, 46, 56, 88}
# sim_78_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {2}
# sim_78_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {91}
# sim_78_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {0, 33, 68, 6, 73, 78, 79, 54, 23, 59}
# sim_78_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {97, 38, 9, 45, 78, 50, 24, 57, 92, 30}
# sim_78_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {56}
# sim_78_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {92}
# sim_78_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {66, 35, 38, 41, 75, 76, 15, 82, 86, 87}
# sim_78_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {32, 96, 99, 67, 75, 76, 80, 87, 60, 94}
# sim_78_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 1.0, 10.0, 1.0, 1, 0.5)
# {94}
# sim_78_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 1.0, 10.0, 1.0, 1, 2)
# {80}
# sim_78_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 1.0, 10.0, 1.0, 10, 0.5)
# {34, 4, 6, 77, 17, 53, 90, 28, 62, 95}
# sim_78_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (78, 1.0, 10.0, 1.0, 10, 2)
# {64, 4, 38, 44, 48, 50, 53, 23, 61, 30}
# sim_78_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.001, 0.01, 1.0, 1, 0.5)
# {70}
# sim_79_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.001, 0.01, 1.0, 1, 2)
# {18}
# sim_79_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.001, 0.01, 1.0, 10, 0.5)
# {98, 40, 74, 45, 80, 50, 24, 26, 94, 63}
# sim_79_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.001, 0.01, 1.0, 10, 2)
# {32, 2, 4, 5, 45, 80, 82, 84, 90, 28}
# sim_79_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {51}
# sim_79_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {94}
# sim_79_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {32, 66, 99, 41, 10, 52, 24, 25, 31, 95}
# sim_79_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {97, 2, 26, 4, 70, 71, 81, 58, 60, 31}
# sim_79_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {3}
# sim_79_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {6}
# sim_79_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {1, 3, 70, 39, 80, 18, 83, 22, 57, 29}
# sim_79_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {35, 36, 7, 74, 45, 13, 80, 82, 50, 93}
# sim_79_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 1.0, 10.0, 1.0, 1, 0.5)
# {29}
# sim_79_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 1.0, 10.0, 1.0, 1, 2)
# {2}
# sim_79_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 1.0, 10.0, 1.0, 10, 0.5)
# {0, 65, 99, 41, 52, 93, 24, 25, 63, 31}
# sim_79_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (79, 1.0, 10.0, 1.0, 10, 2)
# {0, 3, 40, 73, 43, 45, 46, 24, 94, 63}
# sim_79_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.001, 0.01, 1.0, 1, 0.5)
# {53}
# sim_80_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.001, 0.01, 1.0, 1, 2)
# {78}
# sim_80_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.001, 0.01, 1.0, 10, 0.5)
# {65, 37, 75, 47, 16, 80, 81, 20, 90, 92}
# sim_80_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.001, 0.01, 1.0, 10, 2)
# {64, 32, 97, 67, 36, 4, 14, 48, 92, 31}
# sim_80_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {30}
# sim_80_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {93}
# sim_80_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {96, 38, 7, 42, 43, 13, 79, 18, 52, 94}
# sim_80_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {96, 38, 7, 42, 43, 13, 79, 18, 52, 94}
# sim_80_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {98}
# sim_80_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {98}
# sim_80_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {99, 70, 42, 12, 82, 84, 85, 90, 95, 63}
# sim_80_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {39, 8, 72, 93, 55, 57, 59, 29, 62, 95}
# sim_80_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 1.0, 10.0, 1.0, 1, 0.5)
# {73}
# sim_80_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 1.0, 10.0, 1.0, 1, 2)
# {0}
# sim_80_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 1.0, 10.0, 1.0, 10, 0.5)
# {8, 74, 15, 16, 81, 80, 51, 22, 87, 60}
# sim_80_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (80, 1.0, 10.0, 1.0, 10, 2)
# {37, 10, 12, 78, 16, 83, 20, 22, 90, 29}
# sim_80_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.001, 0.01, 1.0, 1, 0.5)
# {5}
# sim_81_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.001, 0.01, 1.0, 1, 2)
# {23}
# sim_81_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.001, 0.01, 1.0, 10, 0.5)
# {33, 12, 45, 52, 85, 24, 88, 93, 62, 31}
# sim_81_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.001, 0.01, 1.0, 10, 2)
# {98, 3, 7, 8, 71, 74, 14, 49, 88, 58}
# sim_81_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {30}
# sim_81_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {14}
# sim_81_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {37, 75, 18, 83, 50, 21, 55, 25, 92, 30}
# sim_81_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {33, 69, 5, 72, 41, 12, 13, 84, 29, 95}
# sim_81_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {99}
# sim_81_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {96}
# sim_81_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {0, 2, 35, 5, 41, 42, 48, 53, 87, 25}
# sim_81_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {89, 0, 3, 73, 42, 18, 83, 24, 57, 58}
# sim_81_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 1.0, 10.0, 1.0, 1, 0.5)
# {22}
# sim_81_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 1.0, 10.0, 1.0, 1, 2)
# {20}
# sim_81_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 1.0, 10.0, 1.0, 10, 0.5)
# {98, 3, 7, 8, 74, 14, 80, 87, 88, 58}
# sim_81_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (81, 1.0, 10.0, 1.0, 10, 2)
# {74, 77, 16, 18, 23, 54, 55, 56, 91, 28}
# sim_81_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.001, 0.01, 1.0, 1, 0.5)
# {85}
# sim_82_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.001, 0.01, 1.0, 1, 2)
# {29}
# sim_82_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.001, 0.01, 1.0, 10, 0.5)
# {33, 73, 41, 76, 78, 80, 49, 52, 21, 88}
# sim_82_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.001, 0.01, 1.0, 10, 2)
# {33, 98, 97, 72, 73, 76, 13, 78, 49, 52}
# sim_82_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {10}
# sim_82_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {19}
# sim_82_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {68, 37, 14, 50, 51, 22, 58, 59, 92, 29}
# sim_82_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {64, 32, 16, 19, 52, 84, 57, 26, 61, 95}
# sim_82_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {61}
# sim_82_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {38}
# sim_82_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {96, 67, 68, 37, 43, 14, 84, 58, 59, 92}
# sim_82_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {96, 97, 34, 35, 69, 72, 10, 77, 45, 16}
# sim_82_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 1.0, 10.0, 1.0, 1, 0.5)
# {78}
# sim_82_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 1.0, 10.0, 1.0, 1, 2)
# {3}
# sim_82_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 1.0, 10.0, 1.0, 10, 0.5)
# {98, 35, 72, 41, 11, 45, 81, 19, 20, 21}
# sim_82_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (82, 1.0, 10.0, 1.0, 10, 2)
# {96, 34, 67, 4, 43, 45, 14, 51, 84, 24}
# sim_82_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.001, 0.01, 1.0, 1, 0.5)
# {40}
# sim_83_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.001, 0.01, 1.0, 1, 2)
# {57}
# sim_83_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.001, 0.01, 1.0, 10, 0.5)
# {64, 33, 39, 10, 43, 45, 53, 54, 94, 30}
# sim_83_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.001, 0.01, 1.0, 10, 2)
# {64, 98, 72, 73, 14, 49, 54, 55, 22, 91}
# sim_83_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {19}
# sim_83_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {61}
# sim_83_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {33, 68, 70, 39, 74, 43, 85, 24, 89, 63}
# sim_83_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {64, 8, 42, 78, 79, 25, 91, 60, 61, 30}
# sim_83_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {25}
# sim_83_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {4}
# sim_83_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {37, 38, 14, 47, 16, 83, 84, 91, 63, 31}
# sim_83_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {97, 69, 13, 46, 92, 81, 50, 53, 87, 28}
# sim_83_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 1.0, 10.0, 1.0, 1, 0.5)
# {54}
# sim_83_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 1.0, 10.0, 1.0, 1, 2)
# {96}
# sim_83_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 1.0, 10.0, 1.0, 10, 0.5)
# {68, 69, 59, 75, 76, 47, 18, 87, 88, 27}
# sim_83_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (83, 1.0, 10.0, 1.0, 10, 2)
# {68, 69, 76, 13, 12, 18, 54, 87, 59, 61}
# sim_83_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.001, 0.01, 1.0, 1, 0.5)
# {58}
# sim_84_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.001, 0.01, 1.0, 1, 2)
# {51}
# sim_84_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.001, 0.01, 1.0, 10, 0.5)
# {34, 99, 3, 37, 70, 9, 74, 43, 54, 24}
# sim_84_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.001, 0.01, 1.0, 10, 2)
# {0, 35, 75, 43, 44, 15, 85, 86, 89, 94}
# sim_84_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {15}
# sim_84_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {16}
# sim_84_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {0, 98, 35, 71, 10, 44, 12, 15, 24, 62}
# sim_84_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {2, 68, 37, 42, 43, 49, 20, 52, 86, 31}
# sim_84_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {19}
# sim_84_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {10}
# sim_84_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {1, 3, 4, 69, 6, 71, 14, 54, 91, 61}
# sim_84_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {0, 98, 35, 71, 10, 75, 44, 12, 15, 89}
# sim_84_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 1.0, 10.0, 1.0, 1, 0.5)
# {41}
# sim_84_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 1.0, 10.0, 1.0, 1, 2)
# {2}
# sim_84_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 1.0, 10.0, 1.0, 10, 0.5)
# {65, 36, 8, 14, 46, 81, 85, 55, 87, 60}
# sim_84_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (84, 1.0, 10.0, 1.0, 10, 2)
# {33, 66, 37, 69, 42, 76, 13, 51, 59, 60}
# sim_84_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.001, 0.01, 1.0, 1, 0.5)
# {41}
# sim_85_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.001, 0.01, 1.0, 1, 2)
# {3}
# sim_85_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.001, 0.01, 1.0, 10, 0.5)
# {64, 0, 78, 81, 19, 52, 53, 84, 55, 58}
# sim_85_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.001, 0.01, 1.0, 10, 2)
# {3, 36, 69, 9, 53, 22, 85, 89, 28, 57}
# sim_85_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {66}
# sim_85_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {32}
# sim_85_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {0, 1, 7, 73, 46, 17, 21, 57, 29, 95}
# sim_85_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {65, 3, 40, 9, 45, 79, 15, 87, 29, 94}
# sim_85_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {40}
# sim_85_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {41}
# sim_85_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {32, 97, 71, 11, 45, 20, 94, 29, 62, 63}
# sim_85_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {96, 65, 34, 3, 40, 77, 15, 53, 59, 63}
# sim_85_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 1.0, 10.0, 1.0, 1, 0.5)
# {37}
# sim_85_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 1.0, 10.0, 1.0, 1, 2)
# {8}
# sim_85_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 1.0, 10.0, 1.0, 10, 0.5)
# {69, 72, 9, 48, 86, 62, 90, 88, 29, 94}
# sim_85_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (85, 1.0, 10.0, 1.0, 10, 2)
# {35, 38, 70, 9, 74, 79, 51, 85, 57, 26}
# sim_85_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.001, 0.01, 1.0, 1, 0.5)
# {90}
# sim_86_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.001, 0.01, 1.0, 1, 2)
# {36}
# sim_86_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.001, 0.01, 1.0, 10, 0.5)
# {72, 41, 76, 13, 46, 14, 79, 21, 54, 59}
# sim_86_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.001, 0.01, 1.0, 10, 2)
# {97, 98, 67, 40, 11, 78, 53, 25, 30, 95}
# sim_86_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {51}
# sim_86_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {71}
# sim_86_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {64, 66, 34, 7, 41, 10, 44, 88, 90, 59}
# sim_86_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {96, 67, 35, 69, 99, 7, 78, 83, 86, 94}
# sim_86_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {79}
# sim_86_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {41}
# sim_86_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {98, 8, 44, 15, 17, 83, 88, 90, 59, 61}
# sim_86_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {66, 35, 4, 5, 6, 72, 73, 41, 14, 90}
# sim_86_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 1.0, 10.0, 1.0, 1, 0.5)
# {72}
# sim_86_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 1.0, 10.0, 1.0, 1, 2)
# {35}
# sim_86_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 1.0, 10.0, 1.0, 10, 0.5)
# {97, 98, 67, 40, 78, 79, 19, 20, 94, 95}
# sim_86_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (86, 1.0, 10.0, 1.0, 10, 2)
# {1, 90, 9, 44, 47, 24, 26, 59, 62, 95}
# sim_86_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.001, 0.01, 1.0, 1, 0.5)
# {59}
# sim_87_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.001, 0.01, 1.0, 1, 2)
# {10}
# sim_87_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.001, 0.01, 1.0, 10, 0.5)
# {33, 4, 74, 43, 13, 15, 82, 56, 57, 29}
# sim_87_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.001, 0.01, 1.0, 10, 2)
# {33, 43, 13, 15, 93, 56, 57, 29, 94, 31}
# sim_87_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {83}
# sim_87_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {40}
# sim_87_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {1, 98, 42, 46, 15, 17, 87, 89, 28, 62}
# sim_87_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {0, 98, 99, 69, 6, 41, 73, 88, 58, 93}
# sim_87_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {51}
# sim_87_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {89}
# sim_87_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {64, 69, 8, 47, 49, 51, 20, 55, 92, 29}
# sim_87_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {33, 67, 36, 6, 73, 9, 48, 17, 80, 88}
# sim_87_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 1.0, 10.0, 1.0, 1, 0.5)
# {95}
# sim_87_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 1.0, 10.0, 1.0, 1, 2)
# {98}
# sim_87_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 1.0, 10.0, 1.0, 10, 0.5)
# {37, 74, 76, 77, 79, 48, 82, 93, 62, 95}
# sim_87_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (87, 1.0, 10.0, 1.0, 10, 2)
# {33, 36, 73, 43, 15, 48, 53, 85, 25, 63}
# sim_87_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.001, 0.01, 1.0, 1, 0.5)
# {66}
# sim_88_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.001, 0.01, 1.0, 1, 2)
# {96}
# sim_88_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.001, 0.01, 1.0, 10, 0.5)
# {33, 35, 5, 80, 48, 54, 87, 91, 95, 31}
# sim_88_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.001, 0.01, 1.0, 10, 2)
# {32, 69, 6, 72, 82, 87, 89, 26, 91, 25}
# sim_88_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {42}
# sim_88_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {91}
# sim_88_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {66, 99, 4, 42, 11, 46, 81, 50, 89, 61}
# sim_88_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {0, 2, 9, 44, 78, 49, 53, 57, 27, 93}
# sim_88_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {76}
# sim_88_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {34}
# sim_88_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {97, 34, 7, 71, 44, 45, 15, 50, 20, 31}
# sim_88_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {96, 97, 5, 7, 11, 80, 19, 21, 22, 63}
# sim_88_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 1.0, 10.0, 1.0, 1, 0.5)
# {11}
# sim_88_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 1.0, 10.0, 1.0, 1, 2)
# {8}
# sim_88_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 1.0, 10.0, 1.0, 10, 0.5)
# {96, 69, 10, 43, 44, 50, 85, 22, 89, 62}
# sim_88_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (88, 1.0, 10.0, 1.0, 10, 2)
# {68, 69, 80, 16, 52, 54, 55, 88, 57, 91}
# sim_88_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.001, 0.01, 1.0, 1, 0.5)
# {47}
# sim_89_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.001, 0.01, 1.0, 1, 2)
# {36}
# sim_89_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.001, 0.01, 1.0, 10, 0.5)
# {2, 34, 71, 74, 43, 14, 47, 15, 84, 52}
# sim_89_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.001, 0.01, 1.0, 10, 2)
# {96, 97, 66, 3, 98, 10, 44, 85, 29, 62}
# sim_89_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {45}
# sim_89_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {64}
# sim_89_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {64, 35, 36, 3, 10, 83, 53, 85, 89, 26}
# sim_89_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {97, 3, 10, 11, 83, 87, 89, 26, 29, 62}
# sim_89_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {52}
# sim_89_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {42}
# sim_89_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {34, 2, 9, 13, 79, 47, 15, 87, 59, 29}
# sim_89_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {35, 68, 10, 49, 82, 83, 87, 88, 89, 56}
# sim_89_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 1.0, 10.0, 1.0, 1, 0.5)
# {77}
# sim_89_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 1.0, 10.0, 1.0, 1, 2)
# {68}
# sim_89_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 1.0, 10.0, 1.0, 10, 0.5)
# {67, 8, 74, 15, 80, 19, 20, 22, 90, 59}
# sim_89_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (89, 1.0, 10.0, 1.0, 10, 2)
# {4, 6, 9, 76, 14, 52, 54, 55, 58, 63}
# sim_89_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.001, 0.01, 1.0, 1, 0.5)
# {3}
# sim_90_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.001, 0.01, 1.0, 1, 2)
# {46}
# sim_90_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.001, 0.01, 1.0, 10, 0.5)
# {38, 6, 73, 59, 9, 47, 80, 53, 91, 63}
# sim_90_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.001, 0.01, 1.0, 10, 2)
# {0, 65, 69, 38, 80, 17, 26, 91, 30, 95}
# sim_90_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {48}
# sim_90_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {45}
# sim_90_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {32, 66, 70, 8, 41, 10, 43, 49, 84, 23}
# sim_90_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {0, 97, 35, 4, 68, 70, 42, 74, 17, 26}
# sim_90_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {37}
# sim_90_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {40}
# sim_90_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {0, 65, 64, 69, 78, 84, 21, 26, 28, 62}
# sim_90_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {89, 4, 37, 6, 9, 47, 81, 82, 25, 90}
# sim_90_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 1.0, 10.0, 1.0, 1, 0.5)
# {60}
# sim_90_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 1.0, 10.0, 1.0, 1, 2)
# {82}
# sim_90_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 1.0, 10.0, 1.0, 10, 0.5)
# {32, 98, 7, 9, 41, 16, 84, 20, 56, 27}
# sim_90_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (90, 1.0, 10.0, 1.0, 10, 2)
# {89, 34, 35, 36, 45, 80, 50, 51, 56, 24}
# sim_90_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.001, 0.01, 1.0, 1, 0.5)
# {66}
# sim_91_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.001, 0.01, 1.0, 1, 2)
# {14}
# sim_91_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.001, 0.01, 1.0, 10, 0.5)
# {32, 97, 99, 7, 13, 78, 18, 21, 91, 29}
# sim_91_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.001, 0.01, 1.0, 10, 2)
# {98, 99, 69, 72, 8, 44, 47, 16, 19, 54}
# sim_91_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {67}
# sim_91_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {14}
# sim_91_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {98, 99, 69, 72, 8, 44, 47, 16, 19, 54}
# sim_91_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {96, 1, 99, 35, 37, 8, 44, 13, 21, 59}
# sim_91_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {57}
# sim_91_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {34}
# sim_91_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {32, 13, 78, 15, 17, 89, 91, 31, 62, 57}
# sim_91_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {1, 34, 99, 9, 42, 10, 46, 47, 49, 57}
# sim_91_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 1.0, 10.0, 1.0, 1, 0.5)
# {56}
# sim_91_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 1.0, 10.0, 1.0, 1, 2)
# {11}
# sim_91_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 1.0, 10.0, 1.0, 10, 0.5)
# {98, 70, 8, 44, 14, 80, 84, 26, 27, 62}
# sim_91_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (91, 1.0, 10.0, 1.0, 10, 2)
# {1, 34, 46, 78, 47, 49, 83, 22, 60, 95}
# sim_91_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.001, 0.01, 1.0, 1, 0.5)
# {27}
# sim_92_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.001, 0.01, 1.0, 1, 2)
# {73}
# sim_92_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.001, 0.01, 1.0, 10, 0.5)
# {96, 41, 43, 31, 78, 88, 59, 60, 62, 63}
# sim_92_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.001, 0.01, 1.0, 10, 2)
# {32, 68, 4, 8, 45, 16, 48, 51, 20, 28}
# sim_92_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {43}
# sim_92_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {58}
# sim_92_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {32, 16, 49, 50, 51, 20, 87, 27, 28, 61}
# sim_92_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {35, 4, 67, 6, 10, 11, 91, 86, 23, 27}
# sim_92_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {71}
# sim_92_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {24}
# sim_92_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {98, 75, 76, 81, 50, 82, 84, 29, 94, 95}
# sim_92_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {33, 97, 5, 39, 40, 78, 18, 57, 95, 31}
# sim_92_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 1.0, 10.0, 1.0, 1, 0.5)
# {71}
# sim_92_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 1.0, 10.0, 1.0, 1, 2)
# {94}
# sim_92_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 1.0, 10.0, 1.0, 10, 0.5)
# {64, 98, 8, 73, 77, 79, 50, 84, 28, 93}
# sim_92_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (92, 1.0, 10.0, 1.0, 10, 2)
# {33, 99, 36, 69, 37, 72, 73, 11, 83, 27}
# sim_92_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.001, 0.01, 1.0, 1, 0.5)
# {23}
# sim_93_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.001, 0.01, 1.0, 1, 2)
# {8}
# sim_93_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.001, 0.01, 1.0, 10, 0.5)
# {0, 38, 71, 8, 74, 10, 77, 22, 57, 94}
# sim_93_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.001, 0.01, 1.0, 10, 2)
# {96, 98, 6, 7, 46, 80, 48, 54, 91, 95}
# sim_93_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {21}
# sim_93_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {43}
# sim_93_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {67, 70, 45, 14, 79, 83, 53, 54, 58, 60}
# sim_93_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {67, 68, 3, 7, 12, 78, 18, 88, 91, 62}
# sim_93_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {86}
# sim_93_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {35}
# sim_93_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {32, 4, 70, 15, 47, 82, 83, 92, 29, 30}
# sim_93_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {98, 99, 6, 74, 44, 49, 21, 86, 27, 93}
# sim_93_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 1.0, 10.0, 1.0, 1, 0.5)
# {57}
# sim_93_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 1.0, 10.0, 1.0, 1, 2)
# {65}
# sim_93_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 1.0, 10.0, 1.0, 10, 0.5)
# {33, 2, 67, 3, 38, 9, 47, 80, 22, 89}
# sim_93_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (93, 1.0, 10.0, 1.0, 10, 2)
# {34, 40, 73, 12, 79, 49, 82, 53, 62, 63}
# sim_93_p_rew_10_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.001, 0.01, 1.0, 1, 0.5)
# {91}
# sim_94_p_rew_0.01_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.001, 0.01, 1.0, 1, 2)
# {53}
# sim_94_p_rew_0.01_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.001, 0.01, 1.0, 10, 0.5)
# {68, 36, 8, 46, 18, 83, 50, 25, 92, 29}
# sim_94_p_rew_0.01_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.001, 0.01, 1.0, 10, 2)
# {65, 33, 99, 97, 69, 9, 44, 48, 92, 31}
# sim_94_p_rew_0.01_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.01, 0.10000000000000002, 1.0, 1, 0.5)
# {93}
# sim_94_p_rew_0.1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.01, 0.10000000000000002, 1.0, 1, 2)
# {2}
# sim_94_p_rew_0.1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.01, 0.10000000000000002, 1.0, 10, 0.5)
# {96, 97, 34, 69, 41, 44, 52, 92, 63, 31}
# sim_94_p_rew_0.1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.01, 0.10000000000000002, 1.0, 10, 2)
# {0, 32, 34, 64, 37, 12, 77, 46, 25, 29}
# sim_94_p_rew_0.1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.10000000000000002, 1.0, 1.0, 1, 0.5)
# {37}
# sim_94_p_rew_1_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.10000000000000002, 1.0, 1.0, 1, 2)
# {67}
# sim_94_p_rew_1_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.10000000000000002, 1.0, 1.0, 10, 0.5)
# {2, 10, 82, 50, 20, 85, 84, 22, 25, 63}
# sim_94_p_rew_1_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 0.10000000000000002, 1.0, 1.0, 10, 2)
# {97, 66, 36, 38, 74, 17, 50, 61, 83, 93}
# sim_94_p_rew_1_start_10_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 1.0, 10.0, 1.0, 1, 0.5)
# {6}
# sim_94_p_rew_10_start_1_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 1.0, 10.0, 1.0, 1, 2)
# {17}
# sim_94_p_rew_10_start_1_dq_2
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 1.0, 10.0, 1.0, 10, 0.5)
# {4, 6, 8, 13, 15, 49, 19, 51, 23, 90}
# sim_94_p_rew_10_start_10_dq_0.5
# (sim,lamb_da,p_rew,w_minus,start,dose_quantity) =  (94, 1.0, 10.0, 1.0, 10, 2)
# {1, 44, 78, 80, 16, 84, 52, 30, 89, 62}
# sim_94_p_rew_10_start_10_dq_2

# %%
for i in range(len(coords)) :
    plt.plot(coords[i][0],coords[i][1],'b+')

# %%
edge_list
# Out:
# [[19, 0],
#  [19, 1],
#  [19, 3],
#  [19, 4],
#  [19, 9],
#  [19, 10],
#  [19, 11],
#  [19, 12],
#  [19, 14],
#  [19, 17],
#  [19, 21],
#  [19, 24],
#  [19, 26],
#  [19, 28],
#  [19, 29],
#  [19, 30],
#  [19, 31],
#  [19, 32],
#  [19, 34],
#  [19, 35],
#  [19, 36],
#  [19, 37],
#  [19, 38],
#  [19, 41],
#  [19, 43],
#  [19, 45],
#  [19, 47],
#  [19, 49],
#  [19, 51],
#  [19, 57],
#  [19, 59],
#  [19, 61],
#  [19, 62],
#  [19, 65],
#  [19, 67],
#  [19, 72],
#  [19, 75],
#  [19, 80],
#  [19, 81],
#  [19, 84],
#  [19, 85],
#  [19, 89],
#  [19, 90],
#  [19, 91],
#  [19, 94],
#  [19, 98],
#  [80, 0],
#  [80, 2],
#  [80, 3],
#  [80, 6],
#  [80, 12],
#  [80, 14],
#  [80, 16],
#  [80, 19],
#  [80, 23],
#  [80, 24],
#  [80, 25],
#  [80, 27],
#  [80, 30],
#  [80, 33],
#  [80, 34],
#  [80, 35],
#  [80, 36],
#  [80, 40],
#  [80, 41],
#  [80, 42],
#  [80, 44],
#  [80, 49],
#  [80, 51],
#  [80, 53],
#  [80, 54],
#  [80, 57],
#  [80, 58],
#  [80, 59],
#  [80, 60],
#  [80, 61],
#  [80, 64],
#  [80, 66],
#  [80, 67],
#  [80, 73],
#  [80, 74],
#  [80, 75],
#  [80, 78],
#  [80, 82],
#  [80, 86],
#  [80, 89],
#  [80, 90],
#  [80, 91],
#  [80, 92],
#  [80, 94],
#  [80, 98],
#  [80, 99]]
