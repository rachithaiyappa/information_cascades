# %% [markdown]
# ## Leaky integrated firing neuron model
# ## Few feautures :
# ### Spatial network, no memory term but exponential decay of cumulative dose
#
# This is a minor change of the Dodds and Watts model
# Implement adaptive rewiring and generate statistics

# %%
#importing the required libraries

import networkx as nx
import matplotlib.pyplot as plt #for plotting
import numpy as np #for using arrays and vectorising the code wherever possible
import scipy
import random
# from numba import jit #numba precomplier to make the code faster
import pandas as pd
import copy

# %% [markdown]
# # Variables used in the simulation

# %%
N = 100
gamma = 1 #decay of cumulative dose per unit time (second)
T = 100 #total number of seconds
dt = 0.05 #seconds
'''number of simulation steps is T/dt'''

'''Dodds watts parameters'''
p = 1 #rate of dose transfer (per unit time (second))
p = p*dt #rate of dose transfer per unit simulation step
r = 1/dt
r = r*dt
rho = 1/dt
rho = rho*dt
# r = 0.5
# r = r*dt

d_star = 1
# dose_quantity = 1
D_ini = 3

'''network parameters'''
circ_rad = 100 #for a network in which each node is connected to other nodes withing a circle of radius circ_rad
nn = 7 #the number of nearest neighbours(i.e. k) in knn
average_degree = 6
total_edges = N*6

'''rewiring parameters'''
# p_rew = 5 #rate of rewiring(per unit time(second))
# p_rew = p_rew*dt
# Out:
# 'rewiring parameters'

# %% [markdown]
# # Creating the network.
# ### The network outputs coordinates, distance matrix, edge_list and adjacency matrix

# %%
'''
obtains the number of nodes N
generates N points
calculates euclidean distance between each pair of points
returns the coordinates of the points and the distance matrix which is N*N
'''
def calc_dist(N) :
    coords = []
    for counter in range(N) :
        coords.append((N*np.random.random(),N*np.random.random()))

    dist_mat = scipy.spatial.distance.cdist(coords,coords)
    return dist_mat,coords

# %% [markdown]
# ### 1. metric network

# %%
'''network = connect to points withing a circle of radius'''
#creates a link between points/nodes which satisfies the conditions of the network
def coupling(dist_mat,circ_rad) :
    edge_list = []
    edge_mask = (dist_mat<circ_rad) & (dist_mat>0)
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(edge_mask))))
#     print(type(np.ndarray.tolist(np.transpose(np.where(edge_mask)))))
    return edge_list

# %% [markdown]
# ### 2. K nearest neighbour network

# %%
'''network = knn'''
def knn(dist_mat,nn,N) :
    near_neigh = np.argsort(dist_mat)
    selec_near_neigh = np.zeros((N,nn))
    selec_near_neigh = near_neigh[:,0:nn+1]

    edge_list = []
    for i in range(N) :
        for j in range(1,nn+1) :
            link = [i,selec_near_neigh[i,j]]
            edge_list.append(link)

    return edge_list

# %% [markdown]
# ### 3. Random Network : GNP type

# %%
'''random network'''
def rand_network(average_degree,N) :
    z1 = np.random.uniform(size = (N,N))
    E,F = np.meshgrid(np.arange(0,N),np.arange(0,N))
    mask = ((average_degree/N) > z1) & (E!=F)
    adjacency_matrix = np.int64(np.zeros(shape=(N,N)))
    adjacency_matrix[mask] = np.int64(1)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list,adjacency_matrix

# %% [markdown]
# ### 4. Random Network : GNM type

# %%
def rand_net_gnm(total_edges,N) :
    the_graph = nx.gnm_random_graph(N, total_edges,directed=True)
    adjacency_matrix = nx.adjacency_matrix(the_graph)
    adjacency_matrix = np.asarray(adjacency_matrix.todense())
    np.fill_diagonal(adjacency_matrix,0)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list

# %% [markdown]
# # Function defintions required for the main part of the script

# %%
# # @jit(nopython=True)
# '''infecting the left part of space.'''
# def left_part_infec(N) :
#     x_coord = []
#     y_coord = []
#     for j in range(len(coords)) :
#         x_coord.append(coords[j][0])
#         y_coord.append(coords[j][1])
#     x_coord = np.asarray(x_coord)
#     y_coord = np.asarray(y_coord)
#     points = np.asarray(np.where(x_coord<(N/5))) 
#     indi_state[points.T] = 2

#     return indi_state

# %%
'''infecting connected nodes'''
def InfectNetworkNeighbors(net,seed_node,init_infected_nodes):
     # if in bulk find one node randomly, and infect its neighbours
    infected_nodes = set()
    candidate_nodes = set()
    explored_nodes = set()

    #pick the seed node
    infected_nodes.add(seed_node)
    explored_nodes.add(seed_node)

    curr_node=seed_node

    #add its neighbors to the list of candidates
    for n in net.neighbors(curr_node):
        candidate_nodes.add(int(n))
    #print( curr_node)
    #print( candidate_nodes)

    #while we need to select more nodes...
    while len(infected_nodes) < init_infected_nodes:

        #if there are candidate nodes, select one of them
        if(len(candidate_nodes) > 0):
            new_node = np.random.choice(list(candidate_nodes),1)[0]
            infected_nodes.add(new_node)
            candidate_nodes.remove(new_node)

        elif len(infected_nodes - explored_nodes) > 0:
            curr_node = np.random.choice(list(infected_nodes -
            explored_nodes),1)[0]
            explored_nodes.add(curr_node)
            for n in set(net.neighbors(curr_node)) - infected_nodes:
                candidate_nodes.add(n)

        else:
            print('Initial node infection step failed')
            return None
    return infected_nodes

# %%
''' function to transfer doses'''
# @jit(nopython=True)
def dose(adj_mat,p,partner_state_prev,d) :

    z1 = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    dose_transfer_mask = p > z1
    mod_adj_mat = np.multiply(adj_mat,z1) #modifying adjacency matrix to include the proability of dose transfer
    dose_mask = (p>mod_adj_mat) & (adj_mat!=0) & (partner_state_prev == 2)
    d[dose_mask] = dose_quantity #whenever it is proabable, dose transfer occurs
    
    return d

# %%
'''rewiring function which returns a new adjacency matrix'''

def rew(p_rew,adjacency_matrix,indi_state_for_rew_prev) :
    
    z1_rew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew > z1_rew)  & (indi_state_for_rew_prev == 1)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    rew_mask_minus = (p_rew > z1_rew) & (indi_state_for_rew_prev == 2)
    #break links. Dont create any.
    adjacency_matrix[rew_mask_minus] = 0
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
'''function to update cumulative doses'''
def cumu_dose(d,D_prev,gamma) :
    I = d.sum(axis=1).reshape(N,1)
#     I = 0
    D = (D_prev - (gamma*D_prev*dt)) + I
    return D

# %%
'''function to update the states of the nodes of the system'''
def upd_indi_state(D,d_star,indi_state_prev) :
    
    z2 = np.random.uniform(size=(N,1))
    z3 = np.random.uniform(size=(N,1))
    
    indi_state = indi_state_prev
    
    indi_state_mask1 = (D>=d_star) & (indi_state_prev==1)
    indi_state[indi_state_mask1] = 2
    
    indi_state_mask21 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho>=z3)
    indi_state[indi_state_mask21] = 1
    
    indi_state_mask22 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho<z3)
    indi_state[indi_state_mask22] = 3
    
    indi_state_mask23 = (D<d_star) & (indi_state_prev==2) & (r<z2)
    indi_state[indi_state_mask23] = 2
    
    return indi_state

# %%
'''function to get/identify the infected nodes and the suceptible nodes'''
def states(indi_state) :
    infec_indi = []
    suscep_indi = []
    infec_indi = np.transpose(np.where(indi_state==2))
    suscep_indi = np.transpose(np.where(indi_state==1))
    return infec_indi,suscep_indi

# %%
def networkx_graph(coords,edge_list) :
    G = nx.DiGraph()
    pos = {(i): (coords[i][0],coords[i][1]) for i in range(N)}
    G.add_nodes_from(pos.keys())
    G.add_edges_from(edge_list)
    return G

# %%
def edge_from_adj_mat(adj_mat_list,q):
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adj_mat_list[q]==1))))
    return edge_list

# %% [markdown]
# # Choose which network you want in the program
# ### Coupling network of knn network?

# %%
'''returns coordinates, distance matrix, edge_list and the adjacency matrix'''

dist_mat,coords = calc_dist(N) #node placement

# edge_list = coupling(dist_mat,circ_rad)
# edge_list = knn(dist_mat,nn,N)
# edge_list = rand_network(average_degree,N)
edge_list = rand_net_gnm(total_edges,N)

org_adj_mat = np.int64(np.zeros((N,N)))
for i in range(len(edge_list)):
    org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)

# %% [markdown]
# # The main part of the script

# %%
#infected state time series data frame
#columns indicate the time steps
timeseries_infec_frac = pd.DataFrame()

#in degree as columns and rows as nodes
timeseries_in_degree = pd.DataFrame() 

#out degree as columns and rows as nodes
timeseries_out_degree = pd.DataFrame()

#strongly connected components as columns
timeseries_strong_comps = pd.DataFrame()

#weakly connected components as columns
timeseries_weak_comps = pd.DataFrame()

# %%
p_rew_vals = [0.1,1,10]
start_vals = [1,10]
dose_quantity_vals = [0.1,2]

# %%
for sim in range(70,171) :
    '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''
    dist_mat,coords = calc_dist(N) #node placement
    edge_list = rand_net_gnm(total_edges,N)
    org_adj_mat = np.int64(np.zeros((N,N)))
    for i in range(len(edge_list)):
        org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)
        
    df_row = 0
    for p_rew in p_rew_vals : #rate of rewiring (per unit time (second))
        p_rew = p_rew*dt        
        for start in start_vals : #rate of dose transfer (per unit time (second))
            for dose_quantity in dose_quantity_vals : #number of nodes to infect initially
                print('(sim,p_rew,start,dose_quantity) = ', (sim,p_rew/dt,start,dose_quantity))

                '''clearing exsiting data frames and creating new ones '''
                timeseries_infec_frac = pd.DataFrame()
                timeseries_in_degree = pd.DataFrame()
                timeseries_out_degree = pd.DataFrame()
                timeseries_strong_comps = pd.DataFrame()
                timeseries_weak_comps = pd.DataFrame()

                q = 0 #to generate new edge_list from the new adjacency matrix 
                t = np.arange(0,T,dt)

    #             numpy_array = np.zeros((N,len(t)),dtype = np.int64) #stores the states of the nodes. Rows are nodes and columns are time steps
                D_array = np.zeros((N,len(t))) #stores the cumulative doses. Rows are nodes and columns are time steps

                adj_mat_list = []
                adj_mat = org_adj_mat
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new) #list of arrays which shows the time series of the adjacency matrix

                #coords remain the same. Get new edge_list from the latest adjacency matrix
                edge_list = edge_from_adj_mat(adj_mat_list,q)
                G = networkx_graph(coords,edge_list) #networkx graph

                '''from G, obtain the in degree and the out degree'''
                timeseries_in_degree.loc[:,0] = np.asarray([val for (node, val) in G.in_degree()])
                timeseries_out_degree.loc[:,0] = np.asarray([val for (node, val) in G.out_degree()])

                '''strongly and weekely connected components'''
                timeseries_strong_comps.loc[0,0] = nx.number_strongly_connected_components(G)
                timeseries_weak_comps.loc[0,0] = nx.number_weakly_connected_components(G)

                '''choosing initially infected nodes'''
                indi_state = np.random.randint(1,2,size=(N,1))
                infected_nodes = None
                while infected_nodes is None : #infecting 'start' number of network neighbours
                    infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)
                    print(infected_nodes)
                infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
                indi_state[infected_nodes[:,0],0] = 2

                A,B = np.meshgrid(indi_state,indi_state) 
                partner_state = A
                indi_state_for_rew = B

    #             numpy_array [:,0] = indi_state[:,0]

                indi_state_prev = indi_state
                partner_state_prev = partner_state
                indi_state_for_rew_prev = indi_state_for_rew

                d = np.zeros((len(adj_mat),len(adj_mat[0])))

                D = np.zeros((N,1))
                D[np.where(indi_state==2)] = D_ini
                D_array[:,0] = D[:,0]
                D_prev = D

                infec_frac = np.count_nonzero(indi_state == 2)/N
                timeseries_infec_frac.loc[df_row,0] = infec_frac
                '''the main part of the simulation'''
                counter = 0
                df_col = 1
                for t in np.arange(dt,T,dt) :
                    q = q + 1 
                    counter = counter + 1
                    infec_indi = []
                    suscep_indi = []
                    d = np.zeros((len(adj_mat),len(adj_mat[0])))
                    d = dose(adj_mat,p,partner_state_prev,d)

                    adj_mat = rew(p_rew,adj_mat,indi_state_for_rew_prev)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    '''from G, obtain the in degree and the out degree'''
                    timeseries_in_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.in_degree()])
                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])

                    '''strongly and weekely connected components'''
                    timeseries_strong_comps.loc[df_row,df_col] = nx.number_strongly_connected_components(G)
                    timeseries_weak_comps.loc[df_row,df_col] = nx.number_weakly_connected_components(G)

                    D = cumu_dose(d,D_prev,gamma)
                    D_array[:,counter] = D[:,0]

                    indi_state = upd_indi_state(D,d_star,indi_state_prev)
                    infec_frac = np.count_nonzero(indi_state == 2)/N
                    timeseries_infec_frac.loc[df_row,df_col] = infec_frac

    #                 numpy_array[:,counter] = indi_state[:,0]
                    A,B = np.meshgrid(indi_state,indi_state)

                    infec_indi, suscep_indi = states(indi_state)

                    partner_state = A
                    indi_state_for_rew = B
                    indi_state_prev = indi_state
                    partner_state_prev = partner_state
                    indi_state_for_rew_prev = indi_state_for_rew

                    D_prev = D
                    D = np.zeros((N,1))
                    df_col = df_col + 1 

    #             df_row = df_row + 1 #going to the next row of the df to store timeseries of next (p,start)

                filename_infec_frac = 'infec_frac.h5'
                filename_in_deg = 'in_deg.h5'
                filename_out_deg = 'out_deg.h5'
                filename_strong_comps = 'strong_comps.h5'
                filename_weak_comps = 'weak_comps.h5'
                key_val = 'sim_'+str(sim)+'_p_rew_'+str(np.int64(p_rew/dt))+'_start_'+str(start)+'_dq_'+str(np.int64(dose_quantity*10))
                print(key_val)
                timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
                timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
                timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
                timeseries_strong_comps.to_hdf(filename_strong_comps, key = key_val, mode='a')
                timeseries_weak_comps.to_hdf(filename_weak_comps, key = key_val, mode='a')
                df_row = 0
# Out:
# (sim,p_rew,start,dose_quantity) =  (70, 0.10000000000000002, 1, 0.1)
# {83}
# sim_70_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (70, 0.10000000000000002, 1, 2)
# {67}
# sim_70_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (70, 0.10000000000000002, 10, 0.1)
# {97, 33, 67, 36, 37, 69, 77, 15, 49, 62}
# sim_70_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (70, 0.10000000000000002, 10, 2)
# {5, 9, 42, 76, 49, 18, 52, 22, 86, 89}
# sim_70_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (70, 1.0, 1, 0.1)
# {87}
# sim_70_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (70, 1.0, 1, 2)
# {35}
# sim_70_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (70, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {66, 6, 72, 75, 53, 87, 62, 25, 27, 30}
# sim_70_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (70, 1.0, 10, 2)
# {4, 72, 11, 79, 47, 84, 85, 24, 90, 59}
# sim_70_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (70, 10.0, 1, 0.1)
# {83}
# sim_70_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (70, 10.0, 1, 2)
# {1}
# sim_70_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (70, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {96, 98, 66, 41, 74, 11, 13, 16, 90, 61}
# sim_70_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (70, 10.0, 10, 2)
# {1, 4, 12, 14, 16, 48, 82, 56, 89, 30}
# sim_70_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (71, 0.10000000000000002, 1, 0.1)
# {81}
# sim_71_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (71, 0.10000000000000002, 1, 2)
# {2}
# sim_71_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (71, 0.10000000000000002, 10, 0.1)
# {96, 42, 75, 78, 49, 82, 53, 90, 59, 95}
# sim_71_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (71, 0.10000000000000002, 10, 2)
# {35, 36, 71, 49, 17, 19, 20, 57, 25, 63}
# sim_71_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (71, 1.0, 1, 0.1)
# {2}
# sim_71_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (71, 1.0, 1, 2)
# {41}
# sim_71_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (71, 1.0, 10, 0.1)
# {32, 98, 67, 68, 5, 70, 74, 48, 57, 60}
# sim_71_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (71, 1.0, 10, 2)
# {2, 67, 69, 7, 46, 14, 86, 58, 60, 31}
# sim_71_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (71, 10.0, 1, 0.1)
# {52}
# sim_71_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (71, 10.0, 1, 2)
# {58}
# sim_71_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (71, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {36, 10, 43, 12, 78, 46, 51, 22, 57, 26}
# sim_71_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (71, 10.0, 10, 2)
# Initial node infection step failed
# None
# {98, 67, 4, 14, 47, 55, 23, 88, 24, 29}
# sim_71_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (72, 0.10000000000000002, 1, 0.1)
# {6}
# sim_72_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (72, 0.10000000000000002, 1, 2)
# {2}
# sim_72_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (72, 0.10000000000000002, 10, 0.1)
# {65, 35, 3, 38, 76, 44, 86, 23, 26, 91}
# sim_72_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (72, 0.10000000000000002, 10, 2)
# {67, 4, 39, 73, 74, 10, 76, 82, 60, 94}
# sim_72_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (72, 1.0, 1, 0.1)
# {88}
# sim_72_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (72, 1.0, 1, 2)
# {90}
# sim_72_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (72, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# {67, 74, 11, 78, 15, 48, 79, 82, 26, 93}
# sim_72_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (72, 1.0, 10, 2)
# {69, 70, 6, 42, 15, 82, 52, 29, 30, 95}
# sim_72_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (72, 10.0, 1, 0.1)
# {39}
# sim_72_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (72, 10.0, 1, 2)
# {54}
# sim_72_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (72, 10.0, 10, 0.1)
# {66, 67, 68, 8, 40, 42, 10, 45, 77, 21}
# sim_72_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (72, 10.0, 10, 2)
# {98, 3, 34, 73, 43, 81, 20, 25, 26, 63}
# sim_72_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (73, 0.10000000000000002, 1, 0.1)
# {14}
# sim_73_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (73, 0.10000000000000002, 1, 2)
# {87}
# sim_73_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (73, 0.10000000000000002, 10, 0.1)
# {32, 97, 2, 3, 99, 98, 36, 70, 43, 51}
# sim_73_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (73, 0.10000000000000002, 10, 2)
# {0, 98, 3, 72, 9, 42, 78, 81, 19, 88}
# sim_73_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (73, 1.0, 1, 0.1)
# {37}
# sim_73_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (73, 1.0, 1, 2)
# {86}
# sim_73_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (73, 1.0, 10, 0.1)
# {64, 65, 32, 38, 8, 44, 79, 80, 52, 86}
# sim_73_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (73, 1.0, 10, 2)
# {4, 6, 72, 27, 40, 75, 48, 22, 59, 94}
# sim_73_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (73, 10.0, 1, 0.1)
# {86}
# sim_73_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (73, 10.0, 1, 2)
# {28}
# sim_73_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (73, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {98, 68, 36, 70, 8, 44, 82, 85, 54, 31}
# sim_73_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (73, 10.0, 10, 2)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {37, 71, 19, 84, 52, 23, 87, 56, 93, 62}
# sim_73_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (74, 0.10000000000000002, 1, 0.1)
# {40}
# sim_74_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (74, 0.10000000000000002, 1, 2)
# {69}
# sim_74_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (74, 0.10000000000000002, 10, 0.1)
# {98, 67, 39, 75, 50, 21, 86, 88, 89, 62}
# sim_74_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (74, 0.10000000000000002, 10, 2)
# {34, 10, 43, 77, 81, 50, 19, 20, 82, 22}
# sim_74_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (74, 1.0, 1, 0.1)
# {66}
# sim_74_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (74, 1.0, 1, 2)
# {51}
# sim_74_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (74, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {65, 98, 70, 41, 46, 82, 20, 53, 87, 29}
# sim_74_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (74, 1.0, 10, 2)
# {37, 70, 10, 44, 60, 15, 19, 23, 28, 95}
# sim_74_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (74, 10.0, 1, 0.1)
# {97}
# sim_74_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (74, 10.0, 1, 2)
# {43}
# sim_74_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (74, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {99, 69, 9, 74, 47, 81, 85, 86, 21, 95}
# sim_74_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (74, 10.0, 10, 2)
# {64, 8, 74, 92, 79, 18, 19, 84, 23, 60}
# sim_74_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (75, 0.10000000000000002, 1, 0.1)
# {7}
# sim_75_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (75, 0.10000000000000002, 1, 2)
# {44}
# sim_75_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (75, 0.10000000000000002, 10, 0.1)
# {97, 67, 74, 77, 46, 20, 86, 57, 26, 29}
# sim_75_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (75, 0.10000000000000002, 10, 2)
# {65, 67, 71, 40, 11, 85, 90, 92, 63, 31}
# sim_75_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (75, 1.0, 1, 0.1)
# {77}
# sim_75_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (75, 1.0, 1, 2)
# {22}
# sim_75_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (75, 1.0, 10, 0.1)
# {4, 9, 41, 75, 44, 15, 48, 80, 20, 91}
# sim_75_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (75, 1.0, 10, 2)
# {0, 97, 9, 76, 28, 53, 23, 60, 94, 95}
# sim_75_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (75, 10.0, 1, 0.1)
# {71}
# sim_75_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (75, 10.0, 1, 2)
# {53}
# sim_75_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (75, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {99, 9, 10, 44, 77, 78, 26, 27, 60, 29}
# sim_75_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (75, 10.0, 10, 2)
# {33, 35, 37, 76, 81, 53, 62, 89, 95, 31}
# sim_75_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (76, 0.10000000000000002, 1, 0.1)
# {17}
# sim_76_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (76, 0.10000000000000002, 1, 2)
# {42}
# sim_76_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (76, 0.10000000000000002, 10, 0.1)
# {67, 37, 39, 11, 76, 45, 83, 22, 94, 95}
# sim_76_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (76, 0.10000000000000002, 10, 2)
# {67, 99, 73, 41, 44, 18, 86, 55, 56, 61}
# sim_76_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (76, 1.0, 1, 0.1)
# {17}
# sim_76_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (76, 1.0, 1, 2)
# {93}
# sim_76_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (76, 1.0, 10, 0.1)
# {34, 71, 74, 13, 77, 79, 19, 20, 57, 90}
# sim_76_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (76, 1.0, 10, 2)
# {6, 72, 42, 80, 19, 51, 21, 56, 90, 88}
# sim_76_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (76, 10.0, 1, 0.1)
# {43}
# sim_76_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (76, 10.0, 1, 2)
# {20}
# sim_76_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (76, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {0, 99, 5, 38, 8, 28, 85, 92, 61, 62}
# sim_76_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (76, 10.0, 10, 2)
# {90, 10, 43, 79, 83, 86, 23, 26, 62, 63}
# sim_76_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (77, 0.10000000000000002, 1, 0.1)
# {97}
# sim_77_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (77, 0.10000000000000002, 1, 2)
# {72}
# sim_77_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (77, 0.10000000000000002, 10, 0.1)
# {26, 36, 7, 41, 45, 83, 53, 22, 87, 90}
# sim_77_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (77, 0.10000000000000002, 10, 2)
# {34, 99, 35, 38, 7, 71, 87, 24, 88, 95}
# sim_77_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (77, 1.0, 1, 0.1)
# {67}
# sim_77_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (77, 1.0, 1, 2)
# {35}
# sim_77_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (77, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# {8, 75, 77, 46, 81, 18, 51, 20, 52, 25}
# sim_77_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (77, 1.0, 10, 2)
# {0, 97, 2, 37, 7, 8, 41, 11, 81, 93}
# sim_77_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (77, 10.0, 1, 0.1)
# {67}
# sim_77_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (77, 10.0, 1, 2)
# {66}
# sim_77_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (77, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {96, 67, 68, 72, 43, 79, 83, 20, 60, 62}
# sim_77_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (77, 10.0, 10, 2)
# Initial node infection step failed
# None
# {97, 2, 3, 37, 6, 80, 22, 54, 59, 93}
# sim_77_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (78, 0.10000000000000002, 1, 0.1)
# {87}
# sim_78_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (78, 0.10000000000000002, 1, 2)
# {77}
# sim_78_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (78, 0.10000000000000002, 10, 0.1)
# {4, 73, 10, 76, 15, 49, 18, 90, 27, 63}
# sim_78_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (78, 0.10000000000000002, 10, 2)
# {73, 75, 44, 77, 17, 82, 88, 90, 27, 29}
# sim_78_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (78, 1.0, 1, 0.1)
# {3}
# sim_78_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (78, 1.0, 1, 2)
# {27}
# sim_78_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (78, 1.0, 10, 0.1)
# {5, 6, 69, 11, 81, 50, 22, 87, 58, 95}
# sim_78_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (78, 1.0, 10, 2)
# {66, 7, 8, 76, 13, 18, 84, 52, 57, 94}
# sim_78_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (78, 10.0, 1, 0.1)
# {23}
# sim_78_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (78, 10.0, 1, 2)
# {83}
# sim_78_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (78, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {33, 98, 4, 15, 86, 89, 58, 93, 25, 57}
# sim_78_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (78, 10.0, 10, 2)
# {0, 2, 43, 12, 46, 51, 87, 91, 28, 63}
# sim_78_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (79, 0.10000000000000002, 1, 0.1)
# {88}
# sim_79_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (79, 0.10000000000000002, 1, 2)
# {11}
# sim_79_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (79, 0.10000000000000002, 10, 0.1)
# {98, 43, 12, 45, 78, 81, 83, 58, 59, 94}
# sim_79_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (79, 0.10000000000000002, 10, 2)
# {64, 33, 39, 77, 14, 78, 83, 52, 88, 60}
# sim_79_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (79, 1.0, 1, 0.1)
# {98}
# sim_79_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (79, 1.0, 1, 2)
# {39}
# sim_79_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (79, 1.0, 10, 0.1)
# {97, 34, 67, 40, 13, 14, 16, 27, 28, 94}
# sim_79_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (79, 1.0, 10, 2)
# {96, 1, 64, 36, 11, 49, 19, 20, 87, 31}
# sim_79_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (79, 10.0, 1, 0.1)
# {69}
# sim_79_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (79, 10.0, 1, 2)
# {97}
# sim_79_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (79, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {96, 1, 45, 80, 17, 23, 87, 92, 61, 94}
# sim_79_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (79, 10.0, 10, 2)
# {1, 35, 69, 5, 8, 9, 76, 17, 87, 91}
# sim_79_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (80, 0.10000000000000002, 1, 0.1)
# {58}
# sim_80_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (80, 0.10000000000000002, 1, 2)
# {37}
# sim_80_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (80, 0.10000000000000002, 10, 0.1)
# {3, 8, 41, 42, 50, 51, 86, 22, 25, 30}
# sim_80_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (80, 0.10000000000000002, 10, 2)
# {0, 32, 35, 71, 45, 78, 81, 50, 17, 61}
# sim_80_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (80, 1.0, 1, 0.1)
# {73}
# sim_80_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (80, 1.0, 1, 2)
# {76}
# sim_80_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (80, 1.0, 10, 0.1)
# {98, 34, 99, 41, 42, 9, 15, 17, 86, 28}
# sim_80_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (80, 1.0, 10, 2)
# {89, 33, 70, 7, 9, 77, 50, 18, 56, 24}
# sim_80_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (80, 10.0, 1, 0.1)
# {73}
# sim_80_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (80, 10.0, 1, 2)
# {59}
# sim_80_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (80, 10.0, 10, 0.1)
# {34, 99, 4, 36, 72, 11, 19, 87, 24, 28}
# sim_80_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (80, 10.0, 10, 2)
# {33, 7, 40, 41, 11, 13, 16, 18, 52, 31}
# sim_80_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (81, 0.10000000000000002, 1, 0.1)
# {0}
# sim_81_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (81, 0.10000000000000002, 1, 2)
# {34}
# sim_81_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (81, 0.10000000000000002, 10, 0.1)
# {32, 67, 7, 11, 49, 20, 25, 27, 61, 94}
# sim_81_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (81, 0.10000000000000002, 10, 2)
# {32, 7, 11, 48, 18, 23, 55, 87, 88, 90}
# sim_81_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (81, 1.0, 1, 0.1)
# {75}
# sim_81_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (81, 1.0, 1, 2)
# {99}
# sim_81_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (81, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# {97, 65, 4, 8, 9, 42, 43, 45, 46, 21}
# sim_81_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (81, 1.0, 10, 2)
# {0, 99, 4, 46, 17, 84, 89, 61, 62, 95}
# sim_81_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (81, 10.0, 1, 0.1)
# {83}
# sim_81_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (81, 10.0, 1, 2)
# {30}
# sim_81_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (81, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {32, 1, 36, 71, 45, 48, 85, 54, 87, 86}
# sim_81_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (81, 10.0, 10, 2)
# {65, 2, 3, 34, 70, 8, 77, 13, 46, 16}
# sim_81_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (82, 0.10000000000000002, 1, 0.1)
# {85}
# sim_82_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (82, 0.10000000000000002, 1, 2)
# {79}
# sim_82_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (82, 0.10000000000000002, 10, 0.1)
# {3, 35, 4, 81, 29, 55, 57, 61, 25, 31}
# sim_82_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (82, 0.10000000000000002, 10, 2)
# {0, 35, 68, 8, 74, 42, 78, 21, 23, 62}
# sim_82_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (82, 1.0, 1, 0.1)
# {98}
# sim_82_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (82, 1.0, 1, 2)
# {80}
# sim_82_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (82, 1.0, 10, 0.1)
# {0, 97, 3, 36, 69, 71, 60, 19, 28, 31}
# sim_82_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (82, 1.0, 10, 2)
# {64, 35, 36, 70, 8, 73, 11, 77, 17, 25}
# sim_82_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (82, 10.0, 1, 0.1)
# {30}
# sim_82_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (82, 10.0, 1, 2)
# {14}
# sim_82_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (82, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {73, 9, 11, 78, 81, 50, 19, 58, 93, 94}
# sim_82_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (82, 10.0, 10, 2)
# {99, 5, 6, 45, 13, 53, 89, 28, 25, 95}
# sim_82_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (83, 0.10000000000000002, 1, 0.1)
# {33}
# sim_83_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (83, 0.10000000000000002, 1, 2)
# {68}
# sim_83_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (83, 0.10000000000000002, 10, 0.1)
# {96, 2, 3, 35, 47, 19, 20, 87, 55, 27}
# sim_83_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (83, 0.10000000000000002, 10, 2)
# {96, 33, 71, 8, 7, 13, 14, 85, 91, 30}
# sim_83_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (83, 1.0, 1, 0.1)
# {96}
# sim_83_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (83, 1.0, 1, 2)
# {72}
# sim_83_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (83, 1.0, 10, 0.1)
# {96, 33, 1, 41, 47, 16, 89, 27, 29, 94}
# sim_83_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (83, 1.0, 10, 2)
# {97, 36, 37, 59, 75, 13, 16, 81, 27, 60}
# sim_83_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (83, 10.0, 1, 0.1)
# {44}
# sim_83_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (83, 10.0, 1, 2)
# {87}
# sim_83_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (83, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {33, 66, 4, 37, 68, 74, 78, 14, 48, 25}
# sim_83_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (83, 10.0, 10, 2)
# {96, 98, 5, 41, 13, 23, 87, 57, 59, 94}
# sim_83_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (84, 0.10000000000000002, 1, 0.1)
# {3}
# sim_84_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (84, 0.10000000000000002, 1, 2)
# {74}
# sim_84_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (84, 0.10000000000000002, 10, 0.1)
# {2, 69, 72, 40, 14, 17, 85, 53, 28, 29}
# sim_84_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (84, 0.10000000000000002, 10, 2)
# {66, 36, 72, 73, 11, 47, 81, 83, 86, 59}
# sim_84_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (84, 1.0, 1, 0.1)
# {47}
# sim_84_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (84, 1.0, 1, 2)
# {54}
# sim_84_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (84, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# {66, 72, 11, 44, 46, 15, 80, 17, 19, 91}
# sim_84_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (84, 1.0, 10, 2)
# {97, 34, 3, 38, 7, 77, 81, 55, 91, 30}
# sim_84_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (84, 10.0, 1, 0.1)
# {81}
# sim_84_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (84, 10.0, 1, 2)
# {24}
# sim_84_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (84, 10.0, 10, 0.1)
# {0, 46, 81, 50, 19, 22, 24, 31, 29, 95}
# sim_84_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (84, 10.0, 10, 2)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {64, 33, 4, 73, 18, 52, 57, 90, 94, 63}
# sim_84_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (85, 0.10000000000000002, 1, 0.1)
# {86}
# sim_85_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (85, 0.10000000000000002, 1, 2)
# {28}
# sim_85_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (85, 0.10000000000000002, 10, 0.1)
# {0, 97, 3, 68, 4, 38, 7, 11, 47, 93}
# sim_85_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (85, 0.10000000000000002, 10, 2)
# {32, 1, 65, 75, 77, 19, 52, 54, 24, 26}
# sim_85_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (85, 1.0, 1, 0.1)
# {92}
# sim_85_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (85, 1.0, 1, 2)
# {14}
# sim_85_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (85, 1.0, 10, 0.1)
# {4, 68, 75, 44, 15, 86, 55, 58, 62, 63}
# sim_85_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (85, 1.0, 10, 2)
# {64, 0, 67, 68, 69, 11, 77, 47, 53, 89}
# sim_85_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (85, 10.0, 1, 0.1)
# {98}
# sim_85_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (85, 10.0, 1, 2)
# {95}
# sim_85_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (85, 10.0, 10, 0.1)
# {33, 34, 73, 75, 78, 46, 48, 53, 86, 87}
# sim_85_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (85, 10.0, 10, 2)
# {97, 2, 10, 78, 17, 18, 84, 86, 88, 93}
# sim_85_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (86, 0.10000000000000002, 1, 0.1)
# {87}
# sim_86_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (86, 0.10000000000000002, 1, 2)
# {42}
# sim_86_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (86, 0.10000000000000002, 10, 0.1)
# {98, 3, 66, 13, 45, 77, 78, 83, 61, 94}
# sim_86_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (86, 0.10000000000000002, 10, 2)
# {0, 1, 34, 73, 12, 13, 50, 20, 86, 95}
# sim_86_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (86, 1.0, 1, 0.1)
# {55}
# sim_86_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (86, 1.0, 1, 2)
# {78}
# sim_86_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (86, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# {35, 68, 67, 6, 40, 45, 13, 78, 80, 88}
# sim_86_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (86, 1.0, 10, 2)
# {65, 33, 5, 76, 46, 14, 55, 87, 90, 63}
# sim_86_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (86, 10.0, 1, 0.1)
# {95}
# sim_86_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (86, 10.0, 1, 2)
# {17}
# sim_86_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (86, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {1, 69, 9, 10, 11, 17, 50, 92, 61, 94}
# sim_86_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (86, 10.0, 10, 2)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {1, 98, 34, 35, 6, 49, 18, 24, 57, 93}
# sim_86_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (87, 0.10000000000000002, 1, 0.1)
# {21}
# sim_87_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (87, 0.10000000000000002, 1, 2)
# {32}
# sim_87_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (87, 0.10000000000000002, 10, 0.1)
# {32, 1, 70, 71, 44, 13, 78, 49, 83, 28}
# sim_87_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (87, 0.10000000000000002, 10, 2)
# {97, 7, 46, 48, 18, 85, 22, 23, 88, 58}
# sim_87_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (87, 1.0, 1, 0.1)
# {55}
# sim_87_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (87, 1.0, 1, 2)
# {36}
# sim_87_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (87, 1.0, 10, 0.1)
# {33, 34, 68, 71, 75, 83, 86, 27, 93, 62}
# sim_87_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (87, 1.0, 10, 2)
# {0, 34, 4, 70, 82, 50, 20, 85, 56, 91}
# sim_87_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (87, 10.0, 1, 0.1)
# {35}
# sim_87_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (87, 10.0, 1, 2)
# {25}
# sim_87_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (87, 10.0, 10, 0.1)
# {1, 36, 74, 10, 18, 19, 22, 24, 26, 62}
# sim_87_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (87, 10.0, 10, 2)
# {35, 38, 43, 79, 92, 50, 21, 53, 23, 28}
# sim_87_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (88, 0.10000000000000002, 1, 0.1)
# {86}
# sim_88_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (88, 0.10000000000000002, 1, 2)
# {99}
# sim_88_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (88, 0.10000000000000002, 10, 0.1)
# {0, 5, 10, 75, 78, 81, 82, 19, 22, 60}
# sim_88_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (88, 0.10000000000000002, 10, 2)
# {66, 40, 47, 17, 82, 61, 93, 50, 24, 29}
# sim_88_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (88, 1.0, 1, 0.1)
# {48}
# sim_88_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (88, 1.0, 1, 2)
# {20}
# sim_88_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (88, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {10, 47, 82, 51, 84, 52, 21, 85, 20, 53}
# sim_88_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (88, 1.0, 10, 2)
# {0, 36, 69, 44, 79, 48, 57, 90, 60, 95}
# sim_88_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (88, 10.0, 1, 0.1)
# {20}
# sim_88_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (88, 10.0, 1, 2)
# {52}
# sim_88_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (88, 10.0, 10, 0.1)
# {96, 34, 5, 41, 59, 13, 50, 55, 24, 27}
# sim_88_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (88, 10.0, 10, 2)
# {98, 35, 11, 15, 16, 81, 56, 25, 93, 95}
# sim_88_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (89, 0.10000000000000002, 1, 0.1)
# {86}
# sim_89_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (89, 0.10000000000000002, 1, 2)
# {90}
# sim_89_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (89, 0.10000000000000002, 10, 0.1)
# {98, 35, 37, 8, 11, 48, 53, 54, 25, 62}
# sim_89_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (89, 0.10000000000000002, 10, 2)
# {34, 40, 43, 78, 52, 53, 54, 88, 25, 31}
# sim_89_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (89, 1.0, 1, 0.1)
# {57}
# sim_89_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (89, 1.0, 1, 2)
# {71}
# sim_89_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (89, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# {33, 67, 5, 71, 72, 40, 11, 15, 19, 29}
# sim_89_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (89, 1.0, 10, 2)
# {1, 43, 75, 79, 17, 82, 85, 27, 28, 29}
# sim_89_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (89, 10.0, 1, 0.1)
# {64}
# sim_89_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (89, 10.0, 1, 2)
# {88}
# sim_89_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (89, 10.0, 10, 0.1)
# {67, 68, 69, 6, 11, 45, 52, 56, 26, 30}
# sim_89_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (89, 10.0, 10, 2)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {98, 38, 73, 74, 75, 20, 55, 88, 59, 94}
# sim_89_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (90, 0.10000000000000002, 1, 0.1)
# {1}
# sim_90_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (90, 0.10000000000000002, 1, 2)
# {92}
# sim_90_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (90, 0.10000000000000002, 10, 0.1)
# {33, 7, 76, 12, 49, 18, 24, 62, 29, 94}
# sim_90_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (90, 0.10000000000000002, 10, 2)
# {97, 3, 67, 38, 9, 13, 78, 52, 22, 90}
# sim_90_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (90, 1.0, 1, 0.1)
# {14}
# sim_90_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (90, 1.0, 1, 2)
# {63}
# sim_90_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (90, 1.0, 10, 0.1)
# {37, 31, 77, 80, 53, 87, 92, 61, 30, 95}
# sim_90_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (90, 1.0, 10, 2)
# {71, 73, 41, 17, 24, 25, 59, 61, 94, 57}
# sim_90_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (90, 10.0, 1, 0.1)
# {73}
# sim_90_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (90, 10.0, 1, 2)
# {92}
# sim_90_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (90, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {32, 71, 10, 45, 13, 53, 87, 24, 88, 28}
# sim_90_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (90, 10.0, 10, 2)
# Initial node infection step failed
# None
# {67, 68, 5, 72, 9, 77, 14, 52, 94, 62}
# sim_90_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (91, 0.10000000000000002, 1, 0.1)
# {40}
# sim_91_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (91, 0.10000000000000002, 1, 2)
# {11}
# sim_91_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (91, 0.10000000000000002, 10, 0.1)
# {36, 68, 70, 76, 78, 14, 16, 17, 50, 20}
# sim_91_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (91, 0.10000000000000002, 10, 2)
# {67, 68, 71, 41, 9, 76, 13, 21, 92, 61}
# sim_91_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (91, 1.0, 1, 0.1)
# {59}
# sim_91_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (91, 1.0, 1, 2)
# {18}
# sim_91_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (91, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {32, 11, 76, 45, 80, 93, 23, 60, 61, 63}
# sim_91_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (91, 1.0, 10, 2)
# {64, 98, 7, 79, 49, 51, 22, 23, 60, 29}
# sim_91_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (91, 10.0, 1, 0.1)
# {10}
# sim_91_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (91, 10.0, 1, 2)
# {93}
# sim_91_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (91, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {1, 70, 7, 41, 15, 95, 90, 93, 62, 31}
# sim_91_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (91, 10.0, 10, 2)
# {39, 8, 41, 46, 81, 89, 26, 91, 61, 30}
# sim_91_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (92, 0.10000000000000002, 1, 0.1)
# {98}
# sim_92_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (92, 0.10000000000000002, 1, 2)
# {1}
# sim_92_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (92, 0.10000000000000002, 10, 0.1)
# {2, 40, 46, 49, 82, 18, 22, 23, 24, 88}
# sim_92_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (92, 0.10000000000000002, 10, 2)
# {66, 98, 45, 46, 81, 86, 87, 90, 91, 92}
# sim_92_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (92, 1.0, 1, 0.1)
# {86}
# sim_92_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (92, 1.0, 1, 2)
# {5}
# sim_92_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (92, 1.0, 10, 0.1)
# {4, 37, 74, 76, 83, 22, 24, 89, 27, 94}
# sim_92_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (92, 1.0, 10, 2)
# {33, 99, 7, 8, 73, 45, 79, 82, 87, 90}
# sim_92_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (92, 10.0, 1, 0.1)
# {32}
# sim_92_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (92, 10.0, 1, 2)
# {48}
# sim_92_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (92, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {96, 59, 11, 44, 50, 52, 87, 26, 91, 30}
# sim_92_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (92, 10.0, 10, 2)
# {32, 5, 38, 41, 74, 80, 49, 18, 50, 90}
# sim_92_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (93, 0.10000000000000002, 1, 0.1)
# {56}
# sim_93_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (93, 0.10000000000000002, 1, 2)
# {34}
# sim_93_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (93, 0.10000000000000002, 10, 0.1)
# {64, 97, 36, 13, 78, 49, 84, 28, 63, 31}
# sim_93_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (93, 0.10000000000000002, 10, 2)
# {69, 7, 71, 74, 44, 50, 55, 89, 62, 31}
# sim_93_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (93, 1.0, 1, 0.1)
# {51}
# sim_93_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (93, 1.0, 1, 2)
# {23}
# sim_93_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (93, 1.0, 10, 0.1)
# {0, 65, 69, 72, 77, 45, 79, 55, 88, 31}
# sim_93_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (93, 1.0, 10, 2)
# {40, 41, 43, 79, 49, 50, 51, 24, 26, 30}
# sim_93_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (93, 10.0, 1, 0.1)
# {1}
# sim_93_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (93, 10.0, 1, 2)
# {78}
# sim_93_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (93, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {0, 66, 67, 69, 78, 19, 22, 91, 60, 31}
# sim_93_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (93, 10.0, 10, 2)
# {0, 96, 97, 98, 40, 73, 42, 45, 49, 31}
# sim_93_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (94, 0.10000000000000002, 1, 0.1)
# {61}
# sim_94_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (94, 0.10000000000000002, 1, 2)
# {14}
# sim_94_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (94, 0.10000000000000002, 10, 0.1)
# {89, 65, 69, 7, 16, 23, 94, 26, 92, 30}
# sim_94_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (94, 0.10000000000000002, 10, 2)
# {37, 42, 76, 14, 49, 83, 51, 90, 28, 63}
# sim_94_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (94, 1.0, 1, 0.1)
# {52}
# sim_94_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (94, 1.0, 1, 2)
# {44}
# sim_94_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (94, 1.0, 10, 0.1)
# {5, 41, 73, 78, 49, 83, 84, 52, 87, 61}
# sim_94_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (94, 1.0, 10, 2)
# ...
# (sim,p_rew,start,dose_quantity) =  (157, 1.0, 1, 2)
# {76}
# sim_157_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (157, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# {32, 64, 44, 14, 15, 84, 88, 90, 28, 94}
# sim_157_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (157, 1.0, 10, 2)
# {97, 99, 74, 13, 16, 29, 84, 90, 59, 93}
# sim_157_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (157, 10.0, 1, 0.1)
# {59}
# sim_157_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (157, 10.0, 1, 2)
# {60}
# sim_157_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (157, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {98, 7, 8, 9, 43, 76, 52, 87, 57, 59}
# sim_157_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (157, 10.0, 10, 2)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {36, 42, 11, 12, 45, 18, 83, 20, 54, 89}
# sim_157_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (158, 0.10000000000000002, 1, 0.1)
# {61}
# sim_158_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (158, 0.10000000000000002, 1, 2)
# {67}
# sim_158_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (158, 0.10000000000000002, 10, 0.1)
# {97, 43, 51, 84, 54, 23, 88, 28, 62, 31}
# sim_158_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (158, 0.10000000000000002, 10, 2)
# {1, 2, 39, 72, 41, 53, 21, 86, 88, 95}
# sim_158_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (158, 1.0, 1, 0.1)
# {68}
# sim_158_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (158, 1.0, 1, 2)
# {13}
# sim_158_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (158, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# {0, 34, 98, 38, 8, 14, 85, 92, 94, 63}
# sim_158_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (158, 1.0, 10, 2)
# {96, 67, 4, 8, 73, 15, 51, 83, 88, 62}
# sim_158_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (158, 10.0, 1, 0.1)
# {65}
# sim_158_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (158, 10.0, 1, 2)
# {78}
# sim_158_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (158, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {98, 6, 71, 72, 73, 77, 78, 82, 20, 62}
# sim_158_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (158, 10.0, 10, 2)
# {66, 39, 40, 43, 49, 24, 90, 91, 28, 31}
# sim_158_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (159, 0.10000000000000002, 1, 0.1)
# {71}
# sim_159_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (159, 0.10000000000000002, 1, 2)
# {87}
# sim_159_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (159, 0.10000000000000002, 10, 0.1)
# {34, 3, 39, 73, 74, 79, 83, 58, 95, 63}
# sim_159_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (159, 0.10000000000000002, 10, 2)
# {35, 12, 77, 17, 50, 84, 85, 89, 90, 25}
# sim_159_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (159, 1.0, 1, 0.1)
# {3}
# sim_159_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (159, 1.0, 1, 2)
# {34}
# sim_159_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (159, 1.0, 10, 0.1)
# {66, 3, 72, 40, 12, 77, 16, 83, 88, 60}
# sim_159_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (159, 1.0, 10, 2)
# {35, 5, 38, 40, 15, 83, 84, 55, 31, 95}
# sim_159_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (159, 10.0, 1, 0.1)
# {67}
# sim_159_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (159, 10.0, 1, 2)
# {66}
# sim_159_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (159, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {35, 36, 50, 51, 19, 86, 22, 57, 92, 95}
# sim_159_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (159, 10.0, 10, 2)
# {34, 99, 12, 77, 49, 17, 83, 22, 55, 93}
# sim_159_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (160, 0.10000000000000002, 1, 0.1)
# {73}
# sim_160_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (160, 0.10000000000000002, 1, 2)
# {43}
# sim_160_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (160, 0.10000000000000002, 10, 0.1)
# {0, 97, 2, 99, 3, 47, 50, 52, 85, 61}
# sim_160_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (160, 0.10000000000000002, 10, 2)
# {0, 1, 68, 70, 44, 51, 84, 27, 92, 93}
# sim_160_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (160, 1.0, 1, 0.1)
# {72}
# sim_160_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (160, 1.0, 1, 2)
# {52}
# sim_160_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (160, 1.0, 10, 0.1)
# {32, 0, 7, 71, 41, 76, 13, 46, 23, 63}
# sim_160_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (160, 1.0, 10, 2)
# {33, 7, 9, 43, 14, 81, 49, 22, 95, 31}
# sim_160_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (160, 10.0, 1, 0.1)
# {45}
# sim_160_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (160, 10.0, 1, 2)
# {91}
# sim_160_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (160, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {1, 2, 11, 50, 83, 19, 85, 86, 54, 28}
# sim_160_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (160, 10.0, 10, 2)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {1, 4, 69, 6, 73, 52, 21, 24, 59, 29}
# sim_160_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (161, 0.10000000000000002, 1, 0.1)
# {8}
# sim_161_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (161, 0.10000000000000002, 1, 2)
# {48}
# sim_161_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (161, 0.10000000000000002, 10, 0.1)
# {64, 3, 36, 69, 73, 77, 82, 55, 56, 63}
# sim_161_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (161, 0.10000000000000002, 10, 2)
# {70, 75, 15, 50, 19, 83, 20, 22, 87, 56}
# sim_161_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (161, 1.0, 1, 0.1)
# {7}
# sim_161_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (161, 1.0, 1, 2)
# {39}
# sim_161_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (161, 1.0, 10, 0.1)
# {3, 4, 5, 67, 99, 48, 82, 20, 26, 62}
# sim_161_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (161, 1.0, 10, 2)
# {96, 33, 2, 67, 37, 48, 50, 60, 93, 62}
# sim_161_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (161, 10.0, 1, 0.1)
# {82}
# sim_161_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (161, 10.0, 1, 2)
# {45}
# sim_161_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (161, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {0, 99, 40, 41, 74, 81, 50, 22, 55, 61}
# sim_161_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (161, 10.0, 10, 2)
# {2, 98, 36, 43, 16, 82, 88, 25, 61, 31}
# sim_161_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (162, 0.10000000000000002, 1, 0.1)
# {49}
# sim_162_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (162, 0.10000000000000002, 1, 2)
# {70}
# sim_162_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (162, 0.10000000000000002, 10, 0.1)
# {97, 5, 71, 73, 13, 82, 20, 53, 27, 31}
# sim_162_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (162, 0.10000000000000002, 10, 2)
# {99, 38, 7, 79, 81, 87, 25, 26, 91, 92}
# sim_162_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (162, 1.0, 1, 0.1)
# {0}
# sim_162_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (162, 1.0, 1, 2)
# {7}
# sim_162_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (162, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# {0, 33, 69, 71, 39, 7, 76, 19, 27, 63}
# sim_162_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (162, 1.0, 10, 2)
# {32, 35, 5, 38, 39, 82, 85, 54, 91, 29}
# sim_162_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (162, 10.0, 1, 0.1)
# {84}
# sim_162_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (162, 10.0, 1, 2)
# {81}
# sim_162_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (162, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# {32, 34, 3, 6, 7, 72, 77, 79, 82, 28}
# sim_162_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (162, 10.0, 10, 2)
# {32, 69, 71, 9, 77, 14, 78, 50, 57, 58}
# sim_162_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (163, 0.10000000000000002, 1, 0.1)
# {71}
# sim_163_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (163, 0.10000000000000002, 1, 2)
# {6}
# sim_163_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (163, 0.10000000000000002, 10, 0.1)
# {3, 68, 10, 76, 79, 80, 93, 57, 91, 61}
# sim_163_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (163, 0.10000000000000002, 10, 2)
# {96, 39, 8, 76, 45, 50, 30, 24, 62, 63}
# sim_163_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (163, 1.0, 1, 0.1)
# {69}
# sim_163_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (163, 1.0, 1, 2)
# {41}
# sim_163_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (163, 1.0, 10, 0.1)
# {3, 79, 15, 20, 54, 24, 57, 90, 61, 95}
# sim_163_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (163, 1.0, 10, 2)
# {33, 36, 4, 38, 43, 48, 18, 19, 86, 58}
# sim_163_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (163, 10.0, 1, 0.1)
# {84}
# sim_163_p_rew_10_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (163, 10.0, 1, 2)
# {32}
# sim_163_p_rew_10_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (163, 10.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {64, 66, 99, 36, 6, 74, 91, 28, 94, 63}
# sim_163_p_rew_10_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (163, 10.0, 10, 2)
# {0, 96, 7, 74, 14, 16, 48, 21, 88, 62}
# sim_163_p_rew_10_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (164, 0.10000000000000002, 1, 0.1)
# {37}
# sim_164_p_rew_0_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (164, 0.10000000000000002, 1, 2)
# {36}
# sim_164_p_rew_0_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (164, 0.10000000000000002, 10, 0.1)
# {38, 9, 76, 46, 17, 85, 55, 88, 60, 62}
# sim_164_p_rew_0_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (164, 0.10000000000000002, 10, 2)
# {64, 1, 67, 36, 4, 72, 78, 62, 94, 95}
# sim_164_p_rew_0_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (164, 1.0, 1, 0.1)
# {66}
# sim_164_p_rew_1_start_1_dq_1
# (sim,p_rew,start,dose_quantity) =  (164, 1.0, 1, 2)
# {90}
# sim_164_p_rew_1_start_1_dq_20
# (sim,p_rew,start,dose_quantity) =  (164, 1.0, 10, 0.1)
# Initial node infection step failed
# None
# Initial node infection step failed
# None
# {1, 4, 36, 5, 73, 9, 21, 26, 29, 95}
# sim_164_p_rew_1_start_10_dq_1
# (sim,p_rew,start,dose_quantity) =  (164, 1.0, 10, 2)
# {41, 42, 75, 77, 14, 81, 18, 93, 30, 31}
# sim_164_p_rew_1_start_10_dq_20
# (sim,p_rew,start,dose_quantity) =  (164, 10.0, 1, 0.1)
# {38}
# sim_164_p_rew_10_start_1_dq_1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-155-afd607d1b714> in <module>
#     131                 print(key_val)
#     132                 timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
# --> 133                 timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
#     134                 timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
#     135                 timeseries_strong_comps.to_hdf(filename_strong_comps, key = key_val, mode='a')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_hdf(self, path_or_buf, key, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/pytables.py in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/pytables.py in open(self, mode, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/tables/file.py in open_file(filename, mode, title, root_uep, filters, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/tables/file.py in __init__(self, filename, mode, title, root_uep, filters, **kwargs)
#
# tables/hdf5extension.pyx in tables.hdf5extension.File._g_new()
#
# ~/anaconda3/lib/python3.7/site-packages/tables/utils.py in check_file_access(filename, mode)
#
# ~/anaconda3/lib/python3.7/site-packages/tables/utils.py in check_file_access(filename, mode)
#
# ~/anaconda3/lib/python3.7/site-packages/tables/utils.py in check_file_access(filename, mode)
#
# OSError: ``in_deg.h5`` is not a regular file

# %%
# '''time series plot of a fixed start but varying p'''
# a = 4 #this is the value of p-1
# for i in np.arange(0,110,10) : 
#     print(a+i)
#     timeseries_infec_frac.loc[a+i,:].plot()
# plt.ylim(-0.1,1.1)
# # plt.xlim(0,10)
# plt.legend(loc=(1,1))
# plt.show()

# %%
# plt.clf()
# '''time series plot of a fixed p but varying start'''
# a = 40 # this is the value of p
# for i in range(0,11) :
#     timeseries_infec_frac.loc[a+i,:].plot()
# plt.ylim(-0.1,1.1)
# # plt.ylim(-0.01,0.11)
# # plt.xlim(0,2.5)
# plt.legend(loc=(1,1))
# plt.show()

# %%
# start_len = 10
# p_len = 11
# X,Y = np.meshgrid([i*0.01 for i in range(11,21)],[i*0.1 for i in range(0,11)])
# print('X = ', X)
# print('Y = ', Y)
# phi = 999*np.ones((p_len,start_len))
# counter = 0
# last_col = np.int64((T/dt)-1)
# for i in range(p_len) :
#     for j in range(start_len) :
#         phi[i,j] = timeseries_infec_frac.loc[counter,(last_col-100)+1:last_col].mean()
#         counter = counter + 1
# # print(counter)
# print(phi)
# fig = plt.gcf()
# fig.set_size_inches(10, 9)
# plt.scatter(X, Y,s=500,c=phi,vmin=0,vmax=1)
# plt.colorbar()
# plt.xlabel(r'$\phi_{ini}$', fontsize = 20)
# plt.ylabel(r'$p\times dt$', fontsize = 20)
# plt.xlim(0.10,0.21)
# plt.title(r'$\phi^*,p_{rew}=0.5,av_{deg}=9,d=1,d^*=3,\gamma=5,T=N=100,dt=0.1,r=1$',fontsize = 15)
# plt.savefig('static_avdeg_9_ini_0_11.svg',format='svg')
# plt.show()

# %%
# filename = 'file_avdeg_'+str(average_degree)+'_ini_'+str(np.int64(X[0,0]*N))+'_'+str(np.int64(X[p_len-1,start_len-1]*N))+'.h5'
# key 
# timeseries_infec_frac.to_hdf(filename, key='timeseries_infec_frac', mode='w')

# %%
# import h5py
# f = h5py.File('in_deg.h5', 'r')
# [key for key in f.keys()]
# # pd.read_hdf('file_avdeg_6_ini_0_11_firstattemp.h5','p_rew_2')
