# %% [markdown]
# ## Leaky integrated firing neuron model
# ## Few feautures :
# ### Spatial network, no memory term but exponential decay of cumulative dose
#
# This is a minor change of the Dodds and Watts model
# Implement adaptive rewiring and generate statistics

# %%
#importing the required libraries

import networkx as nx
import matplotlib.pyplot as plt #for plotting
import numpy as np #for using arrays and vectorising the code wherever possible
import scipy
import random
# from numba import jit #numba precomplier to make the code faster
import pandas as pd
import copy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Variables used in the simulation

# %%
N = 100
gamma = 1 #decay of cumulative dose per unit time (second)
gamma = gamma
T = 100 #total number of seconds
dt = 0.05 #seconds
'''number of simulation steps is T/dt'''

'''Dodds watts parameters'''
p = 1 #rate of dose transfer (per unit time (second))
p = p*dt #rate of dose transfer per unit simulation step
r = 1/dt
r = r*dt
rho = 1/dt
rho = rho*dt
# r = 0.5
# r = r*dt

d_star = 1
# dose_quantity = 1
D_ini = 3

'''network parameters'''
circ_rad = 100 #for a network in which each node is connected to other nodes withing a circle of radius circ_rad
nn = 7 #the number of nearest neighbours(i.e. k) in knn
average_degree = 6
total_edges = N*2

'''rewiring parameters'''
# p_rew = 5 #rate of rewiring(per unit time(second))
# p_rew = p_rew*dt
# Out:
# 'rewiring parameters'

# %% [markdown]
# # Creating the network.
# ### The network outputs coordinates, distance matrix, edge_list and adjacency matrix

# %%
'''
obtains the number of nodes N
generates N points
calculates euclidean distance between each pair of points
returns the coordinates of the points and the distance matrix which is N*N
'''
def calc_dist(N) :
    coords = []
    for counter in range(N) :
        coords.append((N*np.random.random(),N*np.random.random()))

    dist_mat = scipy.spatial.distance.cdist(coords,coords)
    return dist_mat,coords

# %% [markdown]
# ### 1. metric network

# %%
'''network = connect to points withing a circle of radius'''
#creates a link between points/nodes which satisfies the conditions of the network
def coupling(dist_mat,circ_rad) :
    edge_list = []
    edge_mask = (dist_mat<circ_rad) & (dist_mat>0)
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(edge_mask))))
#     print(type(np.ndarray.tolist(np.transpose(np.where(edge_mask)))))
    return edge_list

# %% [markdown]
# ### 2. K nearest neighbour network

# %%
'''network = knn'''
def knn(dist_mat,nn,N) :
    near_neigh = np.argsort(dist_mat)
    selec_near_neigh = np.zeros((N,nn))
    selec_near_neigh = near_neigh[:,0:nn+1]

    edge_list = []
    for i in range(N) :
        for j in range(1,nn+1) :
            link = [i,selec_near_neigh[i,j]]
            edge_list.append(link)

    return edge_list

# %% [markdown]
# ### 3. Random Network : GNP type

# %%
'''random network'''
def rand_network(average_degree,N) :
    z1 = np.random.uniform(size = (N,N))
    E,F = np.meshgrid(np.arange(0,N),np.arange(0,N))
    mask = ((average_degree/N) > z1) & (E!=F)
    adjacency_matrix = np.int64(np.zeros(shape=(N,N)))
    adjacency_matrix[mask] = np.int64(1)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list,adjacency_matrix

# %% [markdown]
# ### 4. Random Network : GNM type

# %%
def rand_net_gnm(total_edges,N) :
    the_graph = nx.gnm_random_graph(N, total_edges,directed=True)
    adjacency_matrix = nx.adjacency_matrix(the_graph)
    adjacency_matrix = np.asarray(adjacency_matrix.todense())
    np.fill_diagonal(adjacency_matrix,0)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list

# %% [markdown]
# # Function defintions required for the main part of the script

# %%
# # @jit(nopython=True)
# '''infecting the left part of space.'''
# def left_part_infec(N) :
#     x_coord = []
#     y_coord = []
#     for j in range(len(coords)) :
#         x_coord.append(coords[j][0])
#         y_coord.append(coords[j][1])
#     x_coord = np.asarray(x_coord)
#     y_coord = np.asarray(y_coord)
#     points = np.asarray(np.where(x_coord<(N/5))) 
#     indi_state[points.T] = 2

#     return indi_state

# %%
'''infecting connected nodes'''
def InfectNetworkNeighbors(net,seed_node,init_infected_nodes):
     # if in bulk find one node randomly, and infect its neighbours
    infected_nodes = set()
    candidate_nodes = set()
    explored_nodes = set()

    #pick the seed node
    infected_nodes.add(seed_node)
    explored_nodes.add(seed_node)

    curr_node=seed_node

    #add its neighbors to the list of candidates
    for n in net.neighbors(curr_node):
        candidate_nodes.add(int(n))
    #print( curr_node)
    #print( candidate_nodes)

    #while we need to select more nodes...
    while len(infected_nodes) < init_infected_nodes:

        #if there are candidate nodes, select one of them
        if(len(candidate_nodes) > 0):
            new_node = np.random.choice(list(candidate_nodes),1)[0]
            infected_nodes.add(new_node)
            candidate_nodes.remove(new_node)

        elif len(infected_nodes - explored_nodes) > 0:
            curr_node = np.random.choice(list(infected_nodes -
            explored_nodes),1)[0]
            explored_nodes.add(curr_node)
            for n in set(net.neighbors(curr_node)) - infected_nodes:
                candidate_nodes.add(n)

        else:
#             print('Initial node infection step failed')
            return None
    return infected_nodes

# %%
''' function to transfer doses'''
# @jit(nopython=True)
def dose(adj_mat,p,partner_state_prev,d) :

    z1 = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    dose_transfer_mask = p > z1
    mod_adj_mat = np.multiply(adj_mat,z1) #modifying adjacency matrix to include the proability of dose transfer
    dose_mask = (p>mod_adj_mat) & (adj_mat!=0) & (partner_state_prev == 2)
    d[dose_mask] = dose_quantity #whenever it is proabable, dose transfer occurs
    
    return d

# %%
def rew(p_rew,adjacency_matrix,indi_state_for_rew_prev,OD_mesh2,lamb_da) :
    
    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew > z1_rew_prew)  & (indi_state_for_rew_prev == 1)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    rew_mask_minus1 = (p_rew > z1_rew_prew) & (indi_state_for_rew_prev == 2)
    #break links. Dont create any.
    adjacency_matrix[rew_mask_minus1] = 0
    rew_mask_minus2 = ((lamb_da*OD_mesh2) > z1_rew_lambda) & (indi_state_for_rew_prev == 1)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
'''function to update cumulative doses'''
def cumu_dose(d,D_prev,gamma) :
    I = d.sum(axis=1).reshape(N,1)
#     I = 0
    D = (D_prev - (gamma*D_prev*dt)) + I
    return D

# %%
'''function to update the states of the nodes of the system'''
def upd_indi_state(D,d_star,indi_state_prev) :
    
    z2 = np.random.uniform(size=(N,1))
    z3 = np.random.uniform(size=(N,1))
    
    indi_state = indi_state_prev
    
    indi_state_mask1 = (D>=d_star) & (indi_state_prev==1)
    indi_state[indi_state_mask1] = 2
    
    indi_state_mask21 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho>=z3)
    indi_state[indi_state_mask21] = 1
    
    indi_state_mask22 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho<z3)
    indi_state[indi_state_mask22] = 3
    
    indi_state_mask23 = (D<d_star) & (indi_state_prev==2) & (r<z2)
    indi_state[indi_state_mask23] = 2
    
    return indi_state

# %%
'''function to get/identify the infected nodes and the suceptible nodes'''
def states(indi_state) :
    infec_indi = []
    suscep_indi = []
    infec_indi = np.transpose(np.where(indi_state==2))
    suscep_indi = np.transpose(np.where(indi_state==1))
    return infec_indi,suscep_indi

# %%
def networkx_graph(coords,edge_list) :
    G = nx.DiGraph()
    pos = {(i): (coords[i][0],coords[i][1]) for i in range(N)}
    G.add_nodes_from(pos.keys())
    G.add_edges_from(edge_list)
    return G

# %%
def edge_from_adj_mat(adj_mat_list,q):
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adj_mat_list[q]==1))))
    return edge_list

# %% [markdown]
# # Choose which network you want in the program
# ### Coupling network of knn network?

# %%
# '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''

# dist_mat,coords = calc_dist(N) #node placement

# # edge_list = coupling(dist_mat,circ_rad)
# # edge_list = knn(dist_mat,nn,N)
# # edge_list = rand_network(average_degree,N)
# edge_list = rand_net_gnm(total_edges,N)

# org_adj_mat = np.int64(np.zeros((N,N)))
# for i in range(len(edge_list)):
#     org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)

# %% [markdown]
# # The main part of the script

# %%
#infected state time series data frame
#columns indicate the time steps
timeseries_infec_frac = pd.DataFrame()

#in degree as columns and rows as nodes
timeseries_in_degree = pd.DataFrame() 

#out degree as columns and rows as nodes
timeseries_out_degree = pd.DataFrame()

#strongly connected components as columns
timeseries_connec_comps = pd.DataFrame()

# %%
p_rew_vals = [0.01,0.1,1,10]
start_vals = [1,10]
dose_quantity_vals = [0.5,2]

# %%
for sim in range(70,70+50) :
    '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''
    dist_mat,coords = calc_dist(N) #node placement
    edge_list = rand_net_gnm(total_edges,N)
    org_adj_mat = np.int64(np.zeros((N,N)))
    for i in range(len(edge_list)):
        org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)
        
    df_row = 0
    for p_rew in p_rew_vals : #rate of rewiring (per unit time (second))
        lamb_da = p_rew/10
        lamb_da = lamb_da*dt
        p_rew = p_rew*dt
        for start in start_vals : #rate of dose transfer (per unit time (second))
            for dose_quantity in dose_quantity_vals : #number of nodes to infect initially
                print('(sim,lamb_da,p_rew,start,dose_quantity) = ', (sim,lamb_da/dt,p_rew/dt,start,dose_quantity))

                '''clearing exsiting data frames and creating new ones '''
                timeseries_infec_frac = pd.DataFrame()
                timeseries_in_degree = pd.DataFrame()
                timeseries_out_degree = pd.DataFrame()
                timeseries_connec_comps = pd.DataFrame()

                q = 0 #to generate new edge_list from the new adjacency matrix 
                t = np.arange(0,T,dt)

    #             numpy_array = np.zeros((N,len(t)),dtype = np.int64) #stores the states of the nodes. Rows are nodes and columns are time steps
                D_array = np.zeros((N,len(t))) #stores the cumulative doses. Rows are nodes and columns are time steps

                adj_mat_list = []
                adj_mat = copy.deepcopy(org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new) #list of arrays which shows the time series of the adjacency matrix

                #coords remain the same. Get new edge_list from the latest adjacency matrix
                edge_list = edge_from_adj_mat(adj_mat_list,q)
                G = networkx_graph(coords,edge_list) #networkx graph

                '''from G, obtain the in degree and the out degree'''
                timeseries_in_degree.loc[:,0] = np.asarray([val for (node, val) in G.in_degree()])
                timeseries_out_degree.loc[:,0] = np.asarray([val for (node, val) in G.out_degree()])

                '''strongly and weekely connected components'''
                timeseries_connec_comps.loc[0,0] = nx.number_connected_components(G.to_undirected())

                '''choosing initially infected nodes'''
                indi_state = np.random.randint(1,2,size=(N,1))
                infected_nodes = None
                while infected_nodes is None : #infecting 'start' number of network neighbours
                    infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)      
                print(infected_nodes)
                infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
                indi_state[infected_nodes[:,0],0] = 2

                A,B = np.meshgrid(indi_state,indi_state) 
                partner_state = A
                indi_state_for_rew = B

    #             numpy_array [:,0] = indi_state[:,0]

                indi_state_prev = indi_state
                partner_state_prev = partner_state
                indi_state_for_rew_prev = indi_state_for_rew

                d = np.zeros((len(adj_mat),len(adj_mat[0])))

                D = np.zeros((N,1))
                D[np.where(indi_state==2)] = D_ini
                D_array[:,0] = D[:,0]
                D_prev = D

                infec_frac = np.count_nonzero(indi_state == 2)/N
                timeseries_infec_frac.loc[df_row,0] = infec_frac
                '''the main part of the simulation'''
                counter = 0
                df_col = 1
                for t in np.arange(dt,T,dt) :
                    q = q + 1 
                    counter = counter + 1
                    infec_indi = []
                    suscep_indi = []
                    d = np.zeros((len(adj_mat),len(adj_mat[0])))
                    d = dose(adj_mat,p,partner_state_prev,d)

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)
                    adj_mat = rew(p_rew,adj_mat,indi_state_for_rew_prev,OD_mesh2,lamb_da)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    '''from G, obtain the in degree and the out degree'''
                    timeseries_in_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.in_degree()])
                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])

                    '''strongly and weekely connected components'''
                    timeseries_connec_comps.loc[df_row,df_col] = nx.number_connected_components(G.to_undirected())

                    D = cumu_dose(d,D_prev,gamma)
                    D_array[:,counter] = D[:,0]

                    indi_state = upd_indi_state(D,d_star,indi_state_prev)
                    infec_frac = np.count_nonzero(indi_state == 2)/N
                    timeseries_infec_frac.loc[df_row,df_col] = infec_frac

    #                 numpy_array[:,counter] = indi_state[:,0]
                    A,B = np.meshgrid(indi_state,indi_state)

                    infec_indi, suscep_indi = states(indi_state)

                    partner_state = A
                    indi_state_for_rew = B
                    indi_state_prev = indi_state
                    partner_state_prev = partner_state
                    indi_state_for_rew_prev = indi_state_for_rew

                    D_prev = D
                    D = np.zeros((N,1))
                    df_col = df_col + 1 

    #             df_row = df_row + 1 #going to the next row of the df to store timeseries of next (p,start)

                filename_infec_frac = 'infec_frac.h5'
                filename_in_deg = 'in_deg.h5'
                filename_out_deg = 'out_deg.h5'
                filename_connec_comps = 'connec_comps.h5'
                p_rew_val = '%g'%(p_rew/dt)
                key_val = 'sim_'+str(sim)+'_p_rew_'+str(p_rew_val)+'_start_'+str(start)+'_dq_'+str(dose_quantity)
#                 print(key_val)
                timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
                timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
                timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
                timeseries_connec_comps.to_hdf(filename_connec_comps, key = key_val, mode='a')
                df_row = 0
# Out:
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.001, 0.01, 1, 0.5)
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.001, 0.01, 1, 2)
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.001, 0.01, 10, 0.5)
# {34, 8, 9, 15, 81, 49, 19, 22, 23, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.001, 0.01, 10, 2)
# {32, 3, 35, 36, 73, 10, 47, 86, 25, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.01, 0.10000000000000002, 1, 0.5)
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.01, 0.10000000000000002, 1, 2)
# {97}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.01, 0.10000000000000002, 10, 0.5)
# {64, 97, 40, 78, 82, 52, 53, 86, 57, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.01, 0.10000000000000002, 10, 2)
# {66, 99, 43, 14, 47, 15, 83, 19, 91, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.10000000000000002, 1.0, 1, 0.5)
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.10000000000000002, 1.0, 1, 2)
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.10000000000000002, 1.0, 10, 0.5)
# {96, 1, 98, 3, 46, 49, 83, 90, 59, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.10000000000000002, 1.0, 10, 2)
# {2, 69, 73, 41, 15, 48, 49, 19, 55, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 1.0, 10.0, 1, 0.5)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 1.0, 10.0, 1, 2)
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 1.0, 10.0, 10, 0.5)
# {34, 48, 50, 19, 22, 23, 59, 60, 29, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 1.0, 10.0, 10, 2)
# {99, 4, 8, 9, 15, 49, 81, 22, 87, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.001, 0.01, 1, 0.5)
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.001, 0.01, 1, 2)
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.001, 0.01, 10, 0.5)
# {65, 66, 98, 73, 14, 50, 85, 22, 55, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.001, 0.01, 10, 2)
# {32, 65, 96, 98, 73, 50, 55, 22, 23, 21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.01, 0.10000000000000002, 1, 0.5)
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.01, 0.10000000000000002, 1, 2)
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.01, 0.10000000000000002, 10, 0.5)
# {65, 66, 73, 75, 60, 85, 22, 55, 92, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.01, 0.10000000000000002, 10, 2)
# {65, 66, 98, 73, 50, 85, 22, 55, 21, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.10000000000000002, 1.0, 1, 0.5)
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.10000000000000002, 1.0, 1, 2)
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.10000000000000002, 1.0, 10, 0.5)
# {3, 4, 69, 7, 27, 10, 76, 58, 59, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.10000000000000002, 1.0, 10, 2)
# {4, 36, 75, 44, 47, 49, 24, 57, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 1.0, 10.0, 1, 0.5)
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 1.0, 10.0, 1, 2)
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 1.0, 10.0, 10, 0.5)
# {96, 65, 98, 73, 77, 50, 21, 22, 56, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 1.0, 10.0, 10, 2)
# {65, 39, 88, 73, 77, 49, 18, 56, 91, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.001, 0.01, 1, 0.5)
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.001, 0.01, 1, 2)
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.001, 0.01, 10, 0.5)
# {41, 10, 43, 44, 42, 46, 15, 80, 23, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.001, 0.01, 10, 2)
# {71, 47, 16, 83, 20, 53, 86, 88, 27, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.01, 0.10000000000000002, 1, 0.5)
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.01, 0.10000000000000002, 1, 2)
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.01, 0.10000000000000002, 10, 0.5)
# {97, 68, 73, 41, 11, 9, 48, 50, 88, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.01, 0.10000000000000002, 10, 2)
# {0, 1, 34, 96, 67, 42, 43, 84, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.10000000000000002, 1.0, 1, 0.5)
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.10000000000000002, 1.0, 1, 2)
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.10000000000000002, 1.0, 10, 0.5)
# {66, 37, 9, 74, 11, 44, 41, 46, 15, 80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.10000000000000002, 1.0, 10, 2)
# {35, 71, 47, 83, 20, 53, 22, 54, 27, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 1.0, 10.0, 1, 0.5)
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 1.0, 10.0, 1, 2)
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 1.0, 10.0, 10, 0.5)
# {97, 68, 8, 73, 11, 48, 50, 88, 90, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 1.0, 10.0, 10, 2)
# {71, 76, 46, 47, 20, 53, 54, 86, 87, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.001, 0.01, 1, 0.5)
# {91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.001, 0.01, 1, 2)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.001, 0.01, 10, 0.5)
# {33, 36, 68, 72, 43, 77, 87, 23, 24, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.001, 0.01, 10, 2)
# {97, 1, 99, 11, 78, 79, 82, 87, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.01, 0.10000000000000002, 1, 0.5)
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.01, 0.10000000000000002, 1, 2)
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.01, 0.10000000000000002, 10, 0.5)
# {96, 42, 77, 46, 78, 82, 52, 25, 27, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.01, 0.10000000000000002, 10, 2)
# {98, 99, 66, 36, 67, 75, 45, 80, 17, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.10000000000000002, 1.0, 1, 0.5)
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.10000000000000002, 1.0, 1, 2)
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.10000000000000002, 1.0, 10, 0.5)
# {33, 68, 72, 43, 77, 16, 18, 23, 87, 24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.10000000000000002, 1.0, 10, 2)
# {34, 42, 10, 74, 77, 78, 52, 25, 27, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 1.0, 10.0, 1, 0.5)
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 1.0, 10.0, 1, 2)
# {91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 1.0, 10.0, 10, 0.5)
# {66, 67, 36, 39, 72, 73, 45, 81, 21, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 1.0, 10.0, 10, 2)
# {99, 58, 9, 47, 48, 81, 18, 19, 90, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.001, 0.01, 1, 0.5)
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.001, 0.01, 1, 2)
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.001, 0.01, 10, 0.5)
# {99, 73, 10, 9, 42, 46, 82, 23, 60, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.001, 0.01, 10, 2)
# {2, 99, 58, 71, 42, 46, 82, 20, 90, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.01, 0.10000000000000002, 1, 0.5)
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.01, 0.10000000000000002, 1, 2)
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.01, 0.10000000000000002, 10, 0.5)
# {98, 58, 6, 11, 13, 77, 54, 24, 26, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.01, 0.10000000000000002, 10, 2)
# {71, 72, 9, 73, 46, 20, 90, 27, 63, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.10000000000000002, 1.0, 1, 0.5)
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.10000000000000002, 1.0, 1, 2)
# {50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.10000000000000002, 1.0, 10, 0.5)
# {97, 5, 41, 43, 77, 49, 84, 93, 88, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.10000000000000002, 1.0, 10, 2)
# {2, 37, 8, 11, 13, 77, 50, 20, 54, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 1.0, 10.0, 1, 0.5)
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 1.0, 10.0, 1, 2)
# {90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 1.0, 10.0, 10, 0.5)
# {64, 67, 36, 90, 71, 11, 14, 16, 58, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 1.0, 10.0, 10, 2)
# {3, 70, 40, 73, 60, 46, 89, 92, 95, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.001, 0.01, 1, 0.5)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.001, 0.01, 1, 2)
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.001, 0.01, 10, 0.5)
# {35, 70, 39, 7, 74, 44, 17, 52, 22, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.001, 0.01, 10, 2)
# {2, 39, 40, 43, 49, 54, 55, 26, 27, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.01, 0.10000000000000002, 1, 0.5)
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.01, 0.10000000000000002, 1, 2)
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.01, 0.10000000000000002, 10, 0.5)
# {34, 35, 3, 39, 76, 44, 17, 52, 53, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.01, 0.10000000000000002, 10, 2)
# {67, 36, 40, 8, 46, 84, 21, 24, 27, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.10000000000000002, 1.0, 1, 0.5)
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.10000000000000002, 1.0, 1, 2)
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.10000000000000002, 1.0, 10, 0.5)
# {0, 73, 9, 75, 11, 29, 51, 90, 61, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.10000000000000002, 1.0, 10, 2)
# {3, 37, 17, 82, 20, 52, 86, 26, 28, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 1.0, 10.0, 1, 0.5)
# {99}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 1.0, 10.0, 1, 2)
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 1.0, 10.0, 10, 0.5)
# {1, 2, 69, 41, 43, 77, 47, 55, 26, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 1.0, 10.0, 10, 2)
# {2, 7, 40, 43, 45, 49, 54, 55, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.001, 0.01, 1, 0.5)
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.001, 0.01, 1, 2)
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.001, 0.01, 10, 0.5)
# {65, 37, 40, 41, 76, 52, 20, 92, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.001, 0.01, 10, 2)
# {64, 68, 71, 9, 76, 52, 20, 21, 90, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.01, 0.10000000000000002, 1, 0.5)
# {22}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.01, 0.10000000000000002, 1, 2)
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.01, 0.10000000000000002, 10, 0.5)
# {97, 98, 1, 4, 5, 8, 29, 83, 93, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.01, 0.10000000000000002, 10, 2)
# {97, 67, 69, 10, 12, 13, 46, 53, 58, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.10000000000000002, 1.0, 1, 0.5)
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.10000000000000002, 1.0, 1, 2)
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.10000000000000002, 1.0, 10, 0.5)
# {96, 67, 68, 76, 20, 56, 25, 26, 91, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.10000000000000002, 1.0, 10, 2)
# {2, 35, 73, 76, 18, 85, 86, 90, 59, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 1.0, 10.0, 1, 0.5)
# {7}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 1.0, 10.0, 1, 2)
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 1.0, 10.0, 10, 0.5)
# {97, 1, 8, 76, 16, 18, 23, 89, 26, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 1.0, 10.0, 10, 2)
# {0, 2, 35, 73, 45, 18, 84, 86, 90, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.001, 0.01, 1, 0.5)
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.001, 0.01, 1, 2)
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.001, 0.01, 10, 0.5)
# {0, 33, 32, 42, 74, 13, 46, 78, 22, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.001, 0.01, 10, 2)
# {32, 10, 42, 14, 46, 78, 19, 84, 22, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.01, 0.10000000000000002, 1, 0.5)
# {92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.01, 0.10000000000000002, 1, 2)
# {22}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.01, 0.10000000000000002, 10, 0.5)
# {3, 36, 58, 8, 11, 13, 45, 21, 57, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.01, 0.10000000000000002, 10, 2)
# {68, 36, 71, 81, 49, 83, 21, 23, 60, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.10000000000000002, 1.0, 1, 0.5)
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.10000000000000002, 1.0, 1, 2)
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.10000000000000002, 1.0, 10, 0.5)
# {34, 3, 2, 4, 7, 43, 75, 46, 22, 24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.10000000000000002, 1.0, 10, 2)
# {36, 68, 71, 7, 81, 49, 83, 52, 50, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 1.0, 10.0, 1, 0.5)
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 1.0, 10.0, 1, 2)
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 1.0, 10.0, 10, 0.5)
# {1, 34, 68, 37, 6, 39, 46, 81, 20, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 1.0, 10.0, 10, 2)
# {36, 9, 74, 77, 78, 19, 22, 23, 29, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.001, 0.01, 1, 0.5)
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.001, 0.01, 1, 2)
# {98}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.001, 0.01, 10, 0.5)
# {0, 65, 1, 34, 40, 79, 20, 54, 88, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.001, 0.01, 10, 2)
# {34, 38, 8, 11, 44, 45, 79, 47, 24, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.01, 0.10000000000000002, 1, 0.5)
# {93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.01, 0.10000000000000002, 1, 2)
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.01, 0.10000000000000002, 10, 0.5)
# {96, 34, 69, 38, 11, 44, 84, 55, 24, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.01, 0.10000000000000002, 10, 2)
# {96, 69, 6, 7, 13, 19, 84, 24, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.10000000000000002, 1.0, 1, 0.5)
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.10000000000000002, 1.0, 1, 2)
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.10000000000000002, 1.0, 10, 0.5)
# {0, 97, 69, 73, 76, 52, 87, 25, 91, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.10000000000000002, 1.0, 10, 2)
# {0, 97, 73, 76, 48, 52, 87, 25, 91, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 1.0, 10.0, 1, 0.5)
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 1.0, 10.0, 1, 2)
# {34}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 1.0, 10.0, 10, 0.5)
# {1, 10, 11, 42, 13, 47, 17, 27, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 1.0, 10.0, 10, 2)
# {69, 6, 43, 11, 45, 13, 47, 84, 24, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.001, 0.01, 1, 0.5)
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.001, 0.01, 1, 2)
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.001, 0.01, 10, 0.5)
# {66, 98, 76, 78, 14, 47, 51, 83, 52, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.001, 0.01, 10, 2)
# {1, 99, 5, 42, 79, 16, 17, 21, 88, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.01, 0.10000000000000002, 1, 0.5)
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.01, 0.10000000000000002, 1, 2)
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.01, 0.10000000000000002, 10, 0.5)
# {2, 98, 68, 43, 12, 15, 81, 50, 58, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.01, 0.10000000000000002, 10, 2)
# {66, 40, 78, 79, 83, 51, 56, 26, 59, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.10000000000000002, 1.0, 1, 0.5)
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.10000000000000002, 1.0, 1, 2)
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.10000000000000002, 1.0, 10, 0.5)
# {65, 2, 75, 12, 77, 45, 19, 58, 28, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.10000000000000002, 1.0, 10, 2)
# {34, 5, 69, 17, 53, 22, 86, 57, 91, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 1.0, 10.0, 1, 0.5)
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 1.0, 10.0, 1, 2)
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 1.0, 10.0, 10, 0.5)
# {33, 68, 69, 5, 7, 72, 17, 89, 58, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 1.0, 10.0, 10, 2)
# {98, 2, 75, 12, 15, 81, 49, 58, 61, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.001, 0.01, 1, 0.5)
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.001, 0.01, 1, 2)
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.001, 0.01, 10, 0.5)
# {97, 67, 38, 42, 12, 45, 78, 79, 84, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.001, 0.01, 10, 2)
# {34, 99, 35, 73, 75, 17, 50, 22, 24, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.01, 0.10000000000000002, 1, 0.5)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.01, 0.10000000000000002, 1, 2)
# {55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.01, 0.10000000000000002, 10, 0.5)
# {64, 72, 75, 12, 15, 85, 57, 26, 59, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.01, 0.10000000000000002, 10, 2)
# {39, 72, 12, 82, 85, 23, 25, 26, 59, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.10000000000000002, 1.0, 1, 0.5)
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.10000000000000002, 1.0, 1, 2)
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.10000000000000002, 1.0, 10, 0.5)
# {68, 70, 50, 29, 86, 62, 91, 93, 94, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.10000000000000002, 1.0, 10, 2)
# {66, 35, 67, 38, 72, 42, 15, 18, 53, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 1.0, 10.0, 1, 0.5)
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 1.0, 10.0, 1, 2)
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 1.0, 10.0, 10, 0.5)
# {66, 35, 67, 72, 73, 42, 13, 15, 53, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 1.0, 10.0, 10, 2)
# {35, 99, 12, 48, 17, 52, 54, 55, 56, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.001, 0.01, 1, 0.5)
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.001, 0.01, 1, 2)
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.001, 0.01, 10, 0.5)
# {96, 35, 5, 8, 74, 13, 50, 24, 29, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.001, 0.01, 10, 2)
# {64, 34, 2, 72, 9, 75, 49, 84, 88, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.01, 0.10000000000000002, 1, 0.5)
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.01, 0.10000000000000002, 1, 2)
# {93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.01, 0.10000000000000002, 10, 0.5)
# {33, 7, 45, 80, 17, 88, 89, 59, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.01, 0.10000000000000002, 10, 2)
# {64, 43, 44, 45, 50, 55, 24, 26, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.10000000000000002, 1.0, 1, 0.5)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.10000000000000002, 1.0, 1, 2)
# {51}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.10000000000000002, 1.0, 10, 0.5)
# {71, 74, 42, 44, 13, 18, 52, 23, 87, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.10000000000000002, 1.0, 10, 2)
# {2, 66, 38, 71, 12, 44, 83, 20, 23, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 1.0, 10.0, 1, 0.5)
# {97}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 1.0, 10.0, 1, 2)
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 1.0, 10.0, 10, 0.5)
# {96, 68, 44, 47, 15, 82, 83, 50, 87, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 1.0, 10.0, 10, 2)
# {2, 38, 71, 12, 44, 81, 83, 23, 91, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.001, 0.01, 1, 0.5)
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.001, 0.01, 1, 2)
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.001, 0.01, 10, 0.5)
# {96, 34, 11, 46, 49, 17, 83, 22, 24, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.001, 0.01, 10, 2)
# {1, 2, 7, 8, 74, 44, 52, 55, 26, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.01, 0.10000000000000002, 1, 0.5)
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.01, 0.10000000000000002, 1, 2)
# {90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.01, 0.10000000000000002, 10, 0.5)
# {1, 70, 43, 81, 51, 20, 86, 87, 25, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.01, 0.10000000000000002, 10, 2)
# {34, 41, 11, 49, 17, 83, 21, 22, 24, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.10000000000000002, 1.0, 1, 0.5)
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.10000000000000002, 1.0, 1, 2)
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.10000000000000002, 1.0, 10, 0.5)
# {1, 70, 7, 8, 80, 81, 20, 52, 25, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.10000000000000002, 1.0, 10, 2)
# {65, 34, 99, 66, 71, 72, 41, 40, 21, 54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 1.0, 10.0, 1, 0.5)
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 1.0, 10.0, 1, 2)
# {25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 1.0, 10.0, 10, 0.5)
# {4, 11, 46, 17, 49, 83, 22, 24, 89, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 1.0, 10.0, 10, 2)
# {98, 36, 72, 74, 44, 76, 47, 48, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.001, 0.01, 1, 0.5)
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.001, 0.01, 1, 2)
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.001, 0.01, 10, 0.5)
# {32, 34, 71, 10, 42, 51, 22, 24, 56, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.001, 0.01, 10, 2)
# {0, 99, 38, 7, 74, 49, 22, 23, 57, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.01, 0.10000000000000002, 1, 0.5)
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.01, 0.10000000000000002, 1, 2)
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.01, 0.10000000000000002, 10, 0.5)
# {69, 37, 10, 18, 51, 52, 85, 53, 59, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.01, 0.10000000000000002, 10, 2)
# {0, 5, 7, 74, 42, 80, 49, 50, 23, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.10000000000000002, 1.0, 1, 0.5)
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.10000000000000002, 1.0, 1, 2)
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.10000000000000002, 1.0, 10, 0.5)
# {96, 3, 37, 12, 15, 79, 19, 52, 53, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.10000000000000002, 1.0, 10, 2)
# {96, 41, 42, 51, 20, 21, 87, 88, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 1.0, 10.0, 1, 0.5)
# {47}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 1.0, 10.0, 1, 2)
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 1.0, 10.0, 10, 0.5)
# {65, 68, 36, 73, 75, 14, 23, 55, 29, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 1.0, 10.0, 10, 2)
# {96, 51, 20, 21, 85, 88, 27, 31, 93, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.001, 0.01, 1, 0.5)
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.001, 0.01, 1, 2)
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.001, 0.01, 10, 0.5)
# {97, 1, 73, 10, 77, 18, 19, 55, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.001, 0.01, 10, 2)
# {66, 35, 2, 37, 77, 49, 84, 53, 26, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.01, 0.10000000000000002, 1, 0.5)
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.01, 0.10000000000000002, 1, 2)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.01, 0.10000000000000002, 10, 0.5)
# {0, 99, 72, 9, 15, 50, 18, 52, 55, 24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.01, 0.10000000000000002, 10, 2)
# {67, 69, 7, 46, 15, 87, 55, 57, 91, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.10000000000000002, 1.0, 1, 0.5)
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.10000000000000002, 1.0, 1, 2)
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.10000000000000002, 1.0, 10, 0.5)
# {64, 66, 39, 9, 82, 50, 52, 22, 55, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.10000000000000002, 1.0, 10, 2)
# {66, 2, 37, 77, 16, 49, 84, 53, 26, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 1.0, 10.0, 1, 0.5)
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 1.0, 10.0, 1, 2)
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 1.0, 10.0, 10, 0.5)
# {0, 68, 5, 7, 76, 78, 79, 19, 83, 22}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 1.0, 10.0, 10, 2)
# {5, 48, 80, 18, 19, 51, 57, 58, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.001, 0.01, 1, 0.5)
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.001, 0.01, 1, 2)
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.001, 0.01, 10, 0.5)
# {98, 35, 73, 13, 28, 16, 86, 55, 59, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.001, 0.01, 10, 2)
# {65, 68, 5, 74, 46, 82, 18, 52, 88, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.01, 0.10000000000000002, 1, 0.5)
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.01, 0.10000000000000002, 1, 2)
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.01, 0.10000000000000002, 10, 0.5)
# {65, 7, 71, 8, 15, 50, 52, 25, 58, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.01, 0.10000000000000002, 10, 2)
# {96, 36, 5, 73, 13, 28, 60, 16, 56, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.10000000000000002, 1.0, 1, 0.5)
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.10000000000000002, 1.0, 1, 2)
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.10000000000000002, 1.0, 10, 0.5)
# {1, 5, 73, 49, 20, 55, 57, 92, 29, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.10000000000000002, 1.0, 10, 2)
# {6, 76, 44, 49, 84, 53, 26, 31, 29, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 1.0, 10.0, 1, 0.5)
# {55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 1.0, 10.0, 1, 2)
# {11}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 1.0, 10.0, 10, 0.5)
# {36, 6, 76, 49, 84, 53, 20, 26, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 1.0, 10.0, 10, 2)
# {96, 5, 73, 13, 81, 49, 55, 56, 92, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.001, 0.01, 1, 0.5)
# {50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.001, 0.01, 1, 2)
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.001, 0.01, 10, 0.5)
# {1, 66, 72, 9, 74, 46, 85, 22, 62, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.001, 0.01, 10, 2)
# {99, 69, 6, 9, 77, 79, 80, 16, 83, 55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.01, 0.10000000000000002, 1, 0.5)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.01, 0.10000000000000002, 1, 2)
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.01, 0.10000000000000002, 10, 0.5)
# {32, 34, 3, 38, 71, 15, 82, 51, 20, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.01, 0.10000000000000002, 10, 2)
# {34, 2, 5, 70, 31, 18, 94, 92, 30, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.10000000000000002, 1.0, 1, 0.5)
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.10000000000000002, 1.0, 1, 2)
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.10000000000000002, 1.0, 10, 0.5)
# {71, 8, 77, 14, 15, 82, 51, 84, 20, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.10000000000000002, 1.0, 10, 2)
# {34, 2, 6, 71, 70, 44, 77, 18, 20, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 1.0, 10.0, 1, 0.5)
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 1.0, 10.0, 1, 2)
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 1.0, 10.0, 10, 0.5)
# {34, 2, 6, 71, 44, 77, 47, 20, 85, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 1.0, 10.0, 10, 2)
# {34, 71, 44, 77, 82, 20, 94, 57, 90, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.001, 0.01, 1, 0.5)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.001, 0.01, 1, 2)
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.001, 0.01, 10, 0.5)
# {32, 26, 68, 39, 71, 74, 77, 80, 18, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.001, 0.01, 10, 2)
# {38, 75, 11, 82, 19, 20, 62, 92, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.01, 0.10000000000000002, 1, 0.5)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.01, 0.10000000000000002, 1, 2)
# {99}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.01, 0.10000000000000002, 10, 0.5)
# {67, 36, 69, 39, 43, 44, 52, 56, 58, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.01, 0.10000000000000002, 10, 2)
# {34, 69, 6, 39, 46, 15, 78, 57, 27, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.10000000000000002, 1.0, 1, 0.5)
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.10000000000000002, 1.0, 1, 2)
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.10000000000000002, 1.0, 10, 0.5)
# {96, 40, 41, 9, 77, 15, 16, 56, 89, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.10000000000000002, 1.0, 10, 2)
# {97, 40, 44, 18, 82, 56, 58, 31, 62, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 1.0, 10.0, 1, 0.5)
# {25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 1.0, 10.0, 1, 2)
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 1.0, 10.0, 10, 0.5)
# {38, 41, 11, 47, 19, 24, 89, 56, 88, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 1.0, 10.0, 10, 2)
# {97, 2, 5, 38, 72, 77, 46, 83, 21, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.001, 0.01, 1, 0.5)
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.001, 0.01, 1, 2)
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.001, 0.01, 10, 0.5)
# {65, 97, 98, 9, 79, 50, 52, 55, 92, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.001, 0.01, 10, 2)
# {64, 66, 3, 2, 72, 17, 51, 20, 92, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.01, 0.10000000000000002, 1, 0.5)
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.01, 0.10000000000000002, 1, 2)
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.01, 0.10000000000000002, 10, 0.5)
# {64, 34, 15, 48, 49, 56, 90, 91, 28, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.01, 0.10000000000000002, 10, 2)
# {65, 97, 9, 76, 79, 50, 51, 52, 55, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.10000000000000002, 1.0, 1, 0.5)
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.10000000000000002, 1.0, 1, 2)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.10000000000000002, 1.0, 10, 0.5)
# {64, 2, 73, 44, 79, 47, 50, 51, 20, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.10000000000000002, 1.0, 10, 2)
# {64, 97, 2, 44, 79, 47, 51, 20, 52, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 1.0, 10.0, 1, 0.5)
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 1.0, 10.0, 1, 2)
# {30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 1.0, 10.0, 10, 0.5)
# {65, 34, 41, 73, 50, 19, 85, 56, 89, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 1.0, 10.0, 10, 2)
# {33, 98, 68, 4, 36, 48, 81, 82, 52, 21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.001, 0.01, 1, 0.5)
# {50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.001, 0.01, 1, 2)
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.001, 0.01, 10, 0.5)
# {65, 97, 37, 40, 74, 10, 81, 20, 23, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.001, 0.01, 10, 2)
# {33, 66, 2, 99, 90, 21, 25, 58, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.01, 0.10000000000000002, 1, 0.5)
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.01, 0.10000000000000002, 1, 2)
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.01, 0.10000000000000002, 10, 0.5)
# {77, 79, 50, 20, 53, 86, 89, 26, 29, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.01, 0.10000000000000002, 10, 2)
# {35, 42, 76, 14, 79, 18, 84, 87, 25, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.10000000000000002, 1.0, 1, 0.5)
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.10000000000000002, 1.0, 1, 2)
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.10000000000000002, 1.0, 10, 0.5)
# {97, 37, 6, 10, 81, 20, 23, 26, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.10000000000000002, 1.0, 10, 2)
# {35, 42, 76, 14, 79, 18, 84, 87, 25, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 1.0, 10.0, 1, 0.5)
# {3}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 1.0, 10.0, 1, 2)
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 1.0, 10.0, 10, 0.5)
# {1, 9, 10, 16, 82, 83, 54, 94, 91, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 1.0, 10.0, 10, 2)
# {97, 37, 6, 10, 81, 20, 23, 26, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.001, 0.01, 1, 0.5)
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.001, 0.01, 1, 2)
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.001, 0.01, 10, 0.5)
# {64, 34, 40, 10, 12, 84, 86, 91, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.001, 0.01, 10, 2)
# {32, 68, 72, 10, 74, 80, 50, 84, 52, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.01, 0.10000000000000002, 1, 0.5)
# {3}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.01, 0.10000000000000002, 1, 2)
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.01, 0.10000000000000002, 10, 0.5)
# {0, 67, 36, 69, 38, 9, 75, 15, 51, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.01, 0.10000000000000002, 10, 2)
# {1, 98, 99, 58, 14, 47, 50, 84, 24, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.10000000000000002, 1.0, 1, 0.5)
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.10000000000000002, 1.0, 1, 2)
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.10000000000000002, 1.0, 10, 0.5)
# {33, 67, 36, 69, 38, 9, 75, 15, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.10000000000000002, 1.0, 10, 2)
# {0, 98, 7, 45, 14, 92, 25, 90, 28, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 1.0, 10.0, 1, 0.5)
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 1.0, 10.0, 1, 2)
# {30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 1.0, 10.0, 10, 0.5)
# {72, 74, 11, 44, 45, 18, 85, 55, 87, 54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 1.0, 10.0, 10, 2)
# {67, 72, 11, 47, 16, 49, 50, 84, 56, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.001, 0.01, 1, 0.5)
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.001, 0.01, 1, 2)
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.001, 0.01, 10, 0.5)
# {97, 36, 88, 74, 44, 54, 86, 56, 58, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.001, 0.01, 10, 2)
# {2, 5, 42, 76, 55, 88, 91, 92, 30, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.01, 0.10000000000000002, 1, 0.5)
# {30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.01, 0.10000000000000002, 1, 2)
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.01, 0.10000000000000002, 10, 0.5)
# {97, 66, 35, 72, 13, 81, 20, 54, 25, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.01, 0.10000000000000002, 10, 2)
# {58, 6, 40, 48, 80, 18, 22, 24, 90, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.10000000000000002, 1.0, 1, 0.5)
# {99}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.10000000000000002, 1.0, 1, 2)
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.10000000000000002, 1.0, 10, 0.5)
# {68, 71, 14, 15, 78, 51, 24, 89, 91, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.10000000000000002, 1.0, 10, 2)
# {32, 5, 73, 42, 13, 78, 55, 89, 92, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 1.0, 10.0, 1, 0.5)
# {55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 1.0, 10.0, 1, 2)
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 1.0, 10.0, 10, 0.5)
# {1, 5, 7, 42, 43, 76, 21, 54, 55, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 1.0, 10.0, 10, 2)
# {0, 64, 37, 38, 70, 8, 40, 47, 79, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.001, 0.01, 1, 0.5)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.001, 0.01, 1, 2)
# {47}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.001, 0.01, 10, 0.5)
# {64, 1, 98, 99, 97, 36, 70, 38, 77, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.001, 0.01, 10, 2)
# {32, 38, 40, 11, 13, 15, 16, 54, 87, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.01, 0.10000000000000002, 1, 0.5)
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.01, 0.10000000000000002, 1, 2)
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.01, 0.10000000000000002, 10, 0.5)
# {64, 1, 98, 99, 68, 97, 70, 38, 77, 20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.01, 0.10000000000000002, 10, 2)
# {0, 36, 41, 80, 84, 22, 87, 24, 58, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.10000000000000002, 1.0, 1, 0.5)
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.10000000000000002, 1.0, 1, 2)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.10000000000000002, 1.0, 10, 0.5)
# {32, 98, 68, 40, 41, 13, 15, 52, 84, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.10000000000000002, 1.0, 10, 2)
# {64, 99, 7, 11, 77, 14, 15, 84, 28, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 1.0, 10.0, 1, 0.5)
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 1.0, 10.0, 1, 2)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 1.0, 10.0, 10, 0.5)
# {64, 1, 70, 71, 38, 77, 19, 90, 60, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 1.0, 10.0, 10, 2)
# {36, 70, 7, 59, 76, 29, 21, 58, 91, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.001, 0.01, 1, 0.5)
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.001, 0.01, 1, 2)
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.001, 0.01, 10, 0.5)
# {96, 2, 7, 11, 44, 78, 51, 20, 84, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.001, 0.01, 10, 2)
# {33, 2, 3, 99, 6, 43, 46, 19, 22, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.01, 0.10000000000000002, 1, 0.5)
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.01, 0.10000000000000002, 1, 2)
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.01, 0.10000000000000002, 10, 0.5)
# {32, 96, 65, 37, 70, 73, 41, 47, 56, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.01, 0.10000000000000002, 10, 2)
# {97, 36, 8, 76, 79, 48, 52, 55, 27, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.10000000000000002, 1.0, 1, 0.5)
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.10000000000000002, 1.0, 1, 2)
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.10000000000000002, 1.0, 10, 0.5)
# {98, 67, 68, 41, 13, 50, 20, 57, 29, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.10000000000000002, 1.0, 10, 2)
# {98, 67, 68, 41, 13, 52, 20, 57, 92, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 1.0, 10.0, 1, 0.5)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 1.0, 10.0, 1, 2)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 1.0, 10.0, 10, 0.5)
# {65, 99, 6, 38, 40, 44, 77, 55, 28, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 1.0, 10.0, 10, 2)
# {97, 42, 74, 75, 79, 17, 82, 21, 55, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.001, 0.01, 1, 0.5)
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.001, 0.01, 1, 2)
# {25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.001, 0.01, 10, 0.5)
# {2, 3, 8, 10, 11, 45, 46, 55, 87, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.001, 0.01, 10, 2)
# {96, 66, 8, 74, 44, 13, 47, 18, 25, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.01, 0.10000000000000002, 1, 0.5)
# {96}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.01, 0.10000000000000002, 1, 2)
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.01, 0.10000000000000002, 10, 0.5)
# {1, 36, 37, 12, 18, 50, 52, 82, 25, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.01, 0.10000000000000002, 10, 2)
# {68, 37, 7, 10, 75, 76, 44, 14, 80, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.10000000000000002, 1.0, 1, 0.5)
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.10000000000000002, 1.0, 1, 2)
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.10000000000000002, 1.0, 10, 0.5)
# {0, 1, 70, 10, 76, 14, 80, 21, 29, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.10000000000000002, 1.0, 10, 2)
# {33, 4, 40, 80, 85, 22, 23, 28, 29, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 1.0, 10.0, 1, 0.5)
# {11}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 1.0, 10.0, 1, 2)
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 1.0, 10.0, 10, 0.5)
# {97, 2, 9, 77, 80, 84, 54, 55, 57, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 1.0, 10.0, 10, 2)
# {64, 66, 4, 40, 75, 43, 47, 87, 25, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.001, 0.01, 1, 0.5)
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.001, 0.01, 1, 2)
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.001, 0.01, 10, 0.5)
# {0, 65, 99, 78, 15, 22, 87, 88, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.001, 0.01, 10, 2)
# {0, 65, 99, 78, 15, 49, 87, 88, 56, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.01, 0.10000000000000002, 1, 0.5)
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.01, 0.10000000000000002, 1, 2)
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.01, 0.10000000000000002, 10, 0.5)
# {27, 42, 43, 76, 78, 48, 19, 22, 88, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.01, 0.10000000000000002, 10, 2)
# {98, 36, 71, 41, 43, 14, 15, 57, 58, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.10000000000000002, 1.0, 1, 0.5)
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.10000000000000002, 1.0, 1, 2)
# {50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.10000000000000002, 1.0, 10, 0.5)
# {33, 74, 12, 44, 79, 49, 18, 52, 23, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 0.10000000000000002, 1.0, 10, 2)
# {0, 65, 99, 78, 15, 22, 87, 88, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 1.0, 10.0, 1, 0.5)
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 1.0, 10.0, 1, 2)
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 1.0, 10.0, 10, 0.5)
# {99, 68, 37, 9, 60, 18, 51, 86, 28, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (95, 1.0, 10.0, 10, 2)
# {64, 36, 71, 8, 11, 14, 89, 58, 57, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.001, 0.01, 1, 0.5)
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.001, 0.01, 1, 2)
# {99}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.001, 0.01, 10, 0.5)
# {65, 37, 38, 70, 12, 29, 53, 88, 26, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.001, 0.01, 10, 2)
# {41, 43, 45, 14, 81, 17, 83, 85, 25, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.01, 0.10000000000000002, 1, 0.5)
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.01, 0.10000000000000002, 1, 2)
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.01, 0.10000000000000002, 10, 0.5)
# {1, 6, 13, 46, 20, 84, 90, 61, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.01, 0.10000000000000002, 10, 2)
# {4, 41, 43, 75, 14, 81, 17, 52, 25, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.10000000000000002, 1.0, 1, 0.5)
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.10000000000000002, 1.0, 1, 2)
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.10000000000000002, 1.0, 10, 0.5)
# {32, 71, 72, 55, 23, 56, 58, 88, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 0.10000000000000002, 1.0, 10, 2)
# {97, 66, 39, 59, 78, 15, 19, 23, 91, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 1.0, 10.0, 1, 0.5)
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 1.0, 10.0, 1, 2)
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 1.0, 10.0, 10, 0.5)
# {34, 37, 69, 44, 14, 29, 85, 54, 92, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (96, 1.0, 10.0, 10, 2)
# {99, 4, 73, 9, 75, 45, 52, 85, 26, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.001, 0.01, 1, 0.5)
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.001, 0.01, 1, 2)
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.001, 0.01, 10, 0.5)
# {32, 4, 70, 14, 15, 80, 78, 82, 21, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.001, 0.01, 10, 2)
# {32, 65, 1, 13, 14, 78, 17, 23, 25, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.01, 0.10000000000000002, 1, 0.5)
# {55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.01, 0.10000000000000002, 1, 2)
# {90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.01, 0.10000000000000002, 10, 0.5)
# {99, 6, 73, 10, 47, 53, 55, 58, 91, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.01, 0.10000000000000002, 10, 2)
# {32, 99, 67, 70, 45, 48, 82, 20, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.10000000000000002, 1.0, 1, 0.5)
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.10000000000000002, 1.0, 1, 2)
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.10000000000000002, 1.0, 10, 0.5)
# {33, 37, 10, 43, 17, 86, 88, 25, 58, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 0.10000000000000002, 1.0, 10, 2)
# {64, 2, 67, 42, 44, 47, 61, 87, 91, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 1.0, 10.0, 1, 0.5)
# {11}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 1.0, 10.0, 1, 2)
# {22}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 1.0, 10.0, 10, 0.5)
# {1, 2, 67, 69, 39, 44, 47, 83, 22, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (97, 1.0, 10.0, 10, 2)
# {97, 99, 37, 31, 88, 58, 28, 29, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.001, 0.01, 1, 0.5)
# {51}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.001, 0.01, 1, 2)
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.001, 0.01, 10, 0.5)
# {0, 33, 3, 8, 74, 82, 19, 50, 54, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.001, 0.01, 10, 2)
# {66, 4, 37, 39, 73, 78, 83, 52, 56, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.01, 0.10000000000000002, 1, 0.5)
# {30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.01, 0.10000000000000002, 1, 2)
# {55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.01, 0.10000000000000002, 10, 0.5)
# {0, 1, 99, 35, 70, 9, 76, 50, 52, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.01, 0.10000000000000002, 10, 2)
# {64, 65, 4, 6, 9, 43, 48, 18, 51, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.10000000000000002, 1.0, 1, 0.5)
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.10000000000000002, 1.0, 1, 2)
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.10000000000000002, 1.0, 10, 0.5)
# {64, 33, 2, 35, 6, 74, 43, 48, 18, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 0.10000000000000002, 1.0, 10, 2)
# {96, 65, 66, 4, 39, 9, 73, 76, 52, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 1.0, 10.0, 1, 0.5)
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 1.0, 10.0, 1, 2)
# {59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 1.0, 10.0, 10, 0.5)
# {35, 3, 6, 7, 43, 76, 48, 18, 52, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (98, 1.0, 10.0, 10, 2)
# {64, 65, 2, 0, 74, 48, 82, 50, 54, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.001, 0.01, 1, 0.5)
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.001, 0.01, 1, 2)
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.001, 0.01, 10, 0.5)
# {1, 34, 6, 11, 28, 14, 17, 26, 92, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.001, 0.01, 10, 2)
# {3, 70, 75, 79, 50, 53, 26, 91, 61, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.01, 0.10000000000000002, 1, 0.5)
# {53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.01, 0.10000000000000002, 1, 2)
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.01, 0.10000000000000002, 10, 0.5)
# {1, 34, 6, 11, 87, 26, 92, 29, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.01, 0.10000000000000002, 10, 2)
# {67, 71, 9, 16, 49, 19, 24, 89, 27, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.10000000000000002, 1.0, 1, 0.5)
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.10000000000000002, 1.0, 1, 2)
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.10000000000000002, 1.0, 10, 0.5)
# {32, 96, 67, 6, 45, 15, 81, 22, 55, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 0.10000000000000002, 1.0, 10, 2)
# {4, 69, 74, 44, 14, 17, 85, 22, 88, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 1.0, 10.0, 1, 0.5)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 1.0, 10.0, 1, 2)
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 1.0, 10.0, 10, 0.5)
# {6, 9, 74, 76, 13, 77, 15, 26, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (99, 1.0, 10.0, 10, 2)
# {1, 99, 38, 40, 42, 11, 49, 24, 26, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.001, 0.01, 1, 0.5)
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.001, 0.01, 1, 2)
# {11}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.001, 0.01, 10, 0.5)
# {38, 73, 59, 77, 79, 81, 25, 90, 91, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.001, 0.01, 10, 2)
# {3, 7, 10, 43, 52, 21, 55, 59, 92, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.01, 0.10000000000000002, 1, 0.5)
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.01, 0.10000000000000002, 1, 2)
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.01, 0.10000000000000002, 10, 0.5)
# {34, 8, 10, 77, 78, 15, 20, 54, 56, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.01, 0.10000000000000002, 10, 2)
# {3, 69, 10, 43, 76, 52, 21, 59, 92, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.10000000000000002, 1.0, 1, 0.5)
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.10000000000000002, 1.0, 1, 2)
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.10000000000000002, 1.0, 10, 0.5)
# {3, 7, 10, 14, 52, 21, 86, 55, 85, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 0.10000000000000002, 1.0, 10, 2)
# {96, 1, 9, 11, 14, 81, 85, 86, 23, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (100, 1.0, 10.0, 1, 0.5)
# {52}
# ...
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (109, 1.0, 10.0, 10, 0.5)
# {68, 5, 71, 47, 81, 82, 22, 86, 25, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (109, 1.0, 10.0, 10, 2)
# {98, 69, 72, 42, 74, 10, 50, 55, 26, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.001, 0.01, 1, 0.5)
# {34}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.001, 0.01, 1, 2)
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.001, 0.01, 10, 0.5)
# {39, 45, 28, 13, 50, 84, 89, 60, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.001, 0.01, 10, 2)
# {39, 10, 45, 60, 13, 14, 50, 84, 28, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.01, 0.10000000000000002, 1, 0.5)
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.01, 0.10000000000000002, 1, 2)
# {91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.01, 0.10000000000000002, 10, 0.5)
# {69, 39, 40, 7, 72, 51, 22, 89, 90, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.01, 0.10000000000000002, 10, 2)
# {97, 66, 35, 67, 34, 74, 48, 52, 57, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.10000000000000002, 1.0, 1, 0.5)
# {0}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.10000000000000002, 1.0, 1, 2)
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.10000000000000002, 1.0, 10, 0.5)
# {96, 70, 72, 73, 42, 17, 85, 55, 25, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 0.10000000000000002, 1.0, 10, 2)
# {32, 96, 67, 41, 42, 77, 17, 55, 92, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 1.0, 10.0, 1, 0.5)
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 1.0, 10.0, 1, 2)
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 1.0, 10.0, 10, 0.5)
# {96, 6, 41, 42, 45, 17, 50, 55, 92, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (110, 1.0, 10.0, 10, 2)
# {65, 67, 39, 7, 45, 13, 84, 53, 21, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.001, 0.01, 1, 0.5)
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.001, 0.01, 1, 2)
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.001, 0.01, 10, 0.5)
# {39, 42, 14, 49, 83, 51, 53, 23, 89, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.001, 0.01, 10, 2)
# {39, 42, 14, 49, 83, 51, 53, 23, 89, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.01, 0.10000000000000002, 1, 0.5)
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.01, 0.10000000000000002, 1, 2)
# {97}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.01, 0.10000000000000002, 10, 0.5)
# {7, 71, 73, 75, 14, 48, 81, 49, 19, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.01, 0.10000000000000002, 10, 2)
# {66, 39, 14, 17, 81, 23, 56, 89, 26, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.10000000000000002, 1.0, 1, 0.5)
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.10000000000000002, 1.0, 1, 2)
# {8}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.10000000000000002, 1.0, 10, 0.5)
# {2, 3, 35, 37, 13, 45, 46, 87, 57, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 0.10000000000000002, 1.0, 10, 2)
# {99, 39, 42, 14, 49, 50, 55, 23, 89, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 1.0, 10.0, 1, 0.5)
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 1.0, 10.0, 1, 2)
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 1.0, 10.0, 10, 0.5)
# {2, 3, 37, 6, 8, 12, 45, 46, 15, 13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (111, 1.0, 10.0, 10, 2)
# {37, 39, 42, 15, 49, 51, 20, 23, 89, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.001, 0.01, 1, 0.5)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.001, 0.01, 1, 2)
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.001, 0.01, 10, 0.5)
# {1, 99, 10, 43, 42, 82, 24, 56, 27, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.001, 0.01, 10, 2)
# {65, 35, 68, 41, 78, 46, 16, 81, 83, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.01, 0.10000000000000002, 1, 0.5)
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.01, 0.10000000000000002, 1, 2)
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.01, 0.10000000000000002, 10, 0.5)
# {32, 90, 76, 79, 48, 50, 58, 59, 93, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.01, 0.10000000000000002, 10, 2)
# {64, 67, 5, 70, 38, 81, 82, 52, 23, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.10000000000000002, 1.0, 1, 0.5)
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.10000000000000002, 1.0, 1, 2)
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.10000000000000002, 1.0, 10, 0.5)
# {32, 99, 9, 11, 80, 48, 58, 27, 93, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 0.10000000000000002, 1.0, 10, 2)
# {97, 98, 90, 40, 80, 21, 55, 24, 58, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 1.0, 10.0, 1, 0.5)
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 1.0, 10.0, 1, 2)
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 1.0, 10.0, 10, 0.5)
# {1, 67, 5, 10, 43, 82, 20, 53, 56, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (112, 1.0, 10.0, 10, 2)
# {9, 42, 11, 80, 24, 58, 27, 60, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.001, 0.01, 1, 0.5)
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.001, 0.01, 1, 2)
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.001, 0.01, 10, 0.5)
# {65, 69, 42, 44, 19, 21, 23, 90, 27, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.001, 0.01, 10, 2)
# {1, 38, 74, 47, 80, 16, 17, 19, 23, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.01, 0.10000000000000002, 1, 0.5)
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.01, 0.10000000000000002, 1, 2)
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.01, 0.10000000000000002, 10, 0.5)
# {67, 69, 6, 5, 40, 9, 15, 50, 53, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.01, 0.10000000000000002, 10, 2)
# {65, 69, 42, 44, 20, 21, 22, 27, 28, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.10000000000000002, 1.0, 1, 0.5)
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.10000000000000002, 1.0, 1, 2)
# {88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.10000000000000002, 1.0, 10, 0.5)
# {65, 69, 42, 44, 19, 21, 22, 23, 27, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 0.10000000000000002, 1.0, 10, 2)
# {68, 37, 71, 77, 81, 82, 86, 55, 89, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 1.0, 10.0, 1, 0.5)
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 1.0, 10.0, 1, 2)
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 1.0, 10.0, 10, 0.5)
# {65, 39, 8, 72, 75, 14, 85, 22, 56, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (113, 1.0, 10.0, 10, 2)
# {4, 37, 68, 71, 42, 80, 51, 25, 89, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.001, 0.01, 1, 0.5)
# {19}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.001, 0.01, 1, 2)
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.001, 0.01, 10, 0.5)
# {96, 1, 72, 92, 81, 84, 22, 55, 26, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.001, 0.01, 10, 2)
# {97, 98, 38, 41, 9, 48, 81, 56, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.01, 0.10000000000000002, 1, 0.5)
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.01, 0.10000000000000002, 1, 2)
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.01, 0.10000000000000002, 10, 0.5)
# {34, 90, 6, 39, 41, 76, 78, 18, 54, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.01, 0.10000000000000002, 10, 2)
# {0, 1, 34, 45, 80, 53, 54, 55, 22, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.10000000000000002, 1.0, 1, 0.5)
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.10000000000000002, 1.0, 1, 2)
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.10000000000000002, 1.0, 10, 0.5)
# {0, 1, 90, 45, 80, 82, 51, 18, 54, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 0.10000000000000002, 1.0, 10, 2)
# {1, 66, 36, 41, 13, 46, 80, 19, 25, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 1.0, 10.0, 1, 0.5)
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 1.0, 10.0, 1, 2)
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 1.0, 10.0, 10, 0.5)
# {72, 27, 42, 74, 91, 73, 51, 22, 55, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (114, 1.0, 10.0, 10, 2)
# {66, 67, 73, 10, 11, 82, 19, 89, 92, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.001, 0.01, 1, 0.5)
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.001, 0.01, 1, 2)
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.001, 0.01, 10, 0.5)
# {26, 67, 5, 71, 74, 45, 46, 17, 87, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.001, 0.01, 10, 2)
# {64, 32, 66, 65, 11, 76, 55, 89, 90, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.01, 0.10000000000000002, 1, 0.5)
# {7}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.01, 0.10000000000000002, 1, 2)
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.01, 0.10000000000000002, 10, 0.5)
# {65, 66, 3, 68, 7, 40, 71, 13, 50, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.01, 0.10000000000000002, 10, 2)
# {34, 3, 67, 72, 11, 78, 93, 22, 91, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.10000000000000002, 1.0, 1, 0.5)
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.10000000000000002, 1.0, 1, 2)
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.10000000000000002, 1.0, 10, 0.5)
# {1, 74, 76, 83, 84, 19, 86, 24, 57, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 0.10000000000000002, 1.0, 10, 2)
# {96, 2, 99, 98, 9, 10, 15, 47, 83, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 1.0, 10.0, 1, 0.5)
# {19}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 1.0, 10.0, 1, 2)
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 1.0, 10.0, 10, 0.5)
# {70, 72, 9, 11, 81, 83, 55, 89, 90, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (115, 1.0, 10.0, 10, 2)
# {5, 37, 75, 44, 47, 21, 22, 91, 60, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.001, 0.01, 1, 0.5)
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.001, 0.01, 1, 2)
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.001, 0.01, 10, 0.5)
# {96, 66, 35, 38, 11, 79, 52, 85, 90, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.001, 0.01, 10, 2)
# {36, 7, 72, 14, 16, 80, 20, 84, 25, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.01, 0.10000000000000002, 1, 0.5)
# {53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.01, 0.10000000000000002, 1, 2)
# {91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.01, 0.10000000000000002, 10, 0.5)
# {3, 4, 70, 73, 48, 49, 80, 54, 57, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.01, 0.10000000000000002, 10, 2)
# {2, 4, 45, 48, 50, 55, 56, 57, 29, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.10000000000000002, 1.0, 1, 0.5)
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.10000000000000002, 1.0, 1, 2)
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.10000000000000002, 1.0, 10, 0.5)
# {36, 7, 72, 11, 77, 14, 16, 80, 25, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 0.10000000000000002, 1.0, 10, 2)
# {98, 36, 7, 40, 76, 14, 87, 88, 28, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 1.0, 10.0, 1, 0.5)
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 1.0, 10.0, 1, 2)
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 1.0, 10.0, 10, 0.5)
# {98, 58, 8, 9, 44, 80, 51, 90, 27, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (116, 1.0, 10.0, 10, 2)
# {66, 36, 37, 5, 43, 23, 86, 55, 28, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.001, 0.01, 1, 0.5)
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.001, 0.01, 1, 2)
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.001, 0.01, 10, 0.5)
# {2, 66, 37, 42, 46, 18, 51, 52, 21, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.001, 0.01, 10, 2)
# {65, 33, 68, 75, 76, 49, 51, 52, 22, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.01, 0.10000000000000002, 1, 0.5)
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.01, 0.10000000000000002, 1, 2)
# {88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.01, 0.10000000000000002, 10, 0.5)
# {3, 56, 38, 11, 44, 13, 83, 24, 90, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.01, 0.10000000000000002, 10, 2)
# {96, 34, 5, 70, 50, 84, 25, 27, 28, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.10000000000000002, 1.0, 1, 0.5)
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.10000000000000002, 1.0, 1, 2)
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.10000000000000002, 1.0, 10, 0.5)
# {66, 68, 69, 42, 46, 18, 51, 89, 26, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 0.10000000000000002, 1.0, 10, 2)
# {1, 66, 38, 11, 19, 84, 24, 25, 27, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 1.0, 10.0, 1, 0.5)
# {34}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 1.0, 10.0, 1, 2)
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 1.0, 10.0, 10, 0.5)
# {69, 39, 71, 10, 46, 47, 82, 85, 88, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (117, 1.0, 10.0, 10, 2)
# {35, 36, 72, 40, 74, 44, 15, 56, 88, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.001, 0.01, 1, 0.5)
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.001, 0.01, 1, 2)
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.001, 0.01, 10, 0.5)
# {0, 1, 34, 98, 99, 81, 54, 89, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.001, 0.01, 10, 2)
# {65, 2, 35, 69, 38, 42, 76, 45, 48, 50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.01, 0.10000000000000002, 1, 0.5)
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.01, 0.10000000000000002, 1, 2)
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.01, 0.10000000000000002, 10, 0.5)
# {33, 34, 3, 8, 73, 45, 14, 19, 89, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.01, 0.10000000000000002, 10, 2)
# {33, 98, 68, 39, 71, 7, 16, 81, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.10000000000000002, 1.0, 1, 0.5)
# {8}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.10000000000000002, 1.0, 1, 2)
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.10000000000000002, 1.0, 10, 0.5)
# {33, 4, 42, 45, 16, 49, 51, 22, 23, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 0.10000000000000002, 1.0, 10, 2)
# {68, 37, 40, 11, 80, 48, 85, 87, 28, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 1.0, 10.0, 1, 0.5)
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 1.0, 10.0, 1, 2)
# {7}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 1.0, 10.0, 10, 0.5)
# {68, 37, 40, 75, 11, 80, 48, 85, 87, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (118, 1.0, 10.0, 10, 2)
# {0, 1, 97, 68, 40, 73, 18, 24, 91, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.001, 0.01, 1, 0.5)
# {51}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.001, 0.01, 1, 2)
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.001, 0.01, 10, 0.5)
# {1, 97, 45, 77, 80, 50, 83, 51, 86, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.001, 0.01, 10, 2)
# {33, 69, 11, 12, 48, 83, 24, 25, 90, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.01, 0.10000000000000002, 1, 0.5)
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.01, 0.10000000000000002, 1, 2)
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.01, 0.10000000000000002, 10, 0.5)
# {97, 98, 6, 75, 15, 83, 87, 56, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.01, 0.10000000000000002, 10, 2)
# {1, 97, 3, 67, 38, 75, 51, 83, 57, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.10000000000000002, 1.0, 1, 0.5)
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.10000000000000002, 1.0, 1, 2)
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.10000000000000002, 1.0, 10, 0.5)
# {37, 72, 75, 77, 14, 47, 54, 55, 88, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 0.10000000000000002, 1.0, 10, 2)
# {33, 34, 9, 75, 48, 49, 80, 57, 90, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 1.0, 10.0, 1, 0.5)
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 1.0, 10.0, 1, 2)
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 1.0, 10.0, 10, 0.5)
# {33, 9, 11, 14, 80, 48, 51, 22, 25, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (119, 1.0, 10.0, 10, 2)
# {1, 3, 67, 38, 75, 77, 51, 83, 57, 27}
