# %% [markdown]
# ## Leaky integrated firing neuron model
# ## Few feautures :
# ### Spatial network, no memory term but exponential decay of cumulative dose
#
# This is a minor change of the Dodds and Watts model
# Implement adaptive rewiring and generate statistics

# %%
#importing the required libraries

import networkx as nx
import matplotlib.pyplot as plt #for plotting
import numpy as np #for using arrays and vectorising the code wherever possible
import scipy
import random
# from numba import jit #numba precomplier to make the code faster
import pandas as pd
import copy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Variables used in the simulation

# %%
N = 100
gamma = 1 #decay of cumulative dose per unit time (second)
gamma = gamma
T = 500 #total number of seconds
dt = 0.05 #seconds
dt_netrun = 10
'''number of simulation steps is T/dt'''

'''Dodds watts parameters'''
p = 1 #rate of dose transfer (per unit time (second))
p = p*dt #rate of dose transfer per unit simulation step
r = 1/dt
r = r*dt
rho = 1/dt
rho = rho*dt
# r = 0.5
# r = r*dt

d_star = 1
# dose_quantity = 1
D_ini = 3

'''network parameters'''
circ_rad = 100 #for a network in which each node is connected to other nodes withing a circle of radius circ_rad
nn = 10 #the number of nearest neighbours(i.e. k) in knn
average_degree = 6
total_edges = N*2

'''rewiring parameters'''
rew_r = 14
density = 1/N
# p_rew = 5 #rate of rewiring(per unit time(second))
# p_rew = p_rew*dt

'''tolerance to determine initial network topology'''
tol = 0.5
steady_counter_val = 500

# %% [markdown]
# # Creating the network.
# ### The network outputs coordinates, distance matrix, edge_list and adjacency matrix

# %%
'''
obtains the number of nodes N
generates N points
calculates euclidean distance between each pair of points
returns the coordinates of the points and the distance matrix which is N*N
'''
def calc_dist(N) :
    coords = []
    for counter in range(N) :
        coords.append((N*np.random.random(),N*np.random.random()))

    dist_mat = scipy.spatial.distance.cdist(coords,coords)
    return dist_mat,coords

# %% [markdown]
# ### 1. metric network

# %%
'''network = connect to points withing a circle of radius'''
#creates a link between points/nodes which satisfies the conditions of the network
def coupling(dist_mat,circ_rad) :
    edge_list = []
    edge_mask = (dist_mat<circ_rad) & (dist_mat>0)
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(edge_mask))))
#     print(type(np.ndarray.tolist(np.transpose(np.where(edge_mask)))))
    return edge_list

# %% [markdown]
# ### 2. K nearest neighbour network

# %%
'''network = knn'''
def knn(dist_mat,nn,N) :
    near_neigh = np.argsort(dist_mat)
    selec_near_neigh = np.zeros((N,nn))
    selec_near_neigh = near_neigh[:,0:nn+1]

    edge_list = []
    for i in range(N) :
        for j in range(1,nn+1) :
            link = [i,selec_near_neigh[i,j]]
            edge_list.append(link)

    return edge_list

# %% [markdown]
# ### 3. Random Network : GNP type

# %%
'''random network'''
def rand_network(average_degree,N) :
    z1 = np.random.uniform(size = (N,N))
    E,F = np.meshgrid(np.arange(0,N),np.arange(0,N))
    mask = ((average_degree/N) > z1) & (E!=F)
    adjacency_matrix = np.int64(np.zeros(shape=(N,N)))
    adjacency_matrix[mask] = np.int64(1)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list,adjacency_matrix

# %% [markdown]
# ### 4. Random Network : GNM type

# %%
def rand_net_gnm(total_edges,N) :
    the_graph = nx.gnm_random_graph(N, total_edges,directed=True)
    adjacency_matrix = nx.adjacency_matrix(the_graph)
    adjacency_matrix = np.asarray(adjacency_matrix.todense())
    np.fill_diagonal(adjacency_matrix,0)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list

# %% [markdown]
# # Function defintions required for the main part of the script

# %%
# # @jit(nopython=True)
# '''infecting the left part of space.'''
# def left_part_infec(N) :
#     x_coord = []
#     y_coord = []
#     for j in range(len(coords)) :
#         x_coord.append(coords[j][0])
#         y_coord.append(coords[j][1])
#     x_coord = np.asarray(x_coord)
#     y_coord = np.asarray(y_coord)
#     points = np.asarray(np.where(x_coord<(N/5))) 
#     indi_state[points.T] = 2

#     return indi_state

# %%
'''infecting connected nodes'''
def InfectNetworkNeighbors(net,seed_node,init_infected_nodes):
     # if in bulk find one node randomly, and infect its neighbours
    infected_nodes = set()
    candidate_nodes = set()
    explored_nodes = set()

    #pick the seed node
    infected_nodes.add(seed_node)
    explored_nodes.add(seed_node)

    curr_node=seed_node

    #add its neighbors to the list of candidates
    for n in net.neighbors(curr_node):
        candidate_nodes.add(int(n))
    #print( curr_node)
    #print( candidate_nodes)

    #while we need to select more nodes...
    while len(infected_nodes) < init_infected_nodes:

        #if there are candidate nodes, select one of them
        if(len(candidate_nodes) > 0):
            new_node = np.random.choice(list(candidate_nodes),1)[0]
            infected_nodes.add(new_node)
            candidate_nodes.remove(new_node)

        elif len(infected_nodes - explored_nodes) > 0:
            curr_node = np.random.choice(list(infected_nodes -
            explored_nodes),1)[0]
            explored_nodes.add(curr_node)
            for n in set(net.neighbors(curr_node)) - infected_nodes:
                candidate_nodes.add(n)

        else:
#             print('Initial node infection step failed')
            return None
    return infected_nodes

# %%
''' function to transfer doses'''
# @jit(nopython=True)
def dose(adj_mat,p,partner_state_prev,d) :

    z1 = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    dose_transfer_mask = p > z1
    mod_adj_mat = np.multiply(adj_mat,z1) #modifying adjacency matrix to include the proability of dose transfer
    dose_mask = (p>mod_adj_mat) & (adj_mat!=0) & (partner_state_prev == 2)
    d[dose_mask] = dose_quantity #whenever it is proabable, dose transfer occurs
    
    return d

# %%
def rew(p_rew,adjacency_matrix,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r) :
    
    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew > z1_rew_prew)  & (indi_state_for_rew_prev == 1) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    rew_mask_minus1 = (p_rew > z1_rew_prew) & (indi_state_for_rew_prev == 2)
    #break links. Dont create any.
    adjacency_matrix[rew_mask_minus1] = 0
    rew_mask_minus2 = ((lamb_da*OD_mesh2) > z1_rew_lambda) & (indi_state_for_rew_prev == 1)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
def let_it_run(p_rew_netrun,adjacency_matrix,OD_mesh2,lamb_da_netrun,density,rew_r) :

    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew_netrun > z1_rew_prew) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    
    rew_mask_minus2 = ((lamb_da_netrun*OD_mesh2) > z1_rew_lambda)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
'''function to update cumulative doses'''
def cumu_dose(d,D_prev,gamma) :
    I = d.sum(axis=1).reshape(N,1)
#     I = 0
    D = (D_prev - (gamma*D_prev*dt)) + I
    return D

# %%
'''function to update the states of the nodes of the system'''
def upd_indi_state(D,d_star,indi_state_prev) :
    
    z2 = np.random.uniform(size=(N,1))
    z3 = np.random.uniform(size=(N,1))
    
    indi_state = indi_state_prev
    
    indi_state_mask1 = (D>=d_star) & (indi_state_prev==1)
    indi_state[indi_state_mask1] = 2
    
    indi_state_mask21 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho>=z3)
    indi_state[indi_state_mask21] = 1
    
    indi_state_mask22 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho<z3)
    indi_state[indi_state_mask22] = 3
    
    indi_state_mask23 = (D<d_star) & (indi_state_prev==2) & (r<z2)
    indi_state[indi_state_mask23] = 2
    
    return indi_state

# %%
'''function to get/identify the infected nodes and the suceptible nodes'''
def states(indi_state) :
    infec_indi = []
    suscep_indi = []
    infec_indi = np.transpose(np.where(indi_state==2))
    suscep_indi = np.transpose(np.where(indi_state==1))
    return infec_indi,suscep_indi

# %%
def networkx_graph(coords,edge_list) :
    G = nx.DiGraph()
    pos = {(i): (coords[i][0],coords[i][1]) for i in range(N)}
    G.add_nodes_from(pos.keys())
    G.add_edges_from(edge_list)
    return G

# %%
def edge_from_adj_mat(adj_mat_list,q):
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adj_mat_list[q]==1))))
    return edge_list

# %% [markdown]
# # The main part of the script

# %%
#infected state time series data frame
#columns indicate the time steps
timeseries_infec_frac = pd.DataFrame()

#in degree as columns and rows as nodes
# timeseries_in_degree = pd.DataFrame() 

#out degree as columns and rows as nodes
timeseries_out_degree = pd.DataFrame()

#strongly connected components as columns
# timeseries_connec_comps = pd.DataFrame()

#mean of out degree as columns and rows as nodes
timeseries_out_degree_mean = pd.DataFrame()

# %%
vals = round(1/((density)*(np.pi)*(rew_r*rew_r)),3)
p_rew_vals = [round(0.1*vals,3),round(vals,3),round(10*vals,3),round(100*vals,3)]
start_vals = [1,10]
dose_quantity_vals = [0.5,2]

# %%
for sim in range(70,70+25) :
    
    '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''
    dist_mat,coords = calc_dist(N) #node placement
    edge_list = knn(dist_mat,nn,N)
    bef_netrun_org_adj_mat = np.int64(np.zeros((N,N)))
    for i in range(len(edge_list)):
        bef_netrun_org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)
    df_row = 0
    
    for p_rew_org in p_rew_vals : #rate of rewiring (per unit time (second))
        if p_rew_org == round(0.1*vals,3) :
            dt_netrun = 100
        elif p_rew_org == round(vals,3):
            dt_netrun = 10
        else :
            dt_netrun = dt
            
        lamb_da_org = p_rew_org/10        
        '''parameters for the coupling dynamics'''
        lamb_da = lamb_da_org*dt
        p_rew = p_rew_org*dt
        
        '''parameters for the network satbilisation'''
        lamb_da_netrun = lamb_da_org*dt_netrun
        p_rew_netrun = p_rew_org*dt_netrun
        
        for start in start_vals : #rate of dose transfer (per unit time (second))
            for dose_quantity in dose_quantity_vals : #number of nodes to infect initially
                print('(sim,lamb_da,p_rew,start,dose_quantity) = ', (sim,lamb_da/dt,p_rew/dt,start,dose_quantity))

                '''clearing exsiting data frames and creating new ones '''
                timeseries_infec_frac = pd.DataFrame()
#                 timeseries_in_degree = pd.DataFrame()
                timeseries_out_degree = pd.DataFrame()
#                 timeseries_connec_comps = pd.DataFrame()
                timeseries_out_degree_mean = pd.DataFrame()

                q = 0 #to generate new edge_list from the new adjacency matrix 
                t = np.arange(0,T,dt)

                adj_mat_list = []
                adj_mat = copy.deepcopy(bef_netrun_org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new) #list of arrays which shows the time series of the adjacency matrix
    
                '''obtaining a steady network topology before starting the dynamics on the network'''

                q = 0
                steady_counter = 0
                df_col = 0
                no_reset = 0 
                while steady_counter < steady_counter_val :

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])
                    timeseries_out_degree_mean.loc[0,df_col] = timeseries_out_degree.iloc[:,df_col].mean()
                    if df_col-1 >= 0 :
            #             print(timeseries_out_degree_mean.loc[0,df_col])
                        if np.abs(timeseries_out_degree_mean.loc[0,df_col] - timeseries_out_degree_mean.loc[0,df_col-1]) <= tol :
                            steady_counter = steady_counter + 1
                        else :
                            steady_counter = 0
                            no_reset = no_reset + 1
#                             print('oops')
                            if no_reset > 100 :
                                break

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)    
                    adj_mat = let_it_run(p_rew_netrun,adj_mat,OD_mesh2,lamb_da_netrun,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    q = q + 1 
                    df_col = df_col + 1
                    
                '''steady network topology obtained, start the dynamics now'''
                print(timeseries_out_degree_mean.loc[0,df_col-1])
                timeseries_out_degree = pd.DataFrame()
                df_col = 0
                q = 0 
                edge_list = copy.deepcopy(edge_list)
                G = copy.deepcopy(G)
                org_adj_mat = copy.deepcopy(adj_mat_new)

                numpy_array = np.zeros((N,len(t)),dtype = np.int64)

                D_array = np.zeros((N,len(t)))
                for i in range(len(edge_list)):
                    org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)

                adj_mat_list = []
                adj_mat = copy.deepcopy(org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new)


                '''from G, obtain the in degree and the out degree'''
#                 timeseries_in_degree.loc[:,0] = np.asarray([val for (node, val) in G.in_degree()])
                timeseries_out_degree.loc[:,0] = np.asarray([val for (node, val) in G.out_degree()])

                '''strongly and weekely connected components'''
#                 timeseries_connec_comps.loc[0,0] = nx.number_connected_components(G.to_undirected())

                '''choosing initially infected nodes'''
                indi_state = np.random.randint(1,2,size=(N,1))
                infected_nodes = None
                while infected_nodes is None : #infecting 'start' number of network neighbours
                    infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)      
                print(infected_nodes)
                infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
                indi_state[infected_nodes[:,0],0] = 2

                A,B = np.meshgrid(indi_state,indi_state) 
                partner_state = copy.deepcopy(A)
                indi_state_for_rew = copy.deepcopy(B)

    #             numpy_array [:,0] = indi_state[:,0]

                indi_state_prev = copy.deepcopy(indi_state)
                partner_state_prev = copy.deepcopy(partner_state)
                indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                d = np.zeros((len(adj_mat),len(adj_mat[0])))

                D = np.zeros((N,1))
                D[np.where(indi_state==2)] = D_ini
                D_array[:,0] = D[:,0]
                D_prev = copy.deepcopy(D)

                infec_frac = np.count_nonzero(indi_state == 2)/N
                timeseries_infec_frac.loc[df_row,0] = infec_frac
                '''the main part of the simulation'''
                counter = 0
                df_col = 1
                for t in np.arange(dt,T,dt) :
                    q = q + 1 
                    counter = counter + 1
                    infec_indi = []
                    suscep_indi = []
                    d = np.zeros((len(adj_mat),len(adj_mat[0])))
                    d = dose(adj_mat,p,partner_state_prev,d)

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)
                    adj_mat = rew(p_rew,adj_mat,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    '''from G, obtain the in degree and the out degree'''
#                     timeseries_in_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.in_degree()])
                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])

                    '''strongly and weekely connected components'''
#                     timeseries_connec_comps.loc[df_row,df_col] = nx.number_connected_components(G.to_undirected())

                    D = cumu_dose(d,D_prev,gamma)
                    D_array[:,counter] = D[:,0]

                    indi_state = upd_indi_state(D,d_star,indi_state_prev)
                    infec_frac = np.count_nonzero(indi_state == 2)/N
                    timeseries_infec_frac.loc[df_row,df_col] = infec_frac

    #                 numpy_array[:,counter] = indi_state[:,0]
                    A,B = np.meshgrid(indi_state,indi_state)

                    infec_indi, suscep_indi = states(indi_state)

                    partner_state = copy.deepcopy(A)
                    indi_state_for_rew = copy.deepcopy(B)
                    indi_state_prev = copy.deepcopy(indi_state)
                    partner_state_prev = copy.deepcopy(partner_state)
                    indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                    D_prev = copy.deepcopy(D)
                    D = np.zeros((N,1))
                    df_col = df_col + 1 

    #             df_row = df_row + 1 #going to the next row of the df to store timeseries of next (p,start)

                filename_infec_frac = 'infec_frac.h5'
                filename_in_deg = 'in_deg.h5'
                filename_out_deg = 'out_deg.h5'
                filename_connec_comps = 'connec_comps.h5'
                p_rew_val = '%g'%(p_rew/dt)
                key_val = 'sim_'+str(sim)+'_p_rew_'+str(p_rew_val)+'_start_'+str(start)+'_dq_'+str(dose_quantity)
#                 print(key_val)
                timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
#                 timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
                timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
#                 timeseries_connec_comps.to_hdf(filename_connec_comps, key = key_val, mode='a')
                df_row = 0
# Out:
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0016, 0.016, 1, 0.5)
# 4.55
# {37}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0016, 0.016, 1, 2)
# 4.75
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0016, 0.016, 10, 0.5)
# 4.66
# {1, 98, 99, 34, 71, 45, 13, 50, 83, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0016, 0.016, 10, 2)
# 4.56
# {33, 98, 34, 36, 1, 71, 79, 83, 23, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0162, 0.162, 1, 0.5)
# 4.7
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0162, 0.162, 1, 2)
# 4.73
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0162, 0.162, 10, 0.5)
# 4.69
# {1, 34, 98, 71, 13, 45, 50, 83, 23, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0162, 0.162, 10, 2)
# 4.6
# {1, 34, 99, 98, 13, 50, 83, 55, 24, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.162, 1.6200000000000003, 1, 0.5)
# 3.63
# {91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.162, 1.6200000000000003, 1, 2)
# 3.77
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.162, 1.6200000000000003, 10, 0.5)
# 3.72
# {1, 34, 98, 36, 33, 13, 79, 83, 23, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.162, 1.6200000000000003, 10, 2)
# 3.61
# {1, 34, 98, 36, 71, 45, 50, 83, 23, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 1.6199999999999999, 16.2, 1, 0.5)
# 3.33
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 1.6199999999999999, 16.2, 1, 2)
# 3.73
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 1.6199999999999999, 16.2, 10, 0.5)
# 3.72
# {64, 5, 8, 9, 47, 20, 86, 22, 91, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 1.6199999999999999, 16.2, 10, 2)
# 3.79
# {5, 70, 8, 41, 42, 43, 20, 53, 22, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0016, 0.016, 1, 0.5)
# 4.56
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0016, 0.016, 1, 2)
# 4.49
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0016, 0.016, 10, 0.5)
# 4.43
# {0, 33, 4, 5, 68, 8, 77, 16, 21, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0016, 0.016, 10, 2)
# 4.68
# {0, 35, 4, 5, 8, 9, 17, 21, 54, 55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0162, 0.162, 1, 0.5)
# 4.64
# {5}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0162, 0.162, 1, 2)
# 4.56
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0162, 0.162, 10, 0.5)
# 4.46
# {0, 33, 4, 5, 6, 8, 77, 16, 21, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0162, 0.162, 10, 2)
# 4.58
# {0, 33, 4, 5, 68, 8, 77, 16, 21, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.162, 1.6200000000000003, 1, 0.5)
# 3.83
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.162, 1.6200000000000003, 1, 2)
# 3.95
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.162, 1.6200000000000003, 10, 0.5)
# 3.84
# {64, 65, 38, 76, 45, 48, 49, 52, 84, 24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.162, 1.6200000000000003, 10, 2)
# 3.8
# {64, 38, 76, 45, 44, 49, 52, 84, 24, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 1.6199999999999999, 16.2, 1, 0.5)
# 3.41
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 1.6199999999999999, 16.2, 1, 2)
# 3.25
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 1.6199999999999999, 16.2, 10, 0.5)
# 3.16
# {7, 71, 40, 12, 80, 19, 57, 27, 63, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 1.6199999999999999, 16.2, 10, 2)
# 3.26
# {0, 35, 4, 5, 68, 8, 77, 16, 17, 21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0016, 0.016, 1, 0.5)
# 4.43
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0016, 0.016, 1, 2)
# 4.23
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0016, 0.016, 10, 0.5)
# 4.11
# {32, 67, 5, 79, 80, 17, 82, 19, 87, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0016, 0.016, 10, 2)
# 4.18
# {65, 34, 10, 81, 18, 52, 57, 28, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0162, 0.162, 1, 0.5)
# 4.1
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0162, 0.162, 1, 2)
# 4.21
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0162, 0.162, 10, 0.5)
# 4.15
# {98, 69, 38, 71, 40, 7, 12, 77, 16, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0162, 0.162, 10, 2)
# 4.36
# {68, 71, 41, 42, 14, 79, 16, 50, 20, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.162, 1.6200000000000003, 1, 0.5)
# 3.56
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.162, 1.6200000000000003, 1, 2)
# 3.51
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.162, 1.6200000000000003, 10, 0.5)
# 3.57
# {96, 66, 77, 56, 24, 90, 59, 93, 62, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.162, 1.6200000000000003, 10, 2)
# 3.64
# {2, 35, 37, 74, 11, 43, 49, 89, 91, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 1.6199999999999999, 16.2, 1, 0.5)
# 3.54
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 1.6199999999999999, 16.2, 1, 2)
# 3.4
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 1.6199999999999999, 16.2, 10, 0.5)
# 3.36
# {68, 40, 41, 42, 12, 79, 16, 50, 87, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 1.6199999999999999, 16.2, 10, 2)
# 3.42
# {97, 10, 44, 28, 13, 46, 81, 52, 92, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0016, 0.016, 1, 0.5)
# 4.63
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0016, 0.016, 1, 2)
# 5.01
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0016, 0.016, 10, 0.5)
# 4.71
# {41, 11, 46, 80, 50, 84, 53, 23, 58, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0016, 0.016, 10, 2)
# 4.69
# {32, 43, 82, 51, 20, 52, 18, 89, 59, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0162, 0.162, 1, 0.5)
# 4.76
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0162, 0.162, 1, 2)
# 4.93
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0162, 0.162, 10, 0.5)
# 4.72
# {2, 4, 5, 71, 75, 45, 78, 19, 55, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0162, 0.162, 10, 2)
# 4.46
# {0, 4, 71, 47, 81, 19, 88, 56, 27, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.162, 1.6200000000000003, 1, 0.5)
# 3.85
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.162, 1.6200000000000003, 1, 2)
# 3.92
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.162, 1.6200000000000003, 10, 0.5)
# 3.85
# {90, 40, 10, 15, 84, 86, 58, 92, 93, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.162, 1.6200000000000003, 10, 2)
# 4.13
# {64, 32, 98, 37, 78, 79, 16, 49, 18, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 1.6199999999999999, 16.2, 1, 0.5)
# 3.55
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 1.6199999999999999, 16.2, 1, 2)
# 3.98
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 1.6199999999999999, 16.2, 10, 0.5)
# 3.87
# {0, 97, 34, 69, 73, 48, 83, 87, 57, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 1.6199999999999999, 16.2, 10, 2)
# 3.35
# {34, 69, 72, 74, 48, 83, 54, 57, 29, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0016, 0.016, 1, 0.5)
# 4.5
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0016, 0.016, 1, 2)
# 4.47
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0016, 0.016, 10, 0.5)
# 4.47
# {96, 66, 41, 44, 79, 86, 22, 58, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0016, 0.016, 10, 2)
# 4.6
# {33, 67, 37, 70, 7, 17, 18, 85, 21, 24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0162, 0.162, 1, 0.5)
# 4.51
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0162, 0.162, 1, 2)
# 4.38
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0162, 0.162, 10, 0.5)
# 4.37
# {3, 59, 74, 75, 13, 14, 16, 54, 27, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0162, 0.162, 10, 2)
# 4.52
# {6, 76, 78, 47, 48, 82, 51, 57, 26, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.162, 1.6200000000000003, 1, 0.5)
# 3.99
# {96}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.162, 1.6200000000000003, 1, 2)
# 3.86
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.162, 1.6200000000000003, 10, 0.5)
# 3.99
# {0, 66, 71, 8, 41, 10, 42, 49, 84, 22}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.162, 1.6200000000000003, 10, 2)
# 3.98
# {98, 5, 6, 76, 78, 48, 52, 57, 25, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 1.6199999999999999, 16.2, 1, 0.5)
# 3.23
# {37}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 1.6199999999999999, 16.2, 1, 2)
# 3.2
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 1.6199999999999999, 16.2, 10, 0.5)
# 3.93
# {96, 3, 44, 14, 79, 20, 86, 58, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 1.6199999999999999, 16.2, 10, 2)
# 3.78
# {64, 6, 40, 78, 82, 51, 87, 89, 26, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0016, 0.016, 1, 0.5)
# 4.78
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0016, 0.016, 1, 2)
# 4.61
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0016, 0.016, 10, 0.5)
# 4.51
# {0, 65, 40, 72, 47, 85, 56, 27, 60, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0016, 0.016, 10, 2)
# 4.47
# {64, 65, 2, 98, 5, 72, 17, 27, 60, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0162, 0.162, 1, 0.5)
# 4.55
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0162, 0.162, 1, 2)
# 4.35
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0162, 0.162, 10, 0.5)
# 4.46
# {0, 65, 34, 35, 4, 9, 47, 85, 56, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0162, 0.162, 10, 2)
# 4.62
# {6, 7, 73, 42, 77, 52, 55, 24, 57, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.162, 1.6200000000000003, 1, 0.5)
# 3.83
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.162, 1.6200000000000003, 1, 2)
# 4.05
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.162, 1.6200000000000003, 10, 0.5)
# 3.76
# {33, 34, 35, 4, 72, 41, 9, 80, 53, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.162, 1.6200000000000003, 10, 2)
# 3.93
# {97, 5, 71, 75, 13, 16, 19, 87, 26, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 1.6199999999999999, 16.2, 1, 0.5)
# 3.35
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 1.6199999999999999, 16.2, 1, 2)
# 3.33
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 1.6199999999999999, 16.2, 10, 0.5)
# 3.71
# {10, 15, 49, 83, 54, 23, 25, 90, 93, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 1.6199999999999999, 16.2, 10, 2)
# 3.32
# {76, 15, 50, 18, 23, 88, 94, 90, 93, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0016, 0.016, 1, 0.5)
# 4.75
# {34}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0016, 0.016, 1, 2)
# 4.69
# {34}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0016, 0.016, 10, 0.5)
# 4.77
# {33, 65, 68, 27, 43, 47, 52, 22, 25, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0016, 0.016, 10, 2)
# 4.58
# {32, 3, 99, 37, 39, 45, 51, 54, 57, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0162, 0.162, 1, 0.5)
# 4.62
# {47}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0162, 0.162, 1, 2)
# 4.57
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0162, 0.162, 10, 0.5)
# 4.77
# {33, 68, 27, 47, 52, 22, 87, 25, 91, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0162, 0.162, 10, 2)
# 4.77
# {33, 68, 27, 43, 47, 52, 22, 25, 91, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.162, 1.6200000000000003, 1, 0.5)
# 3.88
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.162, 1.6200000000000003, 1, 2)
# 3.71
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.162, 1.6200000000000003, 10, 0.5)
# 3.8
# {33, 65, 68, 91, 43, 47, 52, 22, 25, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.162, 1.6200000000000003, 10, 2)
# 3.8
# {33, 27, 43, 47, 52, 22, 87, 89, 90, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 1.6199999999999999, 16.2, 1, 0.5)
# 3.59
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 1.6199999999999999, 16.2, 1, 2)
# 3.29
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 1.6199999999999999, 16.2, 10, 0.5)
# 4.0
# {98, 35, 3, 37, 39, 45, 53, 54, 93, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 1.6199999999999999, 16.2, 10, 2)
# 3.82
# {33, 34, 91, 43, 52, 22, 87, 27, 92, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0016, 0.016, 1, 0.5)
# 4.22
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0016, 0.016, 1, 2)
# 4.03
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0016, 0.016, 10, 0.5)
# 3.95
# {96, 1, 6, 38, 40, 41, 76, 17, 20, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0016, 0.016, 10, 2)
# 4.2
# {32, 35, 4, 99, 9, 80, 19, 51, 53, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0162, 0.162, 1, 0.5)
# 4.16
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0162, 0.162, 1, 2)
# 3.93
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0162, 0.162, 10, 0.5)
# 4.22
# {65, 37, 40, 41, 14, 78, 17, 20, 86, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0162, 0.162, 10, 2)
# 4.09
# {69, 75, 12, 79, 81, 57, 27, 92, 29, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.162, 1.6200000000000003, 1, 0.5)
# 3.75
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.162, 1.6200000000000003, 1, 2)
# 3.79
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.162, 1.6200000000000003, 10, 0.5)
# 3.8
# {64, 34, 10, 43, 42, 77, 81, 18, 85, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.162, 1.6200000000000003, 10, 2)
# 3.92
# {38, 76, 17, 20, 52, 86, 87, 60, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 1.6199999999999999, 16.2, 1, 0.5)
# 3.58
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 1.6199999999999999, 16.2, 1, 2)
# 3.42
# {88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 1.6199999999999999, 16.2, 10, 0.5)
# 3.14
# {64, 33, 10, 42, 77, 15, 81, 18, 85, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 1.6199999999999999, 16.2, 10, 2)
# 3.49
# {3, 69, 7, 74, 75, 12, 82, 27, 92, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0016, 0.016, 1, 0.5)
# 3.06
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0016, 0.016, 1, 2)
# 3.05
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0016, 0.016, 10, 0.5)
# 2.18
# {98, 5, 47, 17, 49, 85, 22, 87, 24, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0016, 0.016, 10, 2)
# 3.33
# {1, 97, 6, 71, 80, 51, 88, 90, 28, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0162, 0.162, 1, 0.5)
# 3.44
# {25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0162, 0.162, 1, 2)
# 3.3
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0162, 0.162, 10, 0.5)
# 3.36
# {64, 69, 38, 8, 11, 46, 48, 88, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0162, 0.162, 10, 2)
# 3.1
# {66, 99, 36, 26, 7, 43, 79, 84, 58, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.162, 1.6200000000000003, 1, 0.5)
# 3.34
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.162, 1.6200000000000003, 1, 2)
# 3.32
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.162, 1.6200000000000003, 10, 0.5)
# 3.55
# {64, 68, 69, 38, 8, 11, 48, 90, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.162, 1.6200000000000003, 10, 2)
# 3.44
# {66, 36, 58, 7, 8, 74, 43, 79, 26, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 1.6199999999999999, 16.2, 1, 0.5)
# 3.26
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 1.6199999999999999, 16.2, 1, 2)
# 3.28
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 1.6199999999999999, 16.2, 10, 0.5)
# 3.1
# {65, 70, 12, 78, 80, 83, 53, 62, 30, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 1.6199999999999999, 16.2, 10, 2)
# 3.19
# {3, 35, 37, 10, 75, 14, 50, 19, 27, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0016, 0.016, 1, 0.5)
# 4.15
# {7}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0016, 0.016, 1, 2)
# 4.25
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0016, 0.016, 10, 0.5)
# 4.13
# {97, 2, 6, 50, 55, 88, 90, 92, 93, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0016, 0.016, 10, 2)
# 4.2
# {33, 2, 9, 75, 17, 54, 55, 88, 58, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0162, 0.162, 1, 0.5)
# 4.2
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0162, 0.162, 1, 2)
# 4.3
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0162, 0.162, 10, 0.5)
# 4.4
# {97, 33, 6, 39, 9, 75, 17, 88, 90, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0162, 0.162, 10, 2)
# 4.44
# {96, 38, 41, 12, 14, 16, 85, 56, 89, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.162, 1.6200000000000003, 1, 0.5)
# 3.69
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.162, 1.6200000000000003, 1, 2)
# 3.81
# {93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.162, 1.6200000000000003, 10, 0.5)
# 3.62
# {0, 99, 36, 35, 82, 83, 52, 50, 59, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.162, 1.6200000000000003, 10, 2)
# 3.85
# {64, 38, 7, 72, 40, 12, 14, 16, 86, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 1.6199999999999999, 16.2, 1, 0.5)
# 3.39
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 1.6199999999999999, 16.2, 1, 2)
# 3.88
# {93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 1.6199999999999999, 16.2, 10, 0.5)
# 3.56
# {4, 74, 43, 42, 81, 83, 53, 59, 60, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 1.6199999999999999, 16.2, 10, 2)
# 3.37
# {1, 98, 68, 11, 45, 79, 29, 25, 61, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0016, 0.016, 1, 0.5)
# 3.95
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0016, 0.016, 1, 2)
# 3.83
# {11}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0016, 0.016, 10, 0.5)
# 3.88
# {64, 0, 72, 9, 44, 45, 14, 51, 84, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0016, 0.016, 10, 2)
# 3.73
# {32, 96, 5, 72, 11, 46, 80, 48, 25, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0162, 0.162, 1, 0.5)
# 3.87
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0162, 0.162, 1, 2)
# 3.67
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0162, 0.162, 10, 0.5)
# 3.8
# {32, 5, 6, 37, 41, 23, 54, 87, 25, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0162, 0.162, 10, 2)
# 3.71
# {1, 38, 7, 50, 19, 85, 55, 26, 60, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.162, 1.6200000000000003, 1, 0.5)
# 3.68
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.162, 1.6200000000000003, 1, 2)
# 3.59
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.162, 1.6200000000000003, 10, 0.5)
# 3.52
# {33, 2, 35, 68, 71, 39, 76, 16, 83, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.162, 1.6200000000000003, 10, 2)
# 3.55
# {64, 67, 72, 11, 75, 77, 46, 45, 84, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 1.6199999999999999, 16.2, 1, 0.5)
# 3.38
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 1.6199999999999999, 16.2, 1, 2)
# 3.15
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 1.6199999999999999, 16.2, 10, 0.5)
# 3.32
# {32, 5, 6, 80, 94, 54, 87, 25, 27, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 1.6199999999999999, 16.2, 10, 2)
# 3.35
# {33, 35, 8, 73, 47, 16, 17, 82, 29, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0016, 0.016, 1, 0.5)
# 4.48
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0016, 0.016, 1, 2)
# 4.22
# {53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0016, 0.016, 10, 0.5)
# 4.25
# {96, 5, 74, 11, 12, 45, 54, 59, 92, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0016, 0.016, 10, 2)
# 4.03
# {68, 7, 10, 43, 17, 82, 86, 62, 30, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0162, 0.162, 1, 0.5)
# 4.51
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0162, 0.162, 1, 2)
# 4.17
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0162, 0.162, 10, 0.5)
# 4.16
# {36, 68, 6, 7, 43, 80, 82, 57, 30, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0162, 0.162, 10, 2)
# 4.16
# {32, 65, 37, 9, 77, 46, 78, 19, 55, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.162, 1.6200000000000003, 1, 0.5)
# 3.69
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.162, 1.6200000000000003, 1, 2)
# 3.7
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.162, 1.6200000000000003, 10, 0.5)
# 3.77
# {97, 34, 66, 90, 74, 75, 76, 24, 26, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.162, 1.6200000000000003, 10, 2)
# 3.69
# {1, 99, 5, 59, 12, 47, 85, 54, 27, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 1.6199999999999999, 16.2, 1, 0.5)
# 3.71
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 1.6199999999999999, 16.2, 1, 2)
# 3.56
# {59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 1.6199999999999999, 16.2, 10, 0.5)
# 3.27
# {98, 37, 40, 73, 46, 19, 55, 91, 60, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 1.6199999999999999, 16.2, 10, 2)
# 3.78
# {32, 65, 35, 37, 73, 46, 19, 53, 55, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0016, 0.016, 1, 0.5)
# 4.13
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0016, 0.016, 1, 2)
# 4.08
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0016, 0.016, 10, 0.5)
# 4.36
# {98, 2, 69, 40, 77, 19, 85, 26, 29, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0016, 0.016, 10, 2)
# 3.88
# {66, 6, 42, 75, 13, 14, 48, 53, 90, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0162, 0.162, 1, 0.5)
# 4.15
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0162, 0.162, 1, 2)
# 4.18
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0162, 0.162, 10, 0.5)
# 4.13
# {38, 40, 77, 17, 19, 85, 25, 26, 29, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0162, 0.162, 10, 2)
# 4.21
# {1, 99, 3, 73, 41, 16, 20, 55, 89, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.162, 1.6200000000000003, 1, 0.5)
# 3.65
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.162, 1.6200000000000003, 1, 2)
# 3.86
# {3}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.162, 1.6200000000000003, 10, 0.5)
# 3.77
# {32, 36, 15, 83, 84, 88, 89, 91, 60, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.162, 1.6200000000000003, 10, 2)
# 3.75
# {66, 6, 38, 72, 42, 14, 47, 90, 27, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 1.6199999999999999, 16.2, 1, 0.5)
# 3.37
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 1.6199999999999999, 16.2, 1, 2)
# 3.6
# {92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 1.6199999999999999, 16.2, 10, 0.5)
# 3.36
# {32, 1, 3, 99, 15, 16, 82, 83, 55, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 1.6199999999999999, 16.2, 10, 2)
# 3.63
# {32, 36, 15, 82, 83, 84, 88, 89, 60, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0016, 0.016, 1, 0.5)
# 4.45
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0016, 0.016, 1, 2)
# 4.36
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0016, 0.016, 10, 0.5)
# 4.17
# {32, 67, 72, 42, 46, 55, 87, 23, 57, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0016, 0.016, 10, 2)
# 4.36
# {32, 67, 69, 42, 46, 23, 55, 87, 89, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0162, 0.162, 1, 0.5)
# 4.46
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0162, 0.162, 1, 2)
# 4.5
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0162, 0.162, 10, 0.5)
# 4.45
# {0, 65, 97, 37, 38, 6, 47, 25, 60, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0162, 0.162, 10, 2)
# 4.55
# {96, 1, 99, 8, 79, 48, 19, 85, 58, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.162, 1.6200000000000003, 1, 0.5)
# 3.79
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.162, 1.6200000000000003, 1, 2)
# 3.73
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.162, 1.6200000000000003, 10, 0.5)
# 3.53
# {64, 11, 16, 82, 21, 56, 59, 92, 29, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.162, 1.6200000000000003, 10, 2)
# 3.71
# {34, 66, 4, 99, 39, 12, 86, 22, 24, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 1.6199999999999999, 16.2, 1, 0.5)
# 3.61
# {30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 1.6199999999999999, 16.2, 1, 2)
# 3.72
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 1.6199999999999999, 16.2, 10, 0.5)
# 3.57
# {34, 99, 4, 66, 39, 9, 41, 86, 90, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 1.6199999999999999, 16.2, 10, 2)
# 3.16
# {33, 35, 3, 7, 74, 76, 45, 17, 84, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0016, 0.016, 1, 0.5)
# 4.45
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0016, 0.016, 1, 2)
# 4.67
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0016, 0.016, 10, 0.5)
# 4.76
# {65, 33, 13, 45, 52, 53, 55, 57, 26, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0016, 0.016, 10, 2)
# 4.6
# {65, 33, 13, 45, 77, 53, 55, 57, 26, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0162, 0.162, 1, 0.5)
# 4.63
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0162, 0.162, 1, 2)
# 4.6
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0162, 0.162, 10, 0.5)
# 4.83
# {64, 98, 71, 11, 12, 21, 54, 91, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0162, 0.162, 10, 2)
# 4.45
# {33, 65, 37, 13, 77, 53, 55, 57, 60, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.162, 1.6200000000000003, 1, 0.5)
# 3.76
# {8}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.162, 1.6200000000000003, 1, 2)
# 3.77
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.162, 1.6200000000000003, 10, 0.5)
# 3.68
# {67, 69, 71, 11, 19, 21, 95, 62, 30, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.162, 1.6200000000000003, 10, 2)
# 3.7
# {99, 8, 9, 10, 75, 44, 79, 49, 84, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 1.6199999999999999, 16.2, 1, 0.5)
# 3.62
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 1.6199999999999999, 16.2, 1, 2)
# 3.07
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 1.6199999999999999, 16.2, 10, 0.5)
# 3.08
# {64, 32, 67, 71, 11, 46, 19, 21, 91, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 1.6199999999999999, 16.2, 10, 2)
# 3.01
# {32, 96, 69, 46, 19, 95, 21, 30, 62, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0016, 0.016, 1, 0.5)
# 4.65
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0016, 0.016, 1, 2)
# 4.33
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0016, 0.016, 10, 0.5)
# 4.56
# {97, 33, 40, 10, 12, 17, 51, 55, 57, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0016, 0.016, 10, 2)
# 4.46
# {96, 5, 75, 43, 13, 45, 80, 24, 25, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0162, 0.162, 1, 0.5)
# 4.61
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0162, 0.162, 1, 2)
# 4.49
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0162, 0.162, 10, 0.5)
# 4.73
# {96, 5, 43, 75, 13, 45, 80, 24, 25, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0162, 0.162, 10, 2)
# 4.59
# {64, 98, 73, 42, 9, 49, 50, 85, 58, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.162, 1.6200000000000003, 1, 0.5)
# 3.96
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.162, 1.6200000000000003, 1, 2)
# 4.04
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.162, 1.6200000000000003, 10, 0.5)
# 3.78
# {65, 8, 41, 91, 78, 48, 19, 27, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.162, 1.6200000000000003, 10, 2)
# 3.86
# {34, 4, 71, 79, 84, 53, 54, 22, 29, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 1.6199999999999999, 16.2, 1, 0.5)
# 3.34
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 1.6199999999999999, 16.2, 1, 2)
# 3.26
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 1.6199999999999999, 16.2, 10, 0.5)
# 3.58
# {0, 26, 36, 77, 14, 87, 25, 90, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 1.6199999999999999, 16.2, 10, 2)
# 3.98
# {33, 6, 40, 12, 15, 17, 81, 51, 56, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0016, 0.016, 1, 0.5)
# 4.79
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0016, 0.016, 1, 2)
# 4.84
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0016, 0.016, 10, 0.5)
# 4.8
# {98, 66, 99, 11, 80, 18, 56, 91, 61, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0016, 0.016, 10, 2)
# 4.61
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-bd63b14e0498> in <module>
#     111                 infected_nodes = None
#     112                 while infected_nodes is None : #infecting 'start' number of network neighbours
# --> 113                     infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)
#     114                 print(infected_nodes)
#     115                 infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
#
# KeyboardInterrupt:
