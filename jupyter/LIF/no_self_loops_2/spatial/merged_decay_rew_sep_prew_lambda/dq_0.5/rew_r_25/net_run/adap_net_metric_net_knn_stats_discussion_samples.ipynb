# %% [markdown]
# ## Leaky integrated firing neuron model
# ## Few feautures :
# ### Spatial network, no memory term but exponential decay of cumulative dose
#
# This is a minor change of the Dodds and Watts model
# Implement adaptive rewiring and generate statistics

# %%
#importing the required libraries

import networkx as nx
import matplotlib.pyplot as plt #for plotting
import numpy as np #for using arrays and vectorising the code wherever possible
import scipy
import random
# from numba import jit #numba precomplier to make the code faster
import pandas as pd
import copy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Variables used in the simulation

# %%
N = 100
gamma = 1 #decay of cumulative dose per unit time (second)
gamma = gamma
T = 100 #total number of seconds
dt = 0.05 #seconds
dt_netrun = 10
'''number of simulation steps is T/dt'''

'''Dodds watts parameters'''
p = 1 #rate of dose transfer (per unit time (second))
p = p*dt #rate of dose transfer per unit simulation step
r = 1/dt
r = r*dt
rho = 1/dt
rho = rho*dt
# r = 0.5
# r = r*dt

d_star = 1
# dose_quantity = 1
D_ini = 3

'''network parameters'''
circ_rad = 100 #for a network in which each node is connected to other nodes withing a circle of radius circ_rad
nn = 10 #the number of nearest neighbours(i.e. k) in knn
average_degree = 6
total_edges = N*2

'''rewiring parameters'''
rew_r = 25
density = 1/N
# p_rew = 5 #rate of rewiring(per unit time(second))
# p_rew = p_rew*dt

'''tolerance to determine initial network topology'''
tol = 0.5
steady_counter_val = 500

# %% [markdown]
# # Creating the network.
# ### The network outputs coordinates, distance matrix, edge_list and adjacency matrix

# %%
'''
obtains the number of nodes N
generates N points
calculates euclidean distance between each pair of points
returns the coordinates of the points and the distance matrix which is N*N
'''
def calc_dist(N) :
    coords = []
    for counter in range(N) :
        coords.append((N*np.random.random(),N*np.random.random()))

    dist_mat = scipy.spatial.distance.cdist(coords,coords)
    return dist_mat,coords

# %% [markdown]
# ### 1. metric network

# %%
'''network = connect to points withing a circle of radius'''
#creates a link between points/nodes which satisfies the conditions of the network
def coupling(dist_mat,circ_rad) :
    edge_list = []
    edge_mask = (dist_mat<circ_rad) & (dist_mat>0)
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(edge_mask))))
#     print(type(np.ndarray.tolist(np.transpose(np.where(edge_mask)))))
    return edge_list

# %% [markdown]
# ### 2. K nearest neighbour network

# %%
'''network = knn'''
def knn(dist_mat,nn,N) :
    near_neigh = np.argsort(dist_mat)
    selec_near_neigh = np.zeros((N,nn))
    selec_near_neigh = near_neigh[:,0:nn+1]

    edge_list = []
    for i in range(N) :
        for j in range(1,nn+1) :
            link = [i,selec_near_neigh[i,j]]
            edge_list.append(link)

    return edge_list

# %% [markdown]
# ### 3. Random Network : GNP type

# %%
'''random network'''
def rand_network(average_degree,N) :
    z1 = np.random.uniform(size = (N,N))
    E,F = np.meshgrid(np.arange(0,N),np.arange(0,N))
    mask = ((average_degree/N) > z1) & (E!=F)
    adjacency_matrix = np.int64(np.zeros(shape=(N,N)))
    adjacency_matrix[mask] = np.int64(1)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list,adjacency_matrix

# %% [markdown]
# ### 4. Random Network : GNM type

# %%
def rand_net_gnm(total_edges,N) :
    the_graph = nx.gnm_random_graph(N, total_edges,directed=True)
    adjacency_matrix = nx.adjacency_matrix(the_graph)
    adjacency_matrix = np.asarray(adjacency_matrix.todense())
    np.fill_diagonal(adjacency_matrix,0)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list

# %% [markdown]
# # Function defintions required for the main part of the script

# %%
# # @jit(nopython=True)
# '''infecting the left part of space.'''
# def left_part_infec(N) :
#     x_coord = []
#     y_coord = []
#     for j in range(len(coords)) :
#         x_coord.append(coords[j][0])
#         y_coord.append(coords[j][1])
#     x_coord = np.asarray(x_coord)
#     y_coord = np.asarray(y_coord)
#     points = np.asarray(np.where(x_coord<(N/5))) 
#     indi_state[points.T] = 2

#     return indi_state

# %%
'''infecting connected nodes'''
def InfectNetworkNeighbors(net,seed_node,init_infected_nodes):
     # if in bulk find one node randomly, and infect its neighbours
    infected_nodes = set()
    candidate_nodes = set()
    explored_nodes = set()

    #pick the seed node
    infected_nodes.add(seed_node)
    explored_nodes.add(seed_node)

    curr_node=seed_node

    #add its neighbors to the list of candidates
    for n in net.neighbors(curr_node):
        candidate_nodes.add(int(n))
    #print( curr_node)
    #print( candidate_nodes)

    #while we need to select more nodes...
    while len(infected_nodes) < init_infected_nodes:

        #if there are candidate nodes, select one of them
        if(len(candidate_nodes) > 0):
            new_node = np.random.choice(list(candidate_nodes),1)[0]
            infected_nodes.add(new_node)
            candidate_nodes.remove(new_node)

        elif len(infected_nodes - explored_nodes) > 0:
            curr_node = np.random.choice(list(infected_nodes -
            explored_nodes),1)[0]
            explored_nodes.add(curr_node)
            for n in set(net.neighbors(curr_node)) - infected_nodes:
                candidate_nodes.add(n)

        else:
#             print('Initial node infection step failed')
            return None
    return infected_nodes

# %%
''' function to transfer doses'''
# @jit(nopython=True)
def dose(adj_mat,p,partner_state_prev,d) :

    z1 = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    dose_transfer_mask = p > z1
    mod_adj_mat = np.multiply(adj_mat,z1) #modifying adjacency matrix to include the proability of dose transfer
    dose_mask = (p>mod_adj_mat) & (adj_mat!=0) & (partner_state_prev == 2)
    d[dose_mask] = dose_quantity #whenever it is proabable, dose transfer occurs
    
    return d

# %%
def rew(p_rew,adjacency_matrix,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r) :
    
    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew > z1_rew_prew)  & (indi_state_for_rew_prev == 1) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    rew_mask_minus1 = (p_rew > z1_rew_prew) & (indi_state_for_rew_prev == 2)
    #break links. Dont create any.
    adjacency_matrix[rew_mask_minus1] = 0
    rew_mask_minus2 = ((lamb_da*OD_mesh2) > z1_rew_lambda) & (indi_state_for_rew_prev == 1)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
def let_it_run(p_rew_netrun,adjacency_matrix,OD_mesh2,lamb_da_netrun,density,rew_r) :

    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew_netrun > z1_rew_prew) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    
    rew_mask_minus2 = ((lamb_da_netrun*OD_mesh2) > z1_rew_lambda)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
'''function to update cumulative doses'''
def cumu_dose(d,D_prev,gamma) :
    I = d.sum(axis=1).reshape(N,1)
#     I = 0
    D = (D_prev - (gamma*D_prev*dt)) + I
    return D

# %%
'''function to update the states of the nodes of the system'''
def upd_indi_state(D,d_star,indi_state_prev) :
    
    z2 = np.random.uniform(size=(N,1))
    z3 = np.random.uniform(size=(N,1))
    
    indi_state = indi_state_prev
    
    indi_state_mask1 = (D>=d_star) & (indi_state_prev==1)
    indi_state[indi_state_mask1] = 2
    
    indi_state_mask21 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho>=z3)
    indi_state[indi_state_mask21] = 1
    
    indi_state_mask22 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho<z3)
    indi_state[indi_state_mask22] = 3
    
    indi_state_mask23 = (D<d_star) & (indi_state_prev==2) & (r<z2)
    indi_state[indi_state_mask23] = 2
    
    return indi_state

# %%
'''function to get/identify the infected nodes and the suceptible nodes'''
def states(indi_state) :
    infec_indi = []
    suscep_indi = []
    infec_indi = np.transpose(np.where(indi_state==2))
    suscep_indi = np.transpose(np.where(indi_state==1))
    return infec_indi,suscep_indi

# %%
def networkx_graph(coords,edge_list) :
    G = nx.DiGraph()
    pos = {(i): (coords[i][0],coords[i][1]) for i in range(N)}
    G.add_nodes_from(pos.keys())
    G.add_edges_from(edge_list)
    return G

# %%
def edge_from_adj_mat(adj_mat_list,q):
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adj_mat_list[q]==1))))
    return edge_list

# %% [markdown]
# # The main part of the script

# %%
#infected state time series data frame
#columns indicate the time steps
timeseries_infec_frac = pd.DataFrame()

#in degree as columns and rows as nodes
timeseries_in_degree = pd.DataFrame() 

#out degree as columns and rows as nodes
timeseries_out_degree = pd.DataFrame()

#strongly connected components as columns
timeseries_connec_comps = pd.DataFrame()

#mean of out degree as columns and rows as nodes
timeseries_out_degree_mean = pd.DataFrame()

# %%
vals = round(1/((density)*(np.pi)*(rew_r*rew_r)),3)
p_rew_vals = [round(0.1*vals,3),round(vals,3),round(10*vals,3),round(100*vals,3)]
start_vals = [1,10]
dose_quantity_vals = [0.5,2]

# %%
for sim in range(70,70+25) :
    
    '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''
    dist_mat,coords = calc_dist(N) #node placement
    edge_list = knn(dist_mat,nn,N)
    bef_netrun_org_adj_mat = np.int64(np.zeros((N,N)))
    for i in range(len(edge_list)):
        bef_netrun_org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)
    df_row = 0
    
    for p_rew_org in p_rew_vals : #rate of rewiring (per unit time (second))
        if p_rew_org == round(0.1*vals,3) :
            dt_netrun = 100
        elif p_rew_org == round(vals,3):
            dt_netrun = 10
        else :
            dt_netrun = dt
            
        lamb_da_org = p_rew_org/10        
        '''parameters for the coupling dynamics'''
        lamb_da = lamb_da_org*dt
        p_rew = p_rew_org*dt
        
        '''parameters for the network satbilisation'''
        lamb_da_netrun = lamb_da_org*dt_netrun
        p_rew_netrun = p_rew_org*dt_netrun
        
        for start in start_vals : #rate of dose transfer (per unit time (second))
            for dose_quantity in dose_quantity_vals : #number of nodes to infect initially
                print('(sim,lamb_da,p_rew,start,dose_quantity) = ', (sim,lamb_da/dt,p_rew/dt,start,dose_quantity))

                '''clearing exsiting data frames and creating new ones '''
                timeseries_infec_frac = pd.DataFrame()
                timeseries_in_degree = pd.DataFrame()
                timeseries_out_degree = pd.DataFrame()
                timeseries_connec_comps = pd.DataFrame()
                timeseries_out_degree_mean = pd.DataFrame()

                q = 0 #to generate new edge_list from the new adjacency matrix 
                t = np.arange(0,T,dt)

                adj_mat_list = []
                adj_mat = copy.deepcopy(bef_netrun_org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new) #list of arrays which shows the time series of the adjacency matrix
    
                '''obtaining a steady network topology before starting the dynamics on the network'''

                q = 0
                steady_counter = 0
                df_col = 0
                no_reset = 0 
                while steady_counter < steady_counter_val :

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])
                    timeseries_out_degree_mean.loc[0,df_col] = timeseries_out_degree.iloc[:,df_col].mean()
                    if df_col-1 >= 0 :
            #             print(timeseries_out_degree_mean.loc[0,df_col])
                        if np.abs(timeseries_out_degree_mean.loc[0,df_col] - timeseries_out_degree_mean.loc[0,df_col-1]) <= tol :
                            steady_counter = steady_counter + 1
                        else :
                            steady_counter = 0
                            no_reset = no_reset + 1
                            print('oops')
                            if no_reset > 100 :
                                break

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)    
                    adj_mat = let_it_run(p_rew_netrun,adj_mat,OD_mesh2,lamb_da_netrun,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    q = q + 1 
                    df_col = df_col + 1
                    
                '''steady network topology obtained, start the dynamics now'''
                print(timeseries_out_degree_mean.loc[0,df_col-1])
                timeseries_out_degree = pd.DataFrame()
                df_col = 0
                q = 0 
                edge_list = copy.deepcopy(edge_list)
                G = copy.deepcopy(G)
                org_adj_mat = copy.deepcopy(adj_mat_new)

                numpy_array = np.zeros((N,len(t)),dtype = np.int64)

                D_array = np.zeros((N,len(t)))
                for i in range(len(edge_list)):
                    org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)

                adj_mat_list = []
                adj_mat = copy.deepcopy(org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new)


                '''from G, obtain the in degree and the out degree'''
                timeseries_in_degree.loc[:,0] = np.asarray([val for (node, val) in G.in_degree()])
                timeseries_out_degree.loc[:,0] = np.asarray([val for (node, val) in G.out_degree()])

                '''strongly and weekely connected components'''
                timeseries_connec_comps.loc[0,0] = nx.number_connected_components(G.to_undirected())

                '''choosing initially infected nodes'''
                indi_state = np.random.randint(1,2,size=(N,1))
                infected_nodes = None
                while infected_nodes is None : #infecting 'start' number of network neighbours
                    infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)      
                print(infected_nodes)
                infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
                indi_state[infected_nodes[:,0],0] = 2

                A,B = np.meshgrid(indi_state,indi_state) 
                partner_state = copy.deepcopy(A)
                indi_state_for_rew = copy.deepcopy(B)

    #             numpy_array [:,0] = indi_state[:,0]

                indi_state_prev = copy.deepcopy(indi_state)
                partner_state_prev = copy.deepcopy(partner_state)
                indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                d = np.zeros((len(adj_mat),len(adj_mat[0])))

                D = np.zeros((N,1))
                D[np.where(indi_state==2)] = D_ini
                D_array[:,0] = D[:,0]
                D_prev = copy.deepcopy(D)

                infec_frac = np.count_nonzero(indi_state == 2)/N
                timeseries_infec_frac.loc[df_row,0] = infec_frac
                '''the main part of the simulation'''
                counter = 0
                df_col = 1
                for t in np.arange(dt,T,dt) :
                    q = q + 1 
                    counter = counter + 1
                    infec_indi = []
                    suscep_indi = []
                    d = np.zeros((len(adj_mat),len(adj_mat[0])))
                    d = dose(adj_mat,p,partner_state_prev,d)

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)
                    adj_mat = rew(p_rew,adj_mat,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    '''from G, obtain the in degree and the out degree'''
                    timeseries_in_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.in_degree()])
                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])

                    '''strongly and weekely connected components'''
                    timeseries_connec_comps.loc[df_row,df_col] = nx.number_connected_components(G.to_undirected())

                    D = cumu_dose(d,D_prev,gamma)
                    D_array[:,counter] = D[:,0]

                    indi_state = upd_indi_state(D,d_star,indi_state_prev)
                    infec_frac = np.count_nonzero(indi_state == 2)/N
                    timeseries_infec_frac.loc[df_row,df_col] = infec_frac

    #                 numpy_array[:,counter] = indi_state[:,0]
                    A,B = np.meshgrid(indi_state,indi_state)

                    infec_indi, suscep_indi = states(indi_state)

                    partner_state = copy.deepcopy(A)
                    indi_state_for_rew = copy.deepcopy(B)
                    indi_state_prev = copy.deepcopy(indi_state)
                    partner_state_prev = copy.deepcopy(partner_state)
                    indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                    D_prev = copy.deepcopy(D)
                    D = np.zeros((N,1))
                    df_col = df_col + 1 

    #             df_row = df_row + 1 #going to the next row of the df to store timeseries of next (p,start)

                filename_infec_frac = 'infec_frac.h5'
                filename_in_deg = 'in_deg.h5'
                filename_out_deg = 'out_deg.h5'
                filename_connec_comps = 'connec_comps.h5'
                p_rew_val = '%g'%(p_rew/dt)
                key_val = 'sim_'+str(sim)+'_p_rew_'+str(p_rew_val)+'_start_'+str(start)+'_dq_'+str(dose_quantity)
#                 print(key_val)
                timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
                timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
                timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
                timeseries_connec_comps.to_hdf(filename_connec_comps, key = key_val, mode='a')
                df_row = 0
# Out:
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0005, 0.005, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.66
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0005, 0.005, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.88
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0005, 0.005, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.72
# {32, 64, 70, 7, 74, 51, 88, 59, 28, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0005, 0.005, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.48
# {33, 99, 72, 42, 75, 12, 46, 14, 59, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.005099999999999999, 0.051000000000000004, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.03
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.005099999999999999, 0.051000000000000004, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.1
# {93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.005099999999999999, 0.051000000000000004, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.94
# {1, 66, 35, 3, 8, 79, 83, 52, 86, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.67
# {3, 36, 5, 6, 8, 43, 17, 22, 23, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.051000000000000004, 0.51, 1, 0.5)
# 8.83
# {8}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.051000000000000004, 0.51, 1, 2)
# 8.75
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.051000000000000004, 0.51, 10, 0.5)
# 8.46
# {97, 4, 5, 39, 79, 19, 56, 57, 58, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.051000000000000004, 0.51, 10, 2)
# 8.75
# {99, 70, 7, 72, 42, 75, 12, 61, 59, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.51, 5.1, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 8.08
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.51, 5.1, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.88
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.51, 5.1, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 8.25
# {66, 35, 36, 39, 43, 80, 51, 90, 27, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.51, 5.1, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 8.1
# {33, 11, 44, 75, 14, 81, 50, 61, 21, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0005, 0.005, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.62
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0005, 0.005, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.53
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0005, 0.005, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.61
# {65, 1, 37, 76, 13, 79, 83, 85, 27, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0005, 0.005, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.47
# {40, 12, 44, 15, 21, 89, 58, 92, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.005099999999999999, 0.051000000000000004, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.53
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.005099999999999999, 0.051000000000000004, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.63
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.005099999999999999, 0.051000000000000004, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.93
# {68, 69, 10, 43, 12, 44, 84, 56, 92, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.01
# {68, 5, 75, 12, 77, 44, 80, 20, 24, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.051000000000000004, 0.51, 1, 0.5)
# 8.72
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.051000000000000004, 0.51, 1, 2)
# 8.5
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.051000000000000004, 0.51, 10, 0.5)
# 8.2
# {97, 34, 99, 33, 7, 74, 11, 50, 22, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.051000000000000004, 0.51, 10, 2)
# 8.74
# {64, 2, 3, 39, 72, 42, 51, 23, 90, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.51, 5.1, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.8
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.51, 5.1, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.8
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.51, 5.1, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 8.1
# {68, 75, 78, 79, 82, 19, 52, 85, 56, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.51, 5.1, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 8.35
# {32, 16, 83, 19, 85, 22, 57, 27, 28, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0005, 0.005, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.03
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0005, 0.005, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.68
# {8}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0005, 0.005, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.64
# {32, 1, 2, 99, 8, 10, 79, 19, 21, 54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0005, 0.005, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.17
# {96, 1, 64, 35, 47, 80, 85, 55, 56, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.005099999999999999, 0.051000000000000004, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.64
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.005099999999999999, 0.051000000000000004, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.84
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.005099999999999999, 0.051000000000000004, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.99
# {38, 71, 8, 47, 79, 19, 85, 54, 86, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.06
# {38, 40, 9, 49, 17, 52, 86, 62, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.051000000000000004, 0.51, 1, 0.5)
# 8.72
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.051000000000000004, 0.51, 1, 2)
# 8.79
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.051000000000000004, 0.51, 10, 0.5)
# 8.79
# {67, 8, 79, 85, 86, 55, 58, 27, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.051000000000000004, 0.51, 10, 2)
# 8.89
# {33, 37, 69, 59, 13, 48, 84, 91, 60, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.51, 5.1, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 8.56
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.51, 5.1, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.5
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.51, 5.1, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.65
# {37, 76, 48, 81, 17, 82, 84, 22, 90, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.51, 5.1, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.69
# {1, 99, 4, 71, 10, 75, 44, 45, 19, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0005, 0.005, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.09
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0005, 0.005, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.12
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0005, 0.005, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.75
# {64, 97, 33, 5, 9, 13, 79, 16, 89, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0005, 0.005, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.79
# {34, 70, 10, 75, 15, 17, 21, 22, 24, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.005099999999999999, 0.051000000000000004, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.24
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.005099999999999999, 0.051000000000000004, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.32
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.005099999999999999, 0.051000000000000004, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.22
# {32, 11, 13, 50, 53, 22, 89, 26, 27, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.09
# {0, 1, 66, 4, 8, 83, 52, 87, 92, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.051000000000000004, 0.51, 1, 0.5)
# 7.46
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.051000000000000004, 0.51, 1, 2)
# 7.37
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.051000000000000004, 0.51, 10, 0.5)
# 7.54
# {64, 3, 9, 79, 16, 18, 20, 88, 89, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.051000000000000004, 0.51, 10, 2)
# 7.66
# {96, 98, 6, 39, 43, 12, 77, 51, 93, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.51, 5.1, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.04
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.51, 5.1, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.12
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.51, 5.1, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.03
# {89, 5, 70, 42, 75, 10, 15, 50, 57, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.51, 5.1, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.03
# {32, 10, 19, 53, 22, 85, 56, 57, 28, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0005, 0.005, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.06
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0005, 0.005, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.16
# {0}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0005, 0.005, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.87
# {0, 33, 2, 70, 73, 47, 80, 19, 24, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0005, 0.005, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.5
# {3, 67, 39, 78, 47, 17, 29, 19, 55, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.005099999999999999, 0.051000000000000004, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.93
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.005099999999999999, 0.051000000000000004, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.39
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.005099999999999999, 0.051000000000000004, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.62
# {32, 66, 99, 44, 77, 60, 15, 49, 86, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.01
# {32, 5, 75, 44, 45, 14, 15, 28, 77, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.051000000000000004, 0.51, 1, 0.5)
# 7.85
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.051000000000000004, 0.51, 1, 2)
# 7.75
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.051000000000000004, 0.51, 10, 0.5)
# 7.59
# {33, 2, 67, 36, 73, 47, 80, 50, 59, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.051000000000000004, 0.51, 10, 2)
# 7.87
# {32, 66, 34, 6, 39, 76, 77, 48, 49, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.51, 5.1, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.56
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.51, 5.1, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.29
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.51, 5.1, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.22
# {69, 74, 17, 18, 81, 20, 22, 89, 29, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.51, 5.1, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.12
# {97, 68, 40, 42, 48, 81, 22, 56, 91, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0005, 0.005, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.26
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0005, 0.005, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.51
# {11}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0005, 0.005, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.35
# {73, 10, 11, 45, 46, 79, 19, 91, 60, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0005, 0.005, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.01
# {96, 59, 45, 77, 82, 51, 52, 24, 91, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.005099999999999999, 0.051000000000000004, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.18
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.005099999999999999, 0.051000000000000004, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.51
# {50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.005099999999999999, 0.051000000000000004, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.97
# {36, 5, 38, 50, 83, 86, 54, 87, 61, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.8
# {73, 77, 46, 79, 19, 52, 51, 23, 92, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.051000000000000004, 0.51, 1, 0.5)
# 7.87
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.051000000000000004, 0.51, 1, 2)
# 8.0
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.051000000000000004, 0.51, 10, 0.5)
# 8.07
# {64, 35, 4, 75, 53, 21, 88, 89, 58, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.051000000000000004, 0.51, 10, 2)
# 7.99
# {0, 99, 68, 37, 47, 48, 17, 50, 87, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.51, 5.1, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.2
# {93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.51, 5.1, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.38
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.51, 5.1, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.25
# {99, 36, 5, 38, 39, 9, 47, 48, 17, 83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.51, 5.1, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.11
# {98, 70, 41, 43, 76, 13, 78, 18, 84, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0005, 0.005, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.2
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0005, 0.005, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.53
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0005, 0.005, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.15
# {64, 36, 8, 41, 74, 82, 94, 90, 62, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0005, 0.005, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.66
# {3, 4, 8, 11, 81, 85, 53, 88, 89, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.005099999999999999, 0.051000000000000004, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.47
# {51}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.005099999999999999, 0.051000000000000004, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.37
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.005099999999999999, 0.051000000000000004, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.57
# {5, 38, 9, 92, 48, 50, 87, 55, 60, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.44
# {70, 6, 73, 74, 46, 80, 17, 89, 91, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.051000000000000004, 0.51, 1, 0.5)
# 7.52
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.051000000000000004, 0.51, 1, 2)
# 8.06
# {17}
# ...
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.05
# {97, 33, 2, 49, 82, 88, 89, 58, 63, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.23
# {1, 98, 3, 37, 43, 11, 48, 86, 57, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.051000000000000004, 0.51, 1, 0.5)
# 7.6
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.051000000000000004, 0.51, 1, 2)
# 7.63
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.051000000000000004, 0.51, 10, 0.5)
# 7.64
# {65, 66, 3, 38, 11, 43, 14, 16, 23, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.051000000000000004, 0.51, 10, 2)
# 7.86
# {65, 66, 36, 38, 11, 15, 16, 20, 22, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.51, 5.1, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.16
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.51, 5.1, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.26
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.51, 5.1, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.2
# {32, 73, 42, 15, 16, 20, 52, 22, 90, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.51, 5.1, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.23
# {96, 0, 2, 7, 44, 77, 49, 25, 58, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0005, 0.005, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.91
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0005, 0.005, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.22
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0005, 0.005, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.72
# {0, 64, 67, 6, 13, 30, 56, 24, 26, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0005, 0.005, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.19
# {35, 68, 70, 75, 48, 49, 83, 87, 92, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.005099999999999999, 0.051000000000000004, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.0
# {50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.005099999999999999, 0.051000000000000004, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.88
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.005099999999999999, 0.051000000000000004, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.08
# {70, 41, 75, 43, 12, 16, 82, 51, 83, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.68
# {2, 99, 69, 91, 75, 12, 83, 27, 60, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.051000000000000004, 0.51, 1, 0.5)
# 7.15
# {96}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.051000000000000004, 0.51, 1, 2)
# 7.56
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.051000000000000004, 0.51, 10, 0.5)
# 7.01
# {66, 67, 6, 71, 8, 78, 15, 52, 55, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.051000000000000004, 0.51, 10, 2)
# 7.71
# {66, 6, 71, 8, 78, 18, 22, 55, 54, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.51, 5.1, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.94
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.51, 5.1, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 6.99
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.51, 5.1, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.98
# {0, 34, 2, 39, 40, 14, 24, 26, 88, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.51, 5.1, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.96
# {64, 67, 4, 39, 42, 15, 16, 82, 56, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0005, 0.005, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.93
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0005, 0.005, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.4
# {90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0005, 0.005, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.07
# {64, 41, 74, 13, 47, 16, 17, 84, 55, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0005, 0.005, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.8
# {0, 2, 6, 40, 59, 83, 22, 91, 60, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.005099999999999999, 0.051000000000000004, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.02
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.005099999999999999, 0.051000000000000004, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 6.89
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.005099999999999999, 0.051000000000000004, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.58
# {67, 36, 69, 80, 49, 82, 52, 22, 88, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.005099999999999999, 0.051000000000000004, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.71
# {0, 99, 6, 40, 78, 79, 83, 22, 59, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.051000000000000004, 0.51, 1, 0.5)
# 8.83
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.051000000000000004, 0.51, 1, 2)
# 8.69
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.051000000000000004, 0.51, 10, 0.5)
# 8.77
# {0, 99, 6, 40, 44, 79, 83, 22, 27, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.051000000000000004, 0.51, 10, 2)
# 8.8
# {66, 38, 9, 10, 11, 43, 42, 87, 56, 24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.51, 5.1, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 8.6
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.51, 5.1, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 8.62
# {97}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.51, 5.1, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 7.74
# {64, 65, 97, 39, 72, 7, 77, 48, 21, 54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.51, 5.1, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 8.23
# {98, 9, 75, 76, 12, 81, 61, 53, 58, 93}
