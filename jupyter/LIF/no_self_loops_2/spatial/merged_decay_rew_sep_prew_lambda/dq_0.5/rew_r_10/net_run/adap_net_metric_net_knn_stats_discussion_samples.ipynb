# %% [markdown]
# ## Leaky integrated firing neuron model
# ## Few feautures :
# ### Spatial network, no memory term but exponential decay of cumulative dose
#
# This is a minor change of the Dodds and Watts model
# Implement adaptive rewiring and generate statistics

# %%
#importing the required libraries

import networkx as nx
import matplotlib.pyplot as plt #for plotting
import numpy as np #for using arrays and vectorising the code wherever possible
import scipy
import random
# from numba import jit #numba precomplier to make the code faster
import pandas as pd
import copy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Variables used in the simulation

# %%
N = 100
gamma = 1 #decay of cumulative dose per unit time (second)
gamma = gamma
T = 100 #total number of seconds
dt = 0.05 #seconds
dt_netrun = 10
'''number of simulation steps is T/dt'''

'''Dodds watts parameters'''
p = 1 #rate of dose transfer (per unit time (second))
p = p*dt #rate of dose transfer per unit simulation step
r = 1/dt
r = r*dt
rho = 1/dt
rho = rho*dt
# r = 0.5
# r = r*dt

d_star = 1
# dose_quantity = 1
D_ini = 3

'''network parameters'''
circ_rad = 100 #for a network in which each node is connected to other nodes withing a circle of radius circ_rad
nn = 10 #the number of nearest neighbours(i.e. k) in knn
average_degree = 6
total_edges = N*2

'''rewiring parameters'''
rew_r = 10
density = 1/N
# p_rew = 5 #rate of rewiring(per unit time(second))
# p_rew = p_rew*dt

'''tolerance to determine initial network topology'''
tol = 0.5
steady_counter_val = 500

# %% [markdown]
# # Creating the network.
# ### The network outputs coordinates, distance matrix, edge_list and adjacency matrix

# %%
'''
obtains the number of nodes N
generates N points
calculates euclidean distance between each pair of points
returns the coordinates of the points and the distance matrix which is N*N
'''
def calc_dist(N) :
    coords = []
    for counter in range(N) :
        coords.append((N*np.random.random(),N*np.random.random()))

    dist_mat = scipy.spatial.distance.cdist(coords,coords)
    return dist_mat,coords

# %% [markdown]
# ### 1. metric network

# %%
'''network = connect to points withing a circle of radius'''
#creates a link between points/nodes which satisfies the conditions of the network
def coupling(dist_mat,circ_rad) :
    edge_list = []
    edge_mask = (dist_mat<circ_rad) & (dist_mat>0)
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(edge_mask))))
#     print(type(np.ndarray.tolist(np.transpose(np.where(edge_mask)))))
    return edge_list

# %% [markdown]
# ### 2. K nearest neighbour network

# %%
'''network = knn'''
def knn(dist_mat,nn,N) :
    near_neigh = np.argsort(dist_mat)
    selec_near_neigh = np.zeros((N,nn))
    selec_near_neigh = near_neigh[:,0:nn+1]

    edge_list = []
    for i in range(N) :
        for j in range(1,nn+1) :
            link = [i,selec_near_neigh[i,j]]
            edge_list.append(link)

    return edge_list

# %% [markdown]
# ### 3. Random Network : GNP type

# %%
'''random network'''
def rand_network(average_degree,N) :
    z1 = np.random.uniform(size = (N,N))
    E,F = np.meshgrid(np.arange(0,N),np.arange(0,N))
    mask = ((average_degree/N) > z1) & (E!=F)
    adjacency_matrix = np.int64(np.zeros(shape=(N,N)))
    adjacency_matrix[mask] = np.int64(1)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list,adjacency_matrix

# %% [markdown]
# ### 4. Random Network : GNM type

# %%
def rand_net_gnm(total_edges,N) :
    the_graph = nx.gnm_random_graph(N, total_edges,directed=True)
    adjacency_matrix = nx.adjacency_matrix(the_graph)
    adjacency_matrix = np.asarray(adjacency_matrix.todense())
    np.fill_diagonal(adjacency_matrix,0)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list

# %% [markdown]
# # Function defintions required for the main part of the script

# %%
# # @jit(nopython=True)
# '''infecting the left part of space.'''
# def left_part_infec(N) :
#     x_coord = []
#     y_coord = []
#     for j in range(len(coords)) :
#         x_coord.append(coords[j][0])
#         y_coord.append(coords[j][1])
#     x_coord = np.asarray(x_coord)
#     y_coord = np.asarray(y_coord)
#     points = np.asarray(np.where(x_coord<(N/5))) 
#     indi_state[points.T] = 2

#     return indi_state

# %%
'''infecting connected nodes'''
def InfectNetworkNeighbors(net,seed_node,init_infected_nodes):
     # if in bulk find one node randomly, and infect its neighbours
    infected_nodes = set()
    candidate_nodes = set()
    explored_nodes = set()

    #pick the seed node
    infected_nodes.add(seed_node)
    explored_nodes.add(seed_node)

    curr_node=seed_node

    #add its neighbors to the list of candidates
    for n in net.neighbors(curr_node):
        candidate_nodes.add(int(n))
    #print( curr_node)
    #print( candidate_nodes)

    #while we need to select more nodes...
    while len(infected_nodes) < init_infected_nodes:

        #if there are candidate nodes, select one of them
        if(len(candidate_nodes) > 0):
            new_node = np.random.choice(list(candidate_nodes),1)[0]
            infected_nodes.add(new_node)
            candidate_nodes.remove(new_node)

        elif len(infected_nodes - explored_nodes) > 0:
            curr_node = np.random.choice(list(infected_nodes -
            explored_nodes),1)[0]
            explored_nodes.add(curr_node)
            for n in set(net.neighbors(curr_node)) - infected_nodes:
                candidate_nodes.add(n)

        else:
#             print('Initial node infection step failed')
            return None
    return infected_nodes

# %%
''' function to transfer doses'''
# @jit(nopython=True)
def dose(adj_mat,p,partner_state_prev,d) :

    z1 = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    dose_transfer_mask = p > z1
    mod_adj_mat = np.multiply(adj_mat,z1) #modifying adjacency matrix to include the proability of dose transfer
    dose_mask = (p>mod_adj_mat) & (adj_mat!=0) & (partner_state_prev == 2)
    d[dose_mask] = dose_quantity #whenever it is proabable, dose transfer occurs
    
    return d

# %%
def rew(p_rew,adjacency_matrix,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r) :
    
    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew > z1_rew_prew)  & (indi_state_for_rew_prev == 1) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    rew_mask_minus1 = (p_rew > z1_rew_prew) & (indi_state_for_rew_prev == 2)
    #break links. Dont create any.
    adjacency_matrix[rew_mask_minus1] = 0
    rew_mask_minus2 = ((lamb_da*OD_mesh2) > z1_rew_lambda) & (indi_state_for_rew_prev == 1)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
def let_it_run(p_rew_netrun,adjacency_matrix,OD_mesh2,lamb_da_netrun,density,rew_r) :

    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew_netrun > z1_rew_prew) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    
    rew_mask_minus2 = ((lamb_da_netrun*OD_mesh2) > z1_rew_lambda)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
'''function to update cumulative doses'''
def cumu_dose(d,D_prev,gamma) :
    I = d.sum(axis=1).reshape(N,1)
#     I = 0
    D = (D_prev - (gamma*D_prev*dt)) + I
    return D

# %%
'''function to update the states of the nodes of the system'''
def upd_indi_state(D,d_star,indi_state_prev) :
    
    z2 = np.random.uniform(size=(N,1))
    z3 = np.random.uniform(size=(N,1))
    
    indi_state = indi_state_prev
    
    indi_state_mask1 = (D>=d_star) & (indi_state_prev==1)
    indi_state[indi_state_mask1] = 2
    
    indi_state_mask21 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho>=z3)
    indi_state[indi_state_mask21] = 1
    
    indi_state_mask22 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho<z3)
    indi_state[indi_state_mask22] = 3
    
    indi_state_mask23 = (D<d_star) & (indi_state_prev==2) & (r<z2)
    indi_state[indi_state_mask23] = 2
    
    return indi_state

# %%
'''function to get/identify the infected nodes and the suceptible nodes'''
def states(indi_state) :
    infec_indi = []
    suscep_indi = []
    infec_indi = np.transpose(np.where(indi_state==2))
    suscep_indi = np.transpose(np.where(indi_state==1))
    return infec_indi,suscep_indi

# %%
def networkx_graph(coords,edge_list) :
    G = nx.DiGraph()
    pos = {(i): (coords[i][0],coords[i][1]) for i in range(N)}
    G.add_nodes_from(pos.keys())
    G.add_edges_from(edge_list)
    return G

# %%
def edge_from_adj_mat(adj_mat_list,q):
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adj_mat_list[q]==1))))
    return edge_list

# %% [markdown]
# # The main part of the script

# %%
#infected state time series data frame
#columns indicate the time steps
timeseries_infec_frac = pd.DataFrame()

#in degree as columns and rows as nodes
timeseries_in_degree = pd.DataFrame() 

#out degree as columns and rows as nodes
timeseries_out_degree = pd.DataFrame()

#strongly connected components as columns
timeseries_connec_comps = pd.DataFrame()

#mean of out degree as columns and rows as nodes
timeseries_out_degree_mean = pd.DataFrame()

# %%
vals = round(1/((density)*(np.pi)*(rew_r*rew_r)),3)
p_rew_vals = [round(0.1*vals,3),round(vals,3),round(10*vals,3),round(100*vals,3)]
start_vals = [1,10]
dose_quantity_vals = [0.5,2]

# %%
for sim in range(70,70+25) :
    
    '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''
    dist_mat,coords = calc_dist(N) #node placement
    edge_list = knn(dist_mat,nn,N)
    bef_netrun_org_adj_mat = np.int64(np.zeros((N,N)))
    for i in range(len(edge_list)):
        bef_netrun_org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)
    df_row = 0
    
    for p_rew_org in p_rew_vals : #rate of rewiring (per unit time (second))
        if p_rew_org == round(0.1*vals,3) :
            dt_netrun = 10
        else :
            dt_netrun = dt
            
        lamb_da_org = p_rew_org/10        
        '''parameters for the coupling dynamics'''
        lamb_da = lamb_da_org*dt
        p_rew = p_rew_org*dt
        
        '''parameters for the network satbilisation'''
        lamb_da_netrun = lamb_da_org*dt_netrun
        p_rew_netrun = p_rew_org*dt_netrun
        
        for start in start_vals : #rate of dose transfer (per unit time (second))
            for dose_quantity in dose_quantity_vals : #number of nodes to infect initially
                print('(sim,lamb_da,p_rew,start,dose_quantity) = ', (sim,lamb_da/dt,p_rew/dt,start,dose_quantity))

                '''clearing exsiting data frames and creating new ones '''
                timeseries_infec_frac = pd.DataFrame()
                timeseries_in_degree = pd.DataFrame()
                timeseries_out_degree = pd.DataFrame()
                timeseries_connec_comps = pd.DataFrame()
                timeseries_out_degree_mean = pd.DataFrame()

                q = 0 #to generate new edge_list from the new adjacency matrix 
                t = np.arange(0,T,dt)

                adj_mat_list = []
                adj_mat = copy.deepcopy(bef_netrun_org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new) #list of arrays which shows the time series of the adjacency matrix
    
                '''obtaining a steady network topology before starting the dynamics on the network'''

                q = 0
                steady_counter = 0
                df_col = 0
                no_reset = 0 
                while steady_counter < steady_counter_val :

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])
                    timeseries_out_degree_mean.loc[0,df_col] = timeseries_out_degree.iloc[:,df_col].mean()
                    if df_col-1 >= 0 :
            #             print(timeseries_out_degree_mean.loc[0,df_col])
                        if np.abs(timeseries_out_degree_mean.loc[0,df_col] - timeseries_out_degree_mean.loc[0,df_col-1]) <= tol :
                            steady_counter = steady_counter + 1
                        else :
                            steady_counter = 0
                            no_reset = no_reset + 1
                            print('oops')
                            if no_reset > 100 :
                                break

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)    
                    adj_mat = let_it_run(p_rew_netrun,adj_mat,OD_mesh2,lamb_da_netrun,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    q = q + 1 
                    df_col = df_col + 1
                    
                '''steady network topology obtained, start the dynamics now'''
                print(timeseries_out_degree_mean.loc[0,df_col-1])
                timeseries_out_degree = pd.DataFrame()
                df_col = 0
                q = 0 
                edge_list = copy.deepcopy(edge_list)
                G = copy.deepcopy(G)
                org_adj_mat = copy.deepcopy(adj_mat_new)

                numpy_array = np.zeros((N,len(t)),dtype = np.int64)

                D_array = np.zeros((N,len(t)))
                for i in range(len(edge_list)):
                    org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)

                adj_mat_list = []
                adj_mat = copy.deepcopy(org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new)


                '''from G, obtain the in degree and the out degree'''
                timeseries_in_degree.loc[:,0] = np.asarray([val for (node, val) in G.in_degree()])
                timeseries_out_degree.loc[:,0] = np.asarray([val for (node, val) in G.out_degree()])

                '''strongly and weekely connected components'''
                timeseries_connec_comps.loc[0,0] = nx.number_connected_components(G.to_undirected())

                '''choosing initially infected nodes'''
                indi_state = np.random.randint(1,2,size=(N,1))
                infected_nodes = None
                while infected_nodes is None : #infecting 'start' number of network neighbours
                    infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)      
                print(infected_nodes)
                infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
                indi_state[infected_nodes[:,0],0] = 2

                A,B = np.meshgrid(indi_state,indi_state) 
                partner_state = copy.deepcopy(A)
                indi_state_for_rew = copy.deepcopy(B)

    #             numpy_array [:,0] = indi_state[:,0]

                indi_state_prev = copy.deepcopy(indi_state)
                partner_state_prev = copy.deepcopy(partner_state)
                indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                d = np.zeros((len(adj_mat),len(adj_mat[0])))

                D = np.zeros((N,1))
                D[np.where(indi_state==2)] = D_ini
                D_array[:,0] = D[:,0]
                D_prev = copy.deepcopy(D)

                infec_frac = np.count_nonzero(indi_state == 2)/N
                timeseries_infec_frac.loc[df_row,0] = infec_frac
                '''the main part of the simulation'''
                counter = 0
                df_col = 1
                for t in np.arange(dt,T,dt) :
                    q = q + 1 
                    counter = counter + 1
                    infec_indi = []
                    suscep_indi = []
                    d = np.zeros((len(adj_mat),len(adj_mat[0])))
                    d = dose(adj_mat,p,partner_state_prev,d)

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)
                    adj_mat = rew(p_rew,adj_mat,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    '''from G, obtain the in degree and the out degree'''
                    timeseries_in_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.in_degree()])
                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])

                    '''strongly and weekely connected components'''
                    timeseries_connec_comps.loc[df_row,df_col] = nx.number_connected_components(G.to_undirected())

                    D = cumu_dose(d,D_prev,gamma)
                    D_array[:,counter] = D[:,0]

                    indi_state = upd_indi_state(D,d_star,indi_state_prev)
                    infec_frac = np.count_nonzero(indi_state == 2)/N
                    timeseries_infec_frac.loc[df_row,df_col] = infec_frac

    #                 numpy_array[:,counter] = indi_state[:,0]
                    A,B = np.meshgrid(indi_state,indi_state)

                    infec_indi, suscep_indi = states(indi_state)

                    partner_state = copy.deepcopy(A)
                    indi_state_for_rew = copy.deepcopy(B)
                    indi_state_prev = copy.deepcopy(indi_state)
                    partner_state_prev = copy.deepcopy(partner_state)
                    indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                    D_prev = copy.deepcopy(D)
                    D = np.zeros((N,1))
                    df_col = df_col + 1 

    #             df_row = df_row + 1 #going to the next row of the df to store timeseries of next (p,start)

                filename_infec_frac = 'infec_frac.h5'
                filename_in_deg = 'in_deg.h5'
                filename_out_deg = 'out_deg.h5'
                filename_connec_comps = 'connec_comps.h5'
                p_rew_val = '%g'%(p_rew/dt)
                key_val = 'sim_'+str(sim)+'_p_rew_'+str(p_rew_val)+'_start_'+str(start)+'_dq_'+str(dose_quantity)
#                 print(key_val)
                timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
                timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
                timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
                timeseries_connec_comps.to_hdf(filename_connec_comps, key = key_val, mode='a')
                df_row = 0
# Out:
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.24
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.04
# {90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.22
# {70, 6, 73, 10, 12, 46, 47, 14, 57, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.17
# {97, 69, 91, 77, 51, 20, 22, 59, 30, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0318, 0.318, 1, 0.5)
# 2.65
# {5}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0318, 0.318, 1, 2)
# 2.44
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0318, 0.318, 10, 0.5)
# 2.46
# {34, 3, 98, 69, 71, 42, 15, 51, 84, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0318, 0.318, 10, 2)
# 2.77
# {97, 98, 69, 91, 77, 48, 51, 20, 59, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.24
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 2.17
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.26
# {6, 73, 10, 12, 14, 47, 55, 56, 57, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# oops
# 2.26
# {97, 98, 69, 59, 77, 51, 20, 23, 91, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.9
# {25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.64
# {88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.78
# {97, 98, 69, 71, 74, 77, 48, 51, 23, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.81
# {97, 98, 69, 71, 42, 15, 48, 51, 84, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.09
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.2
# {90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.15
# {33, 5, 38, 71, 73, 45, 15, 47, 51, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.07
# {32, 66, 71, 72, 73, 45, 83, 23, 88, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0318, 0.318, 1, 0.5)
# 2.44
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0318, 0.318, 1, 2)
# 2.46
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0318, 0.318, 10, 0.5)
# 2.44
# {32, 33, 5, 71, 73, 78, 79, 19, 83, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0318, 0.318, 10, 2)
# 2.56
# {2, 70, 9, 75, 80, 49, 24, 27, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.08
# {96}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 2.18
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.25
# {2, 70, 9, 75, 80, 49, 24, 27, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.21
# {67, 7, 8, 17, 82, 20, 21, 55, 57, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.73
# {7}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.09
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.87
# {36, 68, 43, 12, 14, 18, 56, 60, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.59
# {2, 70, 9, 75, 80, 49, 24, 27, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.36
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.28
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.36
# {34, 37, 40, 13, 83, 20, 23, 58, 93, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.42
# {32, 99, 36, 7, 72, 73, 41, 26, 91, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0318, 0.318, 1, 0.5)
# 2.63
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0318, 0.318, 1, 2)
# 2.53
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0318, 0.318, 10, 0.5)
# 2.6
# {65, 3, 70, 74, 10, 76, 78, 80, 18, 53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0318, 0.318, 10, 2)
# 2.54
# {96, 0, 12, 79, 15, 22, 55, 31, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# 2.31
# {96}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.34
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# 2.29
# {64, 2, 4, 5, 37, 40, 46, 48, 49, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# oops
# 2.41
# {0, 68, 44, 12, 15, 52, 55, 56, 61, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.68
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.17
# {19}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.19
# {64, 2, 4, 42, 11, 46, 48, 81, 24, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.55
# {34, 37, 40, 13, 83, 20, 23, 58, 93, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.04
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# oops
# 2.04
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.05
# {96, 0, 3, 69, 41, 75, 13, 14, 85, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.17
# {2, 4, 38, 40, 43, 78, 79, 16, 18, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0318, 0.318, 1, 0.5)
# 2.43
# {92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0318, 0.318, 1, 2)
# 2.29
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0318, 0.318, 10, 0.5)
# 2.41
# {33, 34, 35, 37, 70, 80, 51, 57, 91, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0318, 0.318, 10, 2)
# 2.44
# {64, 36, 5, 71, 12, 46, 50, 19, 86, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.07
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.08
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.02
# {65, 73, 45, 82, 21, 22, 25, 90, 27, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# 2.16
# {64, 36, 5, 71, 42, 12, 46, 50, 19, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# 1.88
# {8}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 1.78
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.81
# {64, 36, 8, 74, 11, 12, 19, 86, 60, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# 1.78
# {33, 68, 44, 77, 48, 80, 83, 89, 91, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.28
# {99}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.09
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.33
# {64, 73, 77, 15, 17, 18, 51, 21, 93, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.22
# {64, 73, 77, 15, 17, 18, 84, 21, 93, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0318, 0.318, 1, 0.5)
# 2.44
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0318, 0.318, 1, 2)
# 2.5
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0318, 0.318, 10, 0.5)
# 2.68
# {5, 73, 75, 77, 15, 16, 51, 21, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0318, 0.318, 10, 2)
# 2.43
# {32, 97, 8, 75, 13, 20, 54, 25, 27, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.24
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.21
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.12
# {1, 99, 6, 7, 72, 82, 63, 86, 29, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# oops
# 2.2
# {1, 99, 67, 7, 72, 82, 86, 29, 95, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.7
# {30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.97
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.54
# {64, 5, 73, 77, 15, 17, 51, 21, 93, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.58
# {1, 99, 6, 7, 72, 82, 29, 86, 63, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.27
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.41
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.27
# {34, 3, 69, 7, 43, 78, 48, 53, 21, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# oops
# 2.27
# {97, 68, 12, 50, 18, 22, 88, 58, 28, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0318, 0.318, 1, 0.5)
# 2.56
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0318, 0.318, 1, 2)
# 2.6
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0318, 0.318, 10, 0.5)
# 2.58
# {1, 3, 36, 70, 43, 47, 81, 17, 83, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0318, 0.318, 10, 2)
# 2.46
# {32, 68, 74, 12, 76, 20, 86, 22, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.32
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.28
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# 2.26
# {0, 97, 2, 68, 50, 82, 22, 88, 28, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.39
# {34, 3, 69, 7, 43, 78, 53, 21, 26, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.62
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.51
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.31
# {0, 97, 2, 46, 18, 19, 82, 28, 29, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.6
# {33, 35, 41, 77, 16, 80, 23, 91, 63, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.08
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.18
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.11
# {96, 4, 69, 11, 79, 48, 81, 89, 28, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.04
# {96, 33, 68, 69, 70, 76, 81, 25, 90, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0318, 0.318, 1, 0.5)
# 2.31
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0318, 0.318, 1, 2)
# 2.41
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0318, 0.318, 10, 0.5)
# 2.32
# {67, 37, 40, 73, 74, 41, 12, 26, 29, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0318, 0.318, 10, 2)
# 2.48
# {96, 32, 68, 69, 11, 76, 81, 18, 22, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.13
# {19}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# 2.12
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.11
# {98, 6, 39, 10, 13, 80, 19, 53, 23, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.06
# {34, 99, 35, 7, 49, 51, 52, 20, 57, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.82
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.67
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# 1.68
# {96, 33, 68, 69, 70, 11, 76, 81, 25, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# 1.92
# {0, 98, 6, 10, 13, 80, 19, 53, 59, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.13
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.19
# {5}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.21
# {64, 37, 70, 40, 12, 46, 19, 21, 22, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.15
# {67, 8, 77, 78, 79, 81, 18, 24, 25, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0318, 0.318, 1, 0.5)
# 2.45
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0318, 0.318, 1, 2)
# 2.42
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0318, 0.318, 10, 0.5)
# 2.58
# {32, 33, 38, 74, 76, 17, 86, 56, 58, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0318, 0.318, 10, 2)
# 2.47
# {65, 66, 3, 4, 5, 36, 11, 44, 57, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.04
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.22
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.15
# {32, 33, 38, 74, 76, 17, 86, 56, 58, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.2
# {33, 38, 74, 76, 16, 17, 86, 56, 58, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.1
# {92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.48
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.67
# {64, 35, 37, 70, 40, 19, 21, 22, 23, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.75
# {67, 8, 9, 77, 79, 81, 18, 24, 25, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# oops
# 1.92
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# oops
# 1.94
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 1.95
# {96, 66, 5, 75, 44, 18, 24, 27, 29, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 1.94
# {2, 34, 35, 37, 6, 74, 49, 83, 52, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0318, 0.318, 1, 0.5)
# 2.41
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0318, 0.318, 1, 2)
# 2.34
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0318, 0.318, 10, 0.5)
# 2.22
# {67, 69, 42, 43, 76, 45, 53, 26, 93, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0318, 0.318, 10, 2)
# 2.22
# {66, 70, 7, 59, 75, 46, 78, 50, 18, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 1.91
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 1.93
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 1.82
# {2, 35, 34, 37, 6, 74, 49, 83, 52, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# oops
# 1.93
# {32, 34, 35, 40, 14, 81, 83, 86, 87, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.63
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.64
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.7
# {32, 34, 40, 77, 14, 15, 81, 83, 86, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.58
# {32, 34, 35, 40, 77, 15, 81, 83, 86, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.39
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# oops
# 2.32
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.29
# {7, 46, 81, 82, 83, 52, 51, 57, 27, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.3
# {96, 65, 69, 77, 46, 80, 16, 81, 57, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0318, 0.318, 1, 0.5)
# 2.69
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0318, 0.318, 1, 2)
# 2.68
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0318, 0.318, 10, 0.5)
# 2.45
# {0, 3, 71, 40, 72, 76, 15, 84, 23, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0318, 0.318, 10, 2)
# 2.67
# {10, 45, 51, 52, 83, 86, 57, 90, 27, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.16
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.46
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.44
# {7, 77, 46, 80, 16, 81, 83, 52, 57, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# 2.3
# {0, 67, 3, 70, 71, 40, 43, 84, 26, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.66
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.21
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.24
# {39, 9, 11, 44, 12, 14, 47, 85, 88, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.56
# {67, 3, 70, 71, 40, 43, 15, 84, 26, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.13
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# oops
# 2.13
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.12
# {64, 42, 10, 45, 14, 54, 89, 91, 92, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.18
# {0, 3, 36, 72, 73, 44, 47, 22, 23, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0318, 0.318, 1, 0.5)
# 2.44
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0318, 0.318, 1, 2)
# 2.42
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0318, 0.318, 10, 0.5)
# 2.47
# {32, 26, 67, 37, 77, 15, 20, 90, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0318, 0.318, 10, 2)
# 2.52
# {67, 37, 39, 40, 78, 15, 18, 26, 61, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.16
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.14
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.13
# {32, 96, 67, 37, 39, 40, 15, 20, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.14
# {0, 3, 36, 35, 47, 22, 23, 25, 60, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.59
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.57
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.55
# {64, 42, 45, 14, 28, 54, 89, 58, 91, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.16
# {33, 71, 43, 12, 46, 19, 21, 53, 55, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.18
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.2
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.21
# {76, 13, 77, 47, 81, 49, 85, 24, 89, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.15
# {33, 40, 41, 74, 27, 87, 56, 59, 92, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0318, 0.318, 1, 0.5)
# 2.54
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0318, 0.318, 1, 2)
# 2.54
# {5}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0318, 0.318, 10, 0.5)
# 2.69
# {33, 99, 70, 6, 59, 56, 27, 92, 61, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0318, 0.318, 10, 2)
# 2.64
# {32, 42, 75, 13, 14, 82, 19, 18, 90, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.16
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# 2.22
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.19
# {64, 76, 77, 13, 47, 81, 85, 24, 89, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.08
# {33, 99, 6, 27, 74, 87, 56, 59, 92, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.73
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.75
# {0}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.73
# {33, 99, 70, 6, 8, 59, 56, 27, 92, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.86
# {96, 97, 34, 67, 46, 16, 52, 53, 20, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.03
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 1.9
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.01
# {65, 35, 36, 79, 15, 82, 20, 54, 24, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.03
# {40, 73, 10, 28, 81, 52, 85, 56, 92, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0318, 0.318, 1, 0.5)
# 2.35
# {25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0318, 0.318, 1, 2)
# 2.31
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0318, 0.318, 10, 0.5)
# 2.37
# {64, 96, 26, 6, 72, 46, 78, 17, 58, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0318, 0.318, 10, 2)
# 2.41
# {33, 3, 37, 45, 19, 84, 86, 22, 90, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.09
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.05
# {98}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.0
# {32, 38, 74, 76, 77, 80, 49, 18, 89, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# 2.03
# {32, 67, 38, 76, 77, 80, 49, 18, 89, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# 1.69
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 1.75
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.67
# {65, 35, 79, 48, 15, 82, 20, 24, 60, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# 1.78
# {73, 10, 9, 28, 81, 52, 85, 56, 92, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.32
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.27
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.31
# {3, 67, 8, 40, 79, 50, 85, 86, 56, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# oops
# 2.19
# {33, 4, 6, 9, 75, 43, 44, 78, 57, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0318, 0.318, 1, 0.5)
# 2.35
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0318, 0.318, 1, 2)
# 2.63
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0318, 0.318, 10, 0.5)
# 2.44
# {0, 64, 99, 37, 41, 10, 74, 18, 24, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0318, 0.318, 10, 2)
# 2.53
# {67, 3, 40, 8, 79, 21, 86, 85, 61, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.27
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 2.26
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# 2.39
# {3, 67, 8, 79, 50, 85, 86, 56, 62, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# 2.32
# {32, 97, 2, 73, 15, 16, 89, 59, 60, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.14
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.19
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.63
# {3, 67, 8, 40, 79, 50, 85, 86, 56, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.91
# {64, 0, 99, 37, 10, 81, 18, 83, 24, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# oops
# 1.97
# {8}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# oops
# 1.95
# {91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 1.96
# {96, 2, 68, 71, 79, 84, 21, 86, 93, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# oops
# 1.89
# {34, 37, 69, 70, 6, 19, 56, 92, 61, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0318, 0.318, 1, 0.5)
# 2.28
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0318, 0.318, 1, 2)
# 2.26
# {93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0318, 0.318, 10, 0.5)
# 2.29
# {33, 4, 37, 73, 12, 78, 48, 19, 22, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0318, 0.318, 10, 2)
# 2.16
# {2, 39, 8, 71, 16, 82, 93, 58, 29, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# 1.88
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 1.98
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 1.98
# {2, 68, 71, 8, 79, 16, 86, 58, 93, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# oops
# 2.0
# {2, 68, 39, 8, 71, 16, 82, 58, 29, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.69
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 1.75
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# 1.64
# {2, 68, 71, 8, 39, 79, 16, 82, 58, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# 1.59
# {2, 68, 39, 8, 71, 79, 16, 82, 58, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.12
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.12
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.29
# {96, 38, 40, 74, 18, 83, 84, 85, 59, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.23
# {97, 37, 9, 75, 11, 54, 57, 28, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0318, 0.318, 1, 0.5)
# 2.42
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0318, 0.318, 1, 2)
# 2.56
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0318, 0.318, 10, 0.5)
# 2.59
# {66, 69, 5, 72, 73, 46, 79, 82, 55, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0318, 0.318, 10, 2)
# 2.48
# {1, 65, 8, 42, 43, 44, 76, 16, 56, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.23
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.19
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# 2.17
# {35, 99, 5, 11, 13, 79, 50, 19, 93, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# 2.21
# {66, 72, 73, 46, 14, 15, 47, 82, 55, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.44
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.4
# {47}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.57
# {97, 99, 36, 37, 11, 13, 50, 29, 57, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.55
# {97, 99, 37, 70, 9, 75, 54, 28, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.03
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.03
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.0
# {32, 34, 4, 36, 41, 10, 49, 84, 56, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.02
# {64, 97, 74, 44, 77, 63, 54, 91, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0318, 0.318, 1, 0.5)
# 2.39
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0318, 0.318, 1, 2)
# 2.35
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0318, 0.318, 10, 0.5)
# 2.45
# {99, 69, 38, 11, 12, 82, 19, 24, 57, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0318, 0.318, 10, 2)
# 2.34
# {65, 1, 99, 5, 69, 12, 24, 57, 28, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.01
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# 2.08
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.21
# {32, 34, 3, 36, 4, 41, 49, 84, 56, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# ...
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.68
# {50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.17
# {1, 66, 3, 36, 40, 9, 18, 85, 24, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.26
# {65, 2, 5, 44, 45, 46, 50, 25, 26, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.26
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# oops
# 2.43
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.24
# {99, 5, 8, 27, 44, 45, 79, 50, 90, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 2.51
# {65, 98, 35, 10, 18, 53, 87, 24, 56, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0318, 0.318, 1, 0.5)
# 2.8
# {34}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0318, 0.318, 1, 2)
# 2.66
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0318, 0.318, 10, 0.5)
# 2.66
# {36, 37, 70, 7, 47, 18, 21, 22, 55, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0318, 0.318, 10, 2)
# 2.74
# {1, 97, 12, 92, 50, 52, 84, 86, 28, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.4
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 2.38
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.33
# {99, 5, 8, 27, 44, 45, 79, 84, 90, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.44
# {32, 2, 72, 9, 74, 43, 78, 63, 29, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.72
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.48
# {22}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.66
# {12, 79, 92, 50, 84, 52, 89, 90, 27, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.77
# {32, 2, 72, 9, 43, 78, 29, 23, 63, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.02
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 1.99
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.01
# {1, 2, 97, 34, 9, 47, 22, 91, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# oops
# 2.0
# {0, 70, 14, 46, 16, 49, 82, 87, 61, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0318, 0.318, 1, 0.5)
# 2.38
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0318, 0.318, 1, 2)
# 2.47
# {25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0318, 0.318, 10, 0.5)
# 2.55
# {0, 33, 67, 69, 70, 20, 21, 87, 57, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0318, 0.318, 10, 2)
# 2.25
# {0, 70, 46, 16, 83, 19, 87, 23, 60, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.08
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 2.11
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.15
# {0, 70, 46, 16, 49, 83, 23, 19, 87, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.12
# {97, 34, 1, 2, 9, 47, 22, 91, 94, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# 1.64
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.75
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.83
# {0, 70, 46, 49, 19, 83, 87, 23, 60, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# 1.86
# {1, 2, 99, 34, 9, 47, 89, 59, 94, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.16
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.11
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.15
# {0, 3, 5, 42, 12, 80, 54, 22, 25, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# 1.98
# {1, 4, 73, 13, 79, 48, 82, 18, 58, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0318, 0.318, 1, 0.5)
# 2.39
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0318, 0.318, 1, 2)
# 2.47
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0318, 0.318, 10, 0.5)
# 2.32
# {6, 7, 8, 41, 74, 46, 81, 87, 89, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0318, 0.318, 10, 2)
# 2.46
# {34, 68, 8, 41, 45, 47, 81, 20, 87, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.04
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 2.23
# {0}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.12
# {32, 33, 76, 77, 19, 84, 85, 53, 63, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.13
# {38, 72, 75, 77, 84, 53, 85, 55, 88, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.8
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.65
# {0}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.44
# {34, 8, 41, 74, 45, 46, 81, 87, 56, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.65
# {32, 33, 39, 72, 76, 84, 85, 55, 63, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# oops
# 2.16
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# 2.22
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# 2.16
# {66, 68, 6, 40, 41, 46, 47, 52, 88, 24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0032, 0.032, 10, 2)
# oops
# oops
# 2.1
# {0, 89, 12, 77, 15, 49, 84, 56, 57, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0318, 0.318, 1, 0.5)
# 2.49
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0318, 0.318, 1, 2)
# 2.41
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0318, 0.318, 10, 0.5)
# 2.49
# {66, 68, 4, 38, 6, 40, 41, 47, 50, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0318, 0.318, 10, 2)
# 2.48
# {67, 71, 12, 77, 15, 84, 56, 89, 90, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.11
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 2.14
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.18
# {64, 99, 36, 73, 43, 48, 18, 86, 27, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# oops
# 2.08
# {66, 68, 38, 6, 40, 41, 47, 50, 24, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.63
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.06
# {47}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 1.49
# {66, 68, 6, 38, 40, 41, 46, 47, 52, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# oops
# 2.11
# {66, 68, 38, 6, 40, 41, 46, 47, 52, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0032, 0.032, 1, 0.5)
# oops
# oops
# oops
# 2.22
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0032, 0.032, 1, 2)
# oops
# oops
# oops
# oops
# 2.21
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0032, 0.032, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.05
# {65, 1, 3, 67, 7, 42, 43, 49, 83, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0032, 0.032, 10, 2)
# oops
# oops
# oops
# oops
# 2.17
# {64, 68, 39, 73, 41, 53, 54, 57, 91, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0318, 0.318, 1, 0.5)
# 2.42
# {98}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0318, 0.318, 1, 2)
# 2.34
# {19}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0318, 0.318, 10, 0.5)
# 2.31
# {2, 72, 46, 16, 17, 48, 56, 90, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0318, 0.318, 10, 2)
# 2.39
# {64, 33, 41, 73, 11, 21, 54, 53, 88, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.318, 3.1800000000000006, 1, 0.5)
# oops
# oops
# oops
# oops
# oops
# 2.12
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.318, 3.1800000000000006, 1, 2)
# oops
# oops
# oops
# oops
# oops
# 2.08
# {5}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.318, 3.1800000000000006, 10, 0.5)
# oops
# oops
# oops
# oops
# 2.17
# {0, 2, 38, 80, 48, 56, 92, 61, 95, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.318, 3.1800000000000006, 10, 2)
# oops
# oops
# oops
# oops
# 2.13
# {65, 3, 67, 7, 40, 42, 43, 49, 83, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 3.1800000000000006, 31.8, 1, 0.5)
# oops
# oops
# oops
# oops
# 1.72
# {59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 3.1800000000000006, 31.8, 1, 2)
# oops
# oops
# oops
# oops
# 1.95
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 3.1800000000000006, 31.8, 10, 0.5)
# oops
# oops
# oops
# oops
# oops
# 1.84
# {65, 1, 67, 7, 42, 43, 47, 49, 83, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 3.1800000000000006, 31.8, 10, 2)
# oops
# oops
# oops
# oops
# 1.72
# {36, 39, 10, 18, 84, 54, 88, 25, 91, 93}
