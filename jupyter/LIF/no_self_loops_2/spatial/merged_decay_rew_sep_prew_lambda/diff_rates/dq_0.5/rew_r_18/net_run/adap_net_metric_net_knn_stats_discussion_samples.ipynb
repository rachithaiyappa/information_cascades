# %% [markdown]
# ## Leaky integrated firing neuron model
# ## Few feautures :
# ### Spatial network, no memory term but exponential decay of cumulative dose
#
# This is a minor change of the Dodds and Watts model
# Implement adaptive rewiring and generate statistics

# %%
#importing the required libraries

import networkx as nx
import matplotlib.pyplot as plt #for plotting
import numpy as np #for using arrays and vectorising the code wherever possible
import scipy
import random
# from numba import jit #numba precomplier to make the code faster
import pandas as pd
import copy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Variables used in the simulation

# %%
N = 100
gamma = 1 #decay of cumulative dose per unit time (second)
gamma = gamma
T = 400 #total number of seconds
dt = 0.05 #seconds
'''number of simulation steps is T/dt'''

'''Dodds watts parameters'''
p = 1 #rate of dose transfer (per unit time (second))
p = p*dt #rate of dose transfer per unit simulation step
r = 1/dt
r = r*dt
rho = 1/dt
rho = rho*dt
# r = 0.5
# r = r*dt

d_star = 1
# dose_quantity = 1
D_ini = 3

'''network parameters'''
circ_rad = 100 #for a network in which each node is connected to other nodes withing a circle of radius circ_rad
nn = 10 #the number of nearest neighbours(i.e. k) in knn
average_degree = 6
total_edges = N*2

'''rewiring parameters'''
rew_r = 18
density = 1/N
w_minus = 10
w_minus = w_minus*dt
# p_rew = 5 #rate of rewiring(per unit time(second))
# p_rew = p_rew*dt

'''tolerance to determine initial network topology'''
tol = 0.5
steady_counter_val = 500

# %% [markdown]
# # Creating the network.
# ### The network outputs coordinates, distance matrix, edge_list and adjacency matrix

# %%
'''
obtains the number of nodes N
generates N points
calculates euclidean distance between each pair of points
returns the coordinates of the points and the distance matrix which is N*N
'''
def calc_dist(N) :
    coords = []
    for counter in range(N) :
        coords.append((N*np.random.random(),N*np.random.random()))

    dist_mat = scipy.spatial.distance.cdist(coords,coords)
    return dist_mat,coords

# %% [markdown]
# ### 1. metric network

# %%
'''network = connect to points withing a circle of radius'''
#creates a link between points/nodes which satisfies the conditions of the network
def coupling(dist_mat,circ_rad) :
    edge_list = []
    edge_mask = (dist_mat<circ_rad) & (dist_mat>0)
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(edge_mask))))
#     print(type(np.ndarray.tolist(np.transpose(np.where(edge_mask)))))
    return edge_list

# %% [markdown]
# ### 2. K nearest neighbour network

# %%
'''network = knn'''
def knn(dist_mat,nn,N) :
    near_neigh = np.argsort(dist_mat)
    selec_near_neigh = np.zeros((N,nn))
    selec_near_neigh = near_neigh[:,0:nn+1]

    edge_list = []
    for i in range(N) :
        for j in range(1,nn+1) :
            link = [i,selec_near_neigh[i,j]]
            edge_list.append(link)

    return edge_list

# %% [markdown]
# ### 3. Random Network : GNP type

# %%
'''random network'''
def rand_network(average_degree,N) :
    z1 = np.random.uniform(size = (N,N))
    E,F = np.meshgrid(np.arange(0,N),np.arange(0,N))
    mask = ((average_degree/N) > z1) & (E!=F)
    adjacency_matrix = np.int64(np.zeros(shape=(N,N)))
    adjacency_matrix[mask] = np.int64(1)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list,adjacency_matrix

# %% [markdown]
# ### 4. Random Network : GNM type

# %%
def rand_net_gnm(total_edges,N) :
    the_graph = nx.gnm_random_graph(N, total_edges,directed=True)
    adjacency_matrix = nx.adjacency_matrix(the_graph)
    adjacency_matrix = np.asarray(adjacency_matrix.todense())
    np.fill_diagonal(adjacency_matrix,0)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list

# %% [markdown]
# # Function defintions required for the main part of the script

# %%
# # @jit(nopython=True)
# '''infecting the left part of space.'''
# def left_part_infec(N) :
#     x_coord = []
#     y_coord = []
#     for j in range(len(coords)) :
#         x_coord.append(coords[j][0])
#         y_coord.append(coords[j][1])
#     x_coord = np.asarray(x_coord)
#     y_coord = np.asarray(y_coord)
#     points = np.asarray(np.where(x_coord<(N/5))) 
#     indi_state[points.T] = 2

#     return indi_state

# %%
'''infecting connected nodes'''
def InfectNetworkNeighbors(net,seed_node,init_infected_nodes):
     # if in bulk find one node randomly, and infect its neighbours
    infected_nodes = set()
    candidate_nodes = set()
    explored_nodes = set()

    #pick the seed node
    infected_nodes.add(seed_node)
    explored_nodes.add(seed_node)

    curr_node=seed_node

    #add its neighbors to the list of candidates
    for n in net.neighbors(curr_node):
        candidate_nodes.add(int(n))
    #print( curr_node)
    #print( candidate_nodes)

    #while we need to select more nodes...
    while len(infected_nodes) < init_infected_nodes:

        #if there are candidate nodes, select one of them
        if(len(candidate_nodes) > 0):
            new_node = np.random.choice(list(candidate_nodes),1)[0]
            infected_nodes.add(new_node)
            candidate_nodes.remove(new_node)

        elif len(infected_nodes - explored_nodes) > 0:
            curr_node = np.random.choice(list(infected_nodes -
            explored_nodes),1)[0]
            explored_nodes.add(curr_node)
            for n in set(net.neighbors(curr_node)) - infected_nodes:
                candidate_nodes.add(n)

        else:
#             print('Initial node infection step failed')
            return None
    return infected_nodes

# %%
''' function to transfer doses'''
# @jit(nopython=True)
def dose(adj_mat,p,partner_state_prev,d) :

    z1 = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    dose_transfer_mask = p > z1
    mod_adj_mat = np.multiply(adj_mat,z1) #modifying adjacency matrix to include the proability of dose transfer
    dose_mask = (p>mod_adj_mat) & (adj_mat!=0) & (partner_state_prev == 2)
    d[dose_mask] = dose_quantity #whenever it is proabable, dose transfer occurs
    
    return d

# %%
def rew(p_rew,adjacency_matrix,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r) :
    
    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew > z1_rew_prew)  & (indi_state_for_rew_prev == 1) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    rew_mask_minus1 = (w_minus > z1_rew_prew) & (indi_state_for_rew_prev == 2)
    #break links. Dont create any.
    adjacency_matrix[rew_mask_minus1] = 0
    rew_mask_minus2 = ((lamb_da*OD_mesh2) > z1_rew_lambda) & (indi_state_for_rew_prev == 1)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
def let_it_run(p_rew_netrun,adjacency_matrix,OD_mesh2,lamb_da_netrun,density,rew_r) :

    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew_netrun > z1_rew_prew) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    
    rew_mask_minus2 = ((lamb_da_netrun*OD_mesh2) > z1_rew_lambda)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
'''function to update cumulative doses'''
def cumu_dose(d,D_prev,gamma) :
    I = d.sum(axis=1).reshape(N,1)
#     I = 0
    D = (D_prev - (gamma*D_prev*dt)) + I
    return D

# %%
'''function to update the states of the nodes of the system'''
def upd_indi_state(D,d_star,indi_state_prev) :
    
    z2 = np.random.uniform(size=(N,1))
    z3 = np.random.uniform(size=(N,1))
    
    indi_state = indi_state_prev
    
    indi_state_mask1 = (D>=d_star) & (indi_state_prev==1)
    indi_state[indi_state_mask1] = 2
    
    indi_state_mask21 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho>=z3)
    indi_state[indi_state_mask21] = 1
    
    indi_state_mask22 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho<z3)
    indi_state[indi_state_mask22] = 3
    
    indi_state_mask23 = (D<d_star) & (indi_state_prev==2) & (r<z2)
    indi_state[indi_state_mask23] = 2
    
    return indi_state

# %%
'''function to get/identify the infected nodes and the suceptible nodes'''
def states(indi_state) :
    infec_indi = []
    suscep_indi = []
    infec_indi = np.transpose(np.where(indi_state==2))
    suscep_indi = np.transpose(np.where(indi_state==1))
    return infec_indi,suscep_indi

# %%
def networkx_graph(coords,edge_list) :
    G = nx.DiGraph()
    pos = {(i): (coords[i][0],coords[i][1]) for i in range(N)}
    G.add_nodes_from(pos.keys())
    G.add_edges_from(edge_list)
    return G

# %%
def edge_from_adj_mat(adj_mat_list,q):
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adj_mat_list[q]==1))))
    return edge_list

# %% [markdown]
# # The main part of the script

# %%
#infected state time series data frame
#columns indicate the time steps
timeseries_infec_frac = pd.DataFrame()

#in degree as columns and rows as nodes
# timeseries_in_degree = pd.DataFrame() 

#out degree as columns and rows as nodes
timeseries_out_degree = pd.DataFrame()

#strongly connected components as columns
# timeseries_connec_comps = pd.DataFrame()

#mean of out degree as columns and rows as nodes
timeseries_out_degree_mean = pd.DataFrame()

# %%
vals = round(1/((density)*(np.pi)*(rew_r*rew_r)),3)
p_rew_vals = [round(0.1*vals,3),round(vals,3),round(10*vals,3),round(100*vals,3)]
start_vals = [1,10]
dose_quantity_vals = [0.5,2]

# %%
for sim in range(70,70+25) :
    
    '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''
    dist_mat,coords = calc_dist(N) #node placement
    edge_list = knn(dist_mat,nn,N)
    bef_netrun_org_adj_mat = np.int64(np.zeros((N,N)))
    for i in range(len(edge_list)):
        bef_netrun_org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)
    df_row = 0
    
    for p_rew_org in p_rew_vals : #rate of rewiring (per unit time (second))
        if p_rew_org == round(0.1*vals,3) :
            dt_netrun = 100
        elif p_rew_org == round(vals,3):
            dt_netrun = 10
        else :
            dt_netrun = dt
            
        lamb_da_org = p_rew_org/10        
        '''parameters for the coupling dynamics'''
        lamb_da = lamb_da_org*dt
        p_rew = p_rew_org*dt
        
        '''parameters for the network satbilisation'''
        lamb_da_netrun = lamb_da_org*dt_netrun
        p_rew_netrun = p_rew_org*dt_netrun
        
        for start in start_vals : #rate of dose transfer (per unit time (second))
            for dose_quantity in dose_quantity_vals : #number of nodes to infect initially
                print('(sim,lamb_da,p_rew,start,dose_quantity) = ', (sim,lamb_da/dt,p_rew/dt,start,dose_quantity))

                '''clearing exsiting data frames and creating new ones '''
                timeseries_infec_frac = pd.DataFrame()
#                 timeseries_in_degree = pd.DataFrame()
#                 timeseries_out_degree = pd.DataFrame()
                timeseries_connec_comps = pd.DataFrame()
                timeseries_out_degree_mean = pd.DataFrame()

                q = 0 #to generate new edge_list from the new adjacency matrix 
                t = np.arange(0,T,dt)

                adj_mat_list = []
                adj_mat = copy.deepcopy(bef_netrun_org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new) #list of arrays which shows the time series of the adjacency matrix
    
                '''obtaining a steady network topology before starting the dynamics on the network'''

                q = 0
                steady_counter = 0
                df_col = 0
                no_reset = 0 
                while steady_counter < steady_counter_val :

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])
                    timeseries_out_degree_mean.loc[0,df_col] = timeseries_out_degree.iloc[:,df_col].mean()
                    if df_col-1 >= 0 :
            #             print(timeseries_out_degree_mean.loc[0,df_col])
                        if np.abs(timeseries_out_degree_mean.loc[0,df_col] - timeseries_out_degree_mean.loc[0,df_col-1]) <= tol :
                            steady_counter = steady_counter + 1
                        else :
                            steady_counter = 0
                            no_reset = no_reset + 1
#                             print('oops')
                            if no_reset > 100 :
                                break

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)    
                    adj_mat = let_it_run(p_rew_netrun,adj_mat,OD_mesh2,lamb_da_netrun,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    q = q + 1 
                    df_col = df_col + 1
                    
                '''steady network topology obtained, start the dynamics now'''
                print(timeseries_out_degree_mean.loc[0,df_col-1])
                timeseries_out_degree = pd.DataFrame()
                df_col = 0
                q = 0 
                edge_list = copy.deepcopy(edge_list)
                G = copy.deepcopy(G)
                org_adj_mat = copy.deepcopy(adj_mat_new)

                numpy_array = np.zeros((N,len(t)),dtype = np.int64)

                D_array = np.zeros((N,len(t)))
                for i in range(len(edge_list)):
                    org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)

                adj_mat_list = []
                adj_mat = copy.deepcopy(org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new)


                '''from G, obtain the in degree and the out degree'''
#                 timeseries_in_degree.loc[:,0] = np.asarray([val for (node, val) in G.in_degree()])
                timeseries_out_degree.loc[:,0] = np.asarray([val for (node, val) in G.out_degree()])

                '''strongly and weekely connected components'''
#                 timeseries_connec_comps.loc[0,0] = nx.number_connected_components(G.to_undirected())

                '''choosing initially infected nodes'''
                indi_state = np.random.randint(1,2,size=(N,1))
                infected_nodes = None
                while infected_nodes is None : #infecting 'start' number of network neighbours
                    infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)      
                print(infected_nodes)
                infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
                indi_state[infected_nodes[:,0],0] = 2

                A,B = np.meshgrid(indi_state,indi_state) 
                partner_state = copy.deepcopy(A)
                indi_state_for_rew = copy.deepcopy(B)

    #             numpy_array [:,0] = indi_state[:,0]

                indi_state_prev = copy.deepcopy(indi_state)
                partner_state_prev = copy.deepcopy(partner_state)
                indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                d = np.zeros((len(adj_mat),len(adj_mat[0])))

                D = np.zeros((N,1))
                D[np.where(indi_state==2)] = D_ini
                D_array[:,0] = D[:,0]
                D_prev = copy.deepcopy(D)

                infec_frac = np.count_nonzero(indi_state == 2)/N
                timeseries_infec_frac.loc[df_row,0] = infec_frac
                '''the main part of the simulation'''
                counter = 0
                df_col = 1
                for t in np.arange(dt,T,dt) :
                    q = q + 1 
                    counter = counter + 1
                    infec_indi = []
                    suscep_indi = []
                    d = np.zeros((len(adj_mat),len(adj_mat[0])))
                    d = dose(adj_mat,p,partner_state_prev,d)

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)
                    adj_mat = rew(p_rew,adj_mat,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    '''from G, obtain the in degree and the out degree'''
#                     timeseries_in_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.in_degree()])
                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])

                    '''strongly and weekely connected components'''
#                     timeseries_connec_comps.loc[df_row,df_col] = nx.number_connected_components(G.to_undirected())

                    D = cumu_dose(d,D_prev,gamma)
                    D_array[:,counter] = D[:,0]

                    indi_state = upd_indi_state(D,d_star,indi_state_prev)
                    infec_frac = np.count_nonzero(indi_state == 2)/N
                    timeseries_infec_frac.loc[df_row,df_col] = infec_frac

    #                 numpy_array[:,counter] = indi_state[:,0]
                    A,B = np.meshgrid(indi_state,indi_state)

                    infec_indi, suscep_indi = states(indi_state)

                    partner_state = copy.deepcopy(A)
                    indi_state_for_rew = copy.deepcopy(B)
                    indi_state_prev = copy.deepcopy(indi_state)
                    partner_state_prev = copy.deepcopy(partner_state)
                    indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                    D_prev = copy.deepcopy(D)
                    D = np.zeros((N,1))
                    df_col = df_col + 1 

    #             df_row = df_row + 1 #going to the next row of the df to store timeseries of next (p,start)

                filename_infec_frac = 'infec_frac.h5'
                filename_in_deg = 'in_deg.h5'
                filename_out_deg = 'out_deg.h5'
                filename_connec_comps = 'connec_comps.h5'
                p_rew_val = '%g'%(p_rew/dt)
                key_val = 'sim_'+str(sim)+'_p_rew_'+str(p_rew_val)+'_start_'+str(start)+'_dq_'+str(dose_quantity)
#                 print(key_val)
                timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
#                 timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
                timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
#                 timeseries_connec_comps.to_hdf(filename_connec_comps, key = key_val, mode='a')
                df_row = 0
# Out:
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.001, 0.01, 1, 0.5)
# 7.23
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.001, 0.01, 1, 2)
# 7.17
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.001, 0.01, 10, 0.5)
# 7.27
# {0, 1, 73, 11, 13, 46, 47, 23, 24, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.001, 0.01, 10, 2)
# 6.95
# {3, 5, 10, 12, 78, 19, 53, 94, 57, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0098, 0.098, 1, 0.5)
# 6.72
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0098, 0.098, 1, 2)
# 6.63
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0098, 0.098, 10, 0.5)
# 6.67
# {1, 73, 11, 13, 46, 47, 23, 24, 60, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0098, 0.098, 10, 2)
# 6.84
# {32, 69, 70, 40, 16, 85, 55, 57, 59, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.098, 0.98, 1, 0.5)
# 5.3
# {55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.098, 0.98, 1, 2)
# 5.09
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.098, 0.98, 10, 0.5)
# 5.36
# {32, 5, 9, 10, 77, 16, 52, 85, 57, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.098, 0.98, 10, 2)
# 5.21
# {69, 70, 37, 40, 9, 16, 52, 85, 59, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.9800000000000001, 9.8, 1, 0.5)
# 4.97
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.9800000000000001, 9.8, 1, 2)
# 5.04
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.9800000000000001, 9.8, 10, 0.5)
# 5.22
# {3, 37, 12, 78, 51, 19, 53, 87, 25, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.9800000000000001, 9.8, 10, 2)
# 4.86
# {36, 6, 72, 76, 15, 48, 50, 86, 56, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.001, 0.01, 1, 0.5)
# 7.99
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.001, 0.01, 1, 2)
# 7.85
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.001, 0.01, 10, 0.5)
# 7.82
# {96, 68, 69, 70, 6, 81, 86, 88, 27, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.001, 0.01, 10, 2)
# 7.85
# {42, 11, 74, 18, 19, 82, 20, 55, 31, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0098, 0.098, 1, 0.5)
# 7.37
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0098, 0.098, 1, 2)
# 6.74
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0098, 0.098, 10, 0.5)
# 6.63
# {32, 97, 74, 75, 76, 42, 16, 52, 22, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0098, 0.098, 10, 2)
# 6.83
# {32, 72, 73, 74, 44, 46, 15, 48, 21, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.098, 0.98, 1, 0.5)
# 5.62
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.098, 0.98, 1, 2)
# 5.42
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.098, 0.98, 10, 0.5)
# 5.56
# {1, 3, 14, 83, 84, 56, 25, 59, 28, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.098, 0.98, 10, 2)
# 5.66
# {2, 40, 9, 76, 45, 78, 13, 90, 91, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.9800000000000001, 9.8, 1, 0.5)
# 4.76
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.9800000000000001, 9.8, 1, 2)
# 5.48
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.9800000000000001, 9.8, 10, 0.5)
# 4.92
# {99, 9, 13, 78, 79, 29, 85, 90, 61, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.9800000000000001, 9.8, 10, 2)
# 4.84
# {0, 33, 98, 38, 12, 17, 20, 59, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.001, 0.01, 1, 0.5)
# 6.34
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.001, 0.01, 1, 2)
# 6.58
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.001, 0.01, 10, 0.5)
# 6.2
# {96, 33, 2, 67, 36, 71, 41, 82, 83, 53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.001, 0.01, 10, 2)
# 6.56
# {5, 39, 74, 11, 45, 17, 20, 86, 22, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0098, 0.098, 1, 0.5)
# 6.15
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0098, 0.098, 1, 2)
# 5.64
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0098, 0.098, 10, 0.5)
# 5.95
# {98, 6, 38, 73, 77, 52, 55, 90, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0098, 0.098, 10, 2)
# 5.49
# {7, 40, 73, 44, 78, 52, 21, 85, 87, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.098, 0.98, 1, 0.5)
# 5.19
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.098, 0.98, 1, 2)
# 4.95
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.098, 0.98, 10, 0.5)
# 5.14
# {5, 39, 72, 74, 11, 45, 17, 20, 22, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.098, 0.98, 10, 2)
# 5.0
# {97, 38, 73, 10, 44, 85, 87, 28, 62, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.9800000000000001, 9.8, 1, 0.5)
# 4.45
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.9800000000000001, 9.8, 1, 2)
# 4.69
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.9800000000000001, 9.8, 10, 0.5)
# 4.97
# {65, 99, 69, 70, 59, 48, 50, 54, 27, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.9800000000000001, 9.8, 10, 2)
# 4.79
# {96, 33, 1, 2, 36, 71, 12, 19, 83, 53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.001, 0.01, 1, 0.5)
# 5.39
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.001, 0.01, 1, 2)
# 5.53
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.001, 0.01, 10, 0.5)
# 5.69
# {0, 97, 2, 67, 40, 45, 24, 94, 90, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.001, 0.01, 10, 2)
# 5.31
# {37, 39, 8, 43, 12, 45, 79, 91, 60, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0098, 0.098, 1, 0.5)
# 4.85
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0098, 0.098, 1, 2)
# 5.02
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0098, 0.098, 10, 0.5)
# 4.79
# {34, 72, 47, 48, 81, 18, 16, 54, 22, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0098, 0.098, 10, 2)
# 5.0
# {64, 1, 3, 70, 42, 11, 51, 84, 85, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.098, 0.98, 1, 0.5)
# 4.85
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.098, 0.98, 1, 2)
# 4.96
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.098, 0.98, 10, 0.5)
# 4.87
# {3, 37, 70, 42, 11, 51, 84, 85, 23, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.098, 0.98, 10, 2)
# 4.97
# {64, 1, 33, 70, 11, 76, 80, 51, 84, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.9800000000000001, 9.8, 1, 0.5)
# 4.6
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.9800000000000001, 9.8, 1, 2)
# 4.6
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.9800000000000001, 9.8, 10, 0.5)
# 4.51
# {64, 1, 3, 70, 42, 11, 80, 84, 85, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.9800000000000001, 9.8, 10, 2)
# 4.61
# {99, 7, 71, 9, 10, 41, 77, 21, 88, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.001, 0.01, 1, 0.5)
# 8.26
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.001, 0.01, 1, 2)
# 8.47
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.001, 0.01, 10, 0.5)
# 8.32
# {33, 66, 71, 10, 76, 79, 19, 22, 58, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.001, 0.01, 10, 2)
# 8.51
# {98, 67, 68, 73, 75, 77, 82, 86, 54, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0098, 0.098, 1, 0.5)
# 7.79
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0098, 0.098, 1, 2)
# 8.05
# {34}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0098, 0.098, 10, 0.5)
# 7.69
# {65, 67, 68, 69, 72, 75, 82, 54, 56, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0098, 0.098, 10, 2)
# 7.76
# {98, 67, 4, 69, 73, 75, 77, 54, 55, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.098, 0.98, 1, 0.5)
# 5.74
# {99}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.098, 0.98, 1, 2)
# 5.9
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.098, 0.98, 10, 0.5)
# 5.63
# {35, 99, 68, 5, 7, 72, 48, 17, 25, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.098, 0.98, 10, 2)
# 5.63
# {97, 76, 78, 15, 53, 23, 94, 58, 62, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.9800000000000001, 9.8, 1, 0.5)
# 5.56
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.9800000000000001, 9.8, 1, 2)
# 5.57
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.9800000000000001, 9.8, 10, 0.5)
# 5.2
# {97, 3, 74, 11, 76, 15, 80, 85, 94, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.9800000000000001, 9.8, 10, 2)
# 4.8
# {0, 34, 35, 7, 41, 45, 46, 48, 84, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.001, 0.01, 1, 0.5)
# 6.36
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.001, 0.01, 1, 2)
# 6.28
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.001, 0.01, 10, 0.5)
# 6.25
# {68, 6, 41, 42, 44, 45, 20, 22, 30, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.001, 0.01, 10, 2)
# 6.28
# {1, 34, 69, 72, 10, 77, 45, 19, 92, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0098, 0.098, 1, 0.5)
# 5.53
# {59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0098, 0.098, 1, 2)
# 5.77
# {34}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0098, 0.098, 10, 0.5)
# 5.26
# {0, 99, 4, 27, 74, 91, 49, 84, 59, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0098, 0.098, 10, 2)
# 5.29
# {96, 67, 70, 40, 43, 78, 18, 25, 62, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.098, 0.98, 1, 0.5)
# 5.16
# {97}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.098, 0.98, 1, 2)
# 5.02
# {5}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.098, 0.98, 10, 0.5)
# 4.97
# {32, 34, 68, 69, 8, 45, 22, 92, 61, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.098, 0.98, 10, 2)
# 5.14
# {35, 10, 42, 44, 77, 79, 15, 81, 20, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.9800000000000001, 9.8, 1, 0.5)
# 4.82
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.9800000000000001, 9.8, 1, 2)
# 4.64
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.9800000000000001, 9.8, 10, 0.5)
# 4.76
# {32, 1, 34, 6, 72, 45, 19, 22, 92, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.9800000000000001, 9.8, 10, 2)
# 5.03
# {96, 67, 70, 40, 78, 18, 82, 25, 58, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.001, 0.01, 1, 0.5)
# 6.8
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.001, 0.01, 1, 2)
# 6.96
# {96}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.001, 0.01, 10, 0.5)
# 6.78
# {90, 72, 8, 76, 15, 19, 84, 86, 58, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.001, 0.01, 10, 2)
# 6.73
# {32, 96, 58, 8, 76, 15, 84, 54, 90, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0098, 0.098, 1, 0.5)
# 6.25
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0098, 0.098, 1, 2)
# 5.66
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0098, 0.098, 10, 0.5)
# 5.99
# {70, 14, 47, 51, 20, 52, 55, 87, 27, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0098, 0.098, 10, 2)
# 5.43
# {89, 68, 37, 8, 40, 10, 50, 19, 25, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.098, 0.98, 1, 0.5)
# 5.46
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.098, 0.98, 1, 2)
# 5.53
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.098, 0.98, 10, 0.5)
# 5.26
# {34, 70, 71, 7, 74, 14, 49, 55, 87, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.098, 0.98, 10, 2)
# 5.16
# {33, 35, 68, 73, 80, 18, 85, 53, 89, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.9800000000000001, 9.8, 1, 0.5)
# 5.27
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.9800000000000001, 9.8, 1, 2)
# 5.05
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.9800000000000001, 9.8, 10, 0.5)
# 4.97
# {4, 7, 45, 82, 51, 20, 53, 52, 26, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.9800000000000001, 9.8, 10, 2)
# 5.0
# {1, 5, 6, 13, 81, 83, 23, 24, 29, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.001, 0.01, 1, 0.5)
# 6.43
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.001, 0.01, 1, 2)
# 6.5
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.001, 0.01, 10, 0.5)
# 6.59
# {34, 35, 98, 13, 46, 79, 18, 55, 89, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.001, 0.01, 10, 2)
# 6.9
# {99, 41, 74, 43, 47, 17, 51, 84, 54, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0098, 0.098, 1, 0.5)
# 5.6
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0098, 0.098, 1, 2)
# 5.72
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0098, 0.098, 10, 0.5)
# 5.35
# {96, 97, 67, 10, 78, 50, 24, 25, 56, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0098, 0.098, 10, 2)
# 5.8
# {0, 3, 68, 70, 42, 52, 27, 28, 93, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.098, 0.98, 1, 0.5)
# 5.15
# {51}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.098, 0.98, 1, 2)
# 5.08
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.098, 0.98, 10, 0.5)
# 4.95
# {0, 74, 80, 19, 84, 51, 27, 61, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.098, 0.98, 10, 2)
# 4.98
# {66, 3, 36, 5, 9, 42, 52, 27, 28, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.9800000000000001, 9.8, 1, 0.5)
# 4.53
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.9800000000000001, 9.8, 1, 2)
# 4.8
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.9800000000000001, 9.8, 10, 0.5)
# 4.45
# {65, 6, 10, 78, 81, 20, 21, 87, 56, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.9800000000000001, 9.8, 10, 2)
# 4.59
# {34, 35, 98, 13, 46, 79, 18, 55, 89, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.001, 0.01, 1, 0.5)
# 6.66
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.001, 0.01, 1, 2)
# 7.17
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.001, 0.01, 10, 0.5)
# 6.82
# {2, 4, 37, 6, 8, 40, 9, 72, 83, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.001, 0.01, 10, 2)
# 6.87
# {64, 1, 40, 74, 76, 13, 78, 52, 85, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0098, 0.098, 1, 0.5)
# 6.49
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0098, 0.098, 1, 2)
# 6.42
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0098, 0.098, 10, 0.5)
# 6.41
# {97, 73, 42, 11, 45, 48, 54, 24, 56, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0098, 0.098, 10, 2)
# 6.24
# {70, 73, 45, 18, 82, 22, 23, 87, 94, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.098, 0.98, 1, 0.5)
# 5.45
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.098, 0.98, 1, 2)
# 5.56
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.098, 0.98, 10, 0.5)
# 5.37
# {32, 33, 98, 66, 15, 80, 19, 51, 21, 84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.098, 0.98, 10, 2)
# 5.13
# {66, 4, 37, 6, 72, 12, 79, 83, 55, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.9800000000000001, 9.8, 1, 0.5)
# 5.32
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.9800000000000001, 9.8, 1, 2)
# 5.33
# {98}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.9800000000000001, 9.8, 10, 0.5)
# 4.62
# {41, 79, 18, 82, 87, 23, 56, 94, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.9800000000000001, 9.8, 10, 2)
# 4.73
# {96, 97, 73, 45, 48, 54, 22, 24, 56, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.001, 0.01, 1, 0.5)
# 8.15
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.001, 0.01, 1, 2)
# 8.13
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.001, 0.01, 10, 0.5)
# 8.11
# {32, 65, 66, 3, 37, 38, 50, 54, 27, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.001, 0.01, 10, 2)
# 8.25
# {32, 65, 66, 3, 38, 15, 50, 54, 58, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0098, 0.098, 1, 0.5)
# 7.73
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0098, 0.098, 1, 2)
# 7.45
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0098, 0.098, 10, 0.5)
# 7.5
# {1, 9, 75, 11, 14, 47, 46, 88, 91, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0098, 0.098, 10, 2)
# 7.5
# {2, 6, 41, 42, 16, 85, 21, 57, 92, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.098, 0.98, 1, 0.5)
# 5.54
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.098, 0.98, 1, 2)
# 5.67
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.098, 0.98, 10, 0.5)
# 5.83
# {69, 5, 80, 81, 82, 19, 84, 57, 28, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.098, 0.98, 10, 2)
# 5.67
# {64, 4, 69, 40, 73, 43, 80, 49, 86, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.9800000000000001, 9.8, 1, 0.5)
# 4.82
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.9800000000000001, 9.8, 1, 2)
# 5.38
# {11}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.9800000000000001, 9.8, 10, 0.5)
# 4.87
# {33, 98, 67, 39, 72, 71, 74, 10, 53, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.9800000000000001, 9.8, 10, 2)
# 5.45
# {97, 2, 6, 41, 42, 16, 85, 21, 92, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.001, 0.01, 1, 0.5)
# 8.0
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.001, 0.01, 1, 2)
# 8.01
# {96}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.001, 0.01, 10, 0.5)
# 8.02
# {0, 65, 1, 64, 32, 19, 52, 88, 57, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.001, 0.01, 10, 2)
# 8.19
# {32, 2, 5, 37, 46, 47, 48, 21, 26, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0098, 0.098, 1, 0.5)
# 7.63
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0098, 0.098, 1, 2)
# 7.64
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0098, 0.098, 10, 0.5)
# 7.67
# {69, 9, 43, 77, 81, 82, 54, 24, 61, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0098, 0.098, 10, 2)
# 7.79
# {64, 1, 65, 32, 11, 52, 88, 57, 90, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.098, 0.98, 1, 0.5)
# 5.61
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.098, 0.98, 1, 2)
# 5.62
# {53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.098, 0.98, 10, 0.5)
# 5.54
# {64, 65, 1, 32, 35, 52, 88, 57, 90, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.098, 0.98, 10, 2)
# 5.51
# {96, 34, 99, 75, 13, 17, 82, 53, 91, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.9800000000000001, 9.8, 1, 0.5)
# 5.62
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.9800000000000001, 9.8, 1, 2)
# 5.52
# {8}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.9800000000000001, 9.8, 10, 0.5)
# 5.48
# {32, 98, 3, 40, 11, 48, 53, 24, 60, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.9800000000000001, 9.8, 10, 2)
# 5.48
# {32, 64, 98, 3, 37, 11, 48, 18, 52, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.001, 0.01, 1, 0.5)
# 7.13
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.001, 0.01, 1, 2)
# 7.08
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.001, 0.01, 10, 0.5)
# 6.86
# {2, 99, 69, 77, 13, 52, 24, 59, 30, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.001, 0.01, 10, 2)
# 7.09
# {64, 33, 68, 5, 40, 72, 80, 29, 61, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0098, 0.098, 1, 0.5)
# 6.2
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0098, 0.098, 1, 2)
# 6.37
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0098, 0.098, 10, 0.5)
# 6.1
# {0, 1, 38, 41, 44, 45, 81, 20, 21, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0098, 0.098, 10, 2)
# 5.92
# {98, 66, 37, 10, 75, 42, 25, 58, 27, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.098, 0.98, 1, 0.5)
# 5.45
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.098, 0.98, 1, 2)
# 5.29
# {22}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.098, 0.98, 10, 0.5)
# 5.39
# {96, 36, 9, 46, 47, 17, 51, 21, 22, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.098, 0.98, 10, 2)
# 5.34
# {32, 91, 78, 48, 81, 19, 88, 26, 59, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.9800000000000001, 9.8, 1, 0.5)
# 5.13
# {88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.9800000000000001, 9.8, 1, 2)
# 4.8
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.9800000000000001, 9.8, 10, 0.5)
# 5.26
# {70, 77, 13, 52, 84, 23, 55, 89, 30, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.9800000000000001, 9.8, 10, 2)
# 4.99
# {98, 6, 39, 74, 16, 49, 85, 25, 94, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.001, 0.01, 1, 0.5)
# 7.42
# {37}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.001, 0.01, 1, 2)
# 7.41
# {53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.001, 0.01, 10, 0.5)
# 7.17
# {96, 90, 13, 79, 16, 17, 86, 88, 58, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.001, 0.01, 10, 2)
# 7.44
# {2, 4, 37, 71, 41, 9, 11, 76, 45, 74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0098, 0.098, 1, 0.5)
# 6.83
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0098, 0.098, 1, 2)
# 7.15
# {19}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0098, 0.098, 10, 0.5)
# 6.62
# {34, 98, 36, 68, 85, 55, 27, 93, 94, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0098, 0.098, 10, 2)
# 7.05
# {66, 5, 49, 50, 19, 18, 87, 56, 61, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.098, 0.98, 1, 0.5)
# 5.66
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.098, 0.98, 1, 2)
# 5.43
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.098, 0.98, 10, 0.5)
# 5.57
# {4, 41, 74, 43, 80, 83, 84, 21, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.098, 0.98, 10, 2)
# 5.45
# {4, 41, 74, 43, 45, 80, 83, 21, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.9800000000000001, 9.8, 1, 0.5)
# 5.3
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.9800000000000001, 9.8, 1, 2)
# 4.88
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.9800000000000001, 9.8, 10, 0.5)
# 4.88
# {66, 6, 72, 10, 77, 17, 18, 19, 53, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.9800000000000001, 9.8, 10, 2)
# 5.23
# {4, 37, 41, 74, 43, 80, 83, 84, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.001, 0.01, 1, 0.5)
# 8.04
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.001, 0.01, 1, 2)
# 8.18
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.001, 0.01, 10, 0.5)
# 7.98
# {0, 65, 99, 4, 40, 73, 15, 81, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.001, 0.01, 10, 2)
# 7.91
# {0, 65, 99, 73, 15, 81, 49, 85, 21, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0098, 0.098, 1, 0.5)
# 7.24
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0098, 0.098, 1, 2)
# 7.17
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0098, 0.098, 10, 0.5)
# 7.26
# {66, 67, 35, 72, 12, 13, 46, 16, 80, 83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0098, 0.098, 10, 2)
# 7.12
# {36, 69, 37, 8, 10, 43, 76, 51, 55, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.098, 0.98, 1, 0.5)
# 5.36
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.098, 0.98, 1, 2)
# 5.44
# {0}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.098, 0.98, 10, 0.5)
# 5.49
# {32, 68, 72, 9, 45, 46, 16, 80, 83, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.098, 0.98, 10, 2)
# 5.26
# {74, 44, 77, 50, 82, 54, 88, 58, 27, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.9800000000000001, 9.8, 1, 0.5)
# 5.44
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.9800000000000001, 9.8, 1, 2)
# 5.46
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.9800000000000001, 9.8, 10, 0.5)
# 5.39
# {70, 71, 79, 17, 86, 23, 25, 26, 91, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.9800000000000001, 9.8, 10, 2)
# 5.11
# {68, 36, 70, 11, 13, 18, 23, 56, 57, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.001, 0.01, 1, 0.5)
# 7.78
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.001, 0.01, 1, 2)
# 7.59
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.001, 0.01, 10, 0.5)
# 7.51
# {91, 46, 78, 25, 56, 94, 59, 60, 62, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.001, 0.01, 10, 2)
# 7.51
# {32, 33, 10, 75, 12, 44, 48, 84, 21, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0098, 0.098, 1, 0.5)
# 6.94
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0098, 0.098, 1, 2)
# 6.97
# {97}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0098, 0.098, 10, 0.5)
# 6.92
# {32, 65, 33, 39, 10, 75, 12, 84, 21, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0098, 0.098, 10, 2)
# 7.22
# {0, 98, 68, 82, 50, 61, 85, 55, 58, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.098, 0.98, 1, 0.5)
# 5.54
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.098, 0.98, 1, 2)
# 5.61
# {37}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.098, 0.98, 10, 0.5)
# 5.47
# {34, 35, 6, 40, 9, 42, 43, 47, 54, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.098, 0.98, 10, 2)
# 5.39
# {70, 59, 46, 94, 56, 25, 91, 60, 62, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.9800000000000001, 9.8, 1, 0.5)
# 5.07
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.9800000000000001, 9.8, 1, 2)
# 4.9
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.9800000000000001, 9.8, 10, 0.5)
# 4.76
# {66, 58, 15, 50, 29, 85, 22, 55, 26, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.9800000000000001, 9.8, 10, 2)
# 5.28
# {98, 34, 68, 66, 35, 15, 85, 55, 58, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.001, 0.01, 1, 0.5)
# 7.55
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.001, 0.01, 1, 2)
# 7.81
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.001, 0.01, 10, 0.5)
# 7.81
# {98, 35, 5, 37, 71, 77, 15, 18, 27, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.001, 0.01, 10, 2)
# 8.05
# {98, 37, 76, 13, 44, 15, 52, 53, 88, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0098, 0.098, 1, 0.5)
# 6.66
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0098, 0.098, 1, 2)
# 6.45
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0098, 0.098, 10, 0.5)
# 6.96
# {98, 37, 41, 76, 13, 44, 15, 79, 88, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0098, 0.098, 10, 2)
# 6.46
# {98, 35, 5, 71, 77, 82, 18, 27, 60, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.098, 0.98, 1, 0.5)
# 5.51
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.098, 0.98, 1, 2)
# 5.77
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.098, 0.98, 10, 0.5)
# 5.68
# {98, 35, 5, 71, 77, 82, 18, 27, 60, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.098, 0.98, 10, 2)
# 5.75
# {33, 40, 41, 79, 53, 86, 87, 26, 28, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.9800000000000001, 9.8, 1, 0.5)
# 5.32
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.9800000000000001, 9.8, 1, 2)
# 5.05
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.9800000000000001, 9.8, 10, 0.5)
# 5.01
# {36, 40, 41, 79, 53, 86, 26, 28, 62, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.9800000000000001, 9.8, 10, 2)
# 5.4
# {4, 12, 47, 81, 50, 49, 51, 83, 23, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.001, 0.01, 1, 0.5)
# 7.03
# {37}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.001, 0.01, 1, 2)
# 7.06
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.001, 0.01, 10, 0.5)
# 6.87
# {3, 4, 9, 74, 17, 54, 23, 24, 26, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.001, 0.01, 10, 2)
# 7.15
# {1, 34, 39, 75, 43, 77, 50, 20, 92, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0098, 0.098, 1, 0.5)
# 6.5
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0098, 0.098, 1, 2)
# 6.45
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0098, 0.098, 10, 0.5)
# 6.27
# {4, 69, 9, 17, 23, 88, 24, 26, 27, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0098, 0.098, 10, 2)
# 6.33
# {0, 1, 34, 96, 75, 77, 50, 20, 92, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.098, 0.98, 1, 0.5)
# 5.34
# {53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.098, 0.98, 1, 2)
# 5.49
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.098, 0.98, 10, 0.5)
# 5.36
# {0, 96, 39, 10, 43, 81, 51, 20, 84, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.098, 0.98, 10, 2)
# 5.27
# {65, 97, 36, 5, 38, 70, 83, 87, 28, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.9800000000000001, 9.8, 1, 0.5)
# 4.89
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.9800000000000001, 9.8, 1, 2)
# 5.0
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.9800000000000001, 9.8, 10, 0.5)
# 4.92
# {98, 99, 7, 42, 76, 48, 19, 21, 56, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.9800000000000001, 9.8, 10, 2)
# 4.76
# {0, 96, 4, 6, 9, 10, 43, 84, 23, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.001, 0.01, 1, 0.5)
# 7.93
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.001, 0.01, 1, 2)
# 8.15
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.001, 0.01, 10, 0.5)
# 8.16
# {70, 72, 11, 14, 80, 86, 55, 59, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.001, 0.01, 10, 2)
# 8.2
# {96, 1, 65, 5, 82, 19, 21, 23, 56, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0098, 0.098, 1, 0.5)
# 7.8
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0098, 0.098, 1, 2)
# 7.45
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0098, 0.098, 10, 0.5)
# 7.65
# {66, 35, 70, 39, 72, 11, 48, 55, 59, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0098, 0.098, 10, 2)
# 7.51
# {66, 35, 72, 9, 14, 80, 48, 86, 55, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.098, 0.98, 1, 0.5)
# 5.53
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.098, 0.98, 1, 2)
# 5.61
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.098, 0.98, 10, 0.5)
# 5.63
# {77, 45, 79, 19, 20, 52, 54, 24, 28, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.098, 0.98, 10, 2)
# 5.74
# {66, 35, 39, 40, 80, 81, 22, 55, 89, 26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.9800000000000001, 9.8, 1, 0.5)
# 5.0
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.9800000000000001, 9.8, 1, 2)
# 5.53
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.9800000000000001, 9.8, 10, 0.5)
# 5.6
# {1, 3, 4, 5, 71, 82, 19, 21, 56, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.9800000000000001, 9.8, 10, 2)
# 5.52
# {65, 1, 3, 71, 74, 82, 21, 23, 56, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.001, 0.01, 1, 0.5)
# 6.38
# {55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.001, 0.01, 1, 2)
# 6.37
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.001, 0.01, 10, 0.5)
# 6.63
# {1, 97, 33, 37, 39, 40, 47, 54, 57, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.001, 0.01, 10, 2)
# 6.78
# {32, 75, 12, 48, 81, 82, 83, 55, 24, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0098, 0.098, 1, 0.5)
# 5.62
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0098, 0.098, 1, 2)
# 5.78
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0098, 0.098, 10, 0.5)
# 6.11
# {66, 67, 36, 69, 77, 49, 20, 22, 25, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0098, 0.098, 10, 2)
# 5.59
# {64, 65, 98, 68, 9, 11, 84, 55, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.098, 0.98, 1, 0.5)
# 5.26
# {7}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.098, 0.98, 1, 2)
# 4.81
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.098, 0.98, 10, 0.5)
# 5.13
# {96, 35, 37, 27, 74, 46, 23, 87, 59, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.098, 0.98, 10, 2)
# 4.92
# {6, 71, 8, 38, 44, 78, 85, 88, 26, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.9800000000000001, 9.8, 1, 0.5)
# 4.67
# {98}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.9800000000000001, 9.8, 1, 2)
# 4.71
# {21}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.9800000000000001, 9.8, 10, 0.5)
# 4.64
# {34, 39, 72, 73, 14, 47, 80, 17, 56, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.9800000000000001, 9.8, 10, 2)
# 4.59
# {0, 69, 40, 42, 49, 20, 53, 87, 25, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.001, 0.01, 1, 0.5)
# 7.93
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.001, 0.01, 1, 2)
# 7.97
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.001, 0.01, 10, 0.5)
# 7.89
# {58, 70, 46, 79, 16, 48, 55, 56, 26, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.001, 0.01, 10, 2)
# 7.92
# {2, 35, 67, 69, 74, 43, 76, 30, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0098, 0.098, 1, 0.5)
# 7.29
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0098, 0.098, 1, 2)
# 7.19
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0098, 0.098, 10, 0.5)
# 7.35
# {0, 4, 8, 73, 77, 78, 15, 45, 54, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0098, 0.098, 10, 2)
# 7.46
# {64, 1, 68, 7, 41, 49, 50, 20, 30, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.098, 0.98, 1, 0.5)
# 5.67
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.098, 0.98, 1, 2)
# 5.47
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.098, 0.98, 10, 0.5)
# 5.61
# {34, 13, 46, 47, 16, 17, 58, 59, 60, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.098, 0.98, 10, 2)
# 5.84
# {66, 40, 44, 47, 80, 17, 18, 91, 28, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.9800000000000001, 9.8, 1, 0.5)
# 5.15
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.9800000000000001, 9.8, 1, 2)
# 4.9
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.9800000000000001, 9.8, 10, 0.5)
# 4.94
# {2, 35, 68, 76, 49, 50, 51, 30, 94, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.9800000000000001, 9.8, 10, 2)
# 5.39
# {32, 2, 99, 66, 69, 71, 74, 44, 85, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.001, 0.01, 1, 0.5)
# 4.91
# {55}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.001, 0.01, 1, 2)
# 5.19
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.001, 0.01, 10, 0.5)
# 5.01
# {32, 72, 10, 14, 46, 49, 86, 89, 58, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.001, 0.01, 10, 2)
# 5.03
# {64, 65, 98, 38, 77, 16, 82, 50, 55, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0098, 0.098, 1, 0.5)
# 4.85
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0098, 0.098, 1, 2)
# 4.57
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0098, 0.098, 10, 0.5)
# 3.78
# {33, 97, 99, 37, 70, 6, 74, 78, 20, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0098, 0.098, 10, 2)
# 3.85
# {1, 3, 5, 71, 28, 19, 54, 88, 27, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.098, 0.98, 1, 0.5)
# 4.8
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.098, 0.98, 1, 2)
# 4.83
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.098, 0.98, 10, 0.5)
# 4.85
# {64, 0, 65, 75, 45, 48, 82, 50, 55, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.098, 0.98, 10, 2)
# 4.87
# {34, 8, 41, 15, 83, 53, 24, 92, 29, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.9800000000000001, 9.8, 1, 0.5)
# 4.51
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.9800000000000001, 9.8, 1, 2)
# 4.59
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.9800000000000001, 9.8, 10, 0.5)
# 4.64
# {34, 40, 15, 83, 85, 53, 24, 92, 29, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.9800000000000001, 9.8, 10, 2)
# 4.59
# {7, 40, 73, 15, 63, 83, 85, 25, 93, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.001, 0.01, 1, 0.5)
# 6.17
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.001, 0.01, 1, 2)
# 5.92
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.001, 0.01, 10, 0.5)
# 5.98
# {66, 2, 73, 75, 45, 56, 57, 58, 59, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.001, 0.01, 10, 2)
# 6.18
# {33, 67, 68, 90, 16, 17, 85, 54, 26, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0098, 0.098, 1, 0.5)
# 5.25
# {50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0098, 0.098, 1, 2)
# 5.61
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0098, 0.098, 10, 0.5)
# 5.58
# {3, 99, 38, 78, 82, 50, 22, 24, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0098, 0.098, 10, 2)
# 5.55
# {96, 71, 80, 48, 51, 84, 21, 23, 28, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.098, 0.98, 1, 0.5)
# 4.95
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.098, 0.98, 1, 2)
# 5.18
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.098, 0.98, 10, 0.5)
# 5.18
# {96, 71, 46, 80, 48, 51, 83, 53, 21, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.098, 0.98, 10, 2)
# 5.08
# {64, 65, 74, 11, 77, 50, 18, 88, 27, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.9800000000000001, 9.8, 1, 0.5)
# 4.89
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.9800000000000001, 9.8, 1, 2)
# 4.71
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.9800000000000001, 9.8, 10, 0.5)
# 4.86
# {2, 66, 72, 73, 45, 56, 57, 58, 59, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.9800000000000001, 9.8, 10, 2)
# 4.85
# {0, 97, 35, 36, 37, 69, 7, 8, 15, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.001, 0.01, 1, 0.5)
# 7.14
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.001, 0.01, 1, 2)
# 7.27
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.001, 0.01, 10, 0.5)
# 7.11
# {97, 98, 5, 38, 41, 74, 83, 20, 23, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.001, 0.01, 10, 2)
# 7.24
# {96, 65, 2, 67, 4, 10, 55, 87, 59, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0098, 0.098, 1, 0.5)
# 6.97
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0098, 0.098, 1, 2)
# 6.73
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0098, 0.098, 10, 0.5)
# 6.8
# {65, 35, 4, 39, 10, 43, 47, 19, 87, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0098, 0.098, 10, 2)
# 6.24
# {36, 69, 70, 11, 76, 45, 82, 84, 91, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.098, 0.98, 1, 0.5)
# 5.16
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.098, 0.98, 1, 2)
# 5.1
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.098, 0.98, 10, 0.5)
# 5.21
# {89, 35, 8, 9, 44, 48, 16, 25, 57, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.098, 0.98, 10, 2)
# 5.28
# {97, 98, 68, 40, 74, 15, 79, 81, 88, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.9800000000000001, 9.8, 1, 0.5)
# 4.85
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.9800000000000001, 9.8, 1, 2)
# 4.85
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.9800000000000001, 9.8, 10, 0.5)
# 4.69
# {0, 35, 46, 79, 15, 16, 48, 25, 90, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.9800000000000001, 9.8, 10, 2)
# 4.83
# {64, 1, 34, 37, 6, 73, 12, 24, 56, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.001, 0.01, 1, 0.5)
# 7.68
# {99}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.001, 0.01, 1, 2)
# 7.7
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.001, 0.01, 10, 0.5)
# 8.0
# {89, 65, 97, 66, 67, 12, 50, 19, 25, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.001, 0.01, 10, 2)
# 7.56
# {33, 35, 4, 10, 45, 47, 51, 86, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0098, 0.098, 1, 0.5)
# 7.11
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0098, 0.098, 1, 2)
# 6.64
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0098, 0.098, 10, 0.5)
# 7.06
# {36, 69, 43, 44, 77, 82, 83, 54, 28, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0098, 0.098, 10, 2)
# 6.61
# {4, 70, 45, 47, 17, 50, 19, 51, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.098, 0.98, 1, 0.5)
# 5.61
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.098, 0.98, 1, 2)
# 5.72
# {59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.098, 0.98, 10, 0.5)
# 5.32
# {32, 3, 37, 41, 75, 76, 18, 87, 56, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.098, 0.98, 10, 2)
# 5.48
# {2, 3, 98, 37, 6, 41, 76, 48, 20, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.9800000000000001, 9.8, 1, 0.5)
# 4.95
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.9800000000000001, 9.8, 1, 2)
# 4.86
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.9800000000000001, 9.8, 10, 0.5)
# 5.37
# {0, 1, 36, 40, 9, 75, 15, 23, 60, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.9800000000000001, 9.8, 10, 2)
# 5.02
# {64, 32, 6, 39, 75, 18, 23, 56, 59, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.001, 0.01, 1, 0.5)
# 6.29
# {85}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.001, 0.01, 1, 2)
# 6.44
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.001, 0.01, 10, 0.5)
# 6.2
# {96, 33, 74, 44, 14, 78, 17, 20, 24, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.001, 0.01, 10, 2)
# 5.94
# {64, 34, 43, 12, 46, 16, 81, 22, 87, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0098, 0.098, 1, 0.5)
# 5.34
# {3}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0098, 0.098, 1, 2)
# 5.65
# {22}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0098, 0.098, 10, 0.5)
# 6.05
# {32, 33, 99, 39, 72, 78, 14, 17, 21, 24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0098, 0.098, 10, 2)
# 5.72
# {36, 11, 75, 15, 49, 82, 52, 54, 88, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.098, 0.98, 1, 0.5)
# 5.08
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.098, 0.98, 1, 2)
# 5.05
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.098, 0.98, 10, 0.5)
# 5.1
# {2, 36, 4, 49, 83, 52, 84, 23, 25, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.098, 0.98, 10, 2)
# 5.11
# {65, 2, 66, 4, 69, 42, 83, 19, 23, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.9800000000000001, 9.8, 1, 0.5)
# 5.0
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.9800000000000001, 9.8, 1, 2)
# 4.79
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.9800000000000001, 9.8, 10, 0.5)
# 4.92
# {64, 34, 43, 12, 46, 16, 81, 22, 87, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.9800000000000001, 9.8, 10, 2)
# 4.96
# {32, 99, 37, 39, 19, 21, 53, 25, 91, 62}
