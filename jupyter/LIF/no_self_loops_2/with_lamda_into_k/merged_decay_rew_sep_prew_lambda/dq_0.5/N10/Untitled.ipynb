# %%
import h5py
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
out_deg = h5py.File('out_deg.h5', 'r')
print([key for key in out_deg.keys()])
# Out:
# ['sim_100_p_rew_0.01_start_10_dq_0.5', 'sim_100_p_rew_0.01_start_10_dq_2', 'sim_100_p_rew_0.01_start_1_dq_0.5', 'sim_100_p_rew_0.01_start_1_dq_2', 'sim_100_p_rew_0.1_start_10_dq_0.5', 'sim_100_p_rew_0.1_start_10_dq_2', 'sim_100_p_rew_0.1_start_1_dq_0.5', 'sim_100_p_rew_0.1_start_1_dq_2', 'sim_100_p_rew_10_start_10_dq_0.5', 'sim_100_p_rew_10_start_10_dq_2', 'sim_100_p_rew_10_start_1_dq_0.5', 'sim_100_p_rew_10_start_1_dq_2', 'sim_100_p_rew_1_start_10_dq_0.5', 'sim_100_p_rew_1_start_10_dq_2', 'sim_100_p_rew_1_start_1_dq_0.5', 'sim_100_p_rew_1_start_1_dq_2', 'sim_101_p_rew_0.01_start_10_dq_0.5', 'sim_101_p_rew_0.01_start_10_dq_2', 'sim_101_p_rew_0.01_start_1_dq_0.5', 'sim_101_p_rew_0.01_start_1_dq_2', 'sim_101_p_rew_0.1_start_10_dq_0.5', 'sim_101_p_rew_0.1_start_10_dq_2', 'sim_101_p_rew_0.1_start_1_dq_0.5', 'sim_101_p_rew_0.1_start_1_dq_2', 'sim_101_p_rew_10_start_10_dq_0.5', 'sim_101_p_rew_10_start_10_dq_2', 'sim_101_p_rew_10_start_1_dq_0.5', 'sim_101_p_rew_10_start_1_dq_2', 'sim_101_p_
# ...
