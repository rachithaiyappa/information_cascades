# %% [markdown]
# ## Leaky integrated firing neuron model
# ## Few feautures :
# ### Spatial network, no memory term but exponential decay of cumulative dose
#
# This is a minor change of the Dodds and Watts model
# Implement adaptive rewiring and generate statistics

# %%
#importing the required libraries

import networkx as nx
import matplotlib.pyplot as plt #for plotting
import numpy as np #for using arrays and vectorising the code wherever possible
import scipy
import random
# from numba import jit #numba precomplier to make the code faster
import pandas as pd
import copy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Variables used in the simulation

# %%
N = 100
gamma = 1 #decay of cumulative dose per unit time (second)
gamma = gamma
T = 400 #total number of seconds
dt = 0.05 #seconds
'''number of simulation steps is T/dt'''

'''Dodds watts parameters'''
p = 1 #rate of dose transfer (per unit time (second))
p = p*dt #rate of dose transfer per unit simulation step
r = 1/dt
r = r*dt
rho = 1/dt
rho = rho*dt
# r = 0.5
# r = r*dt

d_star = 1
# dose_quantity = 1
D_ini = 3

'''network parameters'''
circ_rad = 100 #for a network in which each node is connected to other nodes withing a circle of radius circ_rad
nn = 10 #the number of nearest neighbours(i.e. k) in knn
average_degree = 6
total_edges = N*2

'''rewiring parameters'''
rew_r = 18
density = 1/N
w_minus = 1
w_minus = w_minus*dt
# p_rew = 5 #rate of rewiring(per unit time(second))
# p_rew = p_rew*dt

# %% [markdown]
# # Creating the network.
# ### The network outputs coordinates, distance matrix, edge_list and adjacency matrix

# %%
'''
obtains the number of nodes N
generates N points
calculates euclidean distance between each pair of points
returns the coordinates of the points and the distance matrix which is N*N
'''
def calc_dist(N) :
    coords = []
    for counter in range(N) :
        coords.append((N*np.random.random(),N*np.random.random()))

    dist_mat = scipy.spatial.distance.cdist(coords,coords)
    return dist_mat,coords

# %% [markdown]
# ### 1. metric network

# %%
'''network = connect to points withing a circle of radius'''
#creates a link between points/nodes which satisfies the conditions of the network
def coupling(dist_mat,circ_rad) :
    edge_list = []
    edge_mask = (dist_mat<circ_rad) & (dist_mat>0)
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(edge_mask))))
#     print(type(np.ndarray.tolist(np.transpose(np.where(edge_mask)))))
    return edge_list

# %% [markdown]
# ### 2. K nearest neighbour network

# %%
'''network = knn'''
def knn(dist_mat,nn,N) :
    near_neigh = np.argsort(dist_mat)
    selec_near_neigh = np.zeros((N,nn))
    selec_near_neigh = near_neigh[:,0:nn+1]

    edge_list = []
    for i in range(N) :
        for j in range(1,nn+1) :
            link = [i,selec_near_neigh[i,j]]
            edge_list.append(link)

    return edge_list

# %% [markdown]
# ### 3. Random Network : GNP type

# %%
'''random network'''
def rand_network(average_degree,N) :
    z1 = np.random.uniform(size = (N,N))
    E,F = np.meshgrid(np.arange(0,N),np.arange(0,N))
    mask = ((average_degree/N) > z1) & (E!=F)
    adjacency_matrix = np.int64(np.zeros(shape=(N,N)))
    adjacency_matrix[mask] = np.int64(1)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list,adjacency_matrix

# %% [markdown]
# ### 4. Random Network : GNM type

# %%
def rand_net_gnm(total_edges,N) :
    the_graph = nx.gnm_random_graph(N, total_edges,directed=True)
    adjacency_matrix = nx.adjacency_matrix(the_graph)
    adjacency_matrix = np.asarray(adjacency_matrix.todense())
    np.fill_diagonal(adjacency_matrix,0)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list

# %% [markdown]
# # Function defintions required for the main part of the script

# %%
# # @jit(nopython=True)
# '''infecting the left part of space.'''
# def left_part_infec(N) :
#     x_coord = []
#     y_coord = []
#     for j in range(len(coords)) :
#         x_coord.append(coords[j][0])
#         y_coord.append(coords[j][1])
#     x_coord = np.asarray(x_coord)
#     y_coord = np.asarray(y_coord)
#     points = np.asarray(np.where(x_coord<(N/5))) 
#     indi_state[points.T] = 2

#     return indi_state

# %%
'''infecting connected nodes'''
def InfectNetworkNeighbors(net,seed_node,init_infected_nodes):
     # if in bulk find one node randomly, and infect its neighbours
    infected_nodes = set()
    candidate_nodes = set()
    explored_nodes = set()

    #pick the seed node
    infected_nodes.add(seed_node)
    explored_nodes.add(seed_node)

    curr_node=seed_node

    #add its neighbors to the list of candidates
    for n in net.neighbors(curr_node):
        candidate_nodes.add(int(n))
    #print( curr_node)
    #print( candidate_nodes)

    #while we need to select more nodes...
    while len(infected_nodes) < init_infected_nodes:

        #if there are candidate nodes, select one of them
        if(len(candidate_nodes) > 0):
            new_node = np.random.choice(list(candidate_nodes),1)[0]
            infected_nodes.add(new_node)
            candidate_nodes.remove(new_node)

        elif len(infected_nodes - explored_nodes) > 0:
            curr_node = np.random.choice(list(infected_nodes -
            explored_nodes),1)[0]
            explored_nodes.add(curr_node)
            for n in set(net.neighbors(curr_node)) - infected_nodes:
                candidate_nodes.add(n)

        else:
#             print('Initial node infection step failed')
            return None
    return infected_nodes

# %%
''' function to transfer doses'''
# @jit(nopython=True)
def dose(adj_mat,p,partner_state_prev,d) :

    z1 = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    dose_transfer_mask = p > z1
    mod_adj_mat = np.multiply(adj_mat,z1) #modifying adjacency matrix to include the proability of dose transfer
    dose_mask = (p>mod_adj_mat) & (adj_mat!=0) & (partner_state_prev == 2)
    d[dose_mask] = dose_quantity #whenever it is proabable, dose transfer occurs
    
    return d

# %%
def rew(p_rew,adjacency_matrix,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r) :
    
    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew > z1_rew_prew)  & (indi_state_for_rew_prev == 1) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    rew_mask_minus1 = (w_minus > z1_rew_prew) & (indi_state_for_rew_prev == 2)
    #break links. Dont create any.
    adjacency_matrix[rew_mask_minus1] = 0
    rew_mask_minus2 = ((lamb_da*OD_mesh2) > z1_rew_lambda) & (indi_state_for_rew_prev == 1)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
'''function to update cumulative doses'''
def cumu_dose(d,D_prev,gamma) :
    I = d.sum(axis=1).reshape(N,1)
#     I = 0
    D = (D_prev - (gamma*D_prev*dt)) + I
    return D

# %%
'''function to update the states of the nodes of the system'''
def upd_indi_state(D,d_star,indi_state_prev) :
    
    z2 = np.random.uniform(size=(N,1))
    z3 = np.random.uniform(size=(N,1))
    
    indi_state = indi_state_prev
    
    indi_state_mask1 = (D>=d_star) & (indi_state_prev==1)
    indi_state[indi_state_mask1] = 2
    
    indi_state_mask21 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho>=z3)
    indi_state[indi_state_mask21] = 1
    
    indi_state_mask22 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho<z3)
    indi_state[indi_state_mask22] = 3
    
    indi_state_mask23 = (D<d_star) & (indi_state_prev==2) & (r<z2)
    indi_state[indi_state_mask23] = 2
    
    return indi_state

# %%
'''function to get/identify the infected nodes and the suceptible nodes'''
def states(indi_state) :
    infec_indi = []
    suscep_indi = []
    infec_indi = np.transpose(np.where(indi_state==2))
    suscep_indi = np.transpose(np.where(indi_state==1))
    return infec_indi,suscep_indi

# %%
def networkx_graph(coords,edge_list) :
    G = nx.DiGraph()
    pos = {(i): (coords[i][0],coords[i][1]) for i in range(N)}
    G.add_nodes_from(pos.keys())
    G.add_edges_from(edge_list)
    return G

# %%
def edge_from_adj_mat(adj_mat_list,q):
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adj_mat_list[q]==1))))
    return edge_list

# %% [markdown]
# # The main part of the script

# %%
#infected state time series data frame
#columns indicate the time steps
timeseries_infec_frac = pd.DataFrame()

#in degree as columns and rows as nodes
timeseries_in_degree = pd.DataFrame() 

#out degree as columns and rows as nodes
timeseries_out_degree = pd.DataFrame()

#strongly connected components as columns
timeseries_connec_comps = pd.DataFrame()

# %%
vals = round(1/((density)*(np.pi)*(rew_r*rew_r)),3)
p_rew_vals = [round(vals,3),round(10*vals,3),round(100*vals,3),round(1000*vals,3)]
start_vals = [1,10]
dose_quantity_vals = [0.5,2]

# %%
for sim in range(70,70+10) :
    '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''
    dist_mat,coords = calc_dist(N) #node placement
    edge_list = knn(dist_mat,nn,N)
    org_adj_mat = np.int64(np.zeros((N,N)))
    for i in range(len(edge_list)):
        org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)
        
    df_row = 0
    for p_rew in p_rew_vals : #rate of rewiring (per unit time (second))
        lamb_da = p_rew/10
        lamb_da = lamb_da*dt
        p_rew = p_rew*dt
        for start in start_vals : #rate of dose transfer (per unit time (second))
            for dose_quantity in dose_quantity_vals : #number of nodes to infect initially
                print('(sim,lamb_da,p_rew,start,dose_quantity) = ', (sim,lamb_da/dt,p_rew/dt,start,dose_quantity))

                '''clearing exsiting data frames and creating new ones '''
                timeseries_infec_frac = pd.DataFrame()
                timeseries_in_degree = pd.DataFrame()
                timeseries_out_degree = pd.DataFrame()
                timeseries_connec_comps = pd.DataFrame()

                q = 0 #to generate new edge_list from the new adjacency matrix 
                t = np.arange(0,T,dt)

    #             numpy_array = np.zeros((N,len(t)),dtype = np.int64) #stores the states of the nodes. Rows are nodes and columns are time steps
                D_array = np.zeros((N,len(t))) #stores the cumulative doses. Rows are nodes and columns are time steps

                adj_mat_list = []
                adj_mat = copy.deepcopy(org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new) #list of arrays which shows the time series of the adjacency matrix

                #coords remain the same. Get new edge_list from the latest adjacency matrix
                edge_list = edge_from_adj_mat(adj_mat_list,q)
                G = networkx_graph(coords,edge_list) #networkx graph

                '''from G, obtain the in degree and the out degree'''
                timeseries_in_degree.loc[:,0] = np.asarray([val for (node, val) in G.in_degree()])
                timeseries_out_degree.loc[:,0] = np.asarray([val for (node, val) in G.out_degree()])

                '''strongly and weekely connected components'''
                timeseries_connec_comps.loc[0,0] = nx.number_connected_components(G.to_undirected())

                '''choosing initially infected nodes'''
                indi_state = np.random.randint(1,2,size=(N,1))
                infected_nodes = None
                while infected_nodes is None : #infecting 'start' number of network neighbours
                    infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)      
                print(infected_nodes)
                infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
                indi_state[infected_nodes[:,0],0] = 2

                A,B = np.meshgrid(indi_state,indi_state) 
                partner_state = copy.deepcopy(A)
                indi_state_for_rew = copy.deepcopy(B)

    #             numpy_array [:,0] = indi_state[:,0]

                indi_state_prev = copy.deepcopy(indi_state)
                partner_state_prev = copy.deepcopy(partner_state)
                indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                d = np.zeros((len(adj_mat),len(adj_mat[0])))

                D = np.zeros((N,1))
                D[np.where(indi_state==2)] = D_ini
                D_array[:,0] = D[:,0]
                D_prev = copy.deepcopy(D)

                infec_frac = np.count_nonzero(indi_state == 2)/N
                timeseries_infec_frac.loc[df_row,0] = infec_frac
                '''the main part of the simulation'''
                counter = 0
                df_col = 1
                for t in np.arange(dt,T,dt) :
                    q = q + 1 
                    counter = counter + 1
                    infec_indi = []
                    suscep_indi = []
                    d = np.zeros((len(adj_mat),len(adj_mat[0])))
                    d = dose(adj_mat,p,partner_state_prev,d)

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)
                    adj_mat = rew(p_rew,adj_mat,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    '''from G, obtain the in degree and the out degree'''
                    timeseries_in_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.in_degree()])
                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])

                    '''strongly and weekely connected components'''
                    timeseries_connec_comps.loc[df_row,df_col] = nx.number_connected_components(G.to_undirected())

                    D = cumu_dose(d,D_prev,gamma)
                    D_array[:,counter] = D[:,0]

                    indi_state = upd_indi_state(D,d_star,indi_state_prev)
                    infec_frac = np.count_nonzero(indi_state == 2)/N
                    timeseries_infec_frac.loc[df_row,df_col] = infec_frac

    #                 numpy_array[:,counter] = indi_state[:,0]
                    A,B = np.meshgrid(indi_state,indi_state)

                    infec_indi, suscep_indi = states(indi_state)

                    partner_state = copy.deepcopy(A)
                    indi_state_for_rew = copy.deepcopy(B)
                    indi_state_prev = copy.deepcopy(indi_state)
                    partner_state_prev = copy.deepcopy(partner_state)
                    indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                    D_prev = copy.deepcopy(D)
                    D = np.zeros((N,1))
                    df_col = df_col + 1 

    #             df_row = df_row + 1 #going to the next row of the df to store timeseries of next (p,start)

                filename_infec_frac = 'infec_frac.h5'
                filename_in_deg = 'in_deg.h5'
                filename_out_deg = 'out_deg.h5'
                filename_connec_comps = 'connec_comps.h5'
                p_rew_val = '%g'%(p_rew/dt)
                key_val = 'sim_'+str(sim)+'_p_rew_'+str(p_rew_val)+'_start_'+str(start)+'_dq_'+str(dose_quantity)
#                 print(key_val)
                timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
                timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
                timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
                timeseries_connec_comps.to_hdf(filename_connec_comps, key = key_val, mode='a')
                df_row = 0
# Out:
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0098, 0.098, 1, 0.5)
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0098, 0.098, 1, 2)
# {53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0098, 0.098, 10, 0.5)
# {97, 34, 4, 69, 38, 7, 73, 74, 28, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0098, 0.098, 10, 2)
# {0, 6, 8, 43, 76, 14, 84, 21, 25, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.098, 0.98, 1, 0.5)
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.098, 0.98, 1, 2)
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.098, 0.98, 10, 0.5)
# {69, 7, 71, 14, 18, 19, 83, 86, 23, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.098, 0.98, 10, 2)
# {97, 34, 4, 38, 7, 73, 74, 28, 92, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.9800000000000001, 9.8, 1, 0.5)
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.9800000000000001, 9.8, 1, 2)
# {91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.9800000000000001, 9.8, 10, 0.5)
# {68, 37, 41, 75, 17, 51, 57, 26, 91, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.9800000000000001, 9.8, 10, 2)
# {4, 38, 10, 74, 45, 49, 81, 60, 61, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 9.8, 98.0, 1, 0.5)
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 9.8, 98.0, 1, 2)
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 9.8, 98.0, 10, 0.5)
# {2, 36, 40, 44, 77, 78, 53, 90, 93, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 9.8, 98.0, 10, 2)
# {69, 71, 14, 18, 83, 19, 21, 86, 23, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0098, 0.098, 1, 0.5)
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0098, 0.098, 1, 2)
# {61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0098, 0.098, 10, 0.5)
# {0, 34, 37, 11, 75, 14, 85, 90, 30, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0098, 0.098, 10, 2)
# {96, 67, 69, 7, 39, 73, 9, 44, 13, 84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.098, 0.98, 1, 0.5)
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.098, 0.98, 1, 2)
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.098, 0.98, 10, 0.5)
# {71, 77, 15, 79, 49, 84, 53, 27, 61, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.098, 0.98, 10, 2)
# {65, 67, 69, 39, 9, 44, 13, 80, 84, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.9800000000000001, 9.8, 1, 0.5)
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.9800000000000001, 9.8, 1, 2)
# {22}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.9800000000000001, 9.8, 10, 0.5)
# {97, 5, 41, 46, 16, 82, 83, 87, 25, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.9800000000000001, 9.8, 10, 2)
# {97, 67, 70, 47, 16, 19, 55, 89, 93, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 9.8, 98.0, 1, 0.5)
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 9.8, 98.0, 1, 2)
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 9.8, 98.0, 10, 0.5)
# {65, 71, 72, 73, 7, 78, 79, 49, 27, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 9.8, 98.0, 10, 2)
# {67, 70, 47, 16, 19, 85, 55, 89, 58, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0098, 0.098, 1, 0.5)
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0098, 0.098, 1, 2)
# {50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0098, 0.098, 10, 0.5)
# {64, 97, 99, 8, 14, 47, 80, 83, 20, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0098, 0.098, 10, 2)
# {32, 2, 4, 75, 43, 49, 23, 56, 62, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.098, 0.98, 1, 0.5)
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.098, 0.98, 1, 2)
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.098, 0.98, 10, 0.5)
# {32, 0, 98, 4, 70, 43, 78, 54, 56, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.098, 0.98, 10, 2)
# {97, 38, 8, 80, 17, 19, 20, 23, 88, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.9800000000000001, 9.8, 1, 0.5)
# {51}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.9800000000000001, 9.8, 1, 2)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.9800000000000001, 9.8, 10, 0.5)
# {96, 33, 1, 73, 46, 82, 18, 22, 86, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.9800000000000001, 9.8, 10, 2)
# {64, 97, 99, 69, 73, 14, 47, 83, 86, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 9.8, 98.0, 1, 0.5)
# {3}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 9.8, 98.0, 1, 2)
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 9.8, 98.0, 10, 0.5)
# {65, 35, 6, 7, 79, 50, 84, 90, 91, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 9.8, 98.0, 10, 2)
# {65, 68, 36, 76, 44, 15, 48, 51, 87, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0098, 0.098, 1, 0.5)
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0098, 0.098, 1, 2)
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0098, 0.098, 10, 0.5)
# {0, 64, 58, 6, 79, 48, 86, 88, 90, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0098, 0.098, 10, 2)
# {65, 45, 14, 80, 49, 20, 21, 91, 92, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.098, 0.98, 1, 0.5)
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.098, 0.98, 1, 2)
# {65}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.098, 0.98, 10, 0.5)
# {2, 71, 73, 14, 92, 80, 17, 20, 60, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.098, 0.98, 10, 2)
# {32, 67, 70, 75, 13, 16, 56, 58, 88, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.9800000000000001, 9.8, 1, 0.5)
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.9800000000000001, 9.8, 1, 2)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.9800000000000001, 9.8, 10, 0.5)
# {65, 2, 14, 92, 80, 49, 82, 21, 91, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.9800000000000001, 9.8, 10, 2)
# {3, 99, 37, 6, 38, 74, 48, 83, 58, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 9.8, 98.0, 1, 0.5)
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 9.8, 98.0, 1, 2)
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 9.8, 98.0, 10, 0.5)
# {98, 36, 5, 42, 45, 82, 54, 87, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 9.8, 98.0, 10, 2)
# {65, 10, 44, 14, 80, 49, 82, 21, 91, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0098, 0.098, 1, 0.5)
# {90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0098, 0.098, 1, 2)
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0098, 0.098, 10, 0.5)
# {36, 5, 74, 46, 14, 79, 81, 47, 84, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0098, 0.098, 10, 2)
# {2, 6, 39, 8, 41, 48, 19, 85, 23, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.098, 0.98, 1, 0.5)
# {98}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.098, 0.98, 1, 2)
# {3}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.098, 0.98, 10, 0.5)
# {42, 28, 80, 82, 52, 87, 25, 58, 92, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.098, 0.98, 10, 2)
# {32, 71, 7, 91, 50, 54, 86, 58, 27, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.9800000000000001, 9.8, 1, 0.5)
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.9800000000000001, 9.8, 1, 2)
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.9800000000000001, 9.8, 10, 0.5)
# {96, 74, 75, 12, 15, 83, 20, 90, 60, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.9800000000000001, 9.8, 10, 2)
# {65, 33, 40, 42, 10, 16, 52, 55, 87, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 9.8, 98.0, 1, 0.5)
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 9.8, 98.0, 1, 2)
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 9.8, 98.0, 10, 0.5)
# {1, 73, 74, 75, 15, 83, 20, 90, 60, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 9.8, 98.0, 10, 2)
# {0, 96, 3, 37, 70, 74, 75, 12, 20, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0098, 0.098, 1, 0.5)
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0098, 0.098, 1, 2)
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0098, 0.098, 10, 0.5)
# {96, 97, 98, 66, 99, 6, 44, 47, 20, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0098, 0.098, 10, 2)
# {34, 72, 40, 8, 10, 12, 82, 22, 86, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.098, 0.98, 1, 0.5)
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.098, 0.98, 1, 2)
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.098, 0.98, 10, 0.5)
# {32, 64, 38, 71, 12, 46, 47, 84, 58, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.098, 0.98, 10, 2)
# {37, 72, 40, 10, 12, 15, 49, 82, 84, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.9800000000000001, 9.8, 1, 0.5)
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.9800000000000001, 9.8, 1, 2)
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.9800000000000001, 9.8, 10, 0.5)
# {67, 4, 41, 11, 75, 14, 81, 19, 55, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.9800000000000001, 9.8, 10, 2)
# {0, 96, 66, 97, 71, 12, 84, 22, 59, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 9.8, 98.0, 1, 0.5)
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 9.8, 98.0, 1, 2)
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 9.8, 98.0, 10, 0.5)
# {35, 68, 9, 73, 45, 48, 49, 52, 25, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 9.8, 98.0, 10, 2)
# {96, 32, 98, 66, 97, 71, 44, 46, 54, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0098, 0.098, 1, 0.5)
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0098, 0.098, 1, 2)
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0098, 0.098, 10, 0.5)
# {64, 6, 8, 41, 79, 88, 57, 27, 92, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0098, 0.098, 10, 2)
# {1, 34, 35, 36, 71, 9, 73, 50, 51, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.098, 0.98, 1, 0.5)
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.098, 0.98, 1, 2)
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.098, 0.98, 10, 0.5)
# {33, 69, 38, 71, 52, 53, 21, 24, 90, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.098, 0.98, 10, 2)
# {99, 69, 11, 76, 16, 84, 21, 52, 24, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.9800000000000001, 9.8, 1, 0.5)
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.9800000000000001, 9.8, 1, 2)
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.9800000000000001, 9.8, 10, 0.5)
# {0, 65, 71, 9, 42, 49, 82, 83, 58, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.9800000000000001, 9.8, 10, 2)
# {4, 11, 76, 16, 52, 21, 20, 23, 84, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 9.8, 98.0, 1, 0.5)
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 9.8, 98.0, 1, 2)
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 9.8, 98.0, 10, 0.5)
# {32, 33, 69, 12, 47, 81, 18, 22, 29, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 9.8, 98.0, 10, 2)
# {97, 66, 72, 12, 13, 14, 18, 22, 26, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0098, 0.098, 1, 0.5)
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0098, 0.098, 1, 2)
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0098, 0.098, 10, 0.5)
# {33, 36, 39, 75, 12, 47, 48, 19, 53, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0098, 0.098, 10, 2)
# {32, 69, 40, 41, 43, 17, 22, 58, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.098, 0.98, 1, 0.5)
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.098, 0.98, 1, 2)
# {91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.098, 0.98, 10, 0.5)
# {66, 98, 13, 81, 50, 20, 84, 55, 91, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.098, 0.98, 10, 2)
# {34, 5, 70, 71, 73, 80, 18, 87, 28, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.9800000000000001, 9.8, 1, 0.5)
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.9800000000000001, 9.8, 1, 2)
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.9800000000000001, 9.8, 10, 0.5)
# {2, 66, 36, 10, 79, 54, 23, 25, 26, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.9800000000000001, 9.8, 10, 2)
# {65, 39, 75, 12, 47, 48, 19, 53, 93, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 9.8, 98.0, 1, 0.5)
# {7}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 9.8, 98.0, 1, 2)
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 9.8, 98.0, 10, 0.5)
# {33, 65, 36, 39, 75, 12, 48, 19, 53, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 9.8, 98.0, 10, 2)
# {66, 11, 79, 48, 81, 19, 20, 53, 27, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0098, 0.098, 1, 0.5)
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0098, 0.098, 1, 2)
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0098, 0.098, 10, 0.5)
# {65, 36, 9, 79, 48, 86, 87, 56, 61, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0098, 0.098, 10, 2)
# {65, 66, 72, 75, 14, 15, 86, 28, 63, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.098, 0.98, 1, 0.5)
# {97}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.098, 0.98, 1, 2)
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.098, 0.98, 10, 0.5)
# {7, 39, 11, 78, 81, 23, 88, 25, 59, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.098, 0.98, 10, 2)
# {64, 6, 8, 42, 43, 74, 80, 18, 55, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.9800000000000001, 9.8, 1, 0.5)
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.9800000000000001, 9.8, 1, 2)
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.9800000000000001, 9.8, 10, 0.5)
# {96, 34, 68, 69, 37, 13, 16, 51, 52, 53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.9800000000000001, 9.8, 10, 2)
# {97, 98, 67, 71, 76, 44, 19, 21, 85, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 9.8, 98.0, 1, 0.5)
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 9.8, 98.0, 1, 2)
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 9.8, 98.0, 10, 0.5)
# {64, 3, 8, 74, 42, 80, 18, 54, 55, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 9.8, 98.0, 10, 2)
# {0, 33, 97, 4, 79, 83, 84, 87, 56, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0098, 0.098, 1, 0.5)
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0098, 0.098, 1, 2)
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0098, 0.098, 10, 0.5)
# {99, 4, 70, 7, 72, 51, 28, 63, 95, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0098, 0.098, 10, 2)
# {64, 2, 9, 11, 43, 83, 20, 53, 58, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.098, 0.98, 1, 0.5)
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.098, 0.98, 1, 2)
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.098, 0.98, 10, 0.5)
# {41, 73, 45, 16, 81, 49, 85, 88, 26, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.098, 0.98, 10, 2)
# {97, 1, 66, 69, 40, 47, 80, 84, 86, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.9800000000000001, 9.8, 1, 0.5)
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.9800000000000001, 9.8, 1, 2)
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.9800000000000001, 9.8, 10, 0.5)
# {37, 6, 8, 43, 46, 14, 55, 24, 27, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.9800000000000001, 9.8, 10, 2)
# {97, 1, 65, 35, 10, 47, 80, 22, 54, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 9.8, 98.0, 1, 0.5)
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 9.8, 98.0, 1, 2)
# {59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 9.8, 98.0, 10, 0.5)
# {64, 43, 14, 46, 52, 55, 24, 27, 60, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 9.8, 98.0, 10, 2)
# {98, 4, 70, 7, 72, 51, 31, 63, 94, 95}
