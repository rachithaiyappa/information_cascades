# %% [markdown]
# ## Leaky integrated firing neuron model
# ## Few feautures :
# ### Spatial network, no memory term but exponential decay of cumulative dose
#
# This is a minor change of the Dodds and Watts model
# Implement adaptive rewiring and generate statistics

# %%
#importing the required libraries

import networkx as nx
import matplotlib.pyplot as plt #for plotting
import numpy as np #for using arrays and vectorising the code wherever possible
import scipy
import random
# from numba import jit #numba precomplier to make the code faster
import pandas as pd
import copy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Variables used in the simulation

# %%
N = 100
gamma = 1 #decay of cumulative dose per unit time (second)
gamma = gamma
T = 500 #total number of seconds
dt = 0.05 #seconds
dt_netrun = 10
'''number of simulation steps is T/dt'''

'''Dodds watts parameters'''
p = 1 #rate of dose transfer (per unit time (second))
p = p*dt #rate of dose transfer per unit simulation step
r = 1/dt
r = r*dt
rho = 1/dt
rho = rho*dt
# r = 0.5
# r = r*dt

d_star = 1
# dose_quantity = 1
D_ini = 3

'''network parameters'''
circ_rad = 100 #for a network in which each node is connected to other nodes withing a circle of radius circ_rad
nn = 10 #the number of nearest neighbours(i.e. k) in knn
average_degree = 6
total_edges = N*2

'''rewiring parameters'''
rew_r = 21
density = 1/N
# p_rew = 5 #rate of rewiring(per unit time(second))
# p_rew = p_rew*dt

'''tolerance to determine initial network topology'''
tol = 0.5
steady_counter_val = 500

# %% [markdown]
# # Creating the network.
# ### The network outputs coordinates, distance matrix, edge_list and adjacency matrix

# %%
'''
obtains the number of nodes N
generates N points
calculates euclidean distance between each pair of points
returns the coordinates of the points and the distance matrix which is N*N
'''
def calc_dist(N) :
    coords = []
    for counter in range(N) :
        coords.append((N*np.random.random(),N*np.random.random()))

    dist_mat = scipy.spatial.distance.cdist(coords,coords)
    return dist_mat,coords

# %% [markdown]
# ### 1. metric network

# %%
'''network = connect to points withing a circle of radius'''
#creates a link between points/nodes which satisfies the conditions of the network
def coupling(dist_mat,circ_rad) :
    edge_list = []
    edge_mask = (dist_mat<circ_rad) & (dist_mat>0)
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(edge_mask))))
#     print(type(np.ndarray.tolist(np.transpose(np.where(edge_mask)))))
    return edge_list

# %% [markdown]
# ### 2. K nearest neighbour network

# %%
'''network = knn'''
def knn(dist_mat,nn,N) :
    near_neigh = np.argsort(dist_mat)
    selec_near_neigh = np.zeros((N,nn))
    selec_near_neigh = near_neigh[:,0:nn+1]

    edge_list = []
    for i in range(N) :
        for j in range(1,nn+1) :
            link = [i,selec_near_neigh[i,j]]
            edge_list.append(link)

    return edge_list

# %% [markdown]
# ### 3. Random Network : GNP type

# %%
'''random network'''
def rand_network(average_degree,N) :
    z1 = np.random.uniform(size = (N,N))
    E,F = np.meshgrid(np.arange(0,N),np.arange(0,N))
    mask = ((average_degree/N) > z1) & (E!=F)
    adjacency_matrix = np.int64(np.zeros(shape=(N,N)))
    adjacency_matrix[mask] = np.int64(1)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list,adjacency_matrix

# %% [markdown]
# ### 4. Random Network : GNM type

# %%
def rand_net_gnm(total_edges,N) :
    the_graph = nx.gnm_random_graph(N, total_edges,directed=True)
    adjacency_matrix = nx.adjacency_matrix(the_graph)
    adjacency_matrix = np.asarray(adjacency_matrix.todense())
    np.fill_diagonal(adjacency_matrix,0)
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adjacency_matrix==1))))
    return edge_list

# %% [markdown]
# # Function defintions required for the main part of the script

# %%
# # @jit(nopython=True)
# '''infecting the left part of space.'''
# def left_part_infec(N) :
#     x_coord = []
#     y_coord = []
#     for j in range(len(coords)) :
#         x_coord.append(coords[j][0])
#         y_coord.append(coords[j][1])
#     x_coord = np.asarray(x_coord)
#     y_coord = np.asarray(y_coord)
#     points = np.asarray(np.where(x_coord<(N/5))) 
#     indi_state[points.T] = 2

#     return indi_state

# %%
'''infecting connected nodes'''
def InfectNetworkNeighbors(net,seed_node,init_infected_nodes):
     # if in bulk find one node randomly, and infect its neighbours
    infected_nodes = set()
    candidate_nodes = set()
    explored_nodes = set()

    #pick the seed node
    infected_nodes.add(seed_node)
    explored_nodes.add(seed_node)

    curr_node=seed_node

    #add its neighbors to the list of candidates
    for n in net.neighbors(curr_node):
        candidate_nodes.add(int(n))
    #print( curr_node)
    #print( candidate_nodes)

    #while we need to select more nodes...
    while len(infected_nodes) < init_infected_nodes:

        #if there are candidate nodes, select one of them
        if(len(candidate_nodes) > 0):
            new_node = np.random.choice(list(candidate_nodes),1)[0]
            infected_nodes.add(new_node)
            candidate_nodes.remove(new_node)

        elif len(infected_nodes - explored_nodes) > 0:
            curr_node = np.random.choice(list(infected_nodes -
            explored_nodes),1)[0]
            explored_nodes.add(curr_node)
            for n in set(net.neighbors(curr_node)) - infected_nodes:
                candidate_nodes.add(n)

        else:
#             print('Initial node infection step failed')
            return None
    return infected_nodes

# %%
''' function to transfer doses'''
# @jit(nopython=True)
def dose(adj_mat,p,partner_state_prev,d) :

    z1 = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    dose_transfer_mask = p > z1
    mod_adj_mat = np.multiply(adj_mat,z1) #modifying adjacency matrix to include the proability of dose transfer
    dose_mask = (p>mod_adj_mat) & (adj_mat!=0) & (partner_state_prev == 2)
    d[dose_mask] = dose_quantity #whenever it is proabable, dose transfer occurs
    
    return d

# %%
def rew(p_rew,adjacency_matrix,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r) :
    
    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew > z1_rew_prew)  & (indi_state_for_rew_prev == 1) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    rew_mask_minus1 = (p_rew > z1_rew_prew) & (indi_state_for_rew_prev == 2)
    #break links. Dont create any.
    adjacency_matrix[rew_mask_minus1] = 0
    rew_mask_minus2 = ((lamb_da*OD_mesh2) > z1_rew_lambda) & (indi_state_for_rew_prev == 1)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
def let_it_run(p_rew_netrun,adjacency_matrix,OD_mesh2,lamb_da_netrun,density,rew_r) :

    z1_rew_prew = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    z1_rew_lambda = np.random.uniform(size=(len(adj_mat),len(adj_mat[0])))
    
    rew_mask_plus = (p_rew_netrun > z1_rew_prew) & (dist_mat <= rew_r)
    #create links. Dont break any.
    adjacency_matrix[rew_mask_plus] = 1
    
    rew_mask_minus2 = ((lamb_da_netrun*OD_mesh2) > z1_rew_lambda)
    adjacency_matrix[rew_mask_minus2] = 0
    
    np.fill_diagonal(adjacency_matrix,0)
    
    return adjacency_matrix

# %%
'''function to update cumulative doses'''
def cumu_dose(d,D_prev,gamma) :
    I = d.sum(axis=1).reshape(N,1)
#     I = 0
    D = (D_prev - (gamma*D_prev*dt)) + I
    return D

# %%
'''function to update the states of the nodes of the system'''
def upd_indi_state(D,d_star,indi_state_prev) :
    
    z2 = np.random.uniform(size=(N,1))
    z3 = np.random.uniform(size=(N,1))
    
    indi_state = indi_state_prev
    
    indi_state_mask1 = (D>=d_star) & (indi_state_prev==1)
    indi_state[indi_state_mask1] = 2
    
    indi_state_mask21 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho>=z3)
    indi_state[indi_state_mask21] = 1
    
    indi_state_mask22 = (D<d_star) & (indi_state_prev==2) & (r>=z2) & (rho<z3)
    indi_state[indi_state_mask22] = 3
    
    indi_state_mask23 = (D<d_star) & (indi_state_prev==2) & (r<z2)
    indi_state[indi_state_mask23] = 2
    
    return indi_state

# %%
'''function to get/identify the infected nodes and the suceptible nodes'''
def states(indi_state) :
    infec_indi = []
    suscep_indi = []
    infec_indi = np.transpose(np.where(indi_state==2))
    suscep_indi = np.transpose(np.where(indi_state==1))
    return infec_indi,suscep_indi

# %%
def networkx_graph(coords,edge_list) :
    G = nx.DiGraph()
    pos = {(i): (coords[i][0],coords[i][1]) for i in range(N)}
    G.add_nodes_from(pos.keys())
    G.add_edges_from(edge_list)
    return G

# %%
def edge_from_adj_mat(adj_mat_list,q):
    edge_list = []
    edge_list.extend(np.ndarray.tolist(np.transpose(np.where(adj_mat_list[q]==1))))
    return edge_list

# %% [markdown]
# # The main part of the script

# %%
#infected state time series data frame
#columns indicate the time steps
timeseries_infec_frac = pd.DataFrame()

#in degree as columns and rows as nodes
# timeseries_in_degree = pd.DataFrame() 

#out degree as columns and rows as nodes
timeseries_out_degree = pd.DataFrame()

#strongly connected components as columns
# timeseries_connec_comps = pd.DataFrame()

#mean of out degree as columns and rows as nodes
timeseries_out_degree_mean = pd.DataFrame()

# %%
vals = round(1/((density)*(np.pi)*(rew_r*rew_r)),3)
p_rew_vals = [round(0.1*vals,3),round(vals,3),round(10*vals,3),round(100*vals,3)]
start_vals = [1,10]
dose_quantity_vals = [0.5,2]

# %%
for sim in range(70,70+25) :
    
    '''returns coordinates, distance matrix, edge_list and the adjacency matrix'''
    dist_mat,coords = calc_dist(N) #node placement
    edge_list = knn(dist_mat,nn,N)
    bef_netrun_org_adj_mat = np.int64(np.zeros((N,N)))
    for i in range(len(edge_list)):
        bef_netrun_org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)
    df_row = 0
    
    for p_rew_org in p_rew_vals : #rate of rewiring (per unit time (second))
        if p_rew_org == round(0.1*vals,3) :
            dt_netrun = 100
        elif p_rew_org == round(vals,3):
            dt_netrun = 10
        else :
            dt_netrun = dt
            
        lamb_da_org = p_rew_org/10        
        '''parameters for the coupling dynamics'''
        lamb_da = lamb_da_org*dt
        p_rew = p_rew_org*dt
        
        '''parameters for the network satbilisation'''
        lamb_da_netrun = lamb_da_org*dt_netrun
        p_rew_netrun = p_rew_org*dt_netrun
        
        for start in start_vals : #rate of dose transfer (per unit time (second))
            for dose_quantity in dose_quantity_vals : #number of nodes to infect initially
                print('(sim,lamb_da,p_rew,start,dose_quantity) = ', (sim,lamb_da/dt,p_rew/dt,start,dose_quantity))

                '''clearing exsiting data frames and creating new ones '''
                timeseries_infec_frac = pd.DataFrame()
#                 timeseries_in_degree = pd.DataFrame()
                timeseries_out_degree = pd.DataFrame()
#                 timeseries_connec_comps = pd.DataFrame()
                timeseries_out_degree_mean = pd.DataFrame()

                q = 0 #to generate new edge_list from the new adjacency matrix 
                t = np.arange(0,T,dt)

                adj_mat_list = []
                adj_mat = copy.deepcopy(bef_netrun_org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new) #list of arrays which shows the time series of the adjacency matrix
    
                '''obtaining a steady network topology before starting the dynamics on the network'''

                q = 0
                steady_counter = 0
                df_col = 0
                no_reset = 0 
                while steady_counter < steady_counter_val :

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])
                    timeseries_out_degree_mean.loc[0,df_col] = timeseries_out_degree.iloc[:,df_col].mean()
                    if df_col-1 >= 0 :
            #             print(timeseries_out_degree_mean.loc[0,df_col])
                        if np.abs(timeseries_out_degree_mean.loc[0,df_col] - timeseries_out_degree_mean.loc[0,df_col-1]) <= tol :
                            steady_counter = steady_counter + 1
                        else :
                            steady_counter = 0
                            no_reset = no_reset + 1
#                             print('oops')
                            if no_reset > 100 :
                                break

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)    
                    adj_mat = let_it_run(p_rew_netrun,adj_mat,OD_mesh2,lamb_da_netrun,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    q = q + 1 
                    df_col = df_col + 1
                    
                '''steady network topology obtained, start the dynamics now'''
                print(timeseries_out_degree_mean.loc[0,df_col-1])
                timeseries_out_degree = pd.DataFrame()
                df_col = 0
                q = 0 
                edge_list = copy.deepcopy(edge_list)
                G = copy.deepcopy(G)
                org_adj_mat = copy.deepcopy(adj_mat_new)

                numpy_array = np.zeros((N,len(t)),dtype = np.int64)

                D_array = np.zeros((N,len(t)))
                for i in range(len(edge_list)):
                    org_adj_mat[edge_list[i][0],edge_list[i][1]] = np.int64(1)

                adj_mat_list = []
                adj_mat = copy.deepcopy(org_adj_mat)
                adj_mat_new = copy.deepcopy(adj_mat)
                adj_mat_list.append(adj_mat_new)


                '''from G, obtain the in degree and the out degree'''
#                 timeseries_in_degree.loc[:,0] = np.asarray([val for (node, val) in G.in_degree()])
                timeseries_out_degree.loc[:,0] = np.asarray([val for (node, val) in G.out_degree()])

                '''strongly and weekely connected components'''
#                 timeseries_connec_comps.loc[0,0] = nx.number_connected_components(G.to_undirected())

                '''choosing initially infected nodes'''
                indi_state = np.random.randint(1,2,size=(N,1))
                infected_nodes = None
                while infected_nodes is None : #infecting 'start' number of network neighbours
                    infected_nodes = InfectNetworkNeighbors(G,np.random.randint(N),start)      
                print(infected_nodes)
                infected_nodes = np.asarray(list(infected_nodes)).reshape(len(infected_nodes),1)
                indi_state[infected_nodes[:,0],0] = 2

                A,B = np.meshgrid(indi_state,indi_state) 
                partner_state = copy.deepcopy(A)
                indi_state_for_rew = copy.deepcopy(B)

    #             numpy_array [:,0] = indi_state[:,0]

                indi_state_prev = copy.deepcopy(indi_state)
                partner_state_prev = copy.deepcopy(partner_state)
                indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                d = np.zeros((len(adj_mat),len(adj_mat[0])))

                D = np.zeros((N,1))
                D[np.where(indi_state==2)] = D_ini
                D_array[:,0] = D[:,0]
                D_prev = copy.deepcopy(D)

                infec_frac = np.count_nonzero(indi_state == 2)/N
                timeseries_infec_frac.loc[df_row,0] = infec_frac
                '''the main part of the simulation'''
                counter = 0
                df_col = 1
                for t in np.arange(dt,T,dt) :
                    q = q + 1 
                    counter = counter + 1
                    infec_indi = []
                    suscep_indi = []
                    d = np.zeros((len(adj_mat),len(adj_mat[0])))
                    d = dose(adj_mat,p,partner_state_prev,d)

                    OD_array = np.asarray([val for (node, val) in G.out_degree()])
                    OD_mesh1,OD_mesh2 = np.meshgrid(OD_array,OD_array)
                    adj_mat = rew(p_rew,adj_mat,indi_state_for_rew_prev,OD_mesh2,lamb_da,density,rew_r)
                    adj_mat_new = copy.deepcopy(adj_mat)
                    adj_mat_list.append(adj_mat_new)

                    #coords remain the same. Get new edge_list from the latest adjacency matrix
                    edge_list = edge_from_adj_mat(adj_mat_list,q)
                    G = networkx_graph(coords,edge_list) #networkx graph

                    '''from G, obtain the in degree and the out degree'''
#                     timeseries_in_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.in_degree()])
                    timeseries_out_degree.loc[:,df_col] = np.asarray([val for (node, val) in G.out_degree()])

                    '''strongly and weekely connected components'''
#                     timeseries_connec_comps.loc[df_row,df_col] = nx.number_connected_components(G.to_undirected())

                    D = cumu_dose(d,D_prev,gamma)
                    D_array[:,counter] = D[:,0]

                    indi_state = upd_indi_state(D,d_star,indi_state_prev)
                    infec_frac = np.count_nonzero(indi_state == 2)/N
                    timeseries_infec_frac.loc[df_row,df_col] = infec_frac

    #                 numpy_array[:,counter] = indi_state[:,0]
                    A,B = np.meshgrid(indi_state,indi_state)

                    infec_indi, suscep_indi = states(indi_state)

                    partner_state = copy.deepcopy(A)
                    indi_state_for_rew = copy.deepcopy(B)
                    indi_state_prev = copy.deepcopy(indi_state)
                    partner_state_prev = copy.deepcopy(partner_state)
                    indi_state_for_rew_prev = copy.deepcopy(indi_state_for_rew)

                    D_prev = copy.deepcopy(D)
                    D = np.zeros((N,1))
                    df_col = df_col + 1 

    #             df_row = df_row + 1 #going to the next row of the df to store timeseries of next (p,start)

                filename_infec_frac = 'infec_frac.h5'
                filename_in_deg = 'in_deg.h5'
                filename_out_deg = 'out_deg.h5'
                filename_connec_comps = 'connec_comps.h5'
                p_rew_val = '%g'%(p_rew/dt)
                key_val = 'sim_'+str(sim)+'_p_rew_'+str(p_rew_val)+'_start_'+str(start)+'_dq_'+str(dose_quantity)
#                 print(key_val)
                timeseries_infec_frac.to_hdf(filename_infec_frac, key = key_val, mode='a')
#                 timeseries_in_degree.to_hdf(filename_in_deg, key = key_val, mode='a')
                timeseries_out_degree.to_hdf(filename_out_deg, key = key_val, mode='a')
#                 timeseries_connec_comps.to_hdf(filename_connec_comps, key = key_val, mode='a')
                df_row = 0
# Out:
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0007, 0.007000000000000001, 1, 0.5)
# 6.14
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0007, 0.007000000000000001, 1, 2)
# 5.34
# {29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.39
# {37, 69, 76, 45, 18, 82, 20, 56, 60, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0007, 0.007000000000000001, 10, 2)
# 6.17
# {64, 96, 6, 7, 46, 79, 49, 84, 89, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0072, 0.072, 1, 0.5)
# 5.89
# {44}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0072, 0.072, 1, 2)
# 5.04
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0072, 0.072, 10, 0.5)
# 5.87
# {0, 2, 73, 12, 81, 21, 53, 58, 91, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.0072, 0.072, 10, 2)
# 5.92
# {0, 68, 5, 38, 10, 77, 52, 85, 25, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.072, 0.7199999999999999, 1, 0.5)
# 6.89
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.072, 0.7199999999999999, 1, 2)
# 6.7
# {19}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.072, 0.7199999999999999, 10, 0.5)
# 6.68
# {98, 70, 76, 13, 47, 80, 18, 28, 93, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.072, 0.7199999999999999, 10, 2)
# 6.64
# {64, 96, 40, 42, 46, 49, 19, 55, 89, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.7199999999999999, 7.2, 1, 0.5)
# 5.99
# {83}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.7199999999999999, 7.2, 1, 2)
# 6.25
# {8}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.7199999999999999, 7.2, 10, 0.5)
# 6.21
# {64, 96, 67, 6, 40, 42, 46, 55, 24, 89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (70, 0.7199999999999999, 7.2, 10, 2)
# 6.32
# {96, 67, 7, 40, 42, 46, 19, 84, 87, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.76
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0007, 0.007000000000000001, 1, 2)
# 5.81
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.02
# {64, 35, 68, 3, 42, 50, 19, 21, 24, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0007, 0.007000000000000001, 10, 2)
# 5.28
# {1, 35, 67, 40, 9, 80, 49, 56, 91, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0072, 0.072, 1, 0.5)
# 5.93
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0072, 0.072, 1, 2)
# 5.24
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0072, 0.072, 10, 0.5)
# 5.19
# {69, 70, 6, 11, 44, 45, 48, 27, 28, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.0072, 0.072, 10, 2)
# 4.96
# {98, 5, 8, 81, 87, 88, 90, 60, 29, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.072, 0.7199999999999999, 1, 0.5)
# 6.1
# {53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.072, 0.7199999999999999, 1, 2)
# 6.25
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.072, 0.7199999999999999, 10, 0.5)
# 6.54
# {96, 97, 70, 39, 10, 11, 44, 58, 27, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.072, 0.7199999999999999, 10, 2)
# 6.29
# {96, 97, 70, 39, 11, 44, 58, 27, 28, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.7199999999999999, 7.2, 1, 0.5)
# 5.89
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.7199999999999999, 7.2, 1, 2)
# 6.35
# {16}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.7199999999999999, 7.2, 10, 0.5)
# 5.85
# {32, 99, 4, 7, 42, 17, 84, 55, 24, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (71, 0.7199999999999999, 7.2, 10, 2)
# 6.08
# {0, 99, 7, 72, 75, 12, 84, 85, 55, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.36
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0007, 0.007000000000000001, 1, 2)
# 5.95
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0007, 0.007000000000000001, 10, 0.5)
# 6.03
# {65, 10, 42, 74, 49, 21, 54, 90, 92, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0007, 0.007000000000000001, 10, 2)
# 5.21
# {3, 99, 58, 69, 10, 78, 85, 53, 90, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0072, 0.072, 1, 0.5)
# 5.37
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0072, 0.072, 1, 2)
# 6.1
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0072, 0.072, 10, 0.5)
# 5.18
# {67, 68, 9, 11, 15, 82, 85, 87, 59, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.0072, 0.072, 10, 2)
# 6.16
# {33, 66, 27, 13, 14, 47, 19, 87, 58, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.072, 0.7199999999999999, 1, 0.5)
# 6.64
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.072, 0.7199999999999999, 1, 2)
# 6.75
# {27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.072, 0.7199999999999999, 10, 0.5)
# 6.83
# {1, 35, 46, 81, 17, 82, 86, 59, 28, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.072, 0.7199999999999999, 10, 2)
# 6.64
# {67, 68, 5, 7, 9, 11, 45, 80, 16, 50}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.7199999999999999, 7.2, 1, 0.5)
# 5.89
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.7199999999999999, 7.2, 1, 2)
# 5.98
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.7199999999999999, 7.2, 10, 0.5)
# 5.66
# {97, 56, 39, 75, 44, 77, 18, 88, 26, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (72, 0.7199999999999999, 7.2, 10, 2)
# 6.58
# {97, 66, 71, 43, 44, 79, 27, 60, 30, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.99
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0007, 0.007000000000000001, 1, 2)
# 6.36
# {90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0007, 0.007000000000000001, 10, 0.5)
# 6.14
# {32, 66, 4, 72, 74, 60, 57, 90, 28, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0007, 0.007000000000000001, 10, 2)
# 5.39
# {35, 99, 7, 74, 49, 52, 84, 87, 63, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0072, 0.072, 1, 0.5)
# 6.02
# {17}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0072, 0.072, 1, 2)
# 5.45
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0072, 0.072, 10, 0.5)
# 6.24
# {97, 2, 50, 20, 53, 22, 89, 63, 30, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.0072, 0.072, 10, 2)
# 6.11
# {4, 6, 11, 79, 84, 87, 25, 28, 62, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.072, 0.7199999999999999, 1, 0.5)
# 6.65
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.072, 0.7199999999999999, 1, 2)
# 6.82
# {96}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.072, 0.7199999999999999, 10, 0.5)
# 6.84
# {97, 34, 67, 2, 5, 40, 78, 50, 20, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.072, 0.7199999999999999, 10, 2)
# 6.61
# {33, 1, 37, 38, 7, 41, 13, 45, 82, 51}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.7199999999999999, 7.2, 1, 0.5)
# 5.87
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.7199999999999999, 7.2, 1, 2)
# 6.45
# {0}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.7199999999999999, 7.2, 10, 0.5)
# 6.31
# {97, 3, 5, 73, 46, 80, 93, 24, 59, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (73, 0.7199999999999999, 7.2, 10, 2)
# 6.4
# {64, 2, 49, 50, 52, 22, 58, 92, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.51
# {28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0007, 0.007000000000000001, 1, 2)
# 5.79
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.8
# {35, 38, 39, 42, 75, 47, 48, 85, 94, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0007, 0.007000000000000001, 10, 2)
# 5.88
# {1, 33, 99, 4, 5, 71, 8, 44, 79, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0072, 0.072, 1, 0.5)
# 5.2
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0072, 0.072, 1, 2)
# 5.01
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0072, 0.072, 10, 0.5)
# 5.12
# {66, 35, 39, 13, 47, 81, 19, 25, 94, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.0072, 0.072, 10, 2)
# 5.05
# {32, 98, 66, 35, 13, 47, 17, 19, 28, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.072, 0.7199999999999999, 1, 0.5)
# 6.18
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.072, 0.7199999999999999, 1, 2)
# 6.21
# {90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.072, 0.7199999999999999, 10, 0.5)
# 6.37
# {96, 65, 67, 58, 70, 43, 14, 18, 90, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.072, 0.7199999999999999, 10, 2)
# 6.48
# {34, 99, 69, 5, 71, 10, 76, 51, 56, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.7199999999999999, 7.2, 1, 0.5)
# 5.86
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.7199999999999999, 7.2, 1, 2)
# 5.78
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.7199999999999999, 7.2, 10, 0.5)
# 5.81
# {64, 73, 12, 77, 78, 15, 16, 50, 52, 84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (74, 0.7199999999999999, 7.2, 10, 2)
# 5.86
# {32, 66, 98, 38, 75, 47, 48, 79, 20, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.86
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0007, 0.007000000000000001, 1, 2)
# 5.6
# {62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0007, 0.007000000000000001, 10, 0.5)
# 4.98
# {65, 38, 71, 42, 11, 14, 21, 54, 26, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0007, 0.007000000000000001, 10, 2)
# 5.58
# {7, 77, 46, 81, 53, 86, 62, 25, 58, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0072, 0.072, 1, 0.5)
# 5.02
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0072, 0.072, 1, 2)
# 5.14
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0072, 0.072, 10, 0.5)
# 4.99
# {0, 4, 70, 41, 43, 15, 80, 48, 49, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.0072, 0.072, 10, 2)
# 4.95
# {96, 7, 12, 77, 82, 19, 23, 25, 58, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.072, 0.7199999999999999, 1, 0.5)
# 6.22
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.072, 0.7199999999999999, 1, 2)
# 6.12
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.072, 0.7199999999999999, 10, 0.5)
# 6.05
# {67, 6, 59, 45, 79, 18, 22, 55, 56, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.072, 0.7199999999999999, 10, 2)
# 5.96
# {32, 97, 76, 31, 78, 51, 88, 92, 93, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.7199999999999999, 7.2, 1, 0.5)
# 5.8
# {0}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.7199999999999999, 7.2, 1, 2)
# 5.82
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.7199999999999999, 7.2, 10, 0.5)
# 5.76
# {66, 68, 4, 42, 50, 84, 87, 24, 57, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (75, 0.7199999999999999, 7.2, 10, 2)
# 5.84
# {32, 39, 72, 75, 76, 78, 88, 89, 93, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0007, 0.007000000000000001, 1, 0.5)
# 4.99
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0007, 0.007000000000000001, 1, 2)
# 5.17
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.14
# {71, 8, 10, 78, 17, 18, 56, 90, 59, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0007, 0.007000000000000001, 10, 2)
# 5.09
# {96, 2, 45, 19, 21, 54, 24, 62, 58, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0072, 0.072, 1, 0.5)
# 4.89
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0072, 0.072, 1, 2)
# 5.66
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0072, 0.072, 10, 0.5)
# 5.69
# {0, 32, 5, 73, 75, 45, 80, 16, 60, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.0072, 0.072, 10, 2)
# 5.05
# {36, 75, 44, 51, 52, 19, 86, 84, 62, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.072, 0.7199999999999999, 1, 0.5)
# 6.43
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.072, 0.7199999999999999, 1, 2)
# 6.28
# {92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.072, 0.7199999999999999, 10, 0.5)
# 6.24
# {36, 7, 77, 51, 84, 54, 86, 29, 62, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.072, 0.7199999999999999, 10, 2)
# 6.53
# {0, 97, 68, 40, 48, 83, 85, 57, 93, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.7199999999999999, 7.2, 1, 0.5)
# 6.0
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.7199999999999999, 7.2, 1, 2)
# 5.71
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.7199999999999999, 7.2, 10, 0.5)
# 5.9
# {97, 40, 13, 48, 81, 83, 88, 57, 93, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (76, 0.7199999999999999, 7.2, 10, 2)
# 6.27
# {33, 3, 37, 9, 12, 76, 15, 47, 20, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.24
# {81}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0007, 0.007000000000000001, 1, 2)
# 6.03
# {59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.17
# {0, 64, 98, 35, 32, 78, 79, 80, 93, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0007, 0.007000000000000001, 10, 2)
# 5.27
# {68, 9, 75, 13, 14, 51, 83, 54, 22, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0072, 0.072, 1, 0.5)
# 5.95
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0072, 0.072, 1, 2)
# 5.69
# {37}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0072, 0.072, 10, 0.5)
# 5.96
# {33, 99, 90, 71, 72, 74, 10, 87, 58, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.0072, 0.072, 10, 2)
# 5.95
# {0, 35, 11, 76, 80, 48, 86, 28, 30, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.072, 0.7199999999999999, 1, 0.5)
# 6.56
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.072, 0.7199999999999999, 1, 2)
# 6.72
# {97}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.072, 0.7199999999999999, 10, 0.5)
# 6.55
# {0, 64, 35, 76, 16, 48, 86, 25, 28, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.072, 0.7199999999999999, 10, 2)
# 6.5
# {67, 36, 69, 81, 19, 20, 84, 23, 88, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.7199999999999999, 7.2, 1, 0.5)
# 5.54
# {39}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.7199999999999999, 7.2, 1, 2)
# 6.04
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.7199999999999999, 7.2, 10, 0.5)
# 6.01
# {1, 98, 35, 7, 11, 79, 25, 93, 62, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (77, 0.7199999999999999, 7.2, 10, 2)
# 6.23
# {33, 99, 4, 8, 41, 10, 74, 56, 58, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.47
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0007, 0.007000000000000001, 1, 2)
# 6.23
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.93
# {64, 98, 6, 72, 8, 45, 85, 58, 59, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0007, 0.007000000000000001, 10, 2)
# 5.94
# {3, 4, 71, 76, 17, 63, 92, 93, 94, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0072, 0.072, 1, 0.5)
# 5.18
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0072, 0.072, 1, 2)
# 5.24
# {14}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0072, 0.072, 10, 0.5)
# 6.1
# {36, 5, 6, 10, 91, 15, 56, 57, 58, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.0072, 0.072, 10, 2)
# 6.19
# {64, 33, 36, 10, 12, 78, 83, 59, 29, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.072, 0.7199999999999999, 1, 0.5)
# 6.73
# {33}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.072, 0.7199999999999999, 1, 2)
# 6.51
# {15}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.072, 0.7199999999999999, 10, 0.5)
# 6.8
# {96, 35, 37, 39, 75, 52, 86, 55, 24, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.072, 0.7199999999999999, 10, 2)
# 6.69
# {64, 33, 98, 36, 10, 12, 22, 56, 58, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.7199999999999999, 7.2, 1, 0.5)
# 6.55
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.7199999999999999, 7.2, 1, 2)
# 6.09
# {59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.7199999999999999, 7.2, 10, 0.5)
# 6.25
# {0, 1, 68, 5, 69, 74, 82, 18, 84, 53}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (78, 0.7199999999999999, 7.2, 10, 2)
# 6.73
# {0, 65, 2, 68, 69, 74, 15, 16, 19, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.58
# {9}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0007, 0.007000000000000001, 1, 2)
# 5.92
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.87
# {96, 68, 7, 77, 60, 48, 25, 58, 92, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0007, 0.007000000000000001, 10, 2)
# 5.09
# {0, 97, 41, 45, 49, 83, 84, 53, 21, 86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0072, 0.072, 1, 0.5)
# 4.9
# {1}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0072, 0.072, 1, 2)
# 4.92
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0072, 0.072, 10, 0.5)
# 5.17
# {1, 8, 42, 14, 46, 86, 24, 89, 59, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.0072, 0.072, 10, 2)
# 5.97
# {96, 68, 60, 79, 80, 30, 25, 58, 92, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.072, 0.7199999999999999, 1, 0.5)
# 6.46
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.072, 0.7199999999999999, 1, 2)
# 6.29
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.072, 0.7199999999999999, 10, 0.5)
# 6.42
# {0, 33, 6, 11, 12, 19, 20, 84, 56, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.072, 0.7199999999999999, 10, 2)
# 6.23
# {69, 75, 46, 50, 87, 24, 89, 88, 94, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.7199999999999999, 7.2, 1, 0.5)
# 5.75
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.7199999999999999, 7.2, 1, 2)
# 5.59
# {54}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.7199999999999999, 7.2, 10, 0.5)
# 5.95
# {0, 6, 9, 41, 12, 84, 23, 56, 57, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (79, 0.7199999999999999, 7.2, 10, 2)
# 6.11
# {32, 36, 37, 41, 16, 84, 21, 23, 27, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0007, 0.007000000000000001, 1, 0.5)
# 4.93
# {26}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0007, 0.007000000000000001, 1, 2)
# 6.05
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0007, 0.007000000000000001, 10, 0.5)
# 6.09
# {64, 68, 11, 78, 48, 16, 84, 85, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0007, 0.007000000000000001, 10, 2)
# 5.92
# {99, 3, 73, 74, 14, 51, 22, 56, 26, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0072, 0.072, 1, 0.5)
# 6.02
# {92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0072, 0.072, 1, 2)
# 5.38
# {36}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0072, 0.072, 10, 0.5)
# 5.13
# {67, 73, 74, 75, 15, 20, 56, 59, 92, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.0072, 0.072, 10, 2)
# 5.32
# {37, 6, 8, 11, 77, 17, 82, 84, 91, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.072, 0.7199999999999999, 1, 0.5)
# 6.73
# {91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.072, 0.7199999999999999, 1, 2)
# 6.75
# {30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.072, 0.7199999999999999, 10, 0.5)
# 6.76
# {96, 67, 10, 75, 74, 46, 81, 22, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.072, 0.7199999999999999, 10, 2)
# 6.84
# {35, 37, 8, 47, 48, 84, 23, 91, 94, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.7199999999999999, 7.2, 1, 0.5)
# 6.44
# {35}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.7199999999999999, 7.2, 1, 2)
# 6.15
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.7199999999999999, 7.2, 10, 0.5)
# 6.65
# {97, 4, 41, 42, 13, 81, 54, 86, 88, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (80, 0.7199999999999999, 7.2, 10, 2)
# 6.01
# {32, 1, 4, 38, 41, 42, 13, 18, 52, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0007, 0.007000000000000001, 1, 0.5)
# 6.02
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0007, 0.007000000000000001, 1, 2)
# 5.87
# {99}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.38
# {66, 68, 71, 9, 75, 43, 18, 50, 90, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0007, 0.007000000000000001, 10, 2)
# 5.84
# {97, 2, 33, 99, 13, 82, 20, 23, 55, 24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0072, 0.072, 1, 0.5)
# 5.91
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0072, 0.072, 1, 2)
# 5.75
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0072, 0.072, 10, 0.5)
# 5.88
# {0, 38, 39, 51, 93, 85, 22, 87, 58, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.0072, 0.072, 10, 2)
# 5.87
# {65, 36, 4, 70, 6, 41, 44, 78, 17, 84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.072, 0.7199999999999999, 1, 0.5)
# 6.49
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.072, 0.7199999999999999, 1, 2)
# 6.42
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.072, 0.7199999999999999, 10, 0.5)
# 6.53
# {70, 7, 76, 79, 17, 81, 56, 89, 62, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.072, 0.7199999999999999, 10, 2)
# 6.61
# {64, 38, 39, 74, 15, 85, 94, 58, 27, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.7199999999999999, 7.2, 1, 0.5)
# 6.0
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.7199999999999999, 7.2, 1, 2)
# 6.4
# {23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.7199999999999999, 7.2, 10, 0.5)
# 5.89
# {96, 34, 35, 4, 98, 70, 44, 80, 61, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (81, 0.7199999999999999, 7.2, 10, 2)
# 6.12
# {5, 74, 91, 45, 21, 86, 30, 88, 27, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.21
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0007, 0.007000000000000001, 1, 2)
# 5.91
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.62
# {97, 2, 98, 7, 11, 44, 43, 48, 18, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0007, 0.007000000000000001, 10, 2)
# 5.23
# {36, 72, 47, 50, 51, 86, 88, 27, 93, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0072, 0.072, 1, 0.5)
# 5.18
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0072, 0.072, 1, 2)
# 6.2
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0072, 0.072, 10, 0.5)
# 5.69
# {38, 10, 12, 45, 80, 20, 85, 87, 26, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.0072, 0.072, 10, 2)
# 5.77
# {64, 65, 66, 99, 8, 74, 76, 78, 17, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.072, 0.7199999999999999, 1, 0.5)
# 6.35
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.072, 0.7199999999999999, 1, 2)
# 6.5
# {48}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.072, 0.7199999999999999, 10, 0.5)
# 6.56
# {96, 0, 35, 37, 40, 73, 13, 82, 53, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.072, 0.7199999999999999, 10, 2)
# 6.7
# {35, 67, 4, 40, 73, 13, 45, 81, 82, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.7199999999999999, 7.2, 1, 0.5)
# 6.28
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.7199999999999999, 7.2, 1, 2)
# 6.22
# {77}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.7199999999999999, 7.2, 10, 0.5)
# 6.02
# {64, 66, 67, 73, 74, 78, 49, 82, 53, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (82, 0.7199999999999999, 7.2, 10, 2)
# 6.07
# {0, 35, 37, 70, 13, 81, 82, 84, 53, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.72
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0007, 0.007000000000000001, 1, 2)
# 6.03
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.21
# {34, 99, 76, 13, 79, 29, 85, 23, 59, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0007, 0.007000000000000001, 10, 2)
# 5.76
# {0, 32, 98, 3, 96, 6, 42, 18, 56, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0072, 0.072, 1, 0.5)
# 5.56
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0072, 0.072, 1, 2)
# 5.06
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0072, 0.072, 10, 0.5)
# 6.02
# {68, 69, 36, 40, 49, 52, 21, 87, 25, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.0072, 0.072, 10, 2)
# 5.78
# {1, 66, 2, 33, 9, 41, 74, 53, 60, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.072, 0.7199999999999999, 1, 0.5)
# 6.35
# {18}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.072, 0.7199999999999999, 1, 2)
# 6.47
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.072, 0.7199999999999999, 10, 0.5)
# 6.42
# {64, 33, 1, 37, 72, 8, 9, 46, 24, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.072, 0.7199999999999999, 10, 2)
# 6.49
# {98, 35, 38, 11, 47, 80, 51, 84, 22, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.7199999999999999, 7.2, 1, 0.5)
# 6.1
# {42}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.7199999999999999, 7.2, 1, 2)
# 6.1
# {46}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.7199999999999999, 7.2, 10, 0.5)
# 5.8
# {68, 69, 36, 40, 73, 48, 49, 82, 87, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (83, 0.7199999999999999, 7.2, 10, 2)
# 6.05
# {96, 32, 98, 3, 10, 75, 11, 84, 92, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.72
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0007, 0.007000000000000001, 1, 2)
# 5.2
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.36
# {97, 2, 35, 39, 76, 13, 80, 50, 59, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0007, 0.007000000000000001, 10, 2)
# 6.06
# {34, 99, 7, 8, 11, 15, 83, 52, 23, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0072, 0.072, 1, 0.5)
# 5.77
# {72}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0072, 0.072, 1, 2)
# 5.88
# {31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0072, 0.072, 10, 0.5)
# 6.05
# {70, 11, 44, 77, 21, 54, 88, 89, 61, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.0072, 0.072, 10, 2)
# 6.01
# {73, 11, 14, 83, 84, 53, 23, 24, 57, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.072, 0.7199999999999999, 1, 0.5)
# 6.58
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.072, 0.7199999999999999, 1, 2)
# 6.67
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.072, 0.7199999999999999, 10, 0.5)
# 6.61
# {99, 5, 7, 73, 14, 15, 52, 84, 87, 23}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.072, 0.7199999999999999, 10, 2)
# 6.46
# {34, 6, 72, 73, 76, 15, 87, 23, 57, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.7199999999999999, 7.2, 1, 0.5)
# 5.75
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.7199999999999999, 7.2, 1, 2)
# 6.52
# {68}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.7199999999999999, 7.2, 10, 0.5)
# 6.2
# {4, 38, 76, 15, 48, 80, 83, 20, 59, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (84, 0.7199999999999999, 7.2, 10, 2)
# 5.92
# {96, 32, 67, 3, 41, 18, 82, 86, 58, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.74
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0007, 0.007000000000000001, 1, 2)
# 5.82
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.19
# {99, 6, 40, 41, 73, 75, 79, 90, 62, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0007, 0.007000000000000001, 10, 2)
# 5.77
# {33, 35, 36, 8, 42, 44, 76, 17, 89, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0072, 0.072, 1, 0.5)
# 5.88
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0072, 0.072, 1, 2)
# 5.16
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0072, 0.072, 10, 0.5)
# 5.24
# {32, 33, 3, 68, 8, 52, 24, 93, 94, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.0072, 0.072, 10, 2)
# 5.44
# {65, 2, 36, 71, 42, 17, 83, 86, 22, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.072, 0.7199999999999999, 1, 0.5)
# 6.41
# {25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.072, 0.7199999999999999, 1, 2)
# 6.26
# {43}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.072, 0.7199999999999999, 10, 0.5)
# 6.22
# {33, 2, 65, 36, 35, 71, 17, 83, 59, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.072, 0.7199999999999999, 10, 2)
# 6.58
# {64, 68, 6, 7, 41, 75, 79, 90, 29, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.7199999999999999, 7.2, 1, 0.5)
# 5.81
# {30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.7199999999999999, 7.2, 1, 2)
# 6.07
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.7199999999999999, 7.2, 10, 0.5)
# 6.14
# {97, 5, 38, 9, 42, 44, 82, 19, 53, 58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (85, 0.7199999999999999, 7.2, 10, 2)
# 6.06
# {1, 65, 97, 70, 71, 77, 13, 80, 84, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.71
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0007, 0.007000000000000001, 1, 2)
# 5.77
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0007, 0.007000000000000001, 10, 0.5)
# 4.97
# {0, 97, 34, 7, 72, 75, 14, 16, 23, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0007, 0.007000000000000001, 10, 2)
# 5.62
# {2, 18, 21, 86, 85, 22, 91, 28, 93, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0072, 0.072, 1, 0.5)
# 4.81
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0072, 0.072, 1, 2)
# 5.14
# {56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0072, 0.072, 10, 0.5)
# 5.66
# {11, 77, 79, 15, 83, 57, 26, 27, 61, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.0072, 0.072, 10, 2)
# 5.02
# {33, 44, 47, 54, 22, 25, 58, 93, 62, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.072, 0.7199999999999999, 1, 0.5)
# 6.24
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.072, 0.7199999999999999, 1, 2)
# 6.11
# {95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.072, 0.7199999999999999, 10, 0.5)
# 6.24
# {65, 74, 11, 77, 79, 15, 83, 26, 61, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.072, 0.7199999999999999, 10, 2)
# 6.16
# {32, 5, 8, 74, 12, 17, 57, 59, 61, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.7199999999999999, 7.2, 1, 0.5)
# 5.68
# {98}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.7199999999999999, 7.2, 1, 2)
# 6.0
# {12}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.7199999999999999, 7.2, 10, 0.5)
# 5.76
# {65, 1, 42, 11, 74, 79, 15, 83, 57, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (86, 0.7199999999999999, 7.2, 10, 2)
# 6.07
# {34, 2, 36, 70, 7, 72, 75, 23, 89, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0007, 0.007000000000000001, 1, 0.5)
# 4.88
# {20}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0007, 0.007000000000000001, 1, 2)
# 4.83
# {38}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.55
# {96, 99, 5, 69, 8, 75, 12, 15, 16, 87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0007, 0.007000000000000001, 10, 2)
# 5.53
# {32, 64, 67, 58, 74, 42, 53, 85, 26, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0072, 0.072, 1, 0.5)
# 4.96
# {52}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0072, 0.072, 1, 2)
# 5.61
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0072, 0.072, 10, 0.5)
# 5.02
# {96, 5, 73, 75, 77, 47, 15, 86, 56, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.0072, 0.072, 10, 2)
# 4.89
# {0, 3, 40, 43, 45, 14, 19, 23, 29, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.072, 0.7199999999999999, 1, 0.5)
# 6.15
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.072, 0.7199999999999999, 1, 2)
# 6.17
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.072, 0.7199999999999999, 10, 0.5)
# 5.98
# {1, 3, 6, 13, 14, 82, 21, 54, 62, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.072, 0.7199999999999999, 10, 2)
# 5.88
# {96, 27, 73, 10, 46, 47, 86, 91, 92, 93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.7199999999999999, 7.2, 1, 0.5)
# 5.91
# {13}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.7199999999999999, 7.2, 1, 2)
# 5.82
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.7199999999999999, 7.2, 10, 0.5)
# 5.62
# {32, 64, 67, 36, 37, 51, 85, 53, 26, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (87, 0.7199999999999999, 7.2, 10, 2)
# 5.6
# {39, 75, 76, 11, 46, 79, 80, 57, 91, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.74
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0007, 0.007000000000000001, 1, 2)
# 5.79
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.16
# {0, 32, 6, 46, 15, 78, 84, 54, 23, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0007, 0.007000000000000001, 10, 2)
# 5.76
# {68, 41, 10, 44, 51, 85, 55, 88, 24, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0072, 0.072, 1, 0.5)
# 4.98
# {7}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0072, 0.072, 1, 2)
# 5.68
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0072, 0.072, 10, 0.5)
# 5.04
# {0, 3, 90, 11, 44, 77, 15, 88, 26, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.0072, 0.072, 10, 2)
# 5.72
# {8, 72, 42, 40, 47, 63, 19, 53, 29, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.072, 0.7199999999999999, 1, 0.5)
# 6.22
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.072, 0.7199999999999999, 1, 2)
# 6.46
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.072, 0.7199999999999999, 10, 0.5)
# 6.25
# {96, 1, 65, 97, 36, 43, 13, 16, 83, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.072, 0.7199999999999999, 10, 2)
# 6.48
# {99, 70, 73, 74, 12, 17, 82, 86, 87, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.7199999999999999, 7.2, 1, 0.5)
# 5.83
# {19}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.7199999999999999, 7.2, 1, 2)
# 5.93
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.7199999999999999, 7.2, 10, 0.5)
# 5.98
# {97, 1, 36, 37, 39, 43, 75, 13, 20, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (88, 0.7199999999999999, 7.2, 10, 2)
# 5.78
# {96, 97, 1, 36, 39, 75, 13, 16, 83, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.96
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0007, 0.007000000000000001, 1, 2)
# 6.0
# {73}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.34
# {66, 36, 69, 74, 12, 20, 21, 22, 60, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0007, 0.007000000000000001, 10, 2)
# 5.27
# {96, 35, 5, 16, 81, 55, 87, 56, 90, 28}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0072, 0.072, 1, 0.5)
# 5.92
# {74}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0072, 0.072, 1, 2)
# 5.9
# {49}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0072, 0.072, 10, 0.5)
# 5.8
# {98, 35, 39, 40, 44, 28, 81, 87, 90, 92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.0072, 0.072, 10, 2)
# 5.23
# {1, 98, 72, 40, 44, 78, 79, 17, 83, 56}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.072, 0.7199999999999999, 1, 0.5)
# 6.56
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.072, 0.7199999999999999, 1, 2)
# 6.65
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.072, 0.7199999999999999, 10, 0.5)
# 6.71
# {32, 7, 73, 76, 49, 29, 18, 84, 59, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.072, 0.7199999999999999, 10, 2)
# 6.79
# {0, 67, 4, 6, 10, 76, 45, 19, 84, 88}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.7199999999999999, 7.2, 1, 0.5)
# 6.54
# {71}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.7199999999999999, 7.2, 1, 2)
# 6.11
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.7199999999999999, 7.2, 10, 0.5)
# 6.46
# {64, 3, 6, 38, 73, 45, 19, 85, 88, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (89, 0.7199999999999999, 7.2, 10, 2)
# 6.12
# {96, 1, 2, 35, 5, 79, 82, 52, 86, 57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.1
# {4}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0007, 0.007000000000000001, 1, 2)
# 5.23
# {19}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.6
# {4, 73, 10, 12, 13, 45, 48, 21, 85, 25}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0007, 0.007000000000000001, 10, 2)
# 5.11
# {73, 41, 12, 13, 15, 21, 54, 22, 25, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0072, 0.072, 1, 0.5)
# 5.07
# {41}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0072, 0.072, 1, 2)
# 5.13
# {2}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0072, 0.072, 10, 0.5)
# 5.06
# {96, 65, 5, 39, 44, 77, 46, 81, 88, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.0072, 0.072, 10, 2)
# 5.86
# {4, 73, 13, 45, 48, 82, 86, 22, 25, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.072, 0.7199999999999999, 1, 0.5)
# 6.28
# {63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.072, 0.7199999999999999, 1, 2)
# 6.54
# {76}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.072, 0.7199999999999999, 10, 0.5)
# 6.26
# {32, 98, 35, 36, 37, 79, 16, 20, 58, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.072, 0.7199999999999999, 10, 2)
# 6.42
# {41, 73, 42, 45, 14, 15, 21, 86, 22, 90}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.7199999999999999, 7.2, 1, 0.5)
# 5.89
# {45}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.7199999999999999, 7.2, 1, 2)
# 6.06
# {86}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.7199999999999999, 7.2, 10, 0.5)
# 5.97
# {96, 65, 3, 67, 70, 71, 44, 18, 57, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (90, 0.7199999999999999, 7.2, 10, 2)
# 5.82
# {8, 75, 76, 77, 48, 50, 53, 55, 26, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.64
# {93}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0007, 0.007000000000000001, 1, 2)
# 5.65
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.68
# {0, 35, 5, 37, 80, 16, 51, 22, 89, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0007, 0.007000000000000001, 10, 2)
# 5.03
# {64, 96, 99, 38, 78, 60, 17, 55, 92, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0072, 0.072, 1, 0.5)
# 4.96
# {75}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0072, 0.072, 1, 2)
# 5.46
# {69}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0072, 0.072, 10, 0.5)
# 5.56
# {0, 99, 8, 41, 28, 17, 56, 89, 92, 29}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.0072, 0.072, 10, 2)
# 5.13
# {64, 99, 38, 8, 55, 89, 59, 60, 29, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.072, 0.7199999999999999, 1, 0.5)
# 6.21
# {84}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.072, 0.7199999999999999, 1, 2)
# 6.07
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.072, 0.7199999999999999, 10, 0.5)
# 6.37
# {1, 70, 42, 11, 75, 14, 87, 57, 90, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.072, 0.7199999999999999, 10, 2)
# 6.22
# {97, 66, 99, 7, 71, 9, 76, 49, 56, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.7199999999999999, 7.2, 1, 0.5)
# 5.8
# {6}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.7199999999999999, 7.2, 1, 2)
# 5.79
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.7199999999999999, 7.2, 10, 0.5)
# 5.7
# {32, 98, 36, 5, 72, 43, 83, 19, 54, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (91, 0.7199999999999999, 7.2, 10, 2)
# 5.63
# {34, 99, 67, 9, 78, 47, 17, 27, 28, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.03
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0007, 0.007000000000000001, 1, 2)
# 5.64
# {79}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.49
# {33, 37, 6, 70, 43, 14, 86, 55, 89, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0007, 0.007000000000000001, 10, 2)
# 4.85
# {39, 46, 47, 15, 51, 22, 58, 92, 93, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0072, 0.072, 1, 0.5)
# 5.48
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0072, 0.072, 1, 2)
# 5.11
# {70}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0072, 0.072, 10, 0.5)
# 5.02
# {97, 66, 3, 35, 11, 12, 82, 19, 27, 60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.0072, 0.072, 10, 2)
# 4.63
# {98, 5, 7, 91, 42, 75, 81, 88, 59, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.072, 0.7199999999999999, 1, 0.5)
# 6.29
# {66}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.072, 0.7199999999999999, 1, 2)
# 6.4
# {67}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.072, 0.7199999999999999, 10, 0.5)
# 6.27
# {41, 9, 77, 46, 15, 51, 22, 58, 93, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.072, 0.7199999999999999, 10, 2)
# 6.18
# {96, 68, 39, 46, 47, 54, 57, 58, 95, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.7199999999999999, 7.2, 1, 0.5)
# 6.01
# {82}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.7199999999999999, 7.2, 1, 2)
# 5.83
# {89}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.7199999999999999, 7.2, 10, 0.5)
# 5.81
# {0, 1, 67, 13, 16, 81, 84, 21, 56, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (92, 0.7199999999999999, 7.2, 10, 2)
# 5.76
# {33, 6, 70, 43, 76, 45, 86, 89, 26, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0007, 0.007000000000000001, 1, 0.5)
# 6.0
# {10}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0007, 0.007000000000000001, 1, 2)
# 6.2
# {24}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.27
# {70, 7, 41, 44, 78, 81, 23, 58, 60, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0007, 0.007000000000000001, 10, 2)
# 5.9
# {1, 66, 72, 9, 74, 11, 15, 89, 26, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0072, 0.072, 1, 0.5)
# 6.01
# {58}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0072, 0.072, 1, 2)
# 5.15
# {64}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0072, 0.072, 10, 0.5)
# 6.06
# {33, 98, 99, 4, 40, 48, 83, 21, 24, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.0072, 0.072, 10, 2)
# 4.97
# {36, 38, 10, 46, 47, 22, 55, 56, 93, 62}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.072, 0.7199999999999999, 1, 0.5)
# 6.81
# {87}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.072, 0.7199999999999999, 1, 2)
# 6.37
# {94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.072, 0.7199999999999999, 10, 0.5)
# 6.85
# {96, 98, 6, 12, 77, 80, 17, 82, 84, 59}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.072, 0.7199999999999999, 10, 2)
# 6.92
# {32, 97, 3, 69, 5, 71, 75, 46, 58, 27}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.7199999999999999, 7.2, 1, 0.5)
# 6.05
# {57}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.7199999999999999, 7.2, 1, 2)
# 5.72
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.7199999999999999, 7.2, 10, 0.5)
# 6.18
# {7, 41, 44, 79, 81, 23, 57, 58, 60, 95}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (93, 0.7199999999999999, 7.2, 10, 2)
# 6.21
# {32, 97, 3, 71, 75, 46, 20, 85, 29, 30}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0007, 0.007000000000000001, 1, 0.5)
# 5.15
# {5}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0007, 0.007000000000000001, 1, 2)
# 5.37
# {98}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0007, 0.007000000000000001, 10, 0.5)
# 5.25
# {97, 33, 3, 4, 65, 43, 46, 51, 59, 61}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0007, 0.007000000000000001, 10, 2)
# 5.28
# {67, 72, 41, 10, 13, 78, 47, 19, 28, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0072, 0.072, 1, 0.5)
# 4.96
# {40}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0072, 0.072, 1, 2)
# 5.81
# {60}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0072, 0.072, 10, 0.5)
# 5.05
# {38, 7, 74, 76, 48, 20, 53, 86, 23, 91}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.0072, 0.072, 10, 2)
# 4.63
# {0, 72, 41, 10, 13, 78, 18, 19, 25, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.072, 0.7199999999999999, 1, 0.5)
# 6.86
# {92}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.072, 0.7199999999999999, 1, 2)
# 6.67
# {78}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.072, 0.7199999999999999, 10, 0.5)
# 6.9
# {67, 70, 72, 10, 13, 81, 19, 56, 25, 31}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.072, 0.7199999999999999, 10, 2)
# 6.53
# {99, 36, 8, 41, 76, 85, 56, 89, 30, 63}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.7199999999999999, 7.2, 1, 0.5)
# 5.71
# {32}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.7199999999999999, 7.2, 1, 2)
# 6.3
# {80}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.7199999999999999, 7.2, 10, 0.5)
# 5.89
# {64, 98, 11, 12, 15, 16, 55, 27, 29, 94}
# (sim,lamb_da,p_rew,start,dose_quantity) =  (94, 0.7199999999999999, 7.2, 10, 2)
# 6.02
# {68, 38, 40, 74, 44, 48, 20, 23, 24, 57}
